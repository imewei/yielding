# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras

def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C045_Cys1_Exp2_Creep_XPCS_110Pa_01_att02_Lq2_001_0001-7999_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d

def fit_c2_polynomial(num_v=4, num_d=5, paras_fname=None):
    # read raw data
    c2_exp, t_length, phi_list, phi_length = read_data()

    # setup bounds
    # dbnds = np.array((299, 301))
    phiobnds = (-5, 5)
    fbnds = (0.5, 1)
    
    dbnds = [np.array((0,   500))]  + [np.array((-400000, 400000)) / np.math.factorial(n)   for n in range(1, num_d)]
    vbnds = [np.array((0,   1000))] + [np.array((-20000, 20000)) / np.math.factorial(n) for n in range(1, num_v)]

    bnds = dbnds + vbnds + [phiobnds] + [fbnds]
    bnds = np.array(bnds).astype(DTYPE)


    # read initial value
    if paras_fname is None:
        random_start = np.random.uniform(0, 1, bnds.shape[0])
        x0 = bnds[:, 0] + (bnds[:, 1] - bnds[:, 0]) * random_start
    else:
        x0 = np.loadtxt(paras_fname).astype(DTYPE)

    if len(x0) > bnds.shape[0]:
        x0 = x0[0:bnds.shape[0]]

    # make sure all initial values are in the bounds
    idx = np.logical_or(x0 < bnds[:, 0], x0 > bnds[:, 1])
    print('correct start point for ', np.sum(idx), ' points.')
    x0 = np.array([
                7.301303224835028232e+02,
                -4.975637438785716427e+01,
                2.195585355333742328e+00,
                -2.396009690754264537e-02,
                8.038846379442008186e-05,
                4.970174566530698144e+02,
                -2.628115198558835885e+01,
                7.934395681398040967e-01,
                -5.509821021538633540e-03,
                7.139120817562172316e-01,
                3.117818868953683813e-03,
                1.760965749691113991e-06,
                -2.455349519450364217e-07,
                1.175296107961422507e-03,
                  ])
    """
    random_start = np.random.uniform(0, 1, np.sum(idx))
    x0[idx] = bnds[idx, 0] + (bnds[idx, 1] - bnds[idx, 0]) * random_start
    """
    
    x0 = read_parameters('C045_FitParas_Final_09072023.csv')[:10]
    for method in (
                'Nelder-Mead',
                # 'Powell',
                # 'L-BFGS-B',
                # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
                # 'trust-ncg', 'trust-exact', 'trust-krylov'):
                ):
    # def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
        FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                                args=(phi_list, num_d, num_v, c2_exp, method),
                                options={"maxiter": 1000000}, tol=0.00001,
                                method=method)

    FitParas = FitOutput['x']
    
    c2_fit = Heterodyne4(FitParas, phi_list)
    shape = c2_fit.shape
    sol_list = []
    for n in range(shape[0]):
        sumy = np.sum(c2_fit[n])
        a = np.array([
            [np.sum(c2_fit[n] ** 2), sumy],
            [sumy, c2_fit[n].size]
        ])
        b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
        sol = np.linalg.solve(a, b)
        sol_list.append(sol)

    
    FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
    np.savetxt('/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/FitParas/C045_FitParas.csv', FitParas, delimiter=",")
    
def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]
    f_c  = paras[num_d + num_v:num_d + num_v + num_f]
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = np.polynomial.Polynomial(v_c)(tabs)
    D = np.polynomial.Polynomial(D_c)(tabs)
    f = np.polynomial.Polynomial(f_c)(tabs)
    
    if all(i >= 0 for i in v) == True \
    and all(i >= 0 for i in D) == True \
    and all(i <= 1 for i in f) \
    and all(i >= 0 for i in f):
    
        shape = c2_exp.shape
        residual = 0.0

        c2_fit = Heterodyne4(paras, phi_list)

        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)

        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        # plt.imshow(c2_fit[0])
        # # plt.imshow(c2_exp[0])
        # plt.show()
    else:
        residual = np.inf
    
    
    return residual

def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 5
    num_v = 4
    num_f = 4
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = np.polynomial.Polynomial(v_c)(tabs)
    D = np.polynomial.Polynomial(D_c)(tabs)
    f = np.polynomial.Polynomial(f_c)(tabs)
    
    return D, v, phio, f, beta, c

# %%
def Heterodyne4(x, phi_list):
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    t_length = 999
    
    num_d = 5
    num_v = 4
    num_f = 4
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = np.polynomial.Polynomial(v_c)(tabs)
    D = np.polynomial.Polynomial(D_c)(tabs)
    f = np.polynomial.Polynomial(f_c)(tabs)
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(qValue**2 / 2 * -abs(DMat) * dt).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2
    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (t0 + 2*f1s*f2s*f1r*f2r * w * g1_s*g1_r) / ftotal**2

    return g2_all

def Heterodyne5(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 5
    num_v = 4
    num_f = 4
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = np.polynomial.Polynomial(v_c)(tabs)
    D = np.polynomial.Polynomial(D_c)(tabs)
    f = np.polynomial.Polynomial(f_c)(tabs)
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(-abs((qValue**2 / 2 * DMat * dt))).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2

    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (t0 +  2*f1s*f2s*f1r*f2r * w * g1_s*g1_r) / ftotal ** 2
    return g2_all

def plot_results(fname):
    c2_exp, t_length, phi_list, phi_length = read_data()
    shape = c2_exp.shape
    paras = read_parameters(fname)
    c2_fit = Heterodyne5(paras, phi_list)
    
    fig = plt.figure(layout='constrained', figsize=(12, 8))
    subfigs = fig.subfigures(6, 4, wspace=0.10)
    subfigs = subfigs.ravel()

    for n in range(phi_length):
        ax = subfigs[n].subplots(1, 2, sharey=True)
        ax[0].imshow(c2_exp[n], vmin=1, vmax=1.35, cmap=plt.cm.jet)
        ax[1].imshow(c2_fit[n], vmin=1, vmax=1.35, cmap=plt.cm.jet)
        # ax[0].imshow(c2_exp[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        # ax[1].imshow(c2_fit[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        ax[0].set_axis_off()
        ax[1].set_axis_off()
    plt.savefig('result_fitting.png', dpi=150)
    plt.show()
    plt.close(fig)

    D, v, phio, f, beta, c = separate_params(paras, phi_length)
    
    fig, ax = plt.subplots(3, 2)
    ax = ax.ravel()
    ax[0].plot(D)
    ax[0].set_title('Diffusion Coefficient')

    ax[1].plot(v)
    ax[1].set_title('velocity')

    ax[2].plot(phio, 'ro', ms=5)
    ax[2].set_title('phio')

    ax[3].plot(f)
    ax[3].set_title('fraction')

    
    ax[4].plot(beta)
    ax[4].set_title('beta')

    ax[5].plot(c)
    ax[5].set_title('c')
    plt.tight_layout()
    


    plt.savefig('result_parameters.png', dpi=300)
    plt.show()
    plt.close(fig)
    print(np.sum(abs(c2_exp.reshape(-1) - c2_fit.reshape(-1))))

# %%
DTYPE = np.float32
gindex = 0
FitParas = None
c2_exp, t_length, phi_list, phi_length = read_data()

num_d=5
num_v=4
num_f=4

# setup bounds
# dbnds = np.array((299, 301))
phiobnds = (-5, 5)
fbnds = (0.5, 1)

dbnds = [np.array((0,   500))]  + [np.array((-400000, 400000)) / np.math.factorial(n)   for n in range(1, num_d)]
vbnds = [np.array((0,   1000))] + [np.array((-20000, 20000)) / np.math.factorial(n) for n in range(1, num_v)]

bnds = dbnds + vbnds + [phiobnds] + [fbnds]
bnds = np.array(bnds).astype(DTYPE)

paras_fname = None
# read initial value
if paras_fname is None:
    random_start = np.random.uniform(0, 1, bnds.shape[0])
    x0 = bnds[:, 0] + (bnds[:, 1] - bnds[:, 0]) * random_start
else:
    x0 = np.loadtxt(paras_fname).astype(DTYPE)

if len(x0) > bnds.shape[0]:
    x0 = x0[0:bnds.shape[0]]

# make sure all initial values are in the bounds
idx = np.logical_or(x0 < bnds[:, 0], x0 > bnds[:, 1])
print('correct start point for ', np.sum(idx), ' points.')
x0 = np.array([
            7.301303224835028232e+02,
            -4.975637438785716427e+01,
            2.195585355333742328e+00,
            -2.396009690754264537e-02,
            8.038846379442008186e-05,
            4.970174566530698144e+02,
            -2.628115198558835885e+01,
            7.934395681398040967e-01,
            -5.509821021538633540e-03,
            7.139120817562172316e-01,
            3.117818868953683813e-03,
            1.760965749691113991e-06,
            -2.455349519450364217e-07,
            1.175296107961422507e-03,
              ])

for method in (
            'Nelder-Mead',
            # 'Powell',
            # 'L-BFGS-B',
            # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
            # 'trust-ncg', 'trust-exact', 'trust-krylov'):
            ):
# def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                            args=(phi_list, num_d, num_v, c2_exp, method),
                            options={"maxiter": 1000000}, tol=0.00001,
                            method=method)

FitParas = FitOutput['x']

c2_fit = Heterodyne4(FitParas, phi_list)
shape = c2_fit.shape
sol_list = []
for n in range(shape[0]):
    sumy = np.sum(c2_fit[n])
    a = np.array([
        [np.sum(c2_fit[n] ** 2), sumy],
        [sumy, c2_fit[n].size]
    ])
    b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
    sol = np.linalg.solve(a, b)
    sol_list.append(sol)
    
FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
np.savetxt('/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/FitParas/C045_FitParas.txt', FitParas, delimiter=",")
# Out:
# c2_cache_1001_2000.npz
# (23, 999, 999) float32
# correct start point for  0  points.
# /tmp/ipykernel_1244254/1407144183.py:15: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   dbnds = [np.array((0,   500))]  + [np.array((-400000, 400000)) / np.math.factorial(n)   for n in range(1, num_d)]
# /tmp/ipykernel_1244254/1407144183.py:16: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   vbnds = [np.array((0,   1000))] + [np.array((-20000, 20000)) / np.math.factorial(n) for n in range(1, num_v)]
# 000001, method='Nelder-Mead', residual=45759.256103515625
# 000002, method='Nelder-Mead', residual=45775.12646484375
# 000003, method='Nelder-Mead', residual=45778.440673828125
# 000004, method='Nelder-Mead', residual=46172.99658203125
# 000005, method='Nelder-Mead', residual=46442.244873046875
# 000006, method='Nelder-Mead', residual=45808.2236328125
# 000007, method='Nelder-Mead', residual=46230.20373535156
# 000008, method='Nelder-Mead', residual=46587.89953613281
# 000009, method='Nelder-Mead', residual=46332.6611328125
# 000010, method='Nelder-Mead', residual=45977.51623535156
# 000011, method='Nelder-Mead', residual=46112.18762207031
# 000012, method='Nelder-Mead', residual=45815.37646484375
# 000013, method='Nelder-Mead', residual=45761.05480957031
# 000014, method='Nelder-Mead', residual=45741.866455078125
# 000015, method='Nelder-Mead', residual=45759.263671875
# 000016, method='Nelder-Mead', residual=46582.29577636719
# 000017, method='Nelder-Mead', residual=46100.243408203125
# 000018, method='Nelder-Mead', residual=46363.325927734375
# 000019, method='Nelder-Mead', residual=46023.35314941406
# 000020, method='Nelder-Mead', residual=46041.005859375
# 000021, method='Nelder-Mead', residual=46423.31689453125
# 000022, method='Nelder-Mead', residual=45974.791748046875
# 000023, method='Nelder-Mead', residual=46334.49621582031
# 000024, method='Nelder-Mead', residual=45926.34973144531
# 000025, method='Nelder-Mead', residual=45742.98718261719
# 000026, method='Nelder-Mead', residual=46125.162841796875
# 000027, method='Nelder-Mead', residual=45915.73449707031
# 000028, method='Nelder-Mead', residual=46090.07458496094
# 000029, method='Nelder-Mead', residual=45862.57531738281
# 000030, method='Nelder-Mead', residual=45859.73046875
# 000031, method='Nelder-Mead', residual=45995.12243652344
# 000032, method='Nelder-Mead', residual=45824.478759765625
# 000033, method='Nelder-Mead', residual=45928.59045410156
# 000034, method='Nelder-Mead', residual=45769.997802734375
# 000035, method='Nelder-Mead', residual=45867.64440917969
# 000036, method='Nelder-Mead', residual=45947.69189453125
# 000037, method='Nelder-Mead', residual=45795.754638671875
# 000038, method='Nelder-Mead', residual=45917.73828125
# 000039, method='Nelder-Mead', residual=45750.47546386719
# 000040, method='Nelder-Mead', residual=45915.46740722656
# 000041, method='Nelder-Mead', residual=45771.53259277344
# 000042, method='Nelder-Mead', residual=45901.03601074219
# 000043, method='Nelder-Mead', residual=45752.386962890625
# 000044, method='Nelder-Mead', residual=45779.629638671875
# 000045, method='Nelder-Mead', residual=45669.911865234375
# 000046, method='Nelder-Mead', residual=45650.641845703125
# 000047, method='Nelder-Mead', residual=45757.71337890625
# 000048, method='Nelder-Mead', residual=45711.615966796875
# 000049, method='Nelder-Mead', residual=45774.70031738281
# 000050, method='Nelder-Mead', residual=45694.777099609375
# 000051, method='Nelder-Mead', residual=45672.33044433594
# 000052, method='Nelder-Mead', residual=45760.68115234375
# 000053, method='Nelder-Mead', residual=45692.49206542969
# 000054, method='Nelder-Mead', residual=45720.02978515625
# 000055, method='Nelder-Mead', residual=45666.89501953125
# 000056, method='Nelder-Mead', residual=45748.902587890625
# 000057, method='Nelder-Mead', residual=45681.20812988281
# 000058, method='Nelder-Mead', residual=45706.04455566406
# 000059, method='Nelder-Mead', residual=45660.8916015625
# 000060, method='Nelder-Mead', residual=45655.79504394531
# 000061, method='Nelder-Mead', residual=45643.16857910156
# 000062, method='Nelder-Mead', residual=45754.82958984375
# 000063, method='Nelder-Mead', residual=45735.74230957031
# 000064, method='Nelder-Mead', residual=45702.5693359375
# 000065, method='Nelder-Mead', residual=45741.83447265625
# 000066, method='Nelder-Mead', residual=45658.9638671875
# 000067, method='Nelder-Mead', residual=45766.63757324219
# 000068, method='Nelder-Mead', residual=45651.32312011719
# 000069, method='Nelder-Mead', residual=45665.01843261719
# 000070, method='Nelder-Mead', residual=45718.62438964844
# 000071, method='Nelder-Mead', residual=45652.73486328125
# 000072, method='Nelder-Mead', residual=45662.27551269531
# 000073, method='Nelder-Mead', residual=45722.26123046875
# 000074, method='Nelder-Mead', residual=45646.12048339844
# 000075, method='Nelder-Mead', residual=45728.45751953125
# 000076, method='Nelder-Mead', residual=45645.89404296875
# 000077, method='Nelder-Mead', residual=45677.01623535156
# 000078, method='Nelder-Mead', residual=45645.128662109375
# 000079, method='Nelder-Mead', residual=45688.1513671875
# 000080, method='Nelder-Mead', residual=45639.98352050781
# 000081, method='Nelder-Mead', residual=45616.22229003906
# 000082, method='Nelder-Mead', residual=45643.78662109375
# 000083, method='Nelder-Mead', residual=45639.38439941406
# 000084, method='Nelder-Mead', residual=45687.78308105469
# 000085, method='Nelder-Mead', residual=45626.34240722656
# 000086, method='Nelder-Mead', residual=45671.04333496094
# 000087, method='Nelder-Mead', residual=45633.32312011719
# 000088, method='Nelder-Mead', residual=45641.371337890625
# 000089, method='Nelder-Mead', residual=45657.53955078125
# 000090, method='Nelder-Mead', residual=45631.78527832031
# 000091, method='Nelder-Mead', residual=45645.83447265625
# 000092, method='Nelder-Mead', residual=45643.80700683594
# 000093, method='Nelder-Mead', residual=45642.29968261719
# 000094, method='Nelder-Mead', residual=45650.867431640625
# 000095, method='Nelder-Mead', residual=45628.36779785156
# 000096, method='Nelder-Mead', residual=45664.137451171875
# 000097, method='Nelder-Mead', residual=45624.2470703125
# 000098, method='Nelder-Mead', residual=45634.34875488281
# 000099, method='Nelder-Mead', residual=45663.00341796875
# 000100, method='Nelder-Mead', residual=45625.07604980469
# 000101, method='Nelder-Mead', residual=45619.826171875
# 000102, method='Nelder-Mead', residual=45637.140869140625
# 000103, method='Nelder-Mead', residual=45648.63854980469
# 000104, method='Nelder-Mead', residual=45622.66467285156
# 000105, method='Nelder-Mead', residual=45641.08459472656
# 000106, method='Nelder-Mead', residual=45663.30529785156
# 000107, method='Nelder-Mead', residual=45616.101806640625
# 000108, method='Nelder-Mead', residual=45647.696044921875
# 000109, method='Nelder-Mead', residual=45620.75354003906
# 000110, method='Nelder-Mead', residual=45629.43005371094
# 000111, method='Nelder-Mead', residual=45627.779296875
# 000112, method='Nelder-Mead', residual=45633.20056152344
# 000113, method='Nelder-Mead', residual=45645.67785644531
# 000114, method='Nelder-Mead', residual=45618.99169921875
# 000115, method='Nelder-Mead', residual=45617.3623046875
# 000116, method='Nelder-Mead', residual=45632.90234375
# 000117, method='Nelder-Mead', residual=45619.180908203125
# 000118, method='Nelder-Mead', residual=45623.185302734375
# 000119, method='Nelder-Mead', residual=45652.88659667969
# 000120, method='Nelder-Mead', residual=45615.588134765625
# 000121, method='Nelder-Mead', residual=45618.004638671875
# 000122, method='Nelder-Mead', residual=45625.60400390625
# 000123, method='Nelder-Mead', residual=45611.944091796875
# 000124, method='Nelder-Mead', residual=45639.98522949219
# 000125, method='Nelder-Mead', residual=45627.08605957031
# 000126, method='Nelder-Mead', residual=45616.001220703125
# 000127, method='Nelder-Mead', residual=45633.49987792969
# 000128, method='Nelder-Mead', residual=45615.12658691406
# 000129, method='Nelder-Mead', residual=45628.422607421875
# 000130, method='Nelder-Mead', residual=45615.46789550781
# 000131, method='Nelder-Mead', residual=45624.045654296875
# 000132, method='Nelder-Mead', residual=45615.01281738281
# 000133, method='Nelder-Mead', residual=45609.562744140625
# 000134, method='Nelder-Mead', residual=45621.88586425781
# 000135, method='Nelder-Mead', residual=45612.04089355469
# 000136, method='Nelder-Mead', residual=45615.099365234375
# 000137, method='Nelder-Mead', residual=45613.470458984375
# 000138, method='Nelder-Mead', residual=45611.38708496094
# 000139, method='Nelder-Mead', residual=45615.88293457031
# 000140, method='Nelder-Mead', residual=45618.01110839844
# 000141, method='Nelder-Mead', residual=45611.252685546875
# 000142, method='Nelder-Mead', residual=45613.92626953125
# 000143, method='Nelder-Mead', residual=45612.79626464844
# 000144, method='Nelder-Mead', residual=45607.02941894531
# 000145, method='Nelder-Mead', residual=45618.18029785156
# 000146, method='Nelder-Mead', residual=45619.18884277344
# 000147, method='Nelder-Mead', residual=45609.8955078125
# 000148, method='Nelder-Mead', residual=45609.63854980469
# 000149, method='Nelder-Mead', residual=45608.055908203125
# 000150, method='Nelder-Mead', residual=45609.28161621094
# 000151, method='Nelder-Mead', residual=45618.3291015625
# 000152, method='Nelder-Mead', residual=45608.58776855469
# 000153, method='Nelder-Mead', residual=45606.60729980469
# 000154, method='Nelder-Mead', residual=45618.60400390625
# 000155, method='Nelder-Mead', residual=45614.92529296875
# 000156, method='Nelder-Mead', residual=45607.990478515625
# 000157, method='Nelder-Mead', residual=45611.005615234375
# 000158, method='Nelder-Mead', residual=45621.41711425781
# 000159, method='Nelder-Mead', residual=45608.31884765625
# 000160, method='Nelder-Mead', residual=45620.19616699219
# 000161, method='Nelder-Mead', residual=45608.33483886719
# 000162, method='Nelder-Mead', residual=45616.63854980469
# 000163, method='Nelder-Mead', residual=45606.89636230469
# 000164, method='Nelder-Mead', residual=45610.402099609375
# 000165, method='Nelder-Mead', residual=45604.65075683594
# 000166, method='Nelder-Mead', residual=45608.97204589844
# 000167, method='Nelder-Mead', residual=45614.800537109375
# 000168, method='Nelder-Mead', residual=45606.60778808594
# 000169, method='Nelder-Mead', residual=45610.03369140625
# 000170, method='Nelder-Mead', residual=45606.60107421875
# 000171, method='Nelder-Mead', residual=45607.05261230469
# 000172, method='Nelder-Mead', residual=45609.662841796875
# 000173, method='Nelder-Mead', residual=45606.21276855469
# 000174, method='Nelder-Mead', residual=45604.89453125
# 000175, method='Nelder-Mead', residual=45610.703125
# 000176, method='Nelder-Mead', residual=45605.67419433594
# 000177, method='Nelder-Mead', residual=45605.43701171875
# 000178, method='Nelder-Mead', residual=45607.28063964844
# 000179, method='Nelder-Mead', residual=45612.06750488281
# 000180, method='Nelder-Mead', residual=45605.61267089844
# 000181, method='Nelder-Mead', residual=45606.768310546875
# 000182, method='Nelder-Mead', residual=45604.967041015625
# 000183, method='Nelder-Mead', residual=45607.13171386719
# 000184, method='Nelder-Mead', residual=45605.29187011719
# 000185, method='Nelder-Mead', residual=45607.673095703125
# 000186, method='Nelder-Mead', residual=45604.82653808594
# 000187, method='Nelder-Mead', residual=45606.06872558594
# 000188, method='Nelder-Mead', residual=45606.29943847656
# 000189, method='Nelder-Mead', residual=45608.96618652344
# 000190, method='Nelder-Mead', residual=45604.57263183594
# 000191, method='Nelder-Mead', residual=45606.055419921875
# 000192, method='Nelder-Mead', residual=45608.06591796875
# 000193, method='Nelder-Mead', residual=45604.52795410156
# 000194, method='Nelder-Mead', residual=45604.65380859375
# 000195, method='Nelder-Mead', residual=45607.162109375
# 000196, method='Nelder-Mead', residual=45604.443359375
# 000197, method='Nelder-Mead', residual=45604.13757324219
# 000198, method='Nelder-Mead', residual=45606.954345703125
# 000199, method='Nelder-Mead', residual=45604.63073730469
# 000200, method='Nelder-Mead', residual=45605.31591796875
# 000201, method='Nelder-Mead', residual=45603.76623535156
# 000202, method='Nelder-Mead', residual=45606.04455566406
# 000203, method='Nelder-Mead', residual=45604.13659667969
# 000204, method='Nelder-Mead', residual=45605.008056640625
# 000205, method='Nelder-Mead', residual=45605.609619140625
# 000206, method='Nelder-Mead', residual=45603.87548828125
# 000207, method='Nelder-Mead', residual=45604.44970703125
# 000208, method='Nelder-Mead', residual=45605.37451171875
# 000209, method='Nelder-Mead', residual=45603.700927734375
# 000210, method='Nelder-Mead', residual=45605.21789550781
# 000211, method='Nelder-Mead', residual=45603.671142578125
# 000212, method='Nelder-Mead', residual=45607.875244140625
# 000213, method='Nelder-Mead', residual=45603.42236328125
# 000214, method='Nelder-Mead', residual=45603.52136230469
# 000215, method='Nelder-Mead', residual=45605.708251953125
# 000216, method='Nelder-Mead', residual=45603.47424316406
# 000217, method='Nelder-Mead', residual=45603.935546875
# 000218, method='Nelder-Mead', residual=45604.30236816406
# 000219, method='Nelder-Mead', residual=45605.68737792969
# 000220, method='Nelder-Mead', residual=45603.45788574219
# 000221, method='Nelder-Mead', residual=45602.57336425781
# 000222, method='Nelder-Mead', residual=45602.81555175781
# 000223, method='Nelder-Mead', residual=45604.72351074219
# 000224, method='Nelder-Mead', residual=45603.29113769531
# 000225, method='Nelder-Mead', residual=45602.59680175781
# 000226, method='Nelder-Mead', residual=45603.90759277344
# 000227, method='Nelder-Mead', residual=45604.129150390625
# 000228, method='Nelder-Mead', residual=45603.60974121094
# 000229, method='Nelder-Mead', residual=45604.271484375
# 000230, method='Nelder-Mead', residual=45603.19494628906
# 000231, method='Nelder-Mead', residual=45603.9384765625
# 000232, method='Nelder-Mead', residual=45603.16809082031
# 000233, method='Nelder-Mead', residual=45604.084716796875
# 000234, method='Nelder-Mead', residual=45603.1259765625
# 000235, method='Nelder-Mead', residual=45603.49963378906
# 000236, method='Nelder-Mead', residual=45603.556396484375
# 000237, method='Nelder-Mead', residual=45603.253662109375
# 000238, method='Nelder-Mead', residual=45602.52307128906
# 000239, method='Nelder-Mead', residual=45602.8251953125
# 000240, method='Nelder-Mead', residual=45604.45166015625
# 000241, method='Nelder-Mead', residual=45602.91931152344
# 000242, method='Nelder-Mead', residual=45603.361083984375
# 000243, method='Nelder-Mead', residual=45603.201171875
# 000244, method='Nelder-Mead', residual=45603.52111816406
# 000245, method='Nelder-Mead', residual=45602.911376953125
# 000246, method='Nelder-Mead', residual=45602.71081542969
# 000247, method='Nelder-Mead', residual=45602.61511230469
# 000248, method='Nelder-Mead', residual=45602.89465332031
# 000249, method='Nelder-Mead', residual=45603.12731933594
# 000250, method='Nelder-Mead', residual=45602.504638671875
# 000251, method='Nelder-Mead', residual=45603.11584472656
# 000252, method='Nelder-Mead', residual=45602.78161621094
# 000253, method='Nelder-Mead', residual=45603.056640625
# 000254, method='Nelder-Mead', residual=45602.35632324219
# 000255, method='Nelder-Mead', residual=45602.922119140625
# 000256, method='Nelder-Mead', residual=45602.02941894531
# 000257, method='Nelder-Mead', residual=45602.09375
# 000258, method='Nelder-Mead', residual=45603.620849609375
# 000259, method='Nelder-Mead', residual=45602.4794921875
# 000260, method='Nelder-Mead', residual=45602.400146484375
# 000261, method='Nelder-Mead', residual=45602.50866699219
# 000262, method='Nelder-Mead', residual=45602.23181152344
# 000263, method='Nelder-Mead', residual=45601.783935546875
# 000264, method='Nelder-Mead', residual=45601.69909667969
# 000265, method='Nelder-Mead', residual=45602.318115234375
# 000266, method='Nelder-Mead', residual=45602.46728515625
# 000267, method='Nelder-Mead', residual=45602.25830078125
# 000268, method='Nelder-Mead', residual=45601.83642578125
# 000269, method='Nelder-Mead', residual=45601.94445800781
# 000270, method='Nelder-Mead', residual=45602.12658691406
# 000271, method='Nelder-Mead', residual=45601.90881347656
# 000272, method='Nelder-Mead', residual=45601.965087890625
# 000273, method='Nelder-Mead', residual=45601.81457519531
# 000274, method='Nelder-Mead', residual=45601.98254394531
# 000275, method='Nelder-Mead', residual=45601.775390625
# 000276, method='Nelder-Mead', residual=45601.271240234375
# 000277, method='Nelder-Mead', residual=45601.23937988281
# 000278, method='Nelder-Mead', residual=45601.02551269531
# 000279, method='Nelder-Mead', residual=45600.804931640625
# 000280, method='Nelder-Mead', residual=45601.74865722656
# 000281, method='Nelder-Mead', residual=45601.87365722656
# 000282, method='Nelder-Mead', residual=45601.16076660156
# 000283, method='Nelder-Mead', residual=45601.94482421875
# 000284, method='Nelder-Mead', residual=45601.70886230469
# 000285, method='Nelder-Mead', residual=45601.42907714844
# 000286, method='Nelder-Mead', residual=45601.99853515625
# 000287, method='Nelder-Mead', residual=45601.42395019531
# 000288, method='Nelder-Mead', residual=45601.70654296875
# 000289, method='Nelder-Mead', residual=45600.92028808594
# 000290, method='Nelder-Mead', residual=45601.5224609375
# 000291, method='Nelder-Mead', residual=45601.15075683594
# 000292, method='Nelder-Mead', residual=45600.68957519531
# 000293, method='Nelder-Mead', residual=45600.74719238281
# 000294, method='Nelder-Mead', residual=45601.742431640625
# 000295, method='Nelder-Mead', residual=45601.34997558594
# 000296, method='Nelder-Mead', residual=45601.305419921875
# 000297, method='Nelder-Mead', residual=45601.32263183594
# 000298, method='Nelder-Mead', residual=45601.47705078125
# 000299, method='Nelder-Mead', residual=45601.093994140625
# 000300, method='Nelder-Mead', residual=45600.32946777344
# 000301, method='Nelder-Mead', residual=45600.229248046875
# 000302, method='Nelder-Mead', residual=45601.061767578125
# 000303, method='Nelder-Mead', residual=45601.318603515625
# 000304, method='Nelder-Mead', residual=45600.86279296875
# 000305, method='Nelder-Mead', residual=45600.27355957031
# 000306, method='Nelder-Mead', residual=45600.745361328125
# 000307, method='Nelder-Mead', residual=45600.65637207031
# 000308, method='Nelder-Mead', residual=45600.93957519531
# 000309, method='Nelder-Mead', residual=45600.97705078125
# 000310, method='Nelder-Mead', residual=45600.437255859375
# 000311, method='Nelder-Mead', residual=45600.536376953125
# 000312, method='Nelder-Mead', residual=45600.19189453125
# 000313, method='Nelder-Mead', residual=45600.79943847656
# 000314, method='Nelder-Mead', residual=45600.94787597656
# 000315, method='Nelder-Mead', residual=45600.67761230469
# 000316, method='Nelder-Mead', residual=45600.641845703125
# 000317, method='Nelder-Mead', residual=45601.152587890625
# 000318, method='Nelder-Mead', residual=45600.383056640625
# 000319, method='Nelder-Mead', residual=45600.57849121094
# 000320, method='Nelder-Mead', residual=45600.064697265625
# 000321, method='Nelder-Mead', residual=45600.604248046875
# 000322, method='Nelder-Mead', residual=45600.023681640625
# 000323, method='Nelder-Mead', residual=45600.59436035156
# 000324, method='Nelder-Mead', residual=45599.575927734375
# 000325, method='Nelder-Mead', residual=45599.41467285156
# 000326, method='Nelder-Mead', residual=45601.0400390625
# 000327, method='Nelder-Mead', residual=45600.130615234375
# 000328, method='Nelder-Mead', residual=45599.69543457031
# 000329, method='Nelder-Mead', residual=45600.287109375
# 000330, method='Nelder-Mead', residual=45600.19287109375
# 000331, method='Nelder-Mead', residual=45600.49951171875
# 000332, method='Nelder-Mead', residual=45600.330078125
# 000333, method='Nelder-Mead', residual=45599.67053222656
# 000334, method='Nelder-Mead', residual=45600.7080078125
# 000335, method='Nelder-Mead', residual=45599.89758300781
# 000336, method='Nelder-Mead', residual=45599.71728515625
# 000337, method='Nelder-Mead', residual=45599.333251953125
# 000338, method='Nelder-Mead', residual=45599.373046875
# 000339, method='Nelder-Mead', residual=45600.23596191406
# 000340, method='Nelder-Mead', residual=45600.06530761719
# 000341, method='Nelder-Mead', residual=45599.647216796875
# 000342, method='Nelder-Mead', residual=45600.498779296875
# 000343, method='Nelder-Mead', residual=45599.72180175781
# 000344, method='Nelder-Mead', residual=45599.27282714844
# 000345, method='Nelder-Mead', residual=45599.39636230469
# 000346, method='Nelder-Mead', residual=45599.99548339844
# 000347, method='Nelder-Mead', residual=45599.62548828125
# 000348, method='Nelder-Mead', residual=45599.526123046875
# 000349, method='Nelder-Mead', residual=45599.66162109375
# 000350, method='Nelder-Mead', residual=45598.881591796875
# 000351, method='Nelder-Mead', residual=45598.64831542969
# 000352, method='Nelder-Mead', residual=45599.456787109375
# 000353, method='Nelder-Mead', residual=45599.9111328125
# 000354, method='Nelder-Mead', residual=45599.38537597656
# 000355, method='Nelder-Mead', residual=45599.052734375
# 000356, method='Nelder-Mead', residual=45599.11071777344
# 000357, method='Nelder-Mead', residual=45599.373291015625
# 000358, method='Nelder-Mead', residual=45598.84704589844
# 000359, method='Nelder-Mead', residual=45599.18200683594
# 000360, method='Nelder-Mead', residual=45599.780517578125
# 000361, method='Nelder-Mead', residual=45599.15905761719
# 000362, method='Nelder-Mead', residual=45599.05773925781
# 000363, method='Nelder-Mead', residual=45598.70959472656
# 000364, method='Nelder-Mead', residual=45598.75671386719
# 000365, method='Nelder-Mead', residual=45598.865234375
# 000366, method='Nelder-Mead', residual=45598.54736328125
# 000367, method='Nelder-Mead', residual=45598.666015625
# 000368, method='Nelder-Mead', residual=45598.74560546875
# 000369, method='Nelder-Mead', residual=45599.112060546875
# 000370, method='Nelder-Mead', residual=45598.220703125
# 000371, method='Nelder-Mead', residual=45597.98498535156
# 000372, method='Nelder-Mead', residual=45598.66223144531
# 000373, method='Nelder-Mead', residual=45598.612548828125
# 000374, method='Nelder-Mead', residual=45598.30114746094
# 000375, method='Nelder-Mead', residual=45598.91882324219
# 000376, method='Nelder-Mead', residual=45598.29443359375
# 000377, method='Nelder-Mead', residual=45598.41162109375
# 000378, method='Nelder-Mead', residual=45598.39172363281
# 000379, method='Nelder-Mead', residual=45598.81237792969
# 000380, method='Nelder-Mead', residual=45597.94921875
# 000381, method='Nelder-Mead', residual=45597.91638183594
# 000382, method='Nelder-Mead', residual=45598.032470703125
# 000383, method='Nelder-Mead', residual=45598.65661621094
# 000384, method='Nelder-Mead', residual=45598.50378417969
# 000385, method='Nelder-Mead', residual=45597.78662109375
# 000386, method='Nelder-Mead', residual=45597.82751464844
# 000387, method='Nelder-Mead', residual=45598.04968261719
# 000388, method='Nelder-Mead', residual=45598.40808105469
# 000389, method='Nelder-Mead', residual=45598.42333984375
# 000390, method='Nelder-Mead', residual=45597.78234863281
# 000391, method='Nelder-Mead', residual=45598.11181640625
# 000392, method='Nelder-Mead', residual=45598.16296386719
# 000393, method='Nelder-Mead', residual=45598.03857421875
# 000394, method='Nelder-Mead', residual=45597.996826171875
# 000395, method='Nelder-Mead', residual=45598.611572265625
# 000396, method='Nelder-Mead', residual=45597.954833984375
# 000397, method='Nelder-Mead', residual=45597.87414550781
# 000398, method='Nelder-Mead', residual=45598.37243652344
# 000399, method='Nelder-Mead', residual=45597.774169921875
# 000400, method='Nelder-Mead', residual=45598.37548828125
# 000401, method='Nelder-Mead', residual=45598.32043457031
# 000402, method='Nelder-Mead', residual=45597.89013671875
# 000403, method='Nelder-Mead', residual=45597.42724609375
# 000404, method='Nelder-Mead', residual=45597.444580078125
# 000405, method='Nelder-Mead', residual=45597.664794921875
# 000406, method='Nelder-Mead', residual=45597.900390625
# 000407, method='Nelder-Mead', residual=45597.552490234375
# 000408, method='Nelder-Mead', residual=45598.234375
# 000409, method='Nelder-Mead', residual=45597.68200683594
# 000410, method='Nelder-Mead', residual=45597.9091796875
# 000411, method='Nelder-Mead', residual=45598.0009765625
# 000412, method='Nelder-Mead', residual=45597.689697265625
# 000413, method='Nelder-Mead', residual=45597.43505859375
# 000414, method='Nelder-Mead', residual=45597.942138671875
# 000415, method='Nelder-Mead', residual=45597.64807128906
# 000416, method='Nelder-Mead', residual=45597.536376953125
# 000417, method='Nelder-Mead', residual=45597.88757324219
# 000418, method='Nelder-Mead', residual=45597.89074707031
# 000419, method='Nelder-Mead', residual=45597.604736328125
# 000420, method='Nelder-Mead', residual=45597.47326660156
# 000421, method='Nelder-Mead', residual=45597.96984863281
# 000422, method='Nelder-Mead', residual=45597.587158203125
# 000423, method='Nelder-Mead', residual=45597.4697265625
# 000424, method='Nelder-Mead', residual=45597.709228515625
# 000425, method='Nelder-Mead', residual=45597.34484863281
# 000426, method='Nelder-Mead', residual=45597.49475097656
# 000427, method='Nelder-Mead', residual=45597.5654296875
# 000428, method='Nelder-Mead', residual=45597.80419921875
# 000429, method='Nelder-Mead', residual=45597.478271484375
# 000430, method='Nelder-Mead', residual=45597.41711425781
# 000431, method='Nelder-Mead', residual=45597.25476074219
# 000432, method='Nelder-Mead', residual=45597.307861328125
# 000433, method='Nelder-Mead', residual=45597.51171875
# 000434, method='Nelder-Mead', residual=45597.42443847656
# 000435, method='Nelder-Mead', residual=45597.21936035156
# 000436, method='Nelder-Mead', residual=45597.27355957031
# 000437, method='Nelder-Mead', residual=45597.30029296875
# 000438, method='Nelder-Mead', residual=45597.44494628906
# 000439, method='Nelder-Mead', residual=45597.4833984375
# 000440, method='Nelder-Mead', residual=45597.25549316406
# 000441, method='Nelder-Mead', residual=45597.51770019531
# 000442, method='Nelder-Mead', residual=45597.330810546875
# 000443, method='Nelder-Mead', residual=45597.52209472656
# 000444, method='Nelder-Mead', residual=45597.32043457031
# 000445, method='Nelder-Mead', residual=45597.1591796875
# 000446, method='Nelder-Mead', residual=45597.193115234375
# 000447, method='Nelder-Mead', residual=45597.33044433594
# 000448, method='Nelder-Mead', residual=45597.50451660156
# 000449, method='Nelder-Mead', residual=45597.29309082031
# 000450, method='Nelder-Mead', residual=45597.47985839844
# 000451, method='Nelder-Mead', residual=45597.28625488281
# 000452, method='Nelder-Mead', residual=45597.25646972656
# 000453, method='Nelder-Mead', residual=45597.08752441406
# 000454, method='Nelder-Mead', residual=45597.05126953125
# 000455, method='Nelder-Mead', residual=45597.39587402344
# 000456, method='Nelder-Mead', residual=45597.25061035156
# 000457, method='Nelder-Mead', residual=45597.3720703125
# 000458, method='Nelder-Mead', residual=45597.223388671875
# 000459, method='Nelder-Mead', residual=45597.176025390625
# 000460, method='Nelder-Mead', residual=45597.11804199219
# 000461, method='Nelder-Mead', residual=45597.28515625
# 000462, method='Nelder-Mead', residual=45597.15637207031
# 000463, method='Nelder-Mead', residual=45597.173828125
# 000464, method='Nelder-Mead', residual=45597.09973144531
# 000465, method='Nelder-Mead', residual=45597.13903808594
# 000466, method='Nelder-Mead', residual=45597.209716796875
# 000467, method='Nelder-Mead', residual=45597.09436035156
# 000468, method='Nelder-Mead', residual=45597.20178222656
# 000469, method='Nelder-Mead', residual=45597.09619140625
# 000470, method='Nelder-Mead', residual=45597.16418457031
# 000471, method='Nelder-Mead', residual=45597.09118652344
# 000472, method='Nelder-Mead', residual=45597.07165527344
# 000473, method='Nelder-Mead', residual=45597.136962890625
# 000474, method='Nelder-Mead', residual=45597.143310546875
# 000475, method='Nelder-Mead', residual=45597.15539550781
# 000476, method='Nelder-Mead', residual=45597.12170410156
# 000477, method='Nelder-Mead', residual=45597.202392578125
# 000478, method='Nelder-Mead', residual=45597.064208984375
# 000479, method='Nelder-Mead', residual=45597.02099609375
# 000480, method='Nelder-Mead', residual=45597.13610839844
# 000481, method='Nelder-Mead', residual=45597.11572265625
# 000482, method='Nelder-Mead', residual=45597.083740234375
# 000483, method='Nelder-Mead', residual=45597.15283203125
# 000484, method='Nelder-Mead', residual=45597.04406738281
# 000485, method='Nelder-Mead', residual=45596.99645996094
# 000486, method='Nelder-Mead', residual=45597.08142089844
# 000487, method='Nelder-Mead', residual=45597.05065917969
# 000488, method='Nelder-Mead', residual=45597.13427734375
# 000489, method='Nelder-Mead', residual=45597.02880859375
# 000490, method='Nelder-Mead', residual=45597.00158691406
# 000491, method='Nelder-Mead', residual=45597.107421875
# 000492, method='Nelder-Mead', residual=45597.02697753906
# 000493, method='Nelder-Mead', residual=45597.011474609375
# 000494, method='Nelder-Mead', residual=45597.087646484375
# 000495, method='Nelder-Mead', residual=45597.232421875
# 000496, method='Nelder-Mead', residual=45597.00427246094
# 000497, method='Nelder-Mead', residual=45597.00439453125
# 000498, method='Nelder-Mead', residual=45597.07922363281
# 000499, method='Nelder-Mead', residual=45597.00354003906
# 000500, method='Nelder-Mead', residual=45597.060546875
# 000501, method='Nelder-Mead', residual=45596.97497558594
# 000502, method='Nelder-Mead', residual=45597.0732421875
# 000503, method='Nelder-Mead', residual=45596.91027832031
# 000504, method='Nelder-Mead', residual=45596.90002441406
# 000505, method='Nelder-Mead', residual=45597.03210449219
# 000506, method='Nelder-Mead', residual=45597.0087890625
# 000507, method='Nelder-Mead', residual=45596.9755859375
# 000508, method='Nelder-Mead', residual=45596.945556640625
# 000509, method='Nelder-Mead', residual=45597.03857421875
# 000510, method='Nelder-Mead', residual=45596.961669921875
# 000511, method='Nelder-Mead', residual=45596.91357421875
# 000512, method='Nelder-Mead', residual=45596.940185546875
# 000513, method='Nelder-Mead', residual=45596.96008300781
# 000514, method='Nelder-Mead', residual=45596.9833984375
# 000515, method='Nelder-Mead', residual=45596.96447753906
# 000516, method='Nelder-Mead', residual=45596.94689941406
# 000517, method='Nelder-Mead', residual=45596.8984375
# 000518, method='Nelder-Mead', residual=45596.97937011719
# 000519, method='Nelder-Mead', residual=45597.01208496094
# 000520, method='Nelder-Mead', residual=45596.92810058594
# 000521, method='Nelder-Mead', residual=45596.852294921875
# 000522, method='Nelder-Mead', residual=45596.86584472656
# 000523, method='Nelder-Mead', residual=45596.86633300781
# 000524, method='Nelder-Mead', residual=45596.95837402344
# 000525, method='Nelder-Mead', residual=45596.98620605469
# 000526, method='Nelder-Mead', residual=45596.90625
# 000527, method='Nelder-Mead', residual=45596.91540527344
# 000528, method='Nelder-Mead', residual=45596.944580078125
# 000529, method='Nelder-Mead', residual=45596.84533691406
# 000530, method='Nelder-Mead', residual=45596.86669921875
# 000531, method='Nelder-Mead', residual=45596.96728515625
# 000532, method='Nelder-Mead', residual=45596.89172363281
# 000533, method='Nelder-Mead', residual=45596.944091796875
# 000534, method='Nelder-Mead', residual=45596.886474609375
# 000535, method='Nelder-Mead', residual=45596.847900390625
# 000536, method='Nelder-Mead', residual=45596.9375
# 000537, method='Nelder-Mead', residual=45596.945556640625
# 000538, method='Nelder-Mead', residual=45596.886474609375
# 000539, method='Nelder-Mead', residual=45596.81005859375
# 000540, method='Nelder-Mead', residual=45596.792724609375
# 000541, method='Nelder-Mead', residual=45596.924072265625
# 000542, method='Nelder-Mead', residual=45596.80554199219
# 000543, method='Nelder-Mead', residual=45596.90515136719
# 000544, method='Nelder-Mead', residual=45596.91662597656
# 000545, method='Nelder-Mead', residual=45596.857666015625
# 000546, method='Nelder-Mead', residual=45596.845703125
# 000547, method='Nelder-Mead', residual=45596.79333496094
# 000548, method='Nelder-Mead', residual=45596.886962890625
# 000549, method='Nelder-Mead', residual=45596.854248046875
# 000550, method='Nelder-Mead', residual=45596.77868652344
# 000551, method='Nelder-Mead', residual=45596.79675292969
# 000552, method='Nelder-Mead', residual=45596.778564453125
# 000553, method='Nelder-Mead', residual=45596.805419921875
# 000554, method='Nelder-Mead', residual=45596.86901855469
# 000555, method='Nelder-Mead', residual=45596.74853515625
# 000556, method='Nelder-Mead', residual=45596.728759765625
# 000557, method='Nelder-Mead', residual=45596.7509765625
# 000558, method='Nelder-Mead', residual=45596.83874511719
# 000559, method='Nelder-Mead', residual=45596.712158203125
# 000560, method='Nelder-Mead', residual=45596.68884277344
# 000561, method='Nelder-Mead', residual=45596.69519042969
# 000562, method='Nelder-Mead', residual=45596.78173828125
# 000563, method='Nelder-Mead', residual=45596.71984863281
# 000564, method='Nelder-Mead', residual=45596.68896484375
# 000565, method='Nelder-Mead', residual=45596.70251464844
# 000566, method='Nelder-Mead', residual=45596.66125488281
# 000567, method='Nelder-Mead', residual=45596.699951171875
# 000568, method='Nelder-Mead', residual=45596.662353515625
# 000569, method='Nelder-Mead', residual=45596.618896484375
# 000570, method='Nelder-Mead', residual=45596.58312988281
# 000571, method='Nelder-Mead', residual=45596.62060546875
# 000572, method='Nelder-Mead', residual=45596.62841796875
# 000573, method='Nelder-Mead', residual=45596.6162109375
# 000574, method='Nelder-Mead', residual=45596.52087402344
# 000575, method='Nelder-Mead', residual=45596.4423828125
# 000576, method='Nelder-Mead', residual=45596.50231933594
# 000577, method='Nelder-Mead', residual=45596.492919921875
# 000578, method='Nelder-Mead', residual=45596.609130859375
# 000579, method='Nelder-Mead', residual=45596.543212890625
# 000580, method='Nelder-Mead', residual=45596.55712890625
# 000581, method='Nelder-Mead', residual=45596.4296875
# 000582, method='Nelder-Mead', residual=45596.34143066406
# 000583, method='Nelder-Mead', residual=45596.4599609375
# 000584, method='Nelder-Mead', residual=45596.431640625
# 000585, method='Nelder-Mead', residual=45596.37878417969
# 000586, method='Nelder-Mead', residual=45596.37548828125
# 000587, method='Nelder-Mead', residual=45596.391357421875
# 000588, method='Nelder-Mead', residual=45596.306884765625
# 000589, method='Nelder-Mead', residual=45596.25134277344
# 000590, method='Nelder-Mead', residual=45596.3603515625
# 000591, method='Nelder-Mead', residual=45596.49865722656
# 000592, method='Nelder-Mead', residual=45596.23193359375
# 000593, method='Nelder-Mead', residual=45596.16162109375
# 000594, method='Nelder-Mead', residual=45596.22375488281
# 000595, method='Nelder-Mead', residual=45596.18603515625
# 000596, method='Nelder-Mead', residual=45596.23193359375
# 000597, method='Nelder-Mead', residual=45596.363525390625
# 000598, method='Nelder-Mead', residual=45596.11572265625
# 000599, method='Nelder-Mead', residual=45596.04943847656
# 000600, method='Nelder-Mead', residual=45596.13098144531
# 000601, method='Nelder-Mead', residual=45596.0869140625
# 000602, method='Nelder-Mead', residual=45596.143310546875
# 000603, method='Nelder-Mead', residual=45596.13781738281
# 000604, method='Nelder-Mead', residual=45596.117431640625
# 000605, method='Nelder-Mead', residual=45596.00341796875
# 000606, method='Nelder-Mead', residual=45596.01025390625
# 000607, method='Nelder-Mead', residual=45596.244873046875
# 000608, method='Nelder-Mead', residual=45596.044677734375
# 000609, method='Nelder-Mead', residual=45595.95397949219
# 000610, method='Nelder-Mead', residual=45595.984375
# 000611, method='Nelder-Mead', residual=45596.02783203125
# 000612, method='Nelder-Mead', residual=45596.16271972656
# 000613, method='Nelder-Mead', residual=45596.00671386719
# 000614, method='Nelder-Mead', residual=45595.971923828125
# 000615, method='Nelder-Mead', residual=45596.01452636719
# 000616, method='Nelder-Mead', residual=45596.171142578125
# 000617, method='Nelder-Mead', residual=45596.03991699219
# 000618, method='Nelder-Mead', residual=45595.917724609375
# 000619, method='Nelder-Mead', residual=45595.95202636719
# 000620, method='Nelder-Mead', residual=45595.869384765625
# 000621, method='Nelder-Mead', residual=45595.818603515625
# 000622, method='Nelder-Mead', residual=45595.865478515625
# 000623, method='Nelder-Mead', residual=45595.90808105469
# 000624, method='Nelder-Mead', residual=45595.806640625
# 000625, method='Nelder-Mead', residual=45595.80847167969
# 000626, method='Nelder-Mead', residual=45595.98254394531
# 000627, method='Nelder-Mead', residual=45595.973876953125
# 000628, method='Nelder-Mead', residual=45595.91809082031
# 000629, method='Nelder-Mead', residual=45595.89562988281
# 000630, method='Nelder-Mead', residual=45595.78503417969
# 000631, method='Nelder-Mead', residual=45595.802734375
# 000632, method='Nelder-Mead', residual=45595.76965332031
# 000633, method='Nelder-Mead', residual=45595.798828125
# 000634, method='Nelder-Mead', residual=45595.87170410156
# 000635, method='Nelder-Mead', residual=45595.80505371094
# 000636, method='Nelder-Mead', residual=45595.83996582031
# 000637, method='Nelder-Mead', residual=45595.902587890625
# 000638, method='Nelder-Mead', residual=45595.72473144531
# 000639, method='Nelder-Mead', residual=45595.760986328125
# 000640, method='Nelder-Mead', residual=45595.76354980469
# 000641, method='Nelder-Mead', residual=45595.83483886719
# 000642, method='Nelder-Mead', residual=45595.68054199219
# 000643, method='Nelder-Mead', residual=45595.69958496094
# 000644, method='Nelder-Mead', residual=45595.78698730469
# 000645, method='Nelder-Mead', residual=45595.84729003906
# 000646, method='Nelder-Mead', residual=45595.70251464844
# 000647, method='Nelder-Mead', residual=45595.74963378906
# 000648, method='Nelder-Mead', residual=45595.71594238281
# 000649, method='Nelder-Mead', residual=45595.82434082031
# 000650, method='Nelder-Mead', residual=45595.683837890625
# 000651, method='Nelder-Mead', residual=45595.71984863281
# 000652, method='Nelder-Mead', residual=45595.83923339844
# 000653, method='Nelder-Mead', residual=45595.71923828125
# 000654, method='Nelder-Mead', residual=45595.63586425781
# 000655, method='Nelder-Mead', residual=45595.6826171875
# 000656, method='Nelder-Mead', residual=45595.65881347656
# 000657, method='Nelder-Mead', residual=45595.77648925781
# 000658, method='Nelder-Mead', residual=45595.66943359375
# 000659, method='Nelder-Mead', residual=45595.67785644531
# 000660, method='Nelder-Mead', residual=45595.76806640625
# 000661, method='Nelder-Mead', residual=45595.6591796875
# 000662, method='Nelder-Mead', residual=45595.7529296875
# 000663, method='Nelder-Mead', residual=45595.61315917969
# 000664, method='Nelder-Mead', residual=45595.706298828125
# 000665, method='Nelder-Mead', residual=45595.739013671875
# 000666, method='Nelder-Mead', residual=45595.70764160156
# 000667, method='Nelder-Mead', residual=45595.719970703125
# 000668, method='Nelder-Mead', residual=45595.595947265625
# 000669, method='Nelder-Mead', residual=45595.6416015625
# 000670, method='Nelder-Mead', residual=45595.72351074219
# 000671, method='Nelder-Mead', residual=45595.643798828125
# 000672, method='Nelder-Mead', residual=45595.69140625
# 000673, method='Nelder-Mead', residual=45595.57507324219
# 000674, method='Nelder-Mead', residual=45595.62414550781
# 000675, method='Nelder-Mead', residual=45595.57287597656
# 000676, method='Nelder-Mead', residual=45595.64465332031
# 000677, method='Nelder-Mead', residual=45595.68444824219
# 000678, method='Nelder-Mead', residual=45595.64953613281
# 000679, method='Nelder-Mead', residual=45595.669189453125
# 000680, method='Nelder-Mead', residual=45595.71533203125
# 000681, method='Nelder-Mead', residual=45595.60974121094
# 000682, method='Nelder-Mead', residual=45595.608154296875
# 000683, method='Nelder-Mead', residual=45595.55432128906
# 000684, method='Nelder-Mead', residual=45595.59631347656
# 000685, method='Nelder-Mead', residual=45595.66394042969
# 000686, method='Nelder-Mead', residual=45595.599365234375
# 000687, method='Nelder-Mead', residual=45595.64599609375
# 000688, method='Nelder-Mead', residual=45595.706787109375
# 000689, method='Nelder-Mead', residual=45595.59240722656
# 000690, method='Nelder-Mead', residual=45595.56457519531
# 000691, method='Nelder-Mead', residual=45595.53576660156
# 000692, method='Nelder-Mead', residual=45595.58251953125
# 000693, method='Nelder-Mead', residual=45595.62512207031
# 000694, method='Nelder-Mead', residual=45595.652099609375
# 000695, method='Nelder-Mead', residual=45595.57702636719
# 000696, method='Nelder-Mead', residual=45595.502685546875
# 000697, method='Nelder-Mead', residual=45595.50158691406
# 000698, method='Nelder-Mead', residual=45595.57727050781
# 000699, method='Nelder-Mead', residual=45595.62023925781
# 000700, method='Nelder-Mead', residual=45595.556396484375
# 000701, method='Nelder-Mead', residual=45595.53747558594
# 000702, method='Nelder-Mead', residual=45595.49755859375
# 000703, method='Nelder-Mead', residual=45595.53015136719
# 000704, method='Nelder-Mead', residual=45595.569580078125
# 000705, method='Nelder-Mead', residual=45595.53625488281
# 000706, method='Nelder-Mead', residual=45595.52404785156
# 000707, method='Nelder-Mead', residual=45595.460205078125
# 000708, method='Nelder-Mead', residual=45595.45959472656
# 000709, method='Nelder-Mead', residual=45595.604248046875
# 000710, method='Nelder-Mead', residual=45595.51208496094
# 000711, method='Nelder-Mead', residual=45595.45788574219
# 000712, method='Nelder-Mead', residual=45595.471435546875
# 000713, method='Nelder-Mead', residual=45595.45202636719
# 000714, method='Nelder-Mead', residual=45595.479736328125
# 000715, method='Nelder-Mead', residual=45595.47741699219
# 000716, method='Nelder-Mead', residual=45595.5078125
# 000717, method='Nelder-Mead', residual=45595.552978515625
# 000718, method='Nelder-Mead', residual=45595.418701171875
# 000719, method='Nelder-Mead', residual=45595.41064453125
# 000720, method='Nelder-Mead', residual=45595.453125
# 000721, method='Nelder-Mead', residual=45595.51306152344
# 000722, method='Nelder-Mead', residual=45595.420166015625
# 000723, method='Nelder-Mead', residual=45595.435546875
# 000724, method='Nelder-Mead', residual=45595.390625
# 000725, method='Nelder-Mead', residual=45595.4326171875
# 000726, method='Nelder-Mead', residual=45595.376708984375
# 000727, method='Nelder-Mead', residual=45595.39978027344
# 000728, method='Nelder-Mead', residual=45595.44934082031
# 000729, method='Nelder-Mead', residual=45595.37353515625
# 000730, method='Nelder-Mead', residual=45595.40783691406
# 000731, method='Nelder-Mead', residual=45595.438720703125
# 000732, method='Nelder-Mead', residual=45595.36242675781
# 000733, method='Nelder-Mead', residual=45595.41076660156
# 000734, method='Nelder-Mead', residual=45595.4072265625
# 000735, method='Nelder-Mead', residual=45595.395751953125
# 000736, method='Nelder-Mead', residual=45595.39685058594
# 000737, method='Nelder-Mead', residual=45595.35461425781
# 000738, method='Nelder-Mead', residual=45595.41296386719
# 000739, method='Nelder-Mead', residual=45595.341796875
# 000740, method='Nelder-Mead', residual=45595.41491699219
# 000741, method='Nelder-Mead', residual=45595.32824707031
# 000742, method='Nelder-Mead', residual=45595.37292480469
# 000743, method='Nelder-Mead', residual=45595.353759765625
# 000744, method='Nelder-Mead', residual=45595.39794921875
# 000745, method='Nelder-Mead', residual=45595.35412597656
# 000746, method='Nelder-Mead', residual=45595.35546875
# 000747, method='Nelder-Mead', residual=45595.29650878906
# 000748, method='Nelder-Mead', residual=45595.32568359375
# 000749, method='Nelder-Mead', residual=45595.31359863281
# 000750, method='Nelder-Mead', residual=45595.40100097656
# 000751, method='Nelder-Mead', residual=45595.3359375
# 000752, method='Nelder-Mead', residual=45595.375
# 000753, method='Nelder-Mead', residual=45595.32958984375
# 000754, method='Nelder-Mead', residual=45595.350341796875
# 000755, method='Nelder-Mead', residual=45595.3203125
# 000756, method='Nelder-Mead', residual=45595.34851074219
# 000757, method='Nelder-Mead', residual=45595.319580078125
# 000758, method='Nelder-Mead', residual=45595.29602050781
# 000759, method='Nelder-Mead', residual=45595.36047363281
# 000760, method='Nelder-Mead', residual=45595.32629394531
# 000761, method='Nelder-Mead', residual=45595.27587890625
# 000762, method='Nelder-Mead', residual=45595.317138671875
# 000763, method='Nelder-Mead', residual=45595.325927734375
# 000764, method='Nelder-Mead', residual=45595.30139160156
# 000765, method='Nelder-Mead', residual=45595.330078125
# 000766, method='Nelder-Mead', residual=45595.330322265625
# 000767, method='Nelder-Mead', residual=45595.284912109375
# 000768, method='Nelder-Mead', residual=45595.28173828125
# 000769, method='Nelder-Mead', residual=45595.31384277344
# 000770, method='Nelder-Mead', residual=45595.31018066406
# 000771, method='Nelder-Mead', residual=45595.283935546875
# 000772, method='Nelder-Mead', residual=45595.22302246094
# 000773, method='Nelder-Mead', residual=45595.2294921875
# 000774, method='Nelder-Mead', residual=45595.29675292969
# 000775, method='Nelder-Mead', residual=45595.30847167969
# 000776, method='Nelder-Mead', residual=45595.27795410156
# 000777, method='Nelder-Mead', residual=45595.28088378906
# 000778, method='Nelder-Mead', residual=45595.253662109375
# 000779, method='Nelder-Mead', residual=45595.28381347656
# 000780, method='Nelder-Mead', residual=45595.27258300781
# 000781, method='Nelder-Mead', residual=45595.27404785156
# 000782, method='Nelder-Mead', residual=45595.296142578125
# 000783, method='Nelder-Mead', residual=45595.32861328125
# 000784, method='Nelder-Mead', residual=45595.25109863281
# 000785, method='Nelder-Mead', residual=45595.22473144531
# 000786, method='Nelder-Mead', residual=45595.29333496094
# 000787, method='Nelder-Mead', residual=45595.22668457031
# 000788, method='Nelder-Mead', residual=45595.28698730469
# 000789, method='Nelder-Mead', residual=45595.247314453125
# 000790, method='Nelder-Mead', residual=45595.2197265625
# 000791, method='Nelder-Mead', residual=45595.26281738281
# 000792, method='Nelder-Mead', residual=45595.25769042969
# 000793, method='Nelder-Mead', residual=45595.30847167969
# 000794, method='Nelder-Mead', residual=45595.23571777344
# 000795, method='Nelder-Mead', residual=45595.24645996094
# 000796, method='Nelder-Mead', residual=45595.28186035156
# 000797, method='Nelder-Mead', residual=45595.235595703125
# 000798, method='Nelder-Mead', residual=45595.22265625
# 000799, method='Nelder-Mead', residual=45595.229248046875
# 000800, method='Nelder-Mead', residual=45595.24841308594
# 000801, method='Nelder-Mead', residual=45595.24914550781
# 000802, method='Nelder-Mead', residual=45595.29748535156
# 000803, method='Nelder-Mead', residual=45595.216064453125
# 000804, method='Nelder-Mead', residual=45595.22998046875
# 000805, method='Nelder-Mead', residual=45595.17883300781
# 000806, method='Nelder-Mead', residual=45595.16491699219
# 000807, method='Nelder-Mead', residual=45595.28210449219
# 000808, method='Nelder-Mead', residual=45595.216796875
# 000809, method='Nelder-Mead', residual=45595.237548828125
# 000810, method='Nelder-Mead', residual=45595.20446777344
# 000811, method='Nelder-Mead', residual=45595.213134765625
# 000812, method='Nelder-Mead', residual=45595.23083496094
# 000813, method='Nelder-Mead', residual=45595.18200683594
# 000814, method='Nelder-Mead', residual=45595.169921875
# 000815, method='Nelder-Mead', residual=45595.21984863281
# 000816, method='Nelder-Mead', residual=45595.226806640625
# 000817, method='Nelder-Mead', residual=45595.24792480469
# 000818, method='Nelder-Mead', residual=45595.193359375
# 000819, method='Nelder-Mead', residual=45595.23059082031
# 000820, method='Nelder-Mead', residual=45595.19323730469
# 000821, method='Nelder-Mead', residual=45595.20080566406
# 000822, method='Nelder-Mead', residual=45595.17565917969
# 000823, method='Nelder-Mead', residual=45595.16357421875
# 000824, method='Nelder-Mead', residual=45595.18713378906
# 000825, method='Nelder-Mead', residual=45595.189208984375
# 000826, method='Nelder-Mead', residual=45595.20275878906
# 000827, method='Nelder-Mead', residual=45595.161376953125
# 000828, method='Nelder-Mead', residual=45595.18469238281
# 000829, method='Nelder-Mead', residual=45595.139404296875
# ...
# 001304, method='Nelder-Mead', residual=45589.99853515625
# 001305, method='Nelder-Mead', residual=45589.99694824219
# 001306, method='Nelder-Mead', residual=45589.993896484375
# 001307, method='Nelder-Mead', residual=45589.99853515625
# 001308, method='Nelder-Mead', residual=45589.99206542969
# 001309, method='Nelder-Mead', residual=45589.99694824219
# 001310, method='Nelder-Mead', residual=45589.9970703125
# 001311, method='Nelder-Mead', residual=45589.9970703125
# 001312, method='Nelder-Mead', residual=45589.99768066406
# 001313, method='Nelder-Mead', residual=45589.9990234375
# 001314, method='Nelder-Mead', residual=45589.996337890625
# 001315, method='Nelder-Mead', residual=45589.9990234375
# 001316, method='Nelder-Mead', residual=45589.99572753906
# 001317, method='Nelder-Mead', residual=45589.998046875
# 001318, method='Nelder-Mead', residual=45589.99670410156
# 001319, method='Nelder-Mead', residual=45589.99792480469
# 001320, method='Nelder-Mead', residual=45589.99426269531
# 001321, method='Nelder-Mead', residual=45589.99548339844
# 001322, method='Nelder-Mead', residual=45589.996337890625
# 001323, method='Nelder-Mead', residual=45589.99645996094
# 001324, method='Nelder-Mead', residual=45589.995849609375
# 001325, method='Nelder-Mead', residual=45589.99450683594
# 001326, method='Nelder-Mead', residual=45589.995849609375
# 001327, method='Nelder-Mead', residual=45589.994873046875
# 001328, method='Nelder-Mead', residual=45589.99523925781
# 001329, method='Nelder-Mead', residual=45589.999755859375
# 001330, method='Nelder-Mead', residual=45589.9951171875
# 001331, method='Nelder-Mead', residual=45589.995849609375
# 001332, method='Nelder-Mead', residual=45589.99353027344
# 001333, method='Nelder-Mead', residual=45589.99597167969
# 001334, method='Nelder-Mead', residual=45589.994140625
# 001335, method='Nelder-Mead', residual=45589.9951171875
# 001336, method='Nelder-Mead', residual=45589.99462890625
# 001337, method='Nelder-Mead', residual=45589.99450683594
# 001338, method='Nelder-Mead', residual=45589.99267578125
# 001339, method='Nelder-Mead', residual=45589.99304199219
# 001340, method='Nelder-Mead', residual=45589.995361328125
# 001341, method='Nelder-Mead', residual=45589.99304199219
# 001342, method='Nelder-Mead', residual=45589.993896484375
# 001343, method='Nelder-Mead', residual=45589.99609375
# 001344, method='Nelder-Mead', residual=45589.995361328125
# 001345, method='Nelder-Mead', residual=45589.995361328125
# 001346, method='Nelder-Mead', residual=45589.99548339844
# 001347, method='Nelder-Mead', residual=45589.9931640625
# 001348, method='Nelder-Mead', residual=45589.994140625
# 001349, method='Nelder-Mead', residual=45589.99365234375
# 001350, method='Nelder-Mead', residual=45589.993408203125
# 001351, method='Nelder-Mead', residual=45589.99450683594
# 001352, method='Nelder-Mead', residual=45589.99645996094
# 001353, method='Nelder-Mead', residual=45589.99560546875
# 001354, method='Nelder-Mead', residual=45589.99304199219
# 001355, method='Nelder-Mead', residual=45589.99658203125
# 001356, method='Nelder-Mead', residual=45589.995849609375
# 001357, method='Nelder-Mead', residual=45589.99475097656
# 001358, method='Nelder-Mead', residual=45589.995361328125
# 001359, method='Nelder-Mead', residual=45589.99462890625
# 001360, method='Nelder-Mead', residual=45589.99475097656
# 001361, method='Nelder-Mead', residual=45589.992431640625
# 001362, method='Nelder-Mead', residual=45589.993408203125
# 001363, method='Nelder-Mead', residual=45589.993896484375
# 001364, method='Nelder-Mead', residual=45589.99792480469
# 001365, method='Nelder-Mead', residual=45589.9970703125
# 001366, method='Nelder-Mead', residual=45589.99365234375
# 001367, method='Nelder-Mead', residual=45589.99353027344
# 001368, method='Nelder-Mead', residual=45589.995361328125
# 001369, method='Nelder-Mead', residual=45589.99401855469
# 001370, method='Nelder-Mead', residual=45589.99353027344
# 001371, method='Nelder-Mead', residual=45589.99609375
# 001372, method='Nelder-Mead', residual=45589.99377441406
# 001373, method='Nelder-Mead', residual=45589.99523925781
# 001374, method='Nelder-Mead', residual=45589.99499511719
# 001375, method='Nelder-Mead', residual=45589.994384765625
# 001376, method='Nelder-Mead', residual=45589.99475097656
# 001377, method='Nelder-Mead', residual=45589.994384765625
# 001378, method='Nelder-Mead', residual=45589.99462890625
# 001379, method='Nelder-Mead', residual=45589.99609375
# 001380, method='Nelder-Mead', residual=45589.9951171875
# 001381, method='Nelder-Mead', residual=45589.9931640625
# 001382, method='Nelder-Mead', residual=45589.9931640625
# 001383, method='Nelder-Mead', residual=45589.99645996094
# 001384, method='Nelder-Mead', residual=45589.99426269531
# 001385, method='Nelder-Mead', residual=45589.99353027344
# 001386, method='Nelder-Mead', residual=45589.9931640625
# 001387, method='Nelder-Mead', residual=45589.99462890625
# 001388, method='Nelder-Mead', residual=45589.99450683594
# 001389, method='Nelder-Mead', residual=45589.99182128906
# 001390, method='Nelder-Mead', residual=45589.995361328125
# 001391, method='Nelder-Mead', residual=45589.99450683594
# 001392, method='Nelder-Mead', residual=45589.99426269531
# 001393, method='Nelder-Mead', residual=45589.99353027344
# 001394, method='Nelder-Mead', residual=45589.99450683594
# 001395, method='Nelder-Mead', residual=45589.9931640625
# 001396, method='Nelder-Mead', residual=45589.99450683594
# 001397, method='Nelder-Mead', residual=45589.99353027344
# 001398, method='Nelder-Mead', residual=45589.99365234375
# 001399, method='Nelder-Mead', residual=45589.99267578125
# 001400, method='Nelder-Mead', residual=45589.992431640625
# 001401, method='Nelder-Mead', residual=45589.99621582031
# 001402, method='Nelder-Mead', residual=45589.993896484375
# 001403, method='Nelder-Mead', residual=45589.99304199219
# 001404, method='Nelder-Mead', residual=45589.994873046875
# 001405, method='Nelder-Mead', residual=45589.99328613281
# 001406, method='Nelder-Mead', residual=45589.995849609375
# 001407, method='Nelder-Mead', residual=45589.993896484375
# 001408, method='Nelder-Mead', residual=45589.9951171875
# 001409, method='Nelder-Mead', residual=45589.99304199219
# 001410, method='Nelder-Mead', residual=45589.99475097656
# 001411, method='Nelder-Mead', residual=45589.99255371094
# 001412, method='Nelder-Mead', residual=45589.99304199219
# 001413, method='Nelder-Mead', residual=45589.99304199219
# 001414, method='Nelder-Mead', residual=45589.99267578125
# 001415, method='Nelder-Mead', residual=45589.99255371094
# 001416, method='Nelder-Mead', residual=45589.99426269531
# 001417, method='Nelder-Mead', residual=45589.99462890625
# 001418, method='Nelder-Mead', residual=45589.995361328125
# 001419, method='Nelder-Mead', residual=45589.992431640625
# 001420, method='Nelder-Mead', residual=45589.99206542969
# 001421, method='Nelder-Mead', residual=45589.99377441406
# 001422, method='Nelder-Mead', residual=45589.99401855469
# 001423, method='Nelder-Mead', residual=45589.99462890625
# 001424, method='Nelder-Mead', residual=45589.99365234375
# 001425, method='Nelder-Mead', residual=45589.99462890625
# 001426, method='Nelder-Mead', residual=45589.99169921875
# 001427, method='Nelder-Mead', residual=45589.995361328125
# 001428, method='Nelder-Mead', residual=45589.99304199219
# 001429, method='Nelder-Mead', residual=45589.99426269531
# 001430, method='Nelder-Mead', residual=45589.99377441406
# 001431, method='Nelder-Mead', residual=45589.99328613281
# 001432, method='Nelder-Mead', residual=45589.99499511719
# 001433, method='Nelder-Mead', residual=45589.99304199219
# 001434, method='Nelder-Mead', residual=45589.9951171875
# 001435, method='Nelder-Mead', residual=45589.99609375
# 001436, method='Nelder-Mead', residual=45589.99462890625
# 001437, method='Nelder-Mead', residual=45589.995849609375
# 001438, method='Nelder-Mead', residual=45589.992919921875
# 001439, method='Nelder-Mead', residual=45589.994140625
# 001440, method='Nelder-Mead', residual=45589.99304199219
# 001441, method='Nelder-Mead', residual=45589.9921875
# 001442, method='Nelder-Mead', residual=45589.992919921875
# 001443, method='Nelder-Mead', residual=45589.99353027344
# 001444, method='Nelder-Mead', residual=45589.99353027344
# 001445, method='Nelder-Mead', residual=45589.99462890625
# 001446, method='Nelder-Mead', residual=45589.994140625
# 001447, method='Nelder-Mead', residual=45589.99499511719
# 001448, method='Nelder-Mead', residual=45589.995361328125
# 001449, method='Nelder-Mead', residual=45589.99353027344
# 001450, method='Nelder-Mead', residual=45589.9931640625
# 001451, method='Nelder-Mead', residual=45589.99572753906
# 001452, method='Nelder-Mead', residual=45589.99719238281
# 001453, method='Nelder-Mead', residual=45589.99377441406
# 001454, method='Nelder-Mead', residual=45589.993408203125
# 001455, method='Nelder-Mead', residual=45589.99353027344
# 001456, method='Nelder-Mead', residual=45589.99353027344
# 001457, method='Nelder-Mead', residual=45589.992919921875
# 001458, method='Nelder-Mead', residual=45589.99523925781
# 001459, method='Nelder-Mead', residual=45589.995361328125
# 001460, method='Nelder-Mead', residual=45589.99523925781
# 001461, method='Nelder-Mead', residual=45589.99365234375
# 001462, method='Nelder-Mead', residual=45589.99365234375
# 001463, method='Nelder-Mead', residual=45589.9912109375
# 001464, method='Nelder-Mead', residual=45589.99304199219
# 001465, method='Nelder-Mead', residual=45589.99267578125
# 001466, method='Nelder-Mead', residual=45589.99255371094
# 001467, method='Nelder-Mead', residual=45589.994384765625
# 001468, method='Nelder-Mead', residual=45589.99621582031
# 001469, method='Nelder-Mead', residual=45589.992431640625
# 001470, method='Nelder-Mead', residual=45589.99475097656
# 001471, method='Nelder-Mead', residual=45589.99255371094
# 001472, method='Nelder-Mead', residual=45589.99597167969
# 001473, method='Nelder-Mead', residual=45589.99365234375
# 001474, method='Nelder-Mead', residual=45589.99499511719
# 001475, method='Nelder-Mead', residual=45589.99475097656
# 001476, method='Nelder-Mead', residual=45589.99255371094
# 001477, method='Nelder-Mead', residual=45589.99426269531
# 001478, method='Nelder-Mead', residual=45589.99377441406
# 001479, method='Nelder-Mead', residual=45589.99462890625
# 001480, method='Nelder-Mead', residual=45589.99426269531
# 001481, method='Nelder-Mead', residual=45589.994140625
# 001482, method='Nelder-Mead', residual=45589.99450683594
# 001483, method='Nelder-Mead', residual=45589.991943359375
# 001484, method='Nelder-Mead', residual=45589.99255371094
# 001485, method='Nelder-Mead', residual=45589.9931640625
# 001486, method='Nelder-Mead', residual=45589.991943359375
# 001487, method='Nelder-Mead', residual=45589.994384765625
# 001488, method='Nelder-Mead', residual=45589.993896484375
# 001489, method='Nelder-Mead', residual=45589.994140625
# 001490, method='Nelder-Mead', residual=45589.99450683594
# 001491, method='Nelder-Mead', residual=45589.99450683594
# 001492, method='Nelder-Mead', residual=45589.99304199219
# 001493, method='Nelder-Mead', residual=45589.99304199219
# 001494, method='Nelder-Mead', residual=45589.99462890625
# 001495, method='Nelder-Mead', residual=45589.995849609375
# 001496, method='Nelder-Mead', residual=45589.994873046875
# 001497, method='Nelder-Mead', residual=45589.99597167969
# 001498, method='Nelder-Mead', residual=45589.995849609375
# 001499, method='Nelder-Mead', residual=45589.995849609375
# 001500, method='Nelder-Mead', residual=45589.995849609375
# 001501, method='Nelder-Mead', residual=45589.99377441406
# 001502, method='Nelder-Mead', residual=45589.995849609375
# 001503, method='Nelder-Mead', residual=45589.99304199219
# 001504, method='Nelder-Mead', residual=45589.99328613281
# 001505, method='Nelder-Mead', residual=45589.99462890625
# 001506, method='Nelder-Mead', residual=45589.99462890625
# 001507, method='Nelder-Mead', residual=45589.995849609375
# 001508, method='Nelder-Mead', residual=45589.99304199219
# 001509, method='Nelder-Mead', residual=45589.9912109375
# 001510, method='Nelder-Mead', residual=45589.99462890625
# 001511, method='Nelder-Mead', residual=45589.99462890625
# 001512, method='Nelder-Mead', residual=45589.99475097656
# 001513, method='Nelder-Mead', residual=45589.99462890625
# 001514, method='Nelder-Mead', residual=45589.99462890625
# 001515, method='Nelder-Mead', residual=45589.99462890625
# 001516, method='Nelder-Mead', residual=45589.99462890625
# 001517, method='Nelder-Mead', residual=45589.99304199219
# 001518, method='Nelder-Mead', residual=45589.995849609375
# 001519, method='Nelder-Mead', residual=45589.99462890625
# 001520, method='Nelder-Mead', residual=45589.9912109375
# 001521, method='Nelder-Mead', residual=45589.99475097656
# 001522, method='Nelder-Mead', residual=45589.99475097656
# 001523, method='Nelder-Mead', residual=45589.99304199219
# 001524, method='Nelder-Mead', residual=45589.995849609375
# 001525, method='Nelder-Mead', residual=45589.9912109375
# 001526, method='Nelder-Mead', residual=45589.99426269531
# 001527, method='Nelder-Mead', residual=45589.99255371094
# 001528, method='Nelder-Mead', residual=45589.99462890625
# 001529, method='Nelder-Mead', residual=45589.99426269531
# 001530, method='Nelder-Mead', residual=45589.99450683594
# 001531, method='Nelder-Mead', residual=45589.99572753906
# 001532, method='Nelder-Mead', residual=45589.99462890625
# 001533, method='Nelder-Mead', residual=45589.99475097656
# 001534, method='Nelder-Mead', residual=45589.9912109375
# 001535, method='Nelder-Mead', residual=45589.992431640625
# 001536, method='Nelder-Mead', residual=45589.99462890625
# 001537, method='Nelder-Mead', residual=45589.9912109375
# 001538, method='Nelder-Mead', residual=45589.9912109375
# 001539, method='Nelder-Mead', residual=45589.99157714844
# 001540, method='Nelder-Mead', residual=45589.9912109375
# 001541, method='Nelder-Mead', residual=45589.99462890625
# 001542, method='Nelder-Mead', residual=45589.9912109375
# 001543, method='Nelder-Mead', residual=45589.9912109375
# 001544, method='Nelder-Mead', residual=45589.99462890625
# 001545, method='Nelder-Mead', residual=45589.9912109375
# 001546, method='Nelder-Mead', residual=45589.9912109375
# 001547, method='Nelder-Mead', residual=45589.9912109375
# 001548, method='Nelder-Mead', residual=45589.99462890625
# 001549, method='Nelder-Mead', residual=45589.9912109375
# 001550, method='Nelder-Mead', residual=45589.9912109375
# 001551, method='Nelder-Mead', residual=45589.99462890625
# 001552, method='Nelder-Mead', residual=45589.9912109375
# 001553, method='Nelder-Mead', residual=45589.99462890625
# 001554, method='Nelder-Mead', residual=45589.9912109375
# 001555, method='Nelder-Mead', residual=45589.9912109375
# 001556, method='Nelder-Mead', residual=45589.9912109375
# 001557, method='Nelder-Mead', residual=45589.9912109375
# 001558, method='Nelder-Mead', residual=45589.9912109375
# 001559, method='Nelder-Mead', residual=45589.9912109375
# 001560, method='Nelder-Mead', residual=45589.9912109375
# 001561, method='Nelder-Mead', residual=45589.9912109375
# 001562, method='Nelder-Mead', residual=45589.9912109375
# 001563, method='Nelder-Mead', residual=45589.9912109375
# 001564, method='Nelder-Mead', residual=45589.9912109375
# 001565, method='Nelder-Mead', residual=45589.9912109375
# 001566, method='Nelder-Mead', residual=45589.9912109375
# 001567, method='Nelder-Mead', residual=45589.9912109375
# 001568, method='Nelder-Mead', residual=45589.9912109375
# 001569, method='Nelder-Mead', residual=45589.9912109375
# 001570, method='Nelder-Mead', residual=45589.9912109375
# 001571, method='Nelder-Mead', residual=45589.9912109375
# 001572, method='Nelder-Mead', residual=45589.9912109375
# 001573, method='Nelder-Mead', residual=45589.9912109375
# 001574, method='Nelder-Mead', residual=45589.9912109375
# 001575, method='Nelder-Mead', residual=45589.9912109375
# 001576, method='Nelder-Mead', residual=45589.9912109375
# 001577, method='Nelder-Mead', residual=45589.9912109375
# 001578, method='Nelder-Mead', residual=45589.9912109375
# 001579, method='Nelder-Mead', residual=45589.9912109375
# 001580, method='Nelder-Mead', residual=45589.9912109375
# 001581, method='Nelder-Mead', residual=45589.9912109375
# 001582, method='Nelder-Mead', residual=45589.9912109375
# 001583, method='Nelder-Mead', residual=45589.9912109375
# 001584, method='Nelder-Mead', residual=45589.9912109375
