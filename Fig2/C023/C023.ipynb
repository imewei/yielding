# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras


def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C023_Cys0_Exp2_Creep_XPCS_30Pa_02_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d

def fit_c2_polynomial(num_v=3, num_d=3, paras_fname=None):
    # read raw data
    c2_exp, t_length, phi_list, phi_length = read_data()

    x0 = np.array([
    1.724881362504279707e+02,
    -3.531338175982419170e-01,
    -1.256596948620673615e+01,
    2.459701729417504770e-02,
    -6.898908455816088470e-01,
    -3.558803589933785773e-04,
    -3.364448363463905523e-01,
    ])
    
    for method in (
                'Nelder-Mead',
                # 'Powell',
                # 'L-BFGS-B',
                # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
                # 'trust-ncg', 'trust-exact', 'trust-krylov'):
                ):
    # def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
        FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                                args=(phi_list, num_d, num_v, c2_exp, method),
                                 options={"maxiter": 1000000}, tol=0.00001,
                                method=method)

    FitParas = FitOutput['x']
    
    c2_fit = Homodyne1(FitParas, phi_list)
    shape = c2_fit.shape
    sol_list = []
    for n in range(shape[0]):
        sumy = np.sum(c2_fit[n])
        a = np.array([
            [np.sum(c2_fit[n] ** 2), sumy],
            [sumy, c2_fit[n].size]
        ])
        b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
        sol = np.linalg.solve(a, b)
        sol_list.append(sol)

    
    FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
    np.savetxt('/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/FitParas/C023_FitParas.txt', FitParas, delimiter=",")

def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    shape = c2_exp.shape
    residual = 0.0
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]


    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    :
        c2_fit = Homodyne1(paras, phi_list)
        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)

        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        # plt.imshow(c2_fit[0])
        # # plt.imshow(c2_exp[0])
        # plt.show()
    else:
        residual = np.inf
    
    
    return residual



def Homodyne1(x, phi_list):
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    g1_s = np.exp(-qValue**2 / 2 * abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    
    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (w * g1_s) ** 2

    return g2_all

def Homodyne2(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    D, v, phio, beta, c = separate_params(x, phi_length)
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    
    g1_s = np.exp(qValue**2 / 2 * -abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (w * g1_s)** 2
    return g2_all


def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    beta = x[num_d + num_v + 1: num_d + num_v + phi_length + 1]
    c = x[num_d + num_v + phi_length + 1: num_d + num_v + 2 * phi_length + 1]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]

    return D, v, phio, beta, c

# %%
dt = 0.1
qValue = 0.0054
gap = 2e6

DTYPE = np.float64
gindex = 0
fit_c2_polynomial()
# Out:
# c2_cache_1001_2000.npz
# (23, 999, 999) float64
# 000001, method='Nelder-Mead', residual=88438.84455168319
# 000002, method='Nelder-Mead', residual=88436.9596865138
# 000003, method='Nelder-Mead', residual=88441.51156945538
# 000004, method='Nelder-Mead', residual=88439.4436070225
# 000005, method='Nelder-Mead', residual=88360.94683057244
# 000006, method='Nelder-Mead', residual=88845.35001607648
# 000007, method='Nelder-Mead', residual=88464.54368852623
# 000008, method='Nelder-Mead', residual=88403.94576329073
# 000009, method='Nelder-Mead', residual=88281.86000078167
# 000010, method='Nelder-Mead', residual=88373.13390980948
# 000011, method='Nelder-Mead', residual=88323.99154809478
# 000012, method='Nelder-Mead', residual=88308.21299196576
# 000013, method='Nelder-Mead', residual=88285.92916165515
# 000014, method='Nelder-Mead', residual=88263.59968719652
# 000015, method='Nelder-Mead', residual=88242.61006553276
# 000016, method='Nelder-Mead', residual=88245.34358721899
# 000017, method='Nelder-Mead', residual=88313.59813621752
# 000018, method='Nelder-Mead', residual=88268.06226236322
# 000019, method='Nelder-Mead', residual=88295.65950842682
# 000020, method='Nelder-Mead', residual=88240.48403672669
# 000021, method='Nelder-Mead', residual=88276.73778796577
# 000022, method='Nelder-Mead', residual=88286.33784949976
# 000023, method='Nelder-Mead', residual=88277.45939829339
# 000024, method='Nelder-Mead', residual=88372.61368717645
# 000025, method='Nelder-Mead', residual=88250.42810371004
# 000026, method='Nelder-Mead', residual=88250.83548878187
# 000027, method='Nelder-Mead', residual=88198.75102120756
# 000028, method='Nelder-Mead', residual=88163.00301924911
# 000029, method='Nelder-Mead', residual=88291.1057552192
# 000030, method='Nelder-Mead', residual=88237.17969171525
# 000031, method='Nelder-Mead', residual=88207.62002510452
# 000032, method='Nelder-Mead', residual=88229.72965797808
# 000033, method='Nelder-Mead', residual=88215.37455729797
# 000034, method='Nelder-Mead', residual=88188.17792866298
# 000035, method='Nelder-Mead', residual=88199.79155741651
# 000036, method='Nelder-Mead', residual=88153.3927267737
# 000037, method='Nelder-Mead', residual=88114.8170913063
# 000038, method='Nelder-Mead', residual=88118.85483912248
# 000039, method='Nelder-Mead', residual=88098.32907505779
# 000040, method='Nelder-Mead', residual=88040.897009388
# 000041, method='Nelder-Mead', residual=88076.73110149524
# 000042, method='Nelder-Mead', residual=88027.09226898687
# 000043, method='Nelder-Mead', residual=87940.8576057345
# 000044, method='Nelder-Mead', residual=88046.86865600196
# 000045, method='Nelder-Mead', residual=87994.29793433094
# 000046, method='Nelder-Mead', residual=87923.61460604529
# 000047, method='Nelder-Mead', residual=87823.93996378896
# 000048, method='Nelder-Mead', residual=87933.87772735045
# 000049, method='Nelder-Mead', residual=87854.193210535
# 000050, method='Nelder-Mead', residual=87814.19837492966
# 000051, method='Nelder-Mead', residual=87715.81637029088
# 000052, method='Nelder-Mead', residual=87735.32738079439
# 000053, method='Nelder-Mead', residual=87687.23779273825
# 000054, method='Nelder-Mead', residual=87548.98331090447
# 000055, method='Nelder-Mead', residual=87579.62776973941
# 000056, method='Nelder-Mead', residual=87552.04689735589
# 000057, method='Nelder-Mead', residual=87436.67299291318
# 000058, method='Nelder-Mead', residual=87227.58616124852
# 000059, method='Nelder-Mead', residual=87329.00958077515
# 000060, method='Nelder-Mead', residual=87331.93423352938
# 000061, method='Nelder-Mead', residual=87220.00369529708
# 000062, method='Nelder-Mead', residual=87037.93425212525
# 000063, method='Nelder-Mead', residual=87039.27329051193
# 000064, method='Nelder-Mead', residual=87034.0813135051
# 000065, method='Nelder-Mead', residual=86861.14421847442
# 000066, method='Nelder-Mead', residual=86853.58256962137
# 000067, method='Nelder-Mead', residual=86624.59464493724
# 000068, method='Nelder-Mead', residual=86643.49872532932
# 000069, method='Nelder-Mead', residual=86609.21525781436
# 000070, method='Nelder-Mead', residual=86384.91739822397
# 000071, method='Nelder-Mead', residual=86517.91395881471
# 000072, method='Nelder-Mead', residual=86533.26449724987
# 000073, method='Nelder-Mead', residual=86469.67880053422
# 000074, method='Nelder-Mead', residual=86367.41943637142
# 000075, method='Nelder-Mead', residual=86545.37474389918
# 000076, method='Nelder-Mead', residual=86327.34505115377
# 000077, method='Nelder-Mead', residual=86470.64476638513
# 000078, method='Nelder-Mead', residual=86445.57639490205
# 000079, method='Nelder-Mead', residual=86485.2454490767
# 000080, method='Nelder-Mead', residual=86268.4250700853
# 000081, method='Nelder-Mead', residual=86235.1397510218
# 000082, method='Nelder-Mead', residual=86446.75590618639
# 000083, method='Nelder-Mead', residual=86276.24631751105
# 000084, method='Nelder-Mead', residual=86213.26399902081
# 000085, method='Nelder-Mead', residual=86230.72236116423
# 000086, method='Nelder-Mead', residual=86408.42017831067
# 000087, method='Nelder-Mead', residual=86282.01127875174
# 000088, method='Nelder-Mead', residual=86279.52073489282
# 000089, method='Nelder-Mead', residual=86437.67094226555
# 000090, method='Nelder-Mead', residual=86253.43137309991
# 000091, method='Nelder-Mead', residual=86143.77600077112
# 000092, method='Nelder-Mead', residual=86163.2634118999
# 000093, method='Nelder-Mead', residual=86153.5969813793
# 000094, method='Nelder-Mead', residual=86357.48548388612
# 000095, method='Nelder-Mead', residual=86188.67963540062
# 000096, method='Nelder-Mead', residual=86294.80191650167
# 000097, method='Nelder-Mead', residual=86198.78729154187
# 000098, method='Nelder-Mead', residual=86168.68946822909
# 000099, method='Nelder-Mead', residual=86210.3826677771
# 000100, method='Nelder-Mead', residual=86155.83823142922
# 000101, method='Nelder-Mead', residual=86159.72033889133
# 000102, method='Nelder-Mead', residual=86299.07673935477
# 000103, method='Nelder-Mead', residual=86145.29940740635
# 000104, method='Nelder-Mead', residual=86206.29069235732
# 000105, method='Nelder-Mead', residual=86151.99039920061
# 000106, method='Nelder-Mead', residual=86158.08749150674
# 000107, method='Nelder-Mead', residual=86212.88144717802
# 000108, method='Nelder-Mead', residual=86137.96955426088
# 000109, method='Nelder-Mead', residual=86182.17734626743
# 000110, method='Nelder-Mead', residual=86135.71630599485
# 000111, method='Nelder-Mead', residual=86195.27227620137
# 000112, method='Nelder-Mead', residual=86135.58549114937
# 000113, method='Nelder-Mead', residual=86149.94097012325
# 000114, method='Nelder-Mead', residual=86187.12475615363
# 000115, method='Nelder-Mead', residual=86134.09709795032
# 000116, method='Nelder-Mead', residual=86126.21692692711
# 000117, method='Nelder-Mead', residual=86132.54622608512
# 000118, method='Nelder-Mead', residual=86152.1264810127
# 000119, method='Nelder-Mead', residual=86135.0772622129
# 000120, method='Nelder-Mead', residual=86143.10689740331
# 000121, method='Nelder-Mead', residual=86129.55914073798
# 000122, method='Nelder-Mead', residual=86150.25051508463
# 000123, method='Nelder-Mead', residual=86130.665320835
# 000124, method='Nelder-Mead', residual=86135.63102150038
# 000125, method='Nelder-Mead', residual=86133.70887521582
# 000126, method='Nelder-Mead', residual=86147.49070589323
# 000127, method='Nelder-Mead', residual=86128.00981907304
# 000128, method='Nelder-Mead', residual=86121.72926413309
# 000129, method='Nelder-Mead', residual=86121.1561116435
# 000130, method='Nelder-Mead', residual=86137.40838657526
# 000131, method='Nelder-Mead', residual=86127.19207302811
# 000132, method='Nelder-Mead', residual=86127.40103088862
# 000133, method='Nelder-Mead', residual=86128.64151617985
# 000134, method='Nelder-Mead', residual=86120.02689879385
# 000135, method='Nelder-Mead', residual=86122.66127782426
# 000136, method='Nelder-Mead', residual=86122.92842465869
# 000137, method='Nelder-Mead', residual=86127.15766318481
# 000138, method='Nelder-Mead', residual=86116.57299693757
# 000139, method='Nelder-Mead', residual=86116.48222622741
# 000140, method='Nelder-Mead', residual=86121.31490690228
# 000141, method='Nelder-Mead', residual=86109.59203882136
# 000142, method='Nelder-Mead', residual=86104.73471612415
# 000143, method='Nelder-Mead', residual=86116.50878544571
# 000144, method='Nelder-Mead', residual=86103.50089197929
# 000145, method='Nelder-Mead', residual=86100.66361539482
# 000146, method='Nelder-Mead', residual=86095.86474787917
# 000147, method='Nelder-Mead', residual=86087.08105270028
# 000148, method='Nelder-Mead', residual=86091.17775717509
# 000149, method='Nelder-Mead', residual=86088.07154639035
# 000150, method='Nelder-Mead', residual=86074.20253386015
# 000151, method='Nelder-Mead', residual=86061.38771559202
# 000152, method='Nelder-Mead', residual=86071.53380177135
# 000153, method='Nelder-Mead', residual=86064.30750618104
# 000154, method='Nelder-Mead', residual=86049.88591336171
# 000155, method='Nelder-Mead', residual=86038.7433981977
# 000156, method='Nelder-Mead', residual=86053.41948582097
# 000157, method='Nelder-Mead', residual=86033.80767633066
# 000158, method='Nelder-Mead', residual=86027.99511845618
# 000159, method='Nelder-Mead', residual=86027.20726616228
# 000160, method='Nelder-Mead', residual=86048.74898506996
# 000161, method='Nelder-Mead', residual=85999.66467982475
# 000162, method='Nelder-Mead', residual=85985.11571554714
# 000163, method='Nelder-Mead', residual=86011.3032355211
# 000164, method='Nelder-Mead', residual=86033.06304879455
# 000165, method='Nelder-Mead', residual=85997.27786147618
# 000166, method='Nelder-Mead', residual=86270.81721576932
# 000167, method='Nelder-Mead', residual=86011.41481586755
# 000168, method='Nelder-Mead', residual=85978.42769175209
# 000169, method='Nelder-Mead', residual=85970.08925397368
# 000170, method='Nelder-Mead', residual=85976.97166993264
# 000171, method='Nelder-Mead', residual=85951.49525988825
# 000172, method='Nelder-Mead', residual=85931.29806162478
# 000173, method='Nelder-Mead', residual=85920.66332790855
# 000174, method='Nelder-Mead', residual=85890.04003312027
# 000175, method='Nelder-Mead', residual=86053.57661527184
# 000176, method='Nelder-Mead', residual=85970.03557857599
# 000177, method='Nelder-Mead', residual=85893.88919390099
# 000178, method='Nelder-Mead', residual=85906.37706417954
# 000179, method='Nelder-Mead', residual=85863.77653610581
# 000180, method='Nelder-Mead', residual=85817.6279439317
# 000181, method='Nelder-Mead', residual=85878.72272429493
# 000182, method='Nelder-Mead', residual=85842.57706315578
# 000183, method='Nelder-Mead', residual=85830.35331398966
# 000184, method='Nelder-Mead', residual=85779.81734431218
# 000185, method='Nelder-Mead', residual=85746.38517645479
# 000186, method='Nelder-Mead', residual=85795.44685397581
# 000187, method='Nelder-Mead', residual=85766.18526720464
# 000188, method='Nelder-Mead', residual=85712.77163999811
# 000189, method='Nelder-Mead', residual=85704.8150946885
# 000190, method='Nelder-Mead', residual=85782.30537915675
# 000191, method='Nelder-Mead', residual=85706.35484633093
# 000192, method='Nelder-Mead', residual=85765.33705927378
# 000193, method='Nelder-Mead', residual=85712.96839844128
# 000194, method='Nelder-Mead', residual=85680.15211860246
# 000195, method='Nelder-Mead', residual=85691.92504576556
# 000196, method='Nelder-Mead', residual=85723.94789886684
# 000197, method='Nelder-Mead', residual=85772.86895906953
# 000198, method='Nelder-Mead', residual=85705.22571599997
# 000199, method='Nelder-Mead', residual=85669.14990836657
# 000200, method='Nelder-Mead', residual=85716.45340347981
# 000201, method='Nelder-Mead', residual=85691.63749416651
# 000202, method='Nelder-Mead', residual=85679.4562000903
# 000203, method='Nelder-Mead', residual=85659.48320046059
# 000204, method='Nelder-Mead', residual=85689.50698995625
# 000205, method='Nelder-Mead', residual=85676.93076577362
# 000206, method='Nelder-Mead', residual=85677.0340429907
# 000207, method='Nelder-Mead', residual=85697.8398671291
# 000208, method='Nelder-Mead', residual=85674.44539385989
# 000209, method='Nelder-Mead', residual=85690.88987838381
# 000210, method='Nelder-Mead', residual=85671.88450905246
# 000211, method='Nelder-Mead', residual=85688.32867189357
# 000212, method='Nelder-Mead', residual=85668.69354255583
# 000213, method='Nelder-Mead', residual=85662.91957791339
# 000214, method='Nelder-Mead', residual=85669.47826237837
# 000215, method='Nelder-Mead', residual=85696.19439451591
# 000216, method='Nelder-Mead', residual=85664.89247080382
# 000217, method='Nelder-Mead', residual=85664.97062628707
# 000218, method='Nelder-Mead', residual=85669.30103031744
# 000219, method='Nelder-Mead', residual=85665.19613013472
# 000220, method='Nelder-Mead', residual=85670.26590998724
# 000221, method='Nelder-Mead', residual=85664.38332879062
# 000222, method='Nelder-Mead', residual=85658.6636479864
# 000223, method='Nelder-Mead', residual=85659.14776513238
# 000224, method='Nelder-Mead', residual=85655.84084988493
# 000225, method='Nelder-Mead', residual=85653.59109669362
# 000226, method='Nelder-Mead', residual=85657.28380239771
# 000227, method='Nelder-Mead', residual=85654.66079743666
# 000228, method='Nelder-Mead', residual=85659.45852662483
# 000229, method='Nelder-Mead', residual=85651.40150145662
# 000230, method='Nelder-Mead', residual=85650.64245560928
# 000231, method='Nelder-Mead', residual=85650.69381872794
# 000232, method='Nelder-Mead', residual=85656.96556126914
# 000233, method='Nelder-Mead', residual=85648.01894426398
# 000234, method='Nelder-Mead', residual=85649.77067681597
# 000235, method='Nelder-Mead', residual=85649.07734272309
# 000236, method='Nelder-Mead', residual=85648.74210309418
# 000237, method='Nelder-Mead', residual=85648.91087858
# 000238, method='Nelder-Mead', residual=85642.30318530608
# 000239, method='Nelder-Mead', residual=85638.99899949353
# 000240, method='Nelder-Mead', residual=85648.5125937245
# 000241, method='Nelder-Mead', residual=85639.82374291368
# 000242, method='Nelder-Mead', residual=85643.72467584009
# 000243, method='Nelder-Mead', residual=85644.94245245462
# 000244, method='Nelder-Mead', residual=85639.05473363814
# 000245, method='Nelder-Mead', residual=85635.54395734782
# 000246, method='Nelder-Mead', residual=85634.38661521989
# 000247, method='Nelder-Mead', residual=85634.15364670467
# 000248, method='Nelder-Mead', residual=85634.82385629219
# 000249, method='Nelder-Mead', residual=85639.20591116318
# 000250, method='Nelder-Mead', residual=85634.97717843519
# 000251, method='Nelder-Mead', residual=85631.88136708102
# 000252, method='Nelder-Mead', residual=85642.04468162327
# 000253, method='Nelder-Mead', residual=85627.39912221002
# 000254, method='Nelder-Mead', residual=85625.08235107706
# 000255, method='Nelder-Mead', residual=85645.47092333666
# 000256, method='Nelder-Mead', residual=85632.7089516724
# 000257, method='Nelder-Mead', residual=85626.59659501258
# 000258, method='Nelder-Mead', residual=85629.4241115243
# 000259, method='Nelder-Mead', residual=85633.35354110527
# 000260, method='Nelder-Mead', residual=85622.34111965794
# 000261, method='Nelder-Mead', residual=85623.24216922467
# 000262, method='Nelder-Mead', residual=85629.45086361188
# 000263, method='Nelder-Mead', residual=85636.09024800581
# 000264, method='Nelder-Mead', residual=85626.88730164745
# 000265, method='Nelder-Mead', residual=85641.40864898666
# 000266, method='Nelder-Mead', residual=85626.80438899185
# 000267, method='Nelder-Mead', residual=85622.70047843669
# 000268, method='Nelder-Mead', residual=85628.03010476846
# 000269, method='Nelder-Mead', residual=85626.02645378301
# 000270, method='Nelder-Mead', residual=85627.82649879646
# 000271, method='Nelder-Mead', residual=85624.36758786511
# 000272, method='Nelder-Mead', residual=85626.82743676961
# 000273, method='Nelder-Mead', residual=85624.23653017696
# 000274, method='Nelder-Mead', residual=85621.97928818622
# 000275, method='Nelder-Mead', residual=85624.62779369093
# 000276, method='Nelder-Mead', residual=85629.0059764571
# 000277, method='Nelder-Mead', residual=85623.61692584917
# 000278, method='Nelder-Mead', residual=85627.83034693063
# 000279, method='Nelder-Mead', residual=85623.59291558107
# 000280, method='Nelder-Mead', residual=85620.39998751064
# 000281, method='Nelder-Mead', residual=85618.9847113066
# 000282, method='Nelder-Mead', residual=85619.93379187473
# 000283, method='Nelder-Mead', residual=85619.74365453672
# 000284, method='Nelder-Mead', residual=85620.28213323795
# 000285, method='Nelder-Mead', residual=85618.63937405171
# 000286, method='Nelder-Mead', residual=85619.1017351368
# 000287, method='Nelder-Mead', residual=85619.00077253231
# 000288, method='Nelder-Mead', residual=85617.75410462637
# 000289, method='Nelder-Mead', residual=85618.74874500721
# 000290, method='Nelder-Mead', residual=85618.95972733885
# 000291, method='Nelder-Mead', residual=85618.30612493903
# 000292, method='Nelder-Mead', residual=85616.7133939646
# 000293, method='Nelder-Mead', residual=85616.30442115777
# 000294, method='Nelder-Mead', residual=85617.37333909869
# 000295, method='Nelder-Mead', residual=85617.36156054502
# 000296, method='Nelder-Mead', residual=85616.81861065984
# 000297, method='Nelder-Mead', residual=85618.48281463256
# 000298, method='Nelder-Mead', residual=85616.64997696313
# 000299, method='Nelder-Mead', residual=85619.6868426375
# 000300, method='Nelder-Mead', residual=85616.66686321556
# 000301, method='Nelder-Mead', residual=85621.843281792
# 000302, method='Nelder-Mead', residual=85616.71141803717
# 000303, method='Nelder-Mead', residual=85616.92046436029
# 000304, method='Nelder-Mead', residual=85618.1282542969
# 000305, method='Nelder-Mead', residual=85616.50166810026
# 000306, method='Nelder-Mead', residual=85616.47282854537
# 000307, method='Nelder-Mead', residual=85616.84429530082
# 000308, method='Nelder-Mead', residual=85616.32310266634
# 000309, method='Nelder-Mead', residual=85616.39056999072
# 000310, method='Nelder-Mead', residual=85616.61745928784
# 000311, method='Nelder-Mead', residual=85617.75557837714
# 000312, method='Nelder-Mead', residual=85616.12996555335
# 000313, method='Nelder-Mead', residual=85616.56080480767
# 000314, method='Nelder-Mead', residual=85616.97846451367
# 000315, method='Nelder-Mead', residual=85616.15830192562
# 000316, method='Nelder-Mead', residual=85616.58164976403
# 000317, method='Nelder-Mead', residual=85616.20330768217
# 000318, method='Nelder-Mead', residual=85615.95311437116
# 000319, method='Nelder-Mead', residual=85616.24992291212
# 000320, method='Nelder-Mead', residual=85617.34659292165
# 000321, method='Nelder-Mead', residual=85616.02939864859
# 000322, method='Nelder-Mead', residual=85616.74595222589
# 000323, method='Nelder-Mead', residual=85616.09740537014
# 000324, method='Nelder-Mead', residual=85615.94148565171
# 000325, method='Nelder-Mead', residual=85616.09844941308
# 000326, method='Nelder-Mead', residual=85616.06395993782
# 000327, method='Nelder-Mead', residual=85615.89457880615
# 000328, method='Nelder-Mead', residual=85616.06620333898
# 000329, method='Nelder-Mead', residual=85616.00154540369
# 000330, method='Nelder-Mead', residual=85616.24995811784
# 000331, method='Nelder-Mead', residual=85615.9496935324
# 000332, method='Nelder-Mead', residual=85615.89949231986
# 000333, method='Nelder-Mead', residual=85616.02146720946
# 000334, method='Nelder-Mead', residual=85615.98089892391
# 000335, method='Nelder-Mead', residual=85616.0268126834
# 000336, method='Nelder-Mead', residual=85615.90468596699
# 000337, method='Nelder-Mead', residual=85616.09477016162
# 000338, method='Nelder-Mead', residual=85615.89680770345
# 000339, method='Nelder-Mead', residual=85616.02426908007
# 000340, method='Nelder-Mead', residual=85615.89024588562
# 000341, method='Nelder-Mead', residual=85615.95891171624
# 000342, method='Nelder-Mead', residual=85615.88876197206
# 000343, method='Nelder-Mead', residual=85615.9604519135
# 000344, method='Nelder-Mead', residual=85615.88582050319
# 000345, method='Nelder-Mead', residual=85615.81695694322
# 000346, method='Nelder-Mead', residual=85615.81587410808
# 000347, method='Nelder-Mead', residual=85615.82633449322
# 000348, method='Nelder-Mead', residual=85615.87929691844
# 000349, method='Nelder-Mead', residual=85615.79780847603
# 000350, method='Nelder-Mead', residual=85615.82043928286
# 000351, method='Nelder-Mead', residual=85616.07738851532
# 000352, method='Nelder-Mead', residual=85615.82092891968
# 000353, method='Nelder-Mead', residual=85615.78072979982
# 000354, method='Nelder-Mead', residual=85615.78278513851
# 000355, method='Nelder-Mead', residual=85615.71886306461
# 000356, method='Nelder-Mead', residual=85615.64785415129
# 000357, method='Nelder-Mead', residual=85615.65900567888
# 000358, method='Nelder-Mead', residual=85615.70081993793
# 000359, method='Nelder-Mead', residual=85615.67226467944
# 000360, method='Nelder-Mead', residual=85615.60634931663
# 000361, method='Nelder-Mead', residual=85615.55470888154
# 000362, method='Nelder-Mead', residual=85615.62042290803
# 000363, method='Nelder-Mead', residual=85615.51871225177
# 000364, method='Nelder-Mead', residual=85615.46823051029
# 000365, method='Nelder-Mead', residual=85615.40363914649
# 000366, method='Nelder-Mead', residual=85615.28004904995
# 000367, method='Nelder-Mead', residual=85615.42050794889
# 000368, method='Nelder-Mead', residual=85615.31865790984
# 000369, method='Nelder-Mead', residual=85615.21559762477
# 000370, method='Nelder-Mead', residual=85615.05325738143
# 000371, method='Nelder-Mead', residual=85615.07112955817
# 000372, method='Nelder-Mead', residual=85615.21618150425
# 000373, method='Nelder-Mead', residual=85615.08348546349
# 000374, method='Nelder-Mead', residual=85614.85729413366
# 000375, method='Nelder-Mead', residual=85614.60715001018
# 000376, method='Nelder-Mead', residual=85614.79940624176
# 000377, method='Nelder-Mead', residual=85614.78199524024
# 000378, method='Nelder-Mead', residual=85614.67471386325
# 000379, method='Nelder-Mead', residual=85614.54247100186
# 000380, method='Nelder-Mead', residual=85614.42599645376
# 000381, method='Nelder-Mead', residual=85614.42387944803
# 000382, method='Nelder-Mead', residual=85614.28338437375
# 000383, method='Nelder-Mead', residual=85614.07178393853
# 000384, method='Nelder-Mead', residual=85613.61604980513
# 000385, method='Nelder-Mead', residual=85613.724334446
# 000386, method='Nelder-Mead', residual=85613.74539961282
# 000387, method='Nelder-Mead', residual=85613.34716537921
# 000388, method='Nelder-Mead', residual=85612.79728686504
# 000389, method='Nelder-Mead', residual=85613.53148154348
# 000390, method='Nelder-Mead', residual=85612.78855297194
# 000391, method='Nelder-Mead', residual=85612.43667219469
# 000392, method='Nelder-Mead', residual=85612.47760937635
# 000393, method='Nelder-Mead', residual=85612.01891698231
# 000394, method='Nelder-Mead', residual=85611.93641463772
# 000395, method='Nelder-Mead', residual=85612.40452083189
# 000396, method='Nelder-Mead', residual=85613.53590909221
# 000397, method='Nelder-Mead', residual=85617.29944778071
# 000398, method='Nelder-Mead', residual=85612.70609265273
# 000399, method='Nelder-Mead', residual=85613.42613144066
# 000400, method='Nelder-Mead', residual=85611.19088294003
# 000401, method='Nelder-Mead', residual=85610.68530818765
# 000402, method='Nelder-Mead', residual=85613.84915980673
# 000403, method='Nelder-Mead', residual=85612.47491791504
# 000404, method='Nelder-Mead', residual=85611.93223768557
# 000405, method='Nelder-Mead', residual=85612.78019455302
# 000406, method='Nelder-Mead', residual=85612.07566792972
# 000407, method='Nelder-Mead', residual=85612.36806693977
# 000408, method='Nelder-Mead', residual=85614.51066932693
# 000409, method='Nelder-Mead', residual=85611.8612142194
# 000410, method='Nelder-Mead', residual=85611.00964512832
# 000411, method='Nelder-Mead', residual=85611.05752421916
# 000412, method='Nelder-Mead', residual=85610.95813313313
# 000413, method='Nelder-Mead', residual=85611.54594077352
# 000414, method='Nelder-Mead', residual=85610.18334971723
# 000415, method='Nelder-Mead', residual=85609.74561519871
# 000416, method='Nelder-Mead', residual=85610.41521851024
# 000417, method='Nelder-Mead', residual=85610.96190473727
# 000418, method='Nelder-Mead', residual=85610.66445788715
# 000419, method='Nelder-Mead', residual=85609.64881644331
# 000420, method='Nelder-Mead', residual=85609.532550271
# 000421, method='Nelder-Mead', residual=85610.33771003669
# 000422, method='Nelder-Mead', residual=85612.22198805392
# 000423, method='Nelder-Mead', residual=85609.85646326197
# 000424, method='Nelder-Mead', residual=85610.67468794626
# 000425, method='Nelder-Mead', residual=85610.32060147218
# 000426, method='Nelder-Mead', residual=85610.70067421868
# 000427, method='Nelder-Mead', residual=85609.96841755656
# 000428, method='Nelder-Mead', residual=85609.6736956353
# 000429, method='Nelder-Mead', residual=85609.41866250536
# 000430, method='Nelder-Mead', residual=85611.39160923606
# 000431, method='Nelder-Mead', residual=85609.09312910026
# 000432, method='Nelder-Mead', residual=85609.5682248275
# 000433, method='Nelder-Mead', residual=85610.33671188116
# 000434, method='Nelder-Mead', residual=85609.60298250816
# 000435, method='Nelder-Mead', residual=85608.93151808962
# 000436, method='Nelder-Mead', residual=85609.14490977002
# 000437, method='Nelder-Mead', residual=85609.02616872224
# 000438, method='Nelder-Mead', residual=85609.71228860901
# 000439, method='Nelder-Mead', residual=85609.14167952714
# 000440, method='Nelder-Mead', residual=85609.18552635974
# 000441, method='Nelder-Mead', residual=85608.88929775023
# 000442, method='Nelder-Mead', residual=85609.69675979727
# 000443, method='Nelder-Mead', residual=85609.2776423677
# 000444, method='Nelder-Mead', residual=85608.89952410903
# 000445, method='Nelder-Mead', residual=85609.66363566021
# 000446, method='Nelder-Mead', residual=85608.75119049045
# 000447, method='Nelder-Mead', residual=85609.41315288734
# 000448, method='Nelder-Mead', residual=85608.85763492306
# 000449, method='Nelder-Mead', residual=85609.02680891723
# 000450, method='Nelder-Mead', residual=85608.9595382206
# 000451, method='Nelder-Mead', residual=85609.12436678207
# 000452, method='Nelder-Mead', residual=85608.80478073635
# 000453, method='Nelder-Mead', residual=85609.38057113434
# 000454, method='Nelder-Mead', residual=85608.77168670169
# 000455, method='Nelder-Mead', residual=85609.08934006175
# 000456, method='Nelder-Mead', residual=85608.77659713743
# 000457, method='Nelder-Mead', residual=85608.68860722118
# 000458, method='Nelder-Mead', residual=85608.8038558199
# 000459, method='Nelder-Mead', residual=85608.83236989906
# 000460, method='Nelder-Mead', residual=85608.81497607246
# 000461, method='Nelder-Mead', residual=85608.58112227716
# 000462, method='Nelder-Mead', residual=85608.69353650011
# 000463, method='Nelder-Mead', residual=85608.69425961784
# 000464, method='Nelder-Mead', residual=85608.8835857812
# 000465, method='Nelder-Mead', residual=85608.67254755225
# 000466, method='Nelder-Mead', residual=85608.73990538232
# 000467, method='Nelder-Mead', residual=85608.67984791778
# 000468, method='Nelder-Mead', residual=85608.49723839134
# 000469, method='Nelder-Mead', residual=85608.53448184265
# 000470, method='Nelder-Mead', residual=85608.73965002994
# 000471, method='Nelder-Mead', residual=85608.65345427509
# 000472, method='Nelder-Mead', residual=85608.69289647514
# 000473, method='Nelder-Mead', residual=85608.74692689699
# 000474, method='Nelder-Mead', residual=85608.59010600134
# 000475, method='Nelder-Mead', residual=85608.71249820798
# 000476, method='Nelder-Mead', residual=85608.58359833165
# 000477, method='Nelder-Mead', residual=85608.60600087019
# 000478, method='Nelder-Mead', residual=85608.63266406982
# 000479, method='Nelder-Mead', residual=85608.57831548504
# 000480, method='Nelder-Mead', residual=85608.69138259359
# 000481, method='Nelder-Mead', residual=85608.5542161142
# 000482, method='Nelder-Mead', residual=85608.67170924076
# 000483, method='Nelder-Mead', residual=85608.54703904418
# 000484, method='Nelder-Mead', residual=85608.66481416419
# 000485, method='Nelder-Mead', residual=85608.53648375162
# 000486, method='Nelder-Mead', residual=85608.57113444144
# 000487, method='Nelder-Mead', residual=85608.46056261475
# 000488, method='Nelder-Mead', residual=85608.43728319394
# 000489, method='Nelder-Mead', residual=85608.54556457799
# 000490, method='Nelder-Mead', residual=85608.46929918391
# 000491, method='Nelder-Mead', residual=85608.54267850466
# 000492, method='Nelder-Mead', residual=85608.43132287855
# 000493, method='Nelder-Mead', residual=85608.46978926116
# 000494, method='Nelder-Mead', residual=85608.43491409048
# 000495, method='Nelder-Mead', residual=85608.52571617169
# 000496, method='Nelder-Mead', residual=85608.72241897936
# 000497, method='Nelder-Mead', residual=85608.45718736883
# 000498, method='Nelder-Mead', residual=85608.3974772673
# 000499, method='Nelder-Mead', residual=85608.42364092353
# 000500, method='Nelder-Mead', residual=85608.49424264222
# 000501, method='Nelder-Mead', residual=85608.38287925975
# 000502, method='Nelder-Mead', residual=85608.4053324923
# 000503, method='Nelder-Mead', residual=85608.44536146126
# 000504, method='Nelder-Mead', residual=85608.41128607809
# 000505, method='Nelder-Mead', residual=85608.46409510913
# 000506, method='Nelder-Mead', residual=85608.41079293874
# 000507, method='Nelder-Mead', residual=85608.53597368763
# 000508, method='Nelder-Mead', residual=85608.39699774695
# 000509, method='Nelder-Mead', residual=85608.38715091052
# 000510, method='Nelder-Mead', residual=85608.37022885692
# 000511, method='Nelder-Mead', residual=85608.39894567839
# 000512, method='Nelder-Mead', residual=85608.35610174474
# 000513, method='Nelder-Mead', residual=85608.3741052277
# 000514, method='Nelder-Mead', residual=85608.42362865582
# 000515, method='Nelder-Mead', residual=85608.37729477415
# 000516, method='Nelder-Mead', residual=85608.3382298016
# 000517, method='Nelder-Mead', residual=85608.33605077301
# 000518, method='Nelder-Mead', residual=85608.33143411894
# 000519, method='Nelder-Mead', residual=85608.33469424571
# 000520, method='Nelder-Mead', residual=85608.3472145639
# 000521, method='Nelder-Mead', residual=85608.3880564941
# 000522, method='Nelder-Mead', residual=85608.35291674799
# 000523, method='Nelder-Mead', residual=85608.34675672899
# 000524, method='Nelder-Mead', residual=85608.30721473348
# 000525, method='Nelder-Mead', residual=85608.30276942202
# 000526, method='Nelder-Mead', residual=85608.31165846111
# 000527, method='Nelder-Mead', residual=85608.28301222225
# 000528, method='Nelder-Mead', residual=85608.27222695027
# 000529, method='Nelder-Mead', residual=85608.27760784872
# 000530, method='Nelder-Mead', residual=85608.30104975158
# 000531, method='Nelder-Mead', residual=85608.23960057524
# 000532, method='Nelder-Mead', residual=85608.22403228738
# 000533, method='Nelder-Mead', residual=85608.24142683476
# 000534, method='Nelder-Mead', residual=85608.27872349333
# 000535, method='Nelder-Mead', residual=85608.19167293272
# 000536, method='Nelder-Mead', residual=85608.1471818962
# 000537, method='Nelder-Mead', residual=85608.23492021025
# 000538, method='Nelder-Mead', residual=85608.28208719935
# 000539, method='Nelder-Mead', residual=85608.23353743427
# 000540, method='Nelder-Mead', residual=85608.18361619732
# 000541, method='Nelder-Mead', residual=85608.17849291474
# 000542, method='Nelder-Mead', residual=85608.1779974929
# 000543, method='Nelder-Mead', residual=85608.17517558433
# 000544, method='Nelder-Mead', residual=85608.1889768305
# 000545, method='Nelder-Mead', residual=85608.09447512365
# 000546, method='Nelder-Mead', residual=85608.03604062962
# 000547, method='Nelder-Mead', residual=85608.05472377609
# 000548, method='Nelder-Mead', residual=85608.12339886073
# 000549, method='Nelder-Mead', residual=85608.07614198726
# 000550, method='Nelder-Mead', residual=85608.02782101744
# 000551, method='Nelder-Mead', residual=85608.02809613115
# 000552, method='Nelder-Mead', residual=85607.99334504273
# 000553, method='Nelder-Mead', residual=85608.01200324603
# 000554, method='Nelder-Mead', residual=85608.00241067074
# 000555, method='Nelder-Mead', residual=85607.98772265013
# 000556, method='Nelder-Mead', residual=85608.06023032025
# 000557, method='Nelder-Mead', residual=85608.02961731088
# 000558, method='Nelder-Mead', residual=85607.9424724103
# 000559, method='Nelder-Mead', residual=85607.94169044375
# 000560, method='Nelder-Mead', residual=85607.93312884116
# 000561, method='Nelder-Mead', residual=85607.9904207764
# 000562, method='Nelder-Mead', residual=85607.97310778109
# 000563, method='Nelder-Mead', residual=85607.90254855886
# 000564, method='Nelder-Mead', residual=85607.89328535722
# 000565, method='Nelder-Mead', residual=85608.0488377123
# 000566, method='Nelder-Mead', residual=85607.94341680543
# 000567, method='Nelder-Mead', residual=85607.92705401909
# 000568, method='Nelder-Mead', residual=85607.9490688432
# 000569, method='Nelder-Mead', residual=85607.88986463599
# 000570, method='Nelder-Mead', residual=85607.93324595071
# 000571, method='Nelder-Mead', residual=85607.91925841909
# 000572, method='Nelder-Mead', residual=85607.88281269188
# 000573, method='Nelder-Mead', residual=85607.90734707189
# 000574, method='Nelder-Mead', residual=85607.90503856803
# 000575, method='Nelder-Mead', residual=85607.93340949884
# 000576, method='Nelder-Mead', residual=85607.89786758876
# 000577, method='Nelder-Mead', residual=85607.8967961506
# 000578, method='Nelder-Mead', residual=85607.87731255038
# 000579, method='Nelder-Mead', residual=85607.92258920196
# 000580, method='Nelder-Mead', residual=85607.88844313034
# 000581, method='Nelder-Mead', residual=85607.88733020723
# 000582, method='Nelder-Mead', residual=85607.88031509609
# 000583, method='Nelder-Mead', residual=85607.88689169413
# 000584, method='Nelder-Mead', residual=85607.87152950859
# 000585, method='Nelder-Mead', residual=85607.90703044883
# 000586, method='Nelder-Mead', residual=85607.87067397278
# 000587, method='Nelder-Mead', residual=85607.91385133656
# 000588, method='Nelder-Mead', residual=85607.86874079714
# 000589, method='Nelder-Mead', residual=85607.88962947852
# 000590, method='Nelder-Mead', residual=85607.87197547764
# 000591, method='Nelder-Mead', residual=85607.88842237384
# 000592, method='Nelder-Mead', residual=85607.87175886273
# 000593, method='Nelder-Mead', residual=85607.89133797474
# 000594, method='Nelder-Mead', residual=85607.87002544275
# 000595, method='Nelder-Mead', residual=85607.8954915473
# 000596, method='Nelder-Mead', residual=85607.86899363378
# 000597, method='Nelder-Mead', residual=85607.87083391669
# 000598, method='Nelder-Mead', residual=85607.87012407817
# 000599, method='Nelder-Mead', residual=85607.87199672298
# 000600, method='Nelder-Mead', residual=85607.86773816992
# 000601, method='Nelder-Mead', residual=85607.87548669001
# 000602, method='Nelder-Mead', residual=85607.867319309
# 000603, method='Nelder-Mead', residual=85607.86492380635
# 000604, method='Nelder-Mead', residual=85607.86823212623
# 000605, method='Nelder-Mead', residual=85607.87739382601
# 000606, method='Nelder-Mead', residual=85607.86630611966
# 000607, method='Nelder-Mead', residual=85607.86668140817
# 000608, method='Nelder-Mead', residual=85607.86634384171
# 000609, method='Nelder-Mead', residual=85607.86648031171
# 000610, method='Nelder-Mead', residual=85607.86907889316
# 000611, method='Nelder-Mead', residual=85607.8654968785
# 000612, method='Nelder-Mead', residual=85607.86531979355
# 000613, method='Nelder-Mead', residual=85607.86527149317
# 000614, method='Nelder-Mead', residual=85607.86696576091
# 000615, method='Nelder-Mead', residual=85607.86473475602
# 000616, method='Nelder-Mead', residual=85607.86763157342
# 000617, method='Nelder-Mead', residual=85607.8645714275
# 000618, method='Nelder-Mead', residual=85607.87147042558
# 000619, method='Nelder-Mead', residual=85607.86420976215
# 000620, method='Nelder-Mead', residual=85607.86458334388
# 000621, method='Nelder-Mead', residual=85607.86390864066
# 000622, method='Nelder-Mead', residual=85607.86556911949
# 000623, method='Nelder-Mead', residual=85607.86496801792
# 000624, method='Nelder-Mead', residual=85607.86223599524
# 000625, method='Nelder-Mead', residual=85607.86144036056
# 000626, method='Nelder-Mead', residual=85607.86477799679
# 000627, method='Nelder-Mead', residual=85607.8652371115
# 000628, method='Nelder-Mead', residual=85607.86354220878
# 000629, method='Nelder-Mead', residual=85607.86481603744
# 000630, method='Nelder-Mead', residual=85607.86349302788
# 000631, method='Nelder-Mead', residual=85607.86385068225
# 000632, method='Nelder-Mead', residual=85607.8629858126
# 000633, method='Nelder-Mead', residual=85607.86315300892
# 000634, method='Nelder-Mead', residual=85607.86300380435
# 000635, method='Nelder-Mead', residual=85607.86335970994
# 000636, method='Nelder-Mead', residual=85607.86236731464
# 000637, method='Nelder-Mead', residual=85607.86278500447
# 000638, method='Nelder-Mead', residual=85607.86111378987
# 000639, method='Nelder-Mead', residual=85607.86056744418
# 000640, method='Nelder-Mead', residual=85607.86268084208
# 000641, method='Nelder-Mead', residual=85607.86397891882
# 000642, method='Nelder-Mead', residual=85607.86200102029
# 000643, method='Nelder-Mead', residual=85607.86222110633
# 000644, method='Nelder-Mead', residual=85607.86197115919
# 000645, method='Nelder-Mead', residual=85607.86206013082
# 000646, method='Nelder-Mead', residual=85607.86308781822
# 000647, method='Nelder-Mead', residual=85607.86176166397
# 000648, method='Nelder-Mead', residual=85607.86189059651
# 000649, method='Nelder-Mead', residual=85607.86170851887
# 000650, method='Nelder-Mead', residual=85607.86163515275
# 000651, method='Nelder-Mead', residual=85607.86097001415
# 000652, method='Nelder-Mead', residual=85607.86141853176
# 000653, method='Nelder-Mead', residual=85607.86191550056
# 000654, method='Nelder-Mead', residual=85607.86129628308
# 000655, method='Nelder-Mead', residual=85607.86177568509
# 000656, method='Nelder-Mead', residual=85607.86127220669
# 000657, method='Nelder-Mead', residual=85607.8607110865
# 000658, method='Nelder-Mead', residual=85607.86053314888
# 000659, method='Nelder-Mead', residual=85607.86092455412
# 000660, method='Nelder-Mead', residual=85607.86097860814
# 000661, method='Nelder-Mead', residual=85607.8607185311
# 000662, method='Nelder-Mead', residual=85607.86082898655
# 000663, method='Nelder-Mead', residual=85607.86078241642
# 000664, method='Nelder-Mead', residual=85607.86069308402
# 000665, method='Nelder-Mead', residual=85607.860704606
# 000666, method='Nelder-Mead', residual=85607.86066491345
# 000667, method='Nelder-Mead', residual=85607.86067393767
# 000668, method='Nelder-Mead', residual=85607.86085492847
# 000669, method='Nelder-Mead', residual=85607.86061066994
# 000670, method='Nelder-Mead', residual=85607.86060135091
# 000671, method='Nelder-Mead', residual=85607.86050615182
# 000672, method='Nelder-Mead', residual=85607.86074368018
# 000673, method='Nelder-Mead', residual=85607.86058388952
# 000674, method='Nelder-Mead', residual=85607.86041785142
# 000675, method='Nelder-Mead', residual=85607.86057212514
# 000676, method='Nelder-Mead', residual=85607.86044295516
# 000677, method='Nelder-Mead', residual=85607.8605203853
# 000678, method='Nelder-Mead', residual=85607.86048075663
# 000679, method='Nelder-Mead', residual=85607.86051739771
# 000680, method='Nelder-Mead', residual=85607.86044056552
# 000681, method='Nelder-Mead', residual=85607.8604292224
# 000682, method='Nelder-Mead', residual=85607.86047358788
# 000683, method='Nelder-Mead', residual=85607.86035934655
# 000684, method='Nelder-Mead', residual=85607.86035683438
# 000685, method='Nelder-Mead', residual=85607.86033386999
# 000686, method='Nelder-Mead', residual=85607.86046712703
# 000687, method='Nelder-Mead', residual=85607.8602976379
# 000688, method='Nelder-Mead', residual=85607.86021476229
# 000689, method='Nelder-Mead', residual=85607.86038761589
# 000690, method='Nelder-Mead', residual=85607.86029494487
# 000691, method='Nelder-Mead', residual=85607.86026770626
# 000692, method='Nelder-Mead', residual=85607.860206029
# 000693, method='Nelder-Mead', residual=85607.86012637605
# 000694, method='Nelder-Mead', residual=85607.85999978447
# 000695, method='Nelder-Mead', residual=85607.86016418888
# 000696, method='Nelder-Mead', residual=85607.86008897357
# 000697, method='Nelder-Mead', residual=85607.85999428325
# 000698, method='Nelder-Mead', residual=85607.8599806738
# 000699, method='Nelder-Mead', residual=85607.85992047528
# 000700, method='Nelder-Mead', residual=85607.85983983769
# 000701, method='Nelder-Mead', residual=85607.85966340225
# 000702, method='Nelder-Mead', residual=85607.8598057814
# 000703, method='Nelder-Mead', residual=85607.85966945818
# 000704, method='Nelder-Mead', residual=85607.8596278977
# 000705, method='Nelder-Mead', residual=85607.85954027795
# 000706, method='Nelder-Mead', residual=85607.8594322834
# 000707, method='Nelder-Mead', residual=85607.85936332156
# 000708, method='Nelder-Mead', residual=85607.85913902598
# 000709, method='Nelder-Mead', residual=85607.85939155736
# 000710, method='Nelder-Mead', residual=85607.8589686796
# 000711, method='Nelder-Mead', residual=85607.85893129036
# 000712, method='Nelder-Mead', residual=85607.85863124624
# 000713, method='Nelder-Mead', residual=85607.85938630378
# 000714, method='Nelder-Mead', residual=85607.85893978846
# 000715, method='Nelder-Mead', residual=85607.85883311782
# 000716, method='Nelder-Mead', residual=85607.85871368575
# 000717, method='Nelder-Mead', residual=85607.85910987065
# 000718, method='Nelder-Mead', residual=85607.8584749021
# 000719, method='Nelder-Mead', residual=85607.85843047376
# 000720, method='Nelder-Mead', residual=85607.85822509734
# 000721, method='Nelder-Mead', residual=85607.85811655155
# 000722, method='Nelder-Mead', residual=85607.85844829572
# 000723, method='Nelder-Mead', residual=85607.85826037358
# 000724, method='Nelder-Mead', residual=85607.85817278597
# 000725, method='Nelder-Mead', residual=85607.85845024162
# 000726, method='Nelder-Mead', residual=85607.85812831477
# 000727, method='Nelder-Mead', residual=85607.85800079642
# 000728, method='Nelder-Mead', residual=85607.85794662611
# 000729, method='Nelder-Mead', residual=85607.85792194736
# 000730, method='Nelder-Mead', residual=85607.85795286506
# 000731, method='Nelder-Mead', residual=85607.85757803291
# 000732, method='Nelder-Mead', residual=85607.8571797569
# 000733, method='Nelder-Mead', residual=85607.85799517835
# 000734, method='Nelder-Mead', residual=85607.85759508294
# 000735, method='Nelder-Mead', residual=85607.85734762876
# 000736, method='Nelder-Mead', residual=85607.85732439958
# 000737, method='Nelder-Mead', residual=85607.857697889
# 000738, method='Nelder-Mead', residual=85607.85752859952
# 000739, method='Nelder-Mead', residual=85607.85687011681
# 000740, method='Nelder-Mead', residual=85607.85635865094
# 000741, method='Nelder-Mead', residual=85607.85651326957
# 000742, method='Nelder-Mead', residual=85607.85727015701
# 000743, method='Nelder-Mead', residual=85607.85661163123
# 000744, method='Nelder-Mead', residual=85607.85659761909
# 000745, method='Nelder-Mead', residual=85607.85631741797
# 000746, method='Nelder-Mead', residual=85607.85600002443
# 000747, method='Nelder-Mead', residual=85607.85579512901
# 000748, method='Nelder-Mead', residual=85607.85507240768
# 000749, method='Nelder-Mead', residual=85607.85555063022
# 000750, method='Nelder-Mead', residual=85607.85503423266
# 000751, method='Nelder-Mead', residual=85607.85426604276
# 000752, method='Nelder-Mead', residual=85607.85611012368
# 000753, method='Nelder-Mead', residual=85607.85522479209
# 000754, method='Nelder-Mead', residual=85607.85592226393
# 000755, method='Nelder-Mead', residual=85607.8546158003
# 000756, method='Nelder-Mead', residual=85607.85422726434
# 000757, method='Nelder-Mead', residual=85607.85394690832
# 000758, method='Nelder-Mead', residual=85607.85325675533
# 000759, method='Nelder-Mead', residual=85607.85317929859
# 000760, method='Nelder-Mead', residual=85607.85352992109
# 000761, method='Nelder-Mead', residual=85607.85255070595
# 000762, method='Nelder-Mead', residual=85607.85132960319
# 000763, method='Nelder-Mead', residual=85607.85237620311
# 000764, method='Nelder-Mead', residual=85607.85159827421
# 000765, method='Nelder-Mead', residual=85607.85134762233
# 000766, method='Nelder-Mead', residual=85607.85063841315
# 000767, method='Nelder-Mead', residual=85607.84951317082
# 000768, method='Nelder-Mead', residual=85607.84972745564
# 000769, method='Nelder-Mead', residual=85607.84946663122
# 000770, method='Nelder-Mead', residual=85607.84847447847
# 000771, method='Nelder-Mead', residual=85607.84795607068
# 000772, method='Nelder-Mead', residual=85607.8462285593
# 000773, method='Nelder-Mead', residual=85607.84649599608
# 000774, method='Nelder-Mead', residual=85607.84590062217
# 000775, method='Nelder-Mead', residual=85607.84367189351
# 000776, method='Nelder-Mead', residual=85607.84432824579
# 000777, method='Nelder-Mead', residual=85607.8442783734
# 000778, method='Nelder-Mead', residual=85607.84453350389
# 000779, method='Nelder-Mead', residual=85607.84177176018
# 000780, method='Nelder-Mead', residual=85607.83999859232
# 000781, method='Nelder-Mead', residual=85607.84055613086
# 000782, method='Nelder-Mead', residual=85607.84262384941
# 000783, method='Nelder-Mead', residual=85607.83944676661
# 000784, method='Nelder-Mead', residual=85607.83823583496
# 000785, method='Nelder-Mead', residual=85607.83777654872
# 000786, method='Nelder-Mead', residual=85607.83520961166
# 000787, method='Nelder-Mead', residual=85607.8381898382
# 000788, method='Nelder-Mead', residual=85607.83633994719
# 000789, method='Nelder-Mead', residual=85607.83859850548
# 000790, method='Nelder-Mead', residual=85607.83206313397
# 000791, method='Nelder-Mead', residual=85607.82775568047
# 000792, method='Nelder-Mead', residual=85607.83774986799
# 000793, method='Nelder-Mead', residual=85607.83381977824
# 000794, method='Nelder-Mead', residual=85607.83235564834
# 000795, method='Nelder-Mead', residual=85607.82968558937
# 000796, method='Nelder-Mead', residual=85607.82951882556
# 000797, method='Nelder-Mead', residual=85607.82954290253
# 000798, method='Nelder-Mead', residual=85607.82516471608
# 000799, method='Nelder-Mead', residual=85607.82207691272
# 000800, method='Nelder-Mead', residual=85607.82428633967
# 000801, method='Nelder-Mead', residual=85607.82565634501
# 000802, method='Nelder-Mead', residual=85607.82039241651
# 000803, method='Nelder-Mead', residual=85607.8171447368
# 000804, method='Nelder-Mead', residual=85607.81859145749
# 000805, method='Nelder-Mead', residual=85607.82163997534
# 000806, method='Nelder-Mead', residual=85607.81417308621
# 000807, method='Nelder-Mead', residual=85607.81010758951
# 000808, method='Nelder-Mead', residual=85607.8173039924
# 000809, method='Nelder-Mead', residual=85607.81638372452
# 000810, method='Nelder-Mead', residual=85607.81279058802
# 000811, method='Nelder-Mead', residual=85607.8120279712
# 000812, method='Nelder-Mead', residual=85607.81102481774
# 000813, method='Nelder-Mead', residual=85607.81318137802
# 000814, method='Nelder-Mead', residual=85607.80671555462
# 000815, method='Nelder-Mead', residual=85607.80430806537
# 000816, method='Nelder-Mead', residual=85607.8092064021
# 000817, method='Nelder-Mead', residual=85607.80746546405
# 000818, method='Nelder-Mead', residual=85607.80656422523
# 000819, method='Nelder-Mead', residual=85607.80291396163
# 000820, method='Nelder-Mead', residual=85607.80259335694
# 000821, method='Nelder-Mead', residual=85607.80832181133
# 000822, method='Nelder-Mead', residual=85607.79809714253
# 000823, method='Nelder-Mead', residual=85607.79382311032
# 000824, method='Nelder-Mead', residual=85607.80047995124
# 000825, method='Nelder-Mead', residual=85607.80037603369
# 000826, method='Nelder-Mead', residual=85607.79831432592
# 000827, method='Nelder-Mead', residual=85607.8049471697
# 000828, method='Nelder-Mead', residual=85607.80519626949
# 000829, method='Nelder-Mead', residual=85607.79981761506
# 000830, method='Nelder-Mead', residual=85607.80213052669
# 000831, method='Nelder-Mead', residual=85607.79707022893
# 000832, method='Nelder-Mead', residual=85607.79060088067
# 000833, method='Nelder-Mead', residual=85607.78561560268
# 000834, method='Nelder-Mead', residual=85607.7969132142
# 000835, method='Nelder-Mead', residual=85607.79108117915
# 000836, method='Nelder-Mead', residual=85607.79012843742
# 000837, method='Nelder-Mead', residual=85607.78418923612
# 000838, method='Nelder-Mead', residual=85607.78030521423
# 000839, method='Nelder-Mead', residual=85607.78630990286
# 000840, method='Nelder-Mead', residual=85607.77985950839
# 000841, method='Nelder-Mead', residual=85607.77843178803
# 000842, method='Nelder-Mead', residual=85607.77606819692
# 000843, method='Nelder-Mead', residual=85607.77678948146
# ...
# 003454, method='Nelder-Mead', residual=85529.41084024534
# 003455, method='Nelder-Mead', residual=85529.41083895553
# 003456, method='Nelder-Mead', residual=85529.41083953597
# 003457, method='Nelder-Mead', residual=85529.41083841298
# 003458, method='Nelder-Mead', residual=85529.4108399749
# 003459, method='Nelder-Mead', residual=85529.41083837672
# 003460, method='Nelder-Mead', residual=85529.4108385808
# 003461, method='Nelder-Mead', residual=85529.41083980036
# 003462, method='Nelder-Mead', residual=85529.41083831663
# 003463, method='Nelder-Mead', residual=85529.41083827493
# 003464, method='Nelder-Mead', residual=85529.41083926073
# 003465, method='Nelder-Mead', residual=85529.41083833018
# 003466, method='Nelder-Mead', residual=85529.41083877312
# 003467, method='Nelder-Mead', residual=85529.41083820236
# 003468, method='Nelder-Mead', residual=85529.41083859565
# 003469, method='Nelder-Mead', residual=85529.41083821315
# 003470, method='Nelder-Mead', residual=85529.41083888698
# 003471, method='Nelder-Mead', residual=85529.41083818319
# 003472, method='Nelder-Mead', residual=85529.4108382443
# 003473, method='Nelder-Mead', residual=85529.41083832268
# 003474, method='Nelder-Mead', residual=85529.4108384058
# 003475, method='Nelder-Mead', residual=85529.41083812315
# 003476, method='Nelder-Mead', residual=85529.41083838425
# 003477, method='Nelder-Mead', residual=85529.41083812159
# 003478, method='Nelder-Mead', residual=85529.41083820893
# 003479, method='Nelder-Mead', residual=85529.4108391396
# 003480, method='Nelder-Mead', residual=85529.41083803194
# 003481, method='Nelder-Mead', residual=85529.4108382288
# 003482, method='Nelder-Mead', residual=85529.41083810538
# 003483, method='Nelder-Mead', residual=85529.41083799156
# 003484, method='Nelder-Mead', residual=85529.41083803053
# 003485, method='Nelder-Mead', residual=85529.41083829294
# 003486, method='Nelder-Mead', residual=85529.41083807274
# 003487, method='Nelder-Mead', residual=85529.41083803024
# 003488, method='Nelder-Mead', residual=85529.4108382104
# 003489, method='Nelder-Mead', residual=85529.41083805505
# 003490, method='Nelder-Mead', residual=85529.41083801958
# 003491, method='Nelder-Mead', residual=85529.41083801255
# 003492, method='Nelder-Mead', residual=85529.41083794151
# 003493, method='Nelder-Mead', residual=85529.41083799221
# 003494, method='Nelder-Mead', residual=85529.4108380203
# 003495, method='Nelder-Mead', residual=85529.4108379905
# 003496, method='Nelder-Mead', residual=85529.4108379521
# 003497, method='Nelder-Mead', residual=85529.41083814121
# 003498, method='Nelder-Mead', residual=85529.41083795608
# 003499, method='Nelder-Mead', residual=85529.41083800743
# 003500, method='Nelder-Mead', residual=85529.41083794973
# 003501, method='Nelder-Mead', residual=85529.41083795814
# 003502, method='Nelder-Mead', residual=85529.41083796056
# 003503, method='Nelder-Mead', residual=85529.41083795995
# 003504, method='Nelder-Mead', residual=85529.41083800522
# 003505, method='Nelder-Mead', residual=85529.41083793557
# 003506, method='Nelder-Mead', residual=85529.41083797654
# 003507, method='Nelder-Mead', residual=85529.41083792798
# 003508, method='Nelder-Mead', residual=85529.41083799051
# 003509, method='Nelder-Mead', residual=85529.41083792657
# 003510, method='Nelder-Mead', residual=85529.41083799803
# 003511, method='Nelder-Mead', residual=85529.41083792558
# 003512, method='Nelder-Mead', residual=85529.41083795254
# 003513, method='Nelder-Mead', residual=85529.41083792738
# 003514, method='Nelder-Mead', residual=85529.41083795555
# 003515, method='Nelder-Mead', residual=85529.41083792708
# 003516, method='Nelder-Mead', residual=85529.4108379871
# 003517, method='Nelder-Mead', residual=85529.41083792347
# 003518, method='Nelder-Mead', residual=85529.41083792785
# 003519, method='Nelder-Mead', residual=85529.41083793082
# 003520, method='Nelder-Mead', residual=85529.41083792038
# 003521, method='Nelder-Mead', residual=85529.41083793176
# 003522, method='Nelder-Mead', residual=85529.41083791977
# 003523, method='Nelder-Mead', residual=85529.41083794327
# 003524, method='Nelder-Mead', residual=85529.41083791874
# 003525, method='Nelder-Mead', residual=85529.41083792594
# 003526, method='Nelder-Mead', residual=85529.41083792041
# 003527, method='Nelder-Mead', residual=85529.4108379201
# 003528, method='Nelder-Mead', residual=85529.41083792888
# 003529, method='Nelder-Mead', residual=85529.41083791816
# 003530, method='Nelder-Mead', residual=85529.41083792418
# 003531, method='Nelder-Mead', residual=85529.4108379177
# 003532, method='Nelder-Mead', residual=85529.41083792858
# 003533, method='Nelder-Mead', residual=85529.41083791718
# 003534, method='Nelder-Mead', residual=85529.41083792376
# 003535, method='Nelder-Mead', residual=85529.41083791663
# 003536, method='Nelder-Mead', residual=85529.4108379178
# 003537, method='Nelder-Mead', residual=85529.41083792705
# 003538, method='Nelder-Mead', residual=85529.410837916
# 003539, method='Nelder-Mead', residual=85529.41083791682
# 003540, method='Nelder-Mead', residual=85529.41083792078
# 003541, method='Nelder-Mead', residual=85529.41083791592
# 003542, method='Nelder-Mead', residual=85529.4108379177
# 003543, method='Nelder-Mead', residual=85529.41083792046
# 003544, method='Nelder-Mead', residual=85529.41083791561
# 003545, method='Nelder-Mead', residual=85529.41083791821
# 003546, method='Nelder-Mead', residual=85529.41083791581
# 003547, method='Nelder-Mead', residual=85529.41083791807
# 003548, method='Nelder-Mead', residual=85529.41083791581
# 003549, method='Nelder-Mead', residual=85529.41083791695
# 003550, method='Nelder-Mead', residual=85529.41083791558
# 003551, method='Nelder-Mead', residual=85529.41083791817
# 003552, method='Nelder-Mead', residual=85529.41083791551
# 003553, method='Nelder-Mead', residual=85529.41083791631
# 003554, method='Nelder-Mead', residual=85529.41083791543
# 003555, method='Nelder-Mead', residual=85529.41083791634
# 003556, method='Nelder-Mead', residual=85529.41083791533
# 003557, method='Nelder-Mead', residual=85529.41083791685
# 003558, method='Nelder-Mead', residual=85529.41083791526
# 003559, method='Nelder-Mead', residual=85529.41083791571
# 003560, method='Nelder-Mead', residual=85529.41083791619
# 003561, method='Nelder-Mead', residual=85529.41083791527
# 003562, method='Nelder-Mead', residual=85529.41083791578
# 003563, method='Nelder-Mead', residual=85529.4108379153
# 003564, method='Nelder-Mead', residual=85529.41083791561
# 003565, method='Nelder-Mead', residual=85529.41083791525
# 003566, method='Nelder-Mead', residual=85529.41083791565
# 003567, method='Nelder-Mead', residual=85529.41083791525
# 003568, method='Nelder-Mead', residual=85529.41083791567
# 003569, method='Nelder-Mead', residual=85529.41083791523
# 003570, method='Nelder-Mead', residual=85529.4108379156
# 003571, method='Nelder-Mead', residual=85529.41083791517
# 003572, method='Nelder-Mead', residual=85529.41083791545
# 003573, method='Nelder-Mead', residual=85529.4108379152
# 003574, method='Nelder-Mead', residual=85529.41083791526
# 003575, method='Nelder-Mead', residual=85529.41083791527
# 003576, method='Nelder-Mead', residual=85529.41083791516
# 003577, method='Nelder-Mead', residual=85529.41083791527
# 003578, method='Nelder-Mead', residual=85529.41083791516
# 003579, method='Nelder-Mead', residual=85529.41083791548
# 003580, method='Nelder-Mead', residual=85529.41083791514
# 003581, method='Nelder-Mead', residual=85529.41083791525
# 003582, method='Nelder-Mead', residual=85529.41083791519
# 003583, method='Nelder-Mead', residual=85529.41083791526
# 003584, method='Nelder-Mead', residual=85529.41083791519
# 003585, method='Nelder-Mead', residual=85529.41083791526
# 003586, method='Nelder-Mead', residual=85529.41083791514
# 003587, method='Nelder-Mead', residual=85529.41083791519
# 003588, method='Nelder-Mead', residual=85529.41083791519
# 003589, method='Nelder-Mead', residual=85529.41083791514
# 003590, method='Nelder-Mead', residual=85529.4108379152
# 003591, method='Nelder-Mead', residual=85529.41083791517
# 003592, method='Nelder-Mead', residual=85529.41083791517
# 003593, method='Nelder-Mead', residual=85529.41083791514
# 003594, method='Nelder-Mead', residual=85529.41083791516
# 003595, method='Nelder-Mead', residual=85529.41083791519
# 003596, method='Nelder-Mead', residual=85529.41083791516
# 003597, method='Nelder-Mead', residual=85529.41083791516
# 003598, method='Nelder-Mead', residual=85529.41083791514
# 003599, method='Nelder-Mead', residual=85529.41083791511
# 003600, method='Nelder-Mead', residual=85529.41083791519
# 003601, method='Nelder-Mead', residual=85529.41083791514
# 003602, method='Nelder-Mead', residual=85529.41083791514
# 003603, method='Nelder-Mead', residual=85529.41083791511
# 003604, method='Nelder-Mead', residual=85529.41083791517
# 003605, method='Nelder-Mead', residual=85529.41083791513
# 003606, method='Nelder-Mead', residual=85529.41083791514
# 003607, method='Nelder-Mead', residual=85529.41083791514
# 003608, method='Nelder-Mead', residual=85529.41083791514
# 003609, method='Nelder-Mead', residual=85529.41083791516
# 003610, method='Nelder-Mead', residual=85529.41083791513
# 003611, method='Nelder-Mead', residual=85529.41083791513
# 003612, method='Nelder-Mead', residual=85529.41083791517
# 003613, method='Nelder-Mead', residual=85529.41083791514
# 003614, method='Nelder-Mead', residual=85529.41083791517
# 003615, method='Nelder-Mead', residual=85529.41083791513
# 003616, method='Nelder-Mead', residual=85529.41083791513
# 003617, method='Nelder-Mead', residual=85529.41083791514
# 003618, method='Nelder-Mead', residual=85529.41083791514
# 003619, method='Nelder-Mead', residual=85529.41083791516
# 003620, method='Nelder-Mead', residual=85529.41083791514
# 003621, method='Nelder-Mead', residual=85529.41083791516
# 003622, method='Nelder-Mead', residual=85529.41083791514
# 003623, method='Nelder-Mead', residual=85529.41083791513
# 003624, method='Nelder-Mead', residual=85529.41083791514
# 003625, method='Nelder-Mead', residual=85529.41083791516
# 003626, method='Nelder-Mead', residual=85529.41083791514
# 003627, method='Nelder-Mead', residual=85529.41083791517
# 003628, method='Nelder-Mead', residual=85529.41083791517
# 003629, method='Nelder-Mead', residual=85529.41083791517
# 003630, method='Nelder-Mead', residual=85529.41083791514
# 003631, method='Nelder-Mead', residual=85529.41083791514
# 003632, method='Nelder-Mead', residual=85529.41083791513
# 003633, method='Nelder-Mead', residual=85529.41083791514
# 003634, method='Nelder-Mead', residual=85529.41083791516
# 003635, method='Nelder-Mead', residual=85529.41083791513
# 003636, method='Nelder-Mead', residual=85529.41083791517
# 003637, method='Nelder-Mead', residual=85529.41083791517
# 003638, method='Nelder-Mead', residual=85529.41083791514
# 003639, method='Nelder-Mead', residual=85529.41083791514
# 003640, method='Nelder-Mead', residual=85529.41083791516
# 003641, method='Nelder-Mead', residual=85529.41083791514
# 003642, method='Nelder-Mead', residual=85529.41083791514
# 003643, method='Nelder-Mead', residual=85529.41083791514
# 003644, method='Nelder-Mead', residual=85529.41083791514
# 003645, method='Nelder-Mead', residual=85529.41083791514
# 003646, method='Nelder-Mead', residual=85529.41083791516
# 003647, method='Nelder-Mead', residual=85529.41083791514
# 003648, method='Nelder-Mead', residual=85529.41083791517
# 003649, method='Nelder-Mead', residual=85529.41083791516
# 003650, method='Nelder-Mead', residual=85529.41083791514
# 003651, method='Nelder-Mead', residual=85529.41083791517
# 003652, method='Nelder-Mead', residual=85529.41083791516
# 003653, method='Nelder-Mead', residual=85529.41083791514
# 003654, method='Nelder-Mead', residual=85529.41083791516
# 003655, method='Nelder-Mead', residual=85529.41083791516
# 003656, method='Nelder-Mead', residual=85529.41083791516
# 003657, method='Nelder-Mead', residual=85529.41083791516
# 003658, method='Nelder-Mead', residual=85529.41083791513
# 003659, method='Nelder-Mead', residual=85529.41083791517
# 003660, method='Nelder-Mead', residual=85529.41083791517
# 003661, method='Nelder-Mead', residual=85529.41083791517
# 003662, method='Nelder-Mead', residual=85529.41083791516
# 003663, method='Nelder-Mead', residual=85529.41083791514
# 003664, method='Nelder-Mead', residual=85529.41083791514
# 003665, method='Nelder-Mead', residual=85529.41083791516
# 003666, method='Nelder-Mead', residual=85529.41083791517
# 003667, method='Nelder-Mead', residual=85529.41083791519
# 003668, method='Nelder-Mead', residual=85529.41083791513
# 003669, method='Nelder-Mead', residual=85529.41083791516
# 003670, method='Nelder-Mead', residual=85529.41083791517
# 003671, method='Nelder-Mead', residual=85529.41083791517
# 003672, method='Nelder-Mead', residual=85529.41083791516
# 003673, method='Nelder-Mead', residual=85529.41083791514
# 003674, method='Nelder-Mead', residual=85529.41083791516
# 003675, method='Nelder-Mead', residual=85529.41083791516
# 003676, method='Nelder-Mead', residual=85529.41083791514
# 003677, method='Nelder-Mead', residual=85529.41083791514
# 003678, method='Nelder-Mead', residual=85529.41083791513
# 003679, method='Nelder-Mead', residual=85529.41083791517
# 003680, method='Nelder-Mead', residual=85529.41083791516
# 003681, method='Nelder-Mead', residual=85529.41083791516
# 003682, method='Nelder-Mead', residual=85529.41083791516
# 003683, method='Nelder-Mead', residual=85529.41083791516
# 003684, method='Nelder-Mead', residual=85529.41083791514
# 003685, method='Nelder-Mead', residual=85529.41083791517
# 003686, method='Nelder-Mead', residual=85529.41083791514
# 003687, method='Nelder-Mead', residual=85529.41083791514
# 003688, method='Nelder-Mead', residual=85529.41083791516
# 003689, method='Nelder-Mead', residual=85529.41083791517
# 003690, method='Nelder-Mead', residual=85529.41083791516
# 003691, method='Nelder-Mead', residual=85529.41083791516
# 003692, method='Nelder-Mead', residual=85529.41083791514
# 003693, method='Nelder-Mead', residual=85529.41083791514
# 003694, method='Nelder-Mead', residual=85529.41083791516
# 003695, method='Nelder-Mead', residual=85529.41083791516
# 003696, method='Nelder-Mead', residual=85529.41083791517
# 003697, method='Nelder-Mead', residual=85529.41083791517
# 003698, method='Nelder-Mead', residual=85529.41083791516
# 003699, method='Nelder-Mead', residual=85529.41083791516
# 003700, method='Nelder-Mead', residual=85529.41083791514
# 003701, method='Nelder-Mead', residual=85529.41083791516
# 003702, method='Nelder-Mead', residual=85529.41083791516
# 003703, method='Nelder-Mead', residual=85529.41083791513
# 003704, method='Nelder-Mead', residual=85529.41083791514
# 003705, method='Nelder-Mead', residual=85529.41083791519
# 003706, method='Nelder-Mead', residual=85529.41083791517
# 003707, method='Nelder-Mead', residual=85529.41083791514
# 003708, method='Nelder-Mead', residual=85529.41083791516
# 003709, method='Nelder-Mead', residual=85529.41083791516
# 003710, method='Nelder-Mead', residual=85529.41083791513
# 003711, method='Nelder-Mead', residual=85529.41083791517
# 003712, method='Nelder-Mead', residual=85529.41083791516
# 003713, method='Nelder-Mead', residual=85529.41083791516
# 003714, method='Nelder-Mead', residual=85529.41083791514
# 003715, method='Nelder-Mead', residual=85529.41083791516
# 003716, method='Nelder-Mead', residual=85529.41083791517
# 003717, method='Nelder-Mead', residual=85529.41083791514
# 003718, method='Nelder-Mead', residual=85529.41083791516
# 003719, method='Nelder-Mead', residual=85529.41083791514
# 003720, method='Nelder-Mead', residual=85529.41083791514
# 003721, method='Nelder-Mead', residual=85529.41083791517
# 003722, method='Nelder-Mead', residual=85529.41083791517
# 003723, method='Nelder-Mead', residual=85529.41083791516
# 003724, method='Nelder-Mead', residual=85529.41083791517
# 003725, method='Nelder-Mead', residual=85529.41083791517
# 003726, method='Nelder-Mead', residual=85529.41083791517
# 003727, method='Nelder-Mead', residual=85529.41083791514
# 003728, method='Nelder-Mead', residual=85529.41083791516
# 003729, method='Nelder-Mead', residual=85529.41083791516
# 003730, method='Nelder-Mead', residual=85529.41083791516
# 003731, method='Nelder-Mead', residual=85529.41083791514
# 003732, method='Nelder-Mead', residual=85529.41083791514
# 003733, method='Nelder-Mead', residual=85529.41083791516
# 003734, method='Nelder-Mead', residual=85529.41083791516
