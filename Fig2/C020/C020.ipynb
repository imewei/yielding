# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras


def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '../data_Twotime'
    DataFolderName = 'C020_Cys0_Exp2_Creep_XPCS_20Pa_01_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')
    
    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d

def fit_c2_polynomial(num_v=3, num_d=3, paras_fname=None):
    # read raw data
    c2_exp, t_length, phi_list, phi_length = read_data()
    x0 = np.array([
              1324.1  ,   -0.014, -124.865*0.0054,
              0.003, -0.909,  0.,
              0,
              ])
    # 0.0006395236354457675, -0.4278605424136395, -6.566316071911294e-05,
    for method in (
                'Nelder-Mead',
                # 'Powell',
                # 'L-BFGS-B',
                # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
                # 'trust-ncg', 'trust-exact', 'trust-krylov'):
                ):
    # def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
        FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                                args=(phi_list, num_d, num_v, c2_exp, method),
                                 options={"maxiter": 1000000}, tol=0.00001,
                                method=method)

    FitParas = FitOutput['x']
    
    c2_fit = Homodyne1(FitParas, phi_list)
    shape = c2_fit.shape
    sol_list = []
    for n in range(shape[0]):
        sumy = np.sum(c2_fit[n])
        a = np.array([
            [np.sum(c2_fit[n] ** 2), sumy],
            [sumy, c2_fit[n].size]
        ])
        b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
        sol = np.linalg.solve(a, b)
        sol_list.append(sol)

    
    FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
    np.savetxt('../FitParas/C020_FitParas.txt', FitParas, delimiter=",")

def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    shape = c2_exp.shape
    residual = 0.0
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]


    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    :
        c2_fit = Homodyne1(paras, phi_list)
        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)

        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        # plt.imshow(c2_fit[0])
        # # plt.imshow(c2_exp[0])
        # plt.show()
    else:
        residual = np.inf
    
    
    return residual



def Homodyne1(x, phi_list):
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054
    gap = 200 * 10000
    
    g1_s = np.exp(qValue**2 / 2 * -abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    
    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (w * g1_s) ** 2

    return g2_all

def Homodyne2(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    D, v, phio, beta, c = separate_params(x, phi_length)
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    dt = 0.1
    qValue = 0.0054
    gap = 200 * 10000
    
    g1_s = np.exp(qValue**2 / 2 * -abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (w * g1_s ) ** 2
    return g2_all


def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    beta = x[num_d + num_v + 1: num_d + num_v + phi_length + 1]
    c = x[num_d + num_v + phi_length + 1: num_d + num_v + 2 * phi_length + 1]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]

    return D, v, phio, beta, c

# %%
DTYPE = np.float64
gindex = 0
fit_c2_polynomial()
# Out:
# c2_cache_1001_2000.npz
# (23, 999, 999) float64
# 000001, method='Nelder-Mead', residual=87624.28057112453
# 000002, method='Nelder-Mead', residual=87448.52672207648
# 000003, method='Nelder-Mead', residual=87633.08951395183
# 000004, method='Nelder-Mead', residual=87624.37728726915
# 000005, method='Nelder-Mead', residual=87110.30577575357
# 000006, method='Nelder-Mead', residual=90560.49957884877
# 000007, method='Nelder-Mead', residual=111370.63465394074
# 000008, method='Nelder-Mead', residual=87624.2782544856
# 000009, method='Nelder-Mead', residual=96655.19231807394
# 000010, method='Nelder-Mead', residual=88120.8221731197
# 000011, method='Nelder-Mead', residual=85827.8716991054
# 000012, method='Nelder-Mead', residual=88150.9996795036
# 000013, method='Nelder-Mead', residual=85721.42074114872
# 000014, method='Nelder-Mead', residual=85564.62754603589
# 000015, method='Nelder-Mead', residual=85629.81422190025
# 000016, method='Nelder-Mead', residual=85538.3106148632
# 000017, method='Nelder-Mead', residual=86061.9967193804
# 000018, method='Nelder-Mead', residual=85752.89269661147
# 000019, method='Nelder-Mead', residual=86346.38179618788
# 000020, method='Nelder-Mead', residual=87524.81934988673
# 000021, method='Nelder-Mead', residual=85801.58870026251
# 000022, method='Nelder-Mead', residual=87292.620915594
# 000023, method='Nelder-Mead', residual=85745.210143742
# 000024, method='Nelder-Mead', residual=86439.36099258768
# 000025, method='Nelder-Mead', residual=85784.79453798592
# 000026, method='Nelder-Mead', residual=85523.61543717387
# 000027, method='Nelder-Mead', residual=85787.07564864145
# 000028, method='Nelder-Mead', residual=85987.22690071435
# 000029, method='Nelder-Mead', residual=85544.62428951569
# 000030, method='Nelder-Mead', residual=85782.07935296545
# 000031, method='Nelder-Mead', residual=85563.69874419077
# 000032, method='Nelder-Mead', residual=86029.79400815295
# 000033, method='Nelder-Mead', residual=85549.86497447464
# 000034, method='Nelder-Mead', residual=85557.1055211953
# 000035, method='Nelder-Mead', residual=85964.05307785906
# 000036, method='Nelder-Mead', residual=85534.4394069385
# 000037, method='Nelder-Mead', residual=85499.5339447897
# 000038, method='Nelder-Mead', residual=85608.22856995191
# 000039, method='Nelder-Mead', residual=85632.18359639012
# 000040, method='Nelder-Mead', residual=85490.18413373393
# 000041, method='Nelder-Mead', residual=85643.68390762429
# 000042, method='Nelder-Mead', residual=85493.5573188423
# 000043, method='Nelder-Mead', residual=85455.35638351129
# 000044, method='Nelder-Mead', residual=85489.10477831964
# 000045, method='Nelder-Mead', residual=85517.8941120604
# 000046, method='Nelder-Mead', residual=85404.52857177521
# 000047, method='Nelder-Mead', residual=85376.86898227381
# 000048, method='Nelder-Mead', residual=85417.71787210643
# 000049, method='Nelder-Mead', residual=85555.71416714287
# 000050, method='Nelder-Mead', residual=85444.99934246516
# 000051, method='Nelder-Mead', residual=85505.87345955013
# 000052, method='Nelder-Mead', residual=85441.49377109249
# 000053, method='Nelder-Mead', residual=85533.96080152129
# 000054, method='Nelder-Mead', residual=85440.50951627629
# 000055, method='Nelder-Mead', residual=85499.9919173027
# 000056, method='Nelder-Mead', residual=85439.79911249802
# 000057, method='Nelder-Mead', residual=85364.56598146787
# 000058, method='Nelder-Mead', residual=85344.60738071427
# 000059, method='Nelder-Mead', residual=85369.94548940995
# 000060, method='Nelder-Mead', residual=85371.40689199671
# 000061, method='Nelder-Mead', residual=85414.3607940978
# 000062, method='Nelder-Mead', residual=85349.18923683929
# 000063, method='Nelder-Mead', residual=85378.7703369098
# 000064, method='Nelder-Mead', residual=85548.41101280897
# 000065, method='Nelder-Mead', residual=85361.73327182235
# 000066, method='Nelder-Mead', residual=85347.82502594417
# 000067, method='Nelder-Mead', residual=85417.14821543492
# 000068, method='Nelder-Mead', residual=85352.24658281395
# 000069, method='Nelder-Mead', residual=85322.5604049221
# 000070, method='Nelder-Mead', residual=85300.95259092977
# 000071, method='Nelder-Mead', residual=85327.041505539
# 000072, method='Nelder-Mead', residual=85324.84700606097
# 000073, method='Nelder-Mead', residual=85343.99829193413
# 000074, method='Nelder-Mead', residual=85314.19375173848
# 000075, method='Nelder-Mead', residual=85313.56055150586
# 000076, method='Nelder-Mead', residual=85313.19253064074
# 000077, method='Nelder-Mead', residual=85311.73851090609
# 000078, method='Nelder-Mead', residual=85320.17318014572
# 000079, method='Nelder-Mead', residual=85289.31353257396
# 000080, method='Nelder-Mead', residual=85280.00342504187
# 000081, method='Nelder-Mead', residual=85272.92105459525
# 000082, method='Nelder-Mead', residual=85252.0077651125
# 000083, method='Nelder-Mead', residual=85309.51488870701
# 000084, method='Nelder-Mead', residual=85278.33594139264
# 000085, method='Nelder-Mead', residual=85293.66598415618
# 000086, method='Nelder-Mead', residual=85258.37134794173
# 000087, method='Nelder-Mead', residual=85241.90648384788
# 000088, method='Nelder-Mead', residual=85225.6860561019
# 000089, method='Nelder-Mead', residual=85222.1813750943
# 000090, method='Nelder-Mead', residual=85205.78631967345
# 000091, method='Nelder-Mead', residual=85222.65713297996
# 000092, method='Nelder-Mead', residual=85223.9382224696
# 000093, method='Nelder-Mead', residual=85171.71580819986
# 000094, method='Nelder-Mead', residual=85131.36959780873
# 000095, method='Nelder-Mead', residual=85163.28890297795
# 000096, method='Nelder-Mead', residual=85130.55946079183
# 000097, method='Nelder-Mead', residual=85093.40173183636
# 000098, method='Nelder-Mead', residual=85084.60100392776
# 000099, method='Nelder-Mead', residual=85025.72644171916
# 000100, method='Nelder-Mead', residual=85197.98738686444
# 000101, method='Nelder-Mead', residual=85047.88872366791
# 000102, method='Nelder-Mead', residual=85119.08437109987
# 000103, method='Nelder-Mead', residual=85018.00201510286
# 000104, method='Nelder-Mead', residual=84987.3861604439
# 000105, method='Nelder-Mead', residual=85052.7104461531
# 000106, method='Nelder-Mead', residual=84987.73384222465
# 000107, method='Nelder-Mead', residual=84987.07683205554
# 000108, method='Nelder-Mead', residual=85033.30299746006
# 000109, method='Nelder-Mead', residual=84989.6512884447
# 000110, method='Nelder-Mead', residual=84937.36078101059
# 000111, method='Nelder-Mead', residual=84947.89097363524
# 000112, method='Nelder-Mead', residual=84953.67107636666
# 000113, method='Nelder-Mead', residual=84943.56831701951
# 000114, method='Nelder-Mead', residual=84978.97667432662
# 000115, method='Nelder-Mead', residual=85065.7528008338
# 000116, method='Nelder-Mead', residual=84946.77441680175
# 000117, method='Nelder-Mead', residual=84936.61752693022
# 000118, method='Nelder-Mead', residual=84967.17929883367
# 000119, method='Nelder-Mead', residual=84946.82300930943
# 000120, method='Nelder-Mead', residual=84942.70587223377
# 000121, method='Nelder-Mead', residual=84947.93030474351
# 000122, method='Nelder-Mead', residual=84980.41468776432
# 000123, method='Nelder-Mead', residual=84928.87815307625
# 000124, method='Nelder-Mead', residual=84980.8482788696
# 000125, method='Nelder-Mead', residual=84927.52338262365
# 000126, method='Nelder-Mead', residual=84941.74507658418
# 000127, method='Nelder-Mead', residual=84937.55201839132
# 000128, method='Nelder-Mead', residual=84941.67614331962
# 000129, method='Nelder-Mead', residual=84957.42320880911
# 000130, method='Nelder-Mead', residual=84927.64131932288
# 000131, method='Nelder-Mead', residual=84932.08427506199
# 000132, method='Nelder-Mead', residual=84951.22376589787
# 000133, method='Nelder-Mead', residual=84927.60749325166
# 000134, method='Nelder-Mead', residual=84938.80674464209
# 000135, method='Nelder-Mead', residual=84926.50909777088
# 000136, method='Nelder-Mead', residual=84942.7390051985
# 000137, method='Nelder-Mead', residual=84925.88225601286
# 000138, method='Nelder-Mead', residual=84942.60987632786
# 000139, method='Nelder-Mead', residual=84925.91097029914
# 000140, method='Nelder-Mead', residual=84938.81928818456
# 000141, method='Nelder-Mead', residual=84924.7809826502
# 000142, method='Nelder-Mead', residual=84931.76227862382
# 000143, method='Nelder-Mead', residual=84924.20167134891
# 000144, method='Nelder-Mead', residual=84922.53370612822
# 000145, method='Nelder-Mead', residual=84927.0200026459
# 000146, method='Nelder-Mead', residual=84926.84234540246
# 000147, method='Nelder-Mead', residual=84938.33907704239
# 000148, method='Nelder-Mead', residual=84922.61217845128
# 000149, method='Nelder-Mead', residual=84927.78283012213
# 000150, method='Nelder-Mead', residual=84923.36842146095
# 000151, method='Nelder-Mead', residual=84927.08826040816
# 000152, method='Nelder-Mead', residual=84923.4130004547
# 000153, method='Nelder-Mead', residual=84926.16430365626
# 000154, method='Nelder-Mead', residual=84923.2576504871
# 000155, method='Nelder-Mead', residual=84921.89707706148
# 000156, method='Nelder-Mead', residual=84925.08485576403
# 000157, method='Nelder-Mead', residual=84926.21288852817
# 000158, method='Nelder-Mead', residual=84922.5087422367
# 000159, method='Nelder-Mead', residual=84920.9628311681
# 000160, method='Nelder-Mead', residual=84921.90566624641
# 000161, method='Nelder-Mead', residual=84920.51775302728
# 000162, method='Nelder-Mead', residual=84920.93502785289
# 000163, method='Nelder-Mead', residual=84920.49778459435
# 000164, method='Nelder-Mead', residual=84921.77534404256
# 000165, method='Nelder-Mead', residual=84919.03061123671
# 000166, method='Nelder-Mead', residual=84918.69950139795
# 000167, method='Nelder-Mead', residual=84919.85745451124
# 000168, method='Nelder-Mead', residual=84921.24488823654
# 000169, method='Nelder-Mead', residual=84916.04668592953
# 000170, method='Nelder-Mead', residual=84913.20479973557
# 000171, method='Nelder-Mead', residual=84917.33664078933
# 000172, method='Nelder-Mead', residual=84920.04943819712
# 000173, method='Nelder-Mead', residual=84917.5319719696
# 000174, method='Nelder-Mead', residual=84914.26086815877
# 000175, method='Nelder-Mead', residual=84913.17210197548
# 000176, method='Nelder-Mead', residual=84912.19816539781
# 000177, method='Nelder-Mead', residual=84912.15416146845
# 000178, method='Nelder-Mead', residual=84912.76947334876
# 000179, method='Nelder-Mead', residual=84916.45884759317
# 000180, method='Nelder-Mead', residual=84907.9245773578
# 000181, method='Nelder-Mead', residual=84903.49420413082
# 000182, method='Nelder-Mead', residual=84906.14703136435
# 000183, method='Nelder-Mead', residual=84903.31622137142
# 000184, method='Nelder-Mead', residual=84899.49192175051
# 000185, method='Nelder-Mead', residual=84907.98493766708
# 000186, method='Nelder-Mead', residual=84897.67787112272
# 000187, method='Nelder-Mead', residual=84890.65592443025
# 000188, method='Nelder-Mead', residual=84891.92244235828
# 000189, method='Nelder-Mead', residual=84895.27900502359
# 000190, method='Nelder-Mead', residual=84886.48180641512
# 000191, method='Nelder-Mead', residual=84880.20117806224
# 000192, method='Nelder-Mead', residual=84884.24056227024
# 000193, method='Nelder-Mead', residual=84882.4736575528
# 000194, method='Nelder-Mead', residual=84868.93970652221
# 000195, method='Nelder-Mead', residual=84853.25208210081
# 000196, method='Nelder-Mead', residual=84862.06094594428
# 000197, method='Nelder-Mead', residual=84872.66175877496
# 000198, method='Nelder-Mead', residual=84859.66018640304
# 000199, method='Nelder-Mead', residual=84866.1827684625
# 000200, method='Nelder-Mead', residual=84858.04529350538
# 000201, method='Nelder-Mead', residual=84840.34852889657
# 000202, method='Nelder-Mead', residual=84820.87327768483
# 000203, method='Nelder-Mead', residual=84827.86525815737
# 000204, method='Nelder-Mead', residual=84831.12775924128
# 000205, method='Nelder-Mead', residual=84829.85163392895
# 000206, method='Nelder-Mead', residual=84840.54186567763
# 000207, method='Nelder-Mead', residual=84804.84709729598
# 000208, method='Nelder-Mead', residual=84783.51045370454
# 000209, method='Nelder-Mead', residual=84785.87922261367
# 000210, method='Nelder-Mead', residual=84787.37350610617
# 000211, method='Nelder-Mead', residual=84791.67882938829
# 000212, method='Nelder-Mead', residual=84773.1014983593
# 000213, method='Nelder-Mead', residual=84757.39924920755
# 000214, method='Nelder-Mead', residual=84814.38240917698
# 000215, method='Nelder-Mead', residual=84728.43327932274
# 000216, method='Nelder-Mead', residual=84717.36340764599
# 000217, method='Nelder-Mead', residual=84746.12089321956
# 000218, method='Nelder-Mead', residual=84753.1445337903
# 000219, method='Nelder-Mead', residual=84855.91698182924
# 000220, method='Nelder-Mead', residual=84762.00626197395
# 000221, method='Nelder-Mead', residual=84719.84812473413
# 000222, method='Nelder-Mead', residual=84671.83878585255
# 000223, method='Nelder-Mead', residual=84720.80118863273
# 000224, method='Nelder-Mead', residual=84665.84337640906
# 000225, method='Nelder-Mead', residual=84630.63551306787
# 000226, method='Nelder-Mead', residual=84697.57801924233
# 000227, method='Nelder-Mead', residual=84642.39944031935
# 000228, method='Nelder-Mead', residual=86117.3753621283
# 000229, method='Nelder-Mead', residual=84698.45718821073
# 000230, method='Nelder-Mead', residual=84673.41644929914
# 000231, method='Nelder-Mead', residual=85036.72557454868
# 000232, method='Nelder-Mead', residual=84678.93775840833
# 000233, method='Nelder-Mead', residual=84688.2847045332
# 000234, method='Nelder-Mead', residual=84693.88120551627
# 000235, method='Nelder-Mead', residual=84703.2761336538
# 000236, method='Nelder-Mead', residual=84637.16919891682
# 000237, method='Nelder-Mead', residual=84701.8375682689
# 000238, method='Nelder-Mead', residual=84615.84357997932
# 000239, method='Nelder-Mead', residual=84709.84553495157
# 000240, method='Nelder-Mead', residual=84643.19850828851
# 000241, method='Nelder-Mead', residual=84671.44386904196
# 000242, method='Nelder-Mead', residual=84754.98124864991
# 000243, method='Nelder-Mead', residual=84629.75162178659
# 000244, method='Nelder-Mead', residual=84611.04261036453
# 000245, method='Nelder-Mead', residual=84872.25115763886
# 000246, method='Nelder-Mead', residual=84650.43186416227
# 000247, method='Nelder-Mead', residual=84628.28465452667
# 000248, method='Nelder-Mead', residual=84666.78503955707
# 000249, method='Nelder-Mead', residual=84621.82211720695
# 000250, method='Nelder-Mead', residual=84685.44619703825
# 000251, method='Nelder-Mead', residual=84615.97011177192
# 000252, method='Nelder-Mead', residual=84615.2221318348
# 000253, method='Nelder-Mead', residual=84593.86435688342
# 000254, method='Nelder-Mead', residual=84587.99578077106
# 000255, method='Nelder-Mead', residual=84598.60811202247
# 000256, method='Nelder-Mead', residual=84606.67295254898
# 000257, method='Nelder-Mead', residual=84633.5520497497
# 000258, method='Nelder-Mead', residual=84602.85597267444
# 000259, method='Nelder-Mead', residual=84582.75265822707
# 000260, method='Nelder-Mead', residual=84589.71774873929
# 000261, method='Nelder-Mead', residual=84572.34440881432
# 000262, method='Nelder-Mead', residual=84571.88279479036
# 000263, method='Nelder-Mead', residual=84633.35544833806
# 000264, method='Nelder-Mead', residual=84590.48459011622
# 000265, method='Nelder-Mead', residual=84582.50998067293
# 000266, method='Nelder-Mead', residual=84604.5737035659
# 000267, method='Nelder-Mead', residual=84588.1693795048
# 000268, method='Nelder-Mead', residual=84567.0707760026
# 000269, method='Nelder-Mead', residual=84572.10503824653
# 000270, method='Nelder-Mead', residual=84606.2321206704
# 000271, method='Nelder-Mead', residual=84580.48548657751
# 000272, method='Nelder-Mead', residual=84567.85813880428
# 000273, method='Nelder-Mead', residual=84570.677101979
# 000274, method='Nelder-Mead', residual=84584.40091188312
# 000275, method='Nelder-Mead', residual=84570.50468157264
# 000276, method='Nelder-Mead', residual=84571.97582757277
# 000277, method='Nelder-Mead', residual=84602.21531593347
# 000278, method='Nelder-Mead', residual=84571.94719921167
# 000279, method='Nelder-Mead', residual=84575.04734506512
# 000280, method='Nelder-Mead', residual=84568.14706729507
# 000281, method='Nelder-Mead', residual=84575.82298715474
# 000282, method='Nelder-Mead', residual=84567.54318642114
# 000283, method='Nelder-Mead', residual=84575.9645148616
# 000284, method='Nelder-Mead', residual=84567.90566405929
# 000285, method='Nelder-Mead', residual=84571.36226427084
# 000286, method='Nelder-Mead', residual=84567.24820913322
# 000287, method='Nelder-Mead', residual=84575.81959240198
# 000288, method='Nelder-Mead', residual=84566.66633207504
# 000289, method='Nelder-Mead', residual=84572.59541920271
# 000290, method='Nelder-Mead', residual=84567.05311624151
# 000291, method='Nelder-Mead', residual=84571.2878213159
# 000292, method='Nelder-Mead', residual=84566.52775145635
# 000293, method='Nelder-Mead', residual=84566.70430253382
# 000294, method='Nelder-Mead', residual=84567.47597919397
# 000295, method='Nelder-Mead', residual=84568.3450265256
# 000296, method='Nelder-Mead', residual=84566.45654734402
# 000297, method='Nelder-Mead', residual=84567.518624693
# 000298, method='Nelder-Mead', residual=84566.40662561702
# 000299, method='Nelder-Mead', residual=84568.0232206272
# 000300, method='Nelder-Mead', residual=84566.31777756069
# 000301, method='Nelder-Mead', residual=84566.89325044389
# 000302, method='Nelder-Mead', residual=84567.41798799131
# 000303, method='Nelder-Mead', residual=84566.31772314296
# 000304, method='Nelder-Mead', residual=84566.82309042517
# 000305, method='Nelder-Mead', residual=84566.27620284409
# 000306, method='Nelder-Mead', residual=84566.62516241224
# 000307, method='Nelder-Mead', residual=84567.77796544852
# 000308, method='Nelder-Mead', residual=84566.13540714169
# 000309, method='Nelder-Mead', residual=84566.66444030993
# 000310, method='Nelder-Mead', residual=84566.23613529967
# 000311, method='Nelder-Mead', residual=84567.13406236094
# 000312, method='Nelder-Mead', residual=84566.16119005668
# 000313, method='Nelder-Mead', residual=84566.42255206213
# 000314, method='Nelder-Mead', residual=84566.18446830855
# 000315, method='Nelder-Mead', residual=84566.39481669325
# 000316, method='Nelder-Mead', residual=84566.18684787047
# 000317, method='Nelder-Mead', residual=84566.53102071326
# 000318, method='Nelder-Mead', residual=84566.14253040685
# 000319, method='Nelder-Mead', residual=84566.0706399202
# 000320, method='Nelder-Mead', residual=84566.21732771207
# 000321, method='Nelder-Mead', residual=84565.93730407655
# 000322, method='Nelder-Mead', residual=84565.89417841802
# 000323, method='Nelder-Mead', residual=84566.01700287643
# 000324, method='Nelder-Mead', residual=84565.93237721943
# 000325, method='Nelder-Mead', residual=84566.11309584377
# 000326, method='Nelder-Mead', residual=84566.49280729362
# 000327, method='Nelder-Mead', residual=84565.977902965
# 000328, method='Nelder-Mead', residual=84565.77019526518
# 000329, method='Nelder-Mead', residual=84565.634896514
# 000330, method='Nelder-Mead', residual=84565.89583597203
# 000331, method='Nelder-Mead', residual=84565.76759695173
# 000332, method='Nelder-Mead', residual=84565.89101418365
# 000333, method='Nelder-Mead', residual=84565.54143000627
# 000334, method='Nelder-Mead', residual=84565.33850119257
# 000335, method='Nelder-Mead', residual=84565.61513795675
# 000336, method='Nelder-Mead', residual=84565.41549758677
# 000337, method='Nelder-Mead', residual=84565.74082988563
# 000338, method='Nelder-Mead', residual=84565.37020679904
# 000339, method='Nelder-Mead', residual=84565.1494548736
# 000340, method='Nelder-Mead', residual=84564.94630857349
# 000341, method='Nelder-Mead', residual=84565.07878652979
# 000342, method='Nelder-Mead', residual=84565.33199473217
# 000343, method='Nelder-Mead', residual=84564.761578103
# 000344, method='Nelder-Mead', residual=84564.36510501543
# 000345, method='Nelder-Mead', residual=84564.75699403971
# 000346, method='Nelder-Mead', residual=84564.51388027357
# 000347, method='Nelder-Mead', residual=84564.82051051588
# 000348, method='Nelder-Mead', residual=84564.21379210494
# 000349, method='Nelder-Mead', residual=84563.8199236394
# 000350, method='Nelder-Mead', residual=84563.80473462342
# 000351, method='Nelder-Mead', residual=84563.2904017632
# 000352, method='Nelder-Mead', residual=84564.18297792324
# 000353, method='Nelder-Mead', residual=84563.54745135986
# 000354, method='Nelder-Mead', residual=84563.2174119181
# 000355, method='Nelder-Mead', residual=84562.77806572037
# 000356, method='Nelder-Mead', residual=84562.47814564459
# 000357, method='Nelder-Mead', residual=84561.47665017928
# 000358, method='Nelder-Mead', residual=84561.95532059883
# 000359, method='Nelder-Mead', residual=84561.62162003596
# 000360, method='Nelder-Mead', residual=84561.26897528852
# 000361, method='Nelder-Mead', residual=84560.72364005438
# 000362, method='Nelder-Mead', residual=84561.05768843404
# 000363, method='Nelder-Mead', residual=84560.75062333925
# 000364, method='Nelder-Mead', residual=84559.32817779788
# 000365, method='Nelder-Mead', residual=84557.88827563243
# 000366, method='Nelder-Mead', residual=84558.37637506792
# 000367, method='Nelder-Mead', residual=84559.14592035435
# 000368, method='Nelder-Mead', residual=84559.97595509114
# 000369, method='Nelder-Mead', residual=84558.94118607526
# 000370, method='Nelder-Mead', residual=84557.66469479998
# 000371, method='Nelder-Mead', residual=84557.17014617161
# 000372, method='Nelder-Mead', residual=84556.90695925214
# 000373, method='Nelder-Mead', residual=84556.42324834062
# 000374, method='Nelder-Mead', residual=84556.0011595294
# 000375, method='Nelder-Mead', residual=84556.49880620246
# 000376, method='Nelder-Mead', residual=84554.72765181595
# 000377, method='Nelder-Mead', residual=84553.60002474579
# 000378, method='Nelder-Mead', residual=84553.67067379807
# 000379, method='Nelder-Mead', residual=84553.5765921733
# 000380, method='Nelder-Mead', residual=84554.07167221371
# 000381, method='Nelder-Mead', residual=84555.08512873058
# 000382, method='Nelder-Mead', residual=84552.65228055857
# 000383, method='Nelder-Mead', residual=84552.58292905746
# 000384, method='Nelder-Mead', residual=84553.29845156446
# 000385, method='Nelder-Mead', residual=84551.27895860552
# 000386, method='Nelder-Mead', residual=84553.19236459259
# 000387, method='Nelder-Mead', residual=84553.80675163263
# 000388, method='Nelder-Mead', residual=84552.47896544592
# 000389, method='Nelder-Mead', residual=84554.08020404592
# 000390, method='Nelder-Mead', residual=84552.2001273126
# 000391, method='Nelder-Mead', residual=84553.32373904086
# 000392, method='Nelder-Mead', residual=84552.79435128318
# 000393, method='Nelder-Mead', residual=84556.9721007947
# 000394, method='Nelder-Mead', residual=84551.90129982732
# 000395, method='Nelder-Mead', residual=84551.90579512597
# 000396, method='Nelder-Mead', residual=84549.8309388736
# 000397, method='Nelder-Mead', residual=84549.32666241836
# 000398, method='Nelder-Mead', residual=84552.5178571274
# 000399, method='Nelder-Mead', residual=84554.70746996948
# 000400, method='Nelder-Mead', residual=84550.92592788748
# 000401, method='Nelder-Mead', residual=84552.75988713211
# 000402, method='Nelder-Mead', residual=84551.29979958484
# 000403, method='Nelder-Mead', residual=84552.92804271234
# 000404, method='Nelder-Mead', residual=84551.2267026148
# 000405, method='Nelder-Mead', residual=84550.2245301723
# 000406, method='Nelder-Mead', residual=84549.9280489711
# 000407, method='Nelder-Mead', residual=84548.97455888137
# 000408, method='Nelder-Mead', residual=84548.44325554094
# 000409, method='Nelder-Mead', residual=84548.92434516859
# 000410, method='Nelder-Mead', residual=84549.14184736334
# 000411, method='Nelder-Mead', residual=84548.95774341866
# 000412, method='Nelder-Mead', residual=84549.04484282352
# 000413, method='Nelder-Mead', residual=84548.77683624414
# 000414, method='Nelder-Mead', residual=84548.66669131293
# 000415, method='Nelder-Mead', residual=84548.54105879263
# 000416, method='Nelder-Mead', residual=84548.83943250452
# 000417, method='Nelder-Mead', residual=84549.05317370937
# 000418, method='Nelder-Mead', residual=84548.41133235596
# 000419, method='Nelder-Mead', residual=84549.36444275707
# 000420, method='Nelder-Mead', residual=84548.344261416
# 000421, method='Nelder-Mead', residual=84549.81257600638
# 000422, method='Nelder-Mead', residual=84548.26708463489
# 000423, method='Nelder-Mead', residual=84548.8920979527
# 000424, method='Nelder-Mead', residual=84548.33137342737
# 000425, method='Nelder-Mead', residual=84549.63997247387
# 000426, method='Nelder-Mead', residual=84548.2560321243
# 000427, method='Nelder-Mead', residual=84548.84824324606
# 000428, method='Nelder-Mead', residual=84548.3046895156
# 000429, method='Nelder-Mead', residual=84548.46954391312
# 000430, method='Nelder-Mead', residual=84548.25035778996
# 000431, method='Nelder-Mead', residual=84548.33458178493
# 000432, method='Nelder-Mead', residual=84548.18673251916
# 000433, method='Nelder-Mead', residual=84548.53864033803
# 000434, method='Nelder-Mead', residual=84548.4080636999
# 000435, method='Nelder-Mead', residual=84548.18855244844
# 000436, method='Nelder-Mead', residual=84548.39177472357
# 000437, method='Nelder-Mead', residual=84548.18120785442
# 000438, method='Nelder-Mead', residual=84548.32674239318
# 000439, method='Nelder-Mead', residual=84548.18404839767
# 000440, method='Nelder-Mead', residual=84548.35860218492
# 000441, method='Nelder-Mead', residual=84548.17253228025
# 000442, method='Nelder-Mead', residual=84548.30178513337
# 000443, method='Nelder-Mead', residual=84548.1633611649
# 000444, method='Nelder-Mead', residual=84548.32537072695
# 000445, method='Nelder-Mead', residual=84548.15954789311
# 000446, method='Nelder-Mead', residual=84548.1945932679
# 000447, method='Nelder-Mead', residual=84548.13914570198
# 000448, method='Nelder-Mead', residual=84548.16607459143
# 000449, method='Nelder-Mead', residual=84548.30550895192
# 000450, method='Nelder-Mead', residual=84548.12992595231
# 000451, method='Nelder-Mead', residual=84548.22003352795
# 000452, method='Nelder-Mead', residual=84548.13986536214
# 000453, method='Nelder-Mead', residual=84548.15498102983
# 000454, method='Nelder-Mead', residual=84548.2050961174
# 000455, method='Nelder-Mead', residual=84548.13459625779
# 000456, method='Nelder-Mead', residual=84548.18296003104
# 000457, method='Nelder-Mead', residual=84548.13398697255
# 000458, method='Nelder-Mead', residual=84548.1457519341
# 000459, method='Nelder-Mead', residual=84548.15927450039
# 000460, method='Nelder-Mead', residual=84548.1325716148
# 000461, method='Nelder-Mead', residual=84548.17772450727
# 000462, method='Nelder-Mead', residual=84548.12955811342
# 000463, method='Nelder-Mead', residual=84548.15065404544
# 000464, method='Nelder-Mead', residual=84548.12933920848
# 000465, method='Nelder-Mead', residual=84548.1494559582
# 000466, method='Nelder-Mead', residual=84548.12729127941
# 000467, method='Nelder-Mead', residual=84548.13699953185
# 000468, method='Nelder-Mead', residual=84548.12695503044
# 000469, method='Nelder-Mead', residual=84548.13967621716
# 000470, method='Nelder-Mead', residual=84548.12607985675
# 000471, method='Nelder-Mead', residual=84548.14836483897
# 000472, method='Nelder-Mead', residual=84548.12514754703
# 000473, method='Nelder-Mead', residual=84548.12907896972
# 000474, method='Nelder-Mead', residual=84548.14191479239
# 000475, method='Nelder-Mead', residual=84548.12419617578
# 000476, method='Nelder-Mead', residual=84548.13002583513
# 000477, method='Nelder-Mead', residual=84548.12529194148
# 000478, method='Nelder-Mead', residual=84548.13703279392
# 000479, method='Nelder-Mead', residual=84548.12465054217
# 000480, method='Nelder-Mead', residual=84548.12971487083
# 000481, method='Nelder-Mead', residual=84548.1252291877
# 000482, method='Nelder-Mead', residual=84548.12331704068
# 000483, method='Nelder-Mead', residual=84548.12600533108
# 000484, method='Nelder-Mead', residual=84548.12606734435
# 000485, method='Nelder-Mead', residual=84548.1260881822
# 000486, method='Nelder-Mead', residual=84548.1240589586
# 000487, method='Nelder-Mead', residual=84548.12685297165
# 000488, method='Nelder-Mead', residual=84548.1239590797
# 000489, method='Nelder-Mead', residual=84548.12492302182
# 000490, method='Nelder-Mead', residual=84548.12625318041
# 000491, method='Nelder-Mead', residual=84548.12370084965
# 000492, method='Nelder-Mead', residual=84548.12444319522
# 000493, method='Nelder-Mead', residual=84548.1253094228
# 000494, method='Nelder-Mead', residual=84548.12360953393
# 000495, method='Nelder-Mead', residual=84548.12421835859
# 000496, method='Nelder-Mead', residual=84548.1253367592
# 000497, method='Nelder-Mead', residual=84548.12340620342
# 000498, method='Nelder-Mead', residual=84548.12451006247
# 000499, method='Nelder-Mead', residual=84548.12340936346
# 000500, method='Nelder-Mead', residual=84548.12422094564
# 000501, method='Nelder-Mead', residual=84548.1234228695
# 000502, method='Nelder-Mead', residual=84548.12370687592
# 000503, method='Nelder-Mead', residual=84548.12287367949
# 000504, method='Nelder-Mead', residual=84548.12341540845
# 000505, method='Nelder-Mead', residual=84548.12364282916
# 000506, method='Nelder-Mead', residual=84548.12446064691
# 000507, method='Nelder-Mead', residual=84548.12309401258
# 000508, method='Nelder-Mead', residual=84548.12384941941
# 000509, method='Nelder-Mead', residual=84548.12313444803
# 000510, method='Nelder-Mead', residual=84548.12421898
# 000511, method='Nelder-Mead', residual=84548.12308969602
# 000512, method='Nelder-Mead', residual=84548.12253702508
# 000513, method='Nelder-Mead', residual=84548.12219374267
# 000514, method='Nelder-Mead', residual=84548.12248062497
# 000515, method='Nelder-Mead', residual=84548.12288145277
# 000516, method='Nelder-Mead', residual=84548.12302619145
# 000517, method='Nelder-Mead', residual=84548.12225799756
# 000518, method='Nelder-Mead', residual=84548.12190013441
# 000519, method='Nelder-Mead', residual=84548.12148969325
# 000520, method='Nelder-Mead', residual=84548.1216671871
# 000521, method='Nelder-Mead', residual=84548.12279595753
# 000522, method='Nelder-Mead', residual=84548.12156656217
# 000523, method='Nelder-Mead', residual=84548.12116850716
# 000524, method='Nelder-Mead', residual=84548.1209533861
# 000525, method='Nelder-Mead', residual=84548.12272721909
# 000526, method='Nelder-Mead', residual=84548.1218627584
# 000527, method='Nelder-Mead', residual=84548.12065583048
# 000528, method='Nelder-Mead', residual=84548.12002921532
# 000529, method='Nelder-Mead', residual=84548.12009536571
# 000530, method='Nelder-Mead', residual=84548.11970072729
# 000531, method='Nelder-Mead', residual=84548.11882731489
# 000532, method='Nelder-Mead', residual=84548.11972941805
# 000533, method='Nelder-Mead', residual=84548.11913774312
# 000534, method='Nelder-Mead', residual=84548.11865078556
# 000535, method='Nelder-Mead', residual=84548.1182736804
# 000536, method='Nelder-Mead', residual=84548.11744396342
# 000537, method='Nelder-Mead', residual=84548.11637457684
# 000538, method='Nelder-Mead', residual=84548.11653935892
# 000539, method='Nelder-Mead', residual=84548.11745726748
# 000540, method='Nelder-Mead', residual=84548.11628309093
# 000541, method='Nelder-Mead', residual=84548.1162571339
# 000542, method='Nelder-Mead', residual=84548.11587675473
# 000543, method='Nelder-Mead', residual=84548.11680644439
# 000544, method='Nelder-Mead', residual=84548.11627860066
# 000545, method='Nelder-Mead', residual=84548.11600032388
# 000546, method='Nelder-Mead', residual=84548.11357894535
# 000547, method='Nelder-Mead', residual=84548.11215821443
# 000548, method='Nelder-Mead', residual=84548.11295805851
# 000549, method='Nelder-Mead', residual=84548.11871722908
# 000550, method='Nelder-Mead', residual=84548.11479431455
# 000551, method='Nelder-Mead', residual=84548.11537359165
# 000552, method='Nelder-Mead', residual=84548.11303401305
# 000553, method='Nelder-Mead', residual=84548.11223130877
# 000554, method='Nelder-Mead', residual=84548.1118668744
# 000555, method='Nelder-Mead', residual=84548.11195981033
# 000556, method='Nelder-Mead', residual=84548.11059683112
# 000557, method='Nelder-Mead', residual=84548.10978589377
# 000558, method='Nelder-Mead', residual=84548.1094863733
# 000559, method='Nelder-Mead', residual=84548.10894316567
# 000560, method='Nelder-Mead', residual=84548.10865068997
# 000561, method='Nelder-Mead', residual=84548.1091018116
# 000562, method='Nelder-Mead', residual=84548.10682650859
# 000563, method='Nelder-Mead', residual=84548.10416113191
# 000564, method='Nelder-Mead', residual=84548.10463784898
# 000565, method='Nelder-Mead', residual=84548.10549227374
# 000566, method='Nelder-Mead', residual=84548.10120500343
# 000567, method='Nelder-Mead', residual=84548.096434867
# 000568, method='Nelder-Mead', residual=84548.09669752546
# 000569, method='Nelder-Mead', residual=84548.09960838605
# 000570, method='Nelder-Mead', residual=84548.10074994707
# 000571, method='Nelder-Mead', residual=84548.0923238813
# 000572, method='Nelder-Mead', residual=84548.08600124877
# 000573, method='Nelder-Mead', residual=84548.0895478433
# 000574, method='Nelder-Mead', residual=84548.08597141207
# 000575, method='Nelder-Mead', residual=84548.07844598213
# 000576, method='Nelder-Mead', residual=84548.08026411105
# 000577, method='Nelder-Mead', residual=84548.08674072567
# 000578, method='Nelder-Mead', residual=84548.07530226847
# 000579, method='Nelder-Mead', residual=84548.06710331801
# 000580, method='Nelder-Mead', residual=84548.07037519268
# 000581, method='Nelder-Mead', residual=84548.06073690373
# 000582, method='Nelder-Mead', residual=84548.04566289144
# 000583, method='Nelder-Mead', residual=84548.06096263524
# 000584, method='Nelder-Mead', residual=84548.05876931178
# 000585, method='Nelder-Mead', residual=84548.04370581571
# 000586, method='Nelder-Mead', residual=84548.02657377215
# 000587, method='Nelder-Mead', residual=84548.0381825677
# 000588, method='Nelder-Mead', residual=84548.02908383135
# 000589, method='Nelder-Mead', residual=84548.02385216599
# 000590, method='Nelder-Mead', residual=84548.01012546556
# 000591, method='Nelder-Mead', residual=84548.01335591443
# 000592, method='Nelder-Mead', residual=84548.0026064245
# 000593, method='Nelder-Mead', residual=84547.98503706582
# 000594, method='Nelder-Mead', residual=84547.98484071545
# 000595, method='Nelder-Mead', residual=84547.9641328903
# 000596, method='Nelder-Mead', residual=84547.98748965508
# 000597, method='Nelder-Mead', residual=84547.96283928303
# 000598, method='Nelder-Mead', residual=84547.94096731256
# 000599, method='Nelder-Mead', residual=84547.95772931499
# 000600, method='Nelder-Mead', residual=84547.95814934198
# 000601, method='Nelder-Mead', residual=84547.95128761927
# 000602, method='Nelder-Mead', residual=84547.93474289353
# 000603, method='Nelder-Mead', residual=84547.9449575903
# 000604, method='Nelder-Mead', residual=84547.91770162129
# 000605, method='Nelder-Mead', residual=84547.89888694951
# 000606, method='Nelder-Mead', residual=84547.93581977216
# 000607, method='Nelder-Mead', residual=84547.96666326125
# 000608, method='Nelder-Mead', residual=84547.93998047637
# 000609, method='Nelder-Mead', residual=84547.90557213337
# 000610, method='Nelder-Mead', residual=84547.9044510524
# 000611, method='Nelder-Mead', residual=84547.90007149096
# 000612, method='Nelder-Mead', residual=84547.92275627238
# 000613, method='Nelder-Mead', residual=84547.9196343376
# 000614, method='Nelder-Mead', residual=84547.88079716825
# 000615, method='Nelder-Mead', residual=84547.86370055175
# 000616, method='Nelder-Mead', residual=84547.86565441002
# 000617, method='Nelder-Mead', residual=84547.86381646461
# 000618, method='Nelder-Mead', residual=84547.88896817135
# 000619, method='Nelder-Mead', residual=84547.85375161016
# 000620, method='Nelder-Mead', residual=84547.84259347581
# 000621, method='Nelder-Mead', residual=84547.84761295645
# 000622, method='Nelder-Mead', residual=84547.84401986745
# 000623, method='Nelder-Mead', residual=84547.8053571832
# 000624, method='Nelder-Mead', residual=84547.76867901489
# 000625, method='Nelder-Mead', residual=84547.82859051925
# 000626, method='Nelder-Mead', residual=84547.81190310436
# 000627, method='Nelder-Mead', residual=84547.83307938113
# 000628, method='Nelder-Mead', residual=84547.77940683922
# 000629, method='Nelder-Mead', residual=84547.7827730956
# 000630, method='Nelder-Mead', residual=84547.77320623185
# 000631, method='Nelder-Mead', residual=84547.76101125193
# 000632, method='Nelder-Mead', residual=84547.76521409005
# 000633, method='Nelder-Mead', residual=84547.7284147631
# 000634, method='Nelder-Mead', residual=84547.69325594981
# 000635, method='Nelder-Mead', residual=84547.72351879996
# 000636, method='Nelder-Mead', residual=84547.70147792717
# 000637, method='Nelder-Mead', residual=84547.70563357406
# 000638, method='Nelder-Mead', residual=84547.66816860586
# 000639, method='Nelder-Mead', residual=84547.62793513584
# 000640, method='Nelder-Mead', residual=84547.66046900942
# 000641, method='Nelder-Mead', residual=84547.5982220772
# 000642, method='Nelder-Mead', residual=84547.5224786174
# 000643, method='Nelder-Mead', residual=84547.56119758009
# 000644, method='Nelder-Mead', residual=84547.5609930222
# 000645, method='Nelder-Mead', residual=84547.5070487194
# 000646, method='Nelder-Mead', residual=84547.4226252497
# 000647, method='Nelder-Mead', residual=84547.50217858408
# 000648, method='Nelder-Mead', residual=84547.42248006955
# 000649, method='Nelder-Mead', residual=84547.35514641079
# 000650, method='Nelder-Mead', residual=84547.32625656141
# 000651, method='Nelder-Mead', residual=84547.19311103635
# 000652, method='Nelder-Mead', residual=84547.20657372291
# 000653, method='Nelder-Mead', residual=84547.21749599781
# 000654, method='Nelder-Mead', residual=84547.09393015085
# 000655, method='Nelder-Mead', residual=84546.89594687709
# 000656, method='Nelder-Mead', residual=84546.99389350302
# 000657, method='Nelder-Mead', residual=84546.90188276734
# 000658, method='Nelder-Mead', residual=84546.88344103476
# 000659, method='Nelder-Mead', residual=84546.82218071469
# 000660, method='Nelder-Mead', residual=84546.66766734126
# 000661, method='Nelder-Mead', residual=84546.42845743
# 000662, method='Nelder-Mead', residual=84546.49756077059
# 000663, method='Nelder-Mead', residual=84546.41325099893
# 000664, method='Nelder-Mead', residual=84546.18706721452
# 000665, method='Nelder-Mead', residual=84546.14885299548
# 000666, method='Nelder-Mead', residual=84545.86720710694
# 000667, method='Nelder-Mead', residual=84546.02520600228
# 000668, method='Nelder-Mead', residual=84545.85370436037
# 000669, method='Nelder-Mead', residual=84545.62618274428
# 000670, method='Nelder-Mead', residual=84545.78516753504
# 000671, method='Nelder-Mead', residual=84545.15640843214
# 000672, method='Nelder-Mead', residual=84544.56332474588
# 000673, method='Nelder-Mead', residual=84545.35641187098
# 000674, method='Nelder-Mead', residual=84545.8784727125
# 000675, method='Nelder-Mead', residual=84545.01032663333
# 000676, method='Nelder-Mead', residual=84545.1901316941
# 000677, method='Nelder-Mead', residual=84545.16154212052
# 000678, method='Nelder-Mead', residual=84544.76852422349
# 000679, method='Nelder-Mead', residual=84544.22596484637
# 000680, method='Nelder-Mead', residual=84543.69077857121
# 000681, method='Nelder-Mead', residual=84544.35141110556
# 000682, method='Nelder-Mead', residual=84543.64257634964
# 000683, method='Nelder-Mead', residual=84542.8585203387
# 000684, method='Nelder-Mead', residual=84543.80783318846
# 000685, method='Nelder-Mead', residual=84543.7856974108
# 000686, method='Nelder-Mead', residual=84543.3090899638
# 000687, method='Nelder-Mead', residual=84542.87116981414
# 000688, method='Nelder-Mead', residual=84542.92140113967
# 000689, method='Nelder-Mead', residual=84541.985897397
# 000690, method='Nelder-Mead', residual=84541.2382618806
# 000691, method='Nelder-Mead', residual=84542.29119982656
# 000692, method='Nelder-Mead', residual=84542.0077836967
# 000693, method='Nelder-Mead', residual=84541.32920170003
# 000694, method='Nelder-Mead', residual=84541.63048975004
# 000695, method='Nelder-Mead', residual=84541.42186445449
# 000696, method='Nelder-Mead', residual=84540.71326335326
# 000697, method='Nelder-Mead', residual=84541.8904372808
# 000698, method='Nelder-Mead', residual=84542.73123001002
# 000699, method='Nelder-Mead', residual=84541.35944696353
# 000700, method='Nelder-Mead', residual=84542.38213438577
# 000701, method='Nelder-Mead', residual=84541.46287550296
# 000702, method='Nelder-Mead', residual=84540.50028312374
# 000703, method='Nelder-Mead', residual=84540.31110810839
# 000704, method='Nelder-Mead', residual=84540.2046191205
# 000705, method='Nelder-Mead', residual=84539.82266269348
# 000706, method='Nelder-Mead', residual=84540.21803275397
# 000707, method='Nelder-Mead', residual=84539.84711394302
# 000708, method='Nelder-Mead', residual=84539.36798884909
# 000709, method='Nelder-Mead', residual=84538.94825605032
# 000710, method='Nelder-Mead', residual=84539.29160124037
# 000711, method='Nelder-Mead', residual=84538.06174316151
# 000712, method='Nelder-Mead', residual=84537.5179959531
# 000713, method='Nelder-Mead', residual=84537.24680000792
# 000714, method='Nelder-Mead', residual=84535.97005912144
# 000715, method='Nelder-Mead', residual=84537.39903542041
# 000716, method='Nelder-Mead', residual=84536.29210800322
# 000717, method='Nelder-Mead', residual=84535.00320692839
# 000718, method='Nelder-Mead', residual=84533.25300504534
# 000719, method='Nelder-Mead', residual=84533.12537308873
# 000720, method='Nelder-Mead', residual=84531.16910438097
# 000721, method='Nelder-Mead', residual=84533.15611681713
# 000722, method='Nelder-Mead', residual=84531.15694871609
# 000723, method='Nelder-Mead', residual=84536.8776289232
# 000724, method='Nelder-Mead', residual=84532.74566201547
# 000725, method='Nelder-Mead', residual=84528.15559536206
# 000726, method='Nelder-Mead', residual=84525.10944431367
# 000727, method='Nelder-Mead', residual=84524.742330249
# 000728, method='Nelder-Mead', residual=84519.93562824084
# 000729, method='Nelder-Mead', residual=84519.75356679395
# 000730, method='Nelder-Mead', residual=84513.0577487855
# 000731, method='Nelder-Mead', residual=84523.44066172076
# 000732, method='Nelder-Mead', residual=84526.37278030165
# 000733, method='Nelder-Mead', residual=84565.40432064065
# 000734, method='Nelder-Mead', residual=84525.81736021601
# 000735, method='Nelder-Mead', residual=84513.09080730546
# 000736, method='Nelder-Mead', residual=84507.92657111547
# 000737, method='Nelder-Mead', residual=84499.85253241808
# 000738, method='Nelder-Mead', residual=84516.7672122814
# 000739, method='Nelder-Mead', residual=84514.29155163985
# 000740, method='Nelder-Mead', residual=84505.56115292892
# 000741, method='Nelder-Mead', residual=84495.39788019199
# 000742, method='Nelder-Mead', residual=84488.20023895618
# 000743, method='Nelder-Mead', residual=84492.61085272524
# 000744, method='Nelder-Mead', residual=84543.06862587143
# 000745, method='Nelder-Mead', residual=84505.35183130375
# 000746, method='Nelder-Mead', residual=84496.82999142542
# 000747, method='Nelder-Mead', residual=84481.83019473428
# 000748, method='Nelder-Mead', residual=84470.87451874814
# 000749, method='Nelder-Mead', residual=84470.2703527635
# 000750, method='Nelder-Mead', residual=84460.21304293825
# 000751, method='Nelder-Mead', residual=84466.54009536911
# 000752, method='Nelder-Mead', residual=84466.72798038826
# 000753, method='Nelder-Mead', residual=84483.93864497746
# 000754, method='Nelder-Mead', residual=84472.45294560611
# 000755, method='Nelder-Mead', residual=84485.05821778809
# 000756, method='Nelder-Mead', residual=84464.67771012944
# 000757, method='Nelder-Mead', residual=84483.57484554371
# 000758, method='Nelder-Mead', residual=84496.58714325706
# 000759, method='Nelder-Mead', residual=84461.7781763358
# 000760, method='Nelder-Mead', residual=84473.07579688492
# 000761, method='Nelder-Mead', residual=84456.68840440955
# 000762, method='Nelder-Mead', residual=84465.46767806006
# 000763, method='Nelder-Mead', residual=84443.55866277449
# 000764, method='Nelder-Mead', residual=84443.11881319639
# 000765, method='Nelder-Mead', residual=84439.90687858402
# 000766, method='Nelder-Mead', residual=84440.11256586933
# 000767, method='Nelder-Mead', residual=84494.29089600996
# 000768, method='Nelder-Mead', residual=84452.01735259533
# 000769, method='Nelder-Mead', residual=84470.72551909921
# 000770, method='Nelder-Mead', residual=84452.91986562609
# 000771, method='Nelder-Mead', residual=84468.29956297996
# 000772, method='Nelder-Mead', residual=84449.23268774876
# 000773, method='Nelder-Mead', residual=84430.7409781059
# 000774, method='Nelder-Mead', residual=84420.32399949258
# 000775, method='Nelder-Mead', residual=84439.06711982338
# 000776, method='Nelder-Mead', residual=84416.92604784908
# 000777, method='Nelder-Mead', residual=84400.35465805966
# 000778, method='Nelder-Mead', residual=84416.04783028648
# 000779, method='Nelder-Mead', residual=84436.4997658623
# 000780, method='Nelder-Mead', residual=84390.26251104094
# 000781, method='Nelder-Mead', residual=84363.52568031053
# 000782, method='Nelder-Mead', residual=84383.90904526325
# 000783, method='Nelder-Mead', residual=84403.77084512361
# 000784, method='Nelder-Mead', residual=84424.67407508986
# 000785, method='Nelder-Mead', residual=84372.29157264436
# 000786, method='Nelder-Mead', residual=84427.75013563274
# 000787, method='Nelder-Mead', residual=84389.94312805145
# 000788, method='Nelder-Mead', residual=84346.06625440567
# 000789, method='Nelder-Mead', residual=84316.51202327886
# 000790, method='Nelder-Mead', residual=84325.26887572902
# 000791, method='Nelder-Mead', residual=84378.72045978396
# 000792, method='Nelder-Mead', residual=84307.46086039128
# 000793, method='Nelder-Mead', residual=84268.42696832455
# 000794, method='Nelder-Mead', residual=84351.28129917338
# 000795, method='Nelder-Mead', residual=84276.38036797255
# 000796, method='Nelder-Mead', residual=84309.93550089758
# 000797, method='Nelder-Mead', residual=84268.60438057323
# 000798, method='Nelder-Mead', residual=84232.69551122059
# 000799, method='Nelder-Mead', residual=84219.01326596766
# 000800, method='Nelder-Mead', residual=84442.22577969675
# 000801, method='Nelder-Mead', residual=84293.84294976915
# 000802, method='Nelder-Mead', residual=84244.96986225671
# 000803, method='Nelder-Mead', residual=84205.30761580887
# 000804, method='Nelder-Mead', residual=84196.5299765047
# 000805, method='Nelder-Mead', residual=84200.04466930144
# 000806, method='Nelder-Mead', residual=84315.87560295252
# 000807, method='Nelder-Mead', residual=84247.20638667552
# 000808, method='Nelder-Mead', residual=84237.59059609378
# 000809, method='Nelder-Mead', residual=84189.75662206701
# 000810, method='Nelder-Mead', residual=84245.91759757008
# 000811, method='Nelder-Mead', residual=84251.36076013418
# 000812, method='Nelder-Mead', residual=84198.07053913662
# 000813, method='Nelder-Mead', residual=84376.00297723208
# 000814, method='Nelder-Mead', residual=84206.75794171655
# 000815, method='Nelder-Mead', residual=84197.23898527888
# 000816, method='Nelder-Mead', residual=84247.16499334878
# 000817, method='Nelder-Mead', residual=84198.06988696211
# 000818, method='Nelder-Mead', residual=84167.18791728046
# 000819, method='Nelder-Mead', residual=84177.05710881836
# 000820, method='Nelder-Mead', residual=84190.94639068499
# 000821, method='Nelder-Mead', residual=84272.45898437129
# 000822, method='Nelder-Mead', residual=84179.64740054897
# 000823, method='Nelder-Mead', residual=84184.98438276659
# 000824, method='Nelder-Mead', residual=84223.40321557685
# 000825, method='Nelder-Mead', residual=84179.93993128113
# 000826, method='Nelder-Mead', residual=84174.57297568179
# 000827, method='Nelder-Mead', residual=84204.51307265792
# 000828, method='Nelder-Mead', residual=84178.21289627953
# 000829, method='Nelder-Mead', residual=84201.27346780569
# 000830, method='Nelder-Mead', residual=84174.98851141962
# 000831, method='Nelder-Mead', residual=84159.22100987419
# 000832, method='Nelder-Mead', residual=84156.26537266257
# 000833, method='Nelder-Mead', residual=84187.38889960122
# 000834, method='Nelder-Mead', residual=84170.46770627152
# 000835, method='Nelder-Mead', residual=84157.25793983645
# 000836, method='Nelder-Mead', residual=84160.9094044762
# 000837, method='Nelder-Mead', residual=84151.24180503312
# 000838, method='Nelder-Mead', residual=84153.36330035879
# 000839, method='Nelder-Mead', residual=84158.26192887018
# 000840, method='Nelder-Mead', residual=84152.34874054723
# 000841, method='Nelder-Mead', residual=84148.88773873978
# 000842, method='Nelder-Mead', residual=84171.5430717381
# 000843, method='Nelder-Mead', residual=84151.35190303341
# 000844, method='Nelder-Mead', residual=84164.67749560568
# ...
# 002019, method='Nelder-Mead', residual=83941.87192252501
# 002020, method='Nelder-Mead', residual=83941.8719371858
# 002021, method='Nelder-Mead', residual=83941.87192563026
# 002022, method='Nelder-Mead', residual=83941.87192140844
# 002023, method='Nelder-Mead', residual=83941.87191963897
# 002024, method='Nelder-Mead', residual=83941.87192996044
# 002025, method='Nelder-Mead', residual=83941.87192191256
# 002026, method='Nelder-Mead', residual=83941.87193065004
# 002027, method='Nelder-Mead', residual=83941.87192134753
# 002028, method='Nelder-Mead', residual=83941.87192674697
# 002029, method='Nelder-Mead', residual=83941.8719208942
# 002030, method='Nelder-Mead', residual=83941.87192265822
# 002031, method='Nelder-Mead', residual=83941.87192122685
# 002032, method='Nelder-Mead', residual=83941.87192163868
# 002033, method='Nelder-Mead', residual=83941.87192662316
# 002034, method='Nelder-Mead', residual=83941.87191873629
# 002035, method='Nelder-Mead', residual=83941.87192372889
# 002036, method='Nelder-Mead', residual=83941.8719189499
# 002037, method='Nelder-Mead', residual=83941.87191730406
# 002038, method='Nelder-Mead', residual=83941.87191909025
# 002039, method='Nelder-Mead', residual=83941.87191693937
# 002040, method='Nelder-Mead', residual=83941.87191954863
# 002041, method='Nelder-Mead', residual=83941.8719225491
# 002042, method='Nelder-Mead', residual=83941.8719181162
# 002043, method='Nelder-Mead', residual=83941.87191638538
# 002044, method='Nelder-Mead', residual=83941.87191914691
# 002045, method='Nelder-Mead', residual=83941.87192249866
# 002046, method='Nelder-Mead', residual=83941.87191717105
# 002047, method='Nelder-Mead', residual=83941.87191551847
# 002048, method='Nelder-Mead', residual=83941.8719159249
# 002049, method='Nelder-Mead', residual=83941.87191606696
# 002050, method='Nelder-Mead', residual=83941.87191840775
# 002051, method='Nelder-Mead', residual=83941.87191653051
# 002052, method='Nelder-Mead', residual=83941.87191613199
# 002053, method='Nelder-Mead', residual=83941.87191728606
# 002054, method='Nelder-Mead', residual=83941.87191606914
# 002055, method='Nelder-Mead', residual=83941.87191683831
# 002056, method='Nelder-Mead', residual=83941.87191559169
# 002057, method='Nelder-Mead', residual=83941.87191631044
# 002058, method='Nelder-Mead', residual=83941.87191570814
# 002059, method='Nelder-Mead', residual=83941.87191509978
# 002060, method='Nelder-Mead', residual=83941.87191607054
# 002061, method='Nelder-Mead', residual=83941.8719170442
# 002062, method='Nelder-Mead', residual=83941.87191535212
# 002063, method='Nelder-Mead', residual=83941.87191599674
# 002064, method='Nelder-Mead', residual=83941.87191582788
# 002065, method='Nelder-Mead', residual=83941.8719150767
# 002066, method='Nelder-Mead', residual=83941.87191623595
# 002067, method='Nelder-Mead', residual=83941.87191653429
# 002068, method='Nelder-Mead', residual=83941.87191516753
# 002069, method='Nelder-Mead', residual=83941.87191567376
# 002070, method='Nelder-Mead', residual=83941.87191560915
# 002071, method='Nelder-Mead', residual=83941.87191559901
# 002072, method='Nelder-Mead', residual=83941.87191588515
# 002073, method='Nelder-Mead', residual=83941.87191506701
# 002074, method='Nelder-Mead', residual=83941.87191559857
# 002075, method='Nelder-Mead', residual=83941.8719150868
# 002076, method='Nelder-Mead', residual=83941.87191614743
# 002077, method='Nelder-Mead', residual=83941.87191503284
# 002078, method='Nelder-Mead', residual=83941.87191506146
# 002079, method='Nelder-Mead', residual=83941.87191499287
# 002080, method='Nelder-Mead', residual=83941.87191580872
# 002081, method='Nelder-Mead', residual=83941.87191493453
# 002082, method='Nelder-Mead', residual=83941.87191555662
# 002083, method='Nelder-Mead', residual=83941.87191523383
# 002084, method='Nelder-Mead', residual=83941.87191485582
# 002085, method='Nelder-Mead', residual=83941.87191484692
# 002086, method='Nelder-Mead', residual=83941.87191529904
# 002087, method='Nelder-Mead', residual=83941.87191567477
# 002088, method='Nelder-Mead', residual=83941.8719147887
# 002089, method='Nelder-Mead', residual=83941.87191530177
# 002090, method='Nelder-Mead', residual=83941.8719148257
# 002091, method='Nelder-Mead', residual=83941.87191507638
# 002092, method='Nelder-Mead', residual=83941.8719148447
# 002093, method='Nelder-Mead', residual=83941.87191468652
# 002094, method='Nelder-Mead', residual=83941.87191483546
# 002095, method='Nelder-Mead', residual=83941.87191491085
# 002096, method='Nelder-Mead', residual=83941.87191495128
# 002097, method='Nelder-Mead', residual=83941.87191477128
# 002098, method='Nelder-Mead', residual=83941.87191501485
# 002099, method='Nelder-Mead', residual=83941.87191475673
# 002100, method='Nelder-Mead', residual=83941.8719147727
# 002101, method='Nelder-Mead', residual=83941.87191487264
# 002102, method='Nelder-Mead', residual=83941.87191474049
# 002103, method='Nelder-Mead', residual=83941.87191467476
# 002104, method='Nelder-Mead', residual=83941.87191477652
# 002105, method='Nelder-Mead', residual=83941.87191483873
# 002106, method='Nelder-Mead', residual=83941.87191471958
# 002107, method='Nelder-Mead', residual=83941.87191472741
# 002108, method='Nelder-Mead', residual=83941.8719147747
# 002109, method='Nelder-Mead', residual=83941.87191470104
# 002110, method='Nelder-Mead', residual=83941.87191469206
# 002111, method='Nelder-Mead', residual=83941.87191474531
# 002112, method='Nelder-Mead', residual=83941.87191468426
# 002113, method='Nelder-Mead', residual=83941.87191464935
# 002114, method='Nelder-Mead', residual=83941.87191470977
# 002115, method='Nelder-Mead', residual=83941.87191471542
# 002116, method='Nelder-Mead', residual=83941.87191471213
# 002117, method='Nelder-Mead', residual=83941.871914714
# 002118, method='Nelder-Mead', residual=83941.87191466651
# 002119, method='Nelder-Mead', residual=83941.87191472373
# 002120, method='Nelder-Mead', residual=83941.87191466468
# 002121, method='Nelder-Mead', residual=83941.87191475823
# 002122, method='Nelder-Mead', residual=83941.8719146579
# 002123, method='Nelder-Mead', residual=83941.87191467421
# 002124, method='Nelder-Mead', residual=83941.87191465497
# 002125, method='Nelder-Mead', residual=83941.87191465344
# 002126, method='Nelder-Mead', residual=83941.87191468326
# 002127, method='Nelder-Mead', residual=83941.87191464876
# 002128, method='Nelder-Mead', residual=83941.8719146563
# 002129, method='Nelder-Mead', residual=83941.87191466744
# 002130, method='Nelder-Mead', residual=83941.87191464556
# 002131, method='Nelder-Mead', residual=83941.87191465819
# 002132, method='Nelder-Mead', residual=83941.87191464225
# 002133, method='Nelder-Mead', residual=83941.87191464604
# 002134, method='Nelder-Mead', residual=83941.87191467741
# 002135, method='Nelder-Mead', residual=83941.87191463941
# 002136, method='Nelder-Mead', residual=83941.87191464542
# 002137, method='Nelder-Mead', residual=83941.87191465743
# 002138, method='Nelder-Mead', residual=83941.87191463952
# 002139, method='Nelder-Mead', residual=83941.87191465544
# 002140, method='Nelder-Mead', residual=83941.8719146383
# 002141, method='Nelder-Mead', residual=83941.87191464922
# 002142, method='Nelder-Mead', residual=83941.8719146386
# 002143, method='Nelder-Mead', residual=83941.87191465173
# 002144, method='Nelder-Mead', residual=83941.87191463742
# 002145, method='Nelder-Mead', residual=83941.87191465007
# 002146, method='Nelder-Mead', residual=83941.87191463742
# 002147, method='Nelder-Mead', residual=83941.87191465287
# 002148, method='Nelder-Mead', residual=83941.87191463707
# 002149, method='Nelder-Mead', residual=83941.87191464355
# 002150, method='Nelder-Mead', residual=83941.87191463695
# 002151, method='Nelder-Mead', residual=83941.87191464005
# 002152, method='Nelder-Mead', residual=83941.87191463633
# 002153, method='Nelder-Mead', residual=83941.87191464388
# 002154, method='Nelder-Mead', residual=83941.8719146359
# 002155, method='Nelder-Mead', residual=83941.87191463818
# 002156, method='Nelder-Mead', residual=83941.87191463754
# 002157, method='Nelder-Mead', residual=83941.8719146402
# 002158, method='Nelder-Mead', residual=83941.87191463582
# 002159, method='Nelder-Mead', residual=83941.87191463778
# 002160, method='Nelder-Mead', residual=83941.8719146358
# 002161, method='Nelder-Mead', residual=83941.87191463939
# 002162, method='Nelder-Mead', residual=83941.87191463562
# 002163, method='Nelder-Mead', residual=83941.87191463771
# 002164, method='Nelder-Mead', residual=83941.87191463578
# 002165, method='Nelder-Mead', residual=83941.8719146392
# 002166, method='Nelder-Mead', residual=83941.87191463554
# 002167, method='Nelder-Mead', residual=83941.8719146366
# 002168, method='Nelder-Mead', residual=83941.87191463559
# 002169, method='Nelder-Mead', residual=83941.87191463639
# 002170, method='Nelder-Mead', residual=83941.8719146355
# 002171, method='Nelder-Mead', residual=83941.87191463674
# 002172, method='Nelder-Mead', residual=83941.87191463533
# 002173, method='Nelder-Mead', residual=83941.87191463598
# 002174, method='Nelder-Mead', residual=83941.87191463537
# 002175, method='Nelder-Mead', residual=83941.87191463605
# 002176, method='Nelder-Mead', residual=83941.87191463533
# 002177, method='Nelder-Mead', residual=83941.87191463567
# 002178, method='Nelder-Mead', residual=83941.87191463534
# 002179, method='Nelder-Mead', residual=83941.87191463572
# 002180, method='Nelder-Mead', residual=83941.87191463534
# 002181, method='Nelder-Mead', residual=83941.87191463553
# 002182, method='Nelder-Mead', residual=83941.87191463588
# 002183, method='Nelder-Mead', residual=83941.87191463531
# 002184, method='Nelder-Mead', residual=83941.87191463554
# 002185, method='Nelder-Mead', residual=83941.87191463531
# 002186, method='Nelder-Mead', residual=83941.87191463553
# 002187, method='Nelder-Mead', residual=83941.8719146353
# 002188, method='Nelder-Mead', residual=83941.87191463546
# 002189, method='Nelder-Mead', residual=83941.8719146353
# 002190, method='Nelder-Mead', residual=83941.8719146353
# 002191, method='Nelder-Mead', residual=83941.87191463549
# 002192, method='Nelder-Mead', residual=83941.87191463524
# 002193, method='Nelder-Mead', residual=83941.87191463527
# 002194, method='Nelder-Mead', residual=83941.87191463551
# 002195, method='Nelder-Mead', residual=83941.87191463524
# 002196, method='Nelder-Mead', residual=83941.87191463524
# 002197, method='Nelder-Mead', residual=83941.87191463531
# 002198, method='Nelder-Mead', residual=83941.87191463524
# 002199, method='Nelder-Mead', residual=83941.87191463537
# 002200, method='Nelder-Mead', residual=83941.87191463521
# 002201, method='Nelder-Mead', residual=83941.8719146352
# 002202, method='Nelder-Mead', residual=83941.87191463524
# 002203, method='Nelder-Mead', residual=83941.87191463531
# 002204, method='Nelder-Mead', residual=83941.87191463524
# 002205, method='Nelder-Mead', residual=83941.87191463527
# 002206, method='Nelder-Mead', residual=83941.87191463524
# 002207, method='Nelder-Mead', residual=83941.87191463525
# 002208, method='Nelder-Mead', residual=83941.87191463525
# 002209, method='Nelder-Mead', residual=83941.87191463524
# 002210, method='Nelder-Mead', residual=83941.87191463521
# 002211, method='Nelder-Mead', residual=83941.87191463522
# 002212, method='Nelder-Mead', residual=83941.87191463522
# 002213, method='Nelder-Mead', residual=83941.87191463521
# 002214, method='Nelder-Mead', residual=83941.87191463524
# 002215, method='Nelder-Mead', residual=83941.8719146352
# 002216, method='Nelder-Mead', residual=83941.87191463518
# 002217, method='Nelder-Mead', residual=83941.87191463522
# 002218, method='Nelder-Mead', residual=83941.87191463521
# 002219, method='Nelder-Mead', residual=83941.8719146352
# 002220, method='Nelder-Mead', residual=83941.87191463521
# 002221, method='Nelder-Mead', residual=83941.87191463524
# 002222, method='Nelder-Mead', residual=83941.87191463521
# 002223, method='Nelder-Mead', residual=83941.87191463522
# 002224, method='Nelder-Mead', residual=83941.8719146352
# 002225, method='Nelder-Mead', residual=83941.8719146352
# 002226, method='Nelder-Mead', residual=83941.87191463521
# 002227, method='Nelder-Mead', residual=83941.87191463521
# 002228, method='Nelder-Mead', residual=83941.8719146352
# 002229, method='Nelder-Mead', residual=83941.87191463518
# 002230, method='Nelder-Mead', residual=83941.87191463521
# 002231, method='Nelder-Mead', residual=83941.87191463521
# 002232, method='Nelder-Mead', residual=83941.87191463522
# 002233, method='Nelder-Mead', residual=83941.87191463524
# 002234, method='Nelder-Mead', residual=83941.87191463517
# 002235, method='Nelder-Mead', residual=83941.8719146352
# 002236, method='Nelder-Mead', residual=83941.87191463518
# 002237, method='Nelder-Mead', residual=83941.87191463522
# 002238, method='Nelder-Mead', residual=83941.87191463518
# 002239, method='Nelder-Mead', residual=83941.87191463522
# 002240, method='Nelder-Mead', residual=83941.87191463521
# 002241, method='Nelder-Mead', residual=83941.8719146352
# 002242, method='Nelder-Mead', residual=83941.87191463521
# 002243, method='Nelder-Mead', residual=83941.8719146352
# 002244, method='Nelder-Mead', residual=83941.87191463518
# 002245, method='Nelder-Mead', residual=83941.87191463521
# 002246, method='Nelder-Mead', residual=83941.87191463521
# 002247, method='Nelder-Mead', residual=83941.87191463521
# 002248, method='Nelder-Mead', residual=83941.87191463518
# 002249, method='Nelder-Mead', residual=83941.8719146352
# 002250, method='Nelder-Mead', residual=83941.8719146352
# 002251, method='Nelder-Mead', residual=83941.87191463521
# 002252, method='Nelder-Mead', residual=83941.87191463524
# 002253, method='Nelder-Mead', residual=83941.8719146352
# 002254, method='Nelder-Mead', residual=83941.8719146352
# 002255, method='Nelder-Mead', residual=83941.87191463521
# 002256, method='Nelder-Mead', residual=83941.87191463524
# 002257, method='Nelder-Mead', residual=83941.8719146352
# 002258, method='Nelder-Mead', residual=83941.8719146352
# 002259, method='Nelder-Mead', residual=83941.87191463521
# 002260, method='Nelder-Mead', residual=83941.87191463521
# 002261, method='Nelder-Mead', residual=83941.8719146352
# 002262, method='Nelder-Mead', residual=83941.87191463521
# 002263, method='Nelder-Mead', residual=83941.87191463518
# 002264, method='Nelder-Mead', residual=83941.87191463521
# 002265, method='Nelder-Mead', residual=83941.8719146352
# 002266, method='Nelder-Mead', residual=83941.87191463525
# 002267, method='Nelder-Mead', residual=83941.87191463521
# 002268, method='Nelder-Mead', residual=83941.87191463517
# 002269, method='Nelder-Mead', residual=83941.87191463521
# 002270, method='Nelder-Mead', residual=83941.87191463521
# 002271, method='Nelder-Mead', residual=83941.87191463521
# 002272, method='Nelder-Mead', residual=83941.87191463521
# 002273, method='Nelder-Mead', residual=83941.87191463518
# 002274, method='Nelder-Mead', residual=83941.87191463522
# 002275, method='Nelder-Mead', residual=83941.87191463518
# 002276, method='Nelder-Mead', residual=83941.87191463518
# 002277, method='Nelder-Mead', residual=83941.87191463521
# 002278, method='Nelder-Mead', residual=83941.87191463518
# 002279, method='Nelder-Mead', residual=83941.87191463521
# 002280, method='Nelder-Mead', residual=83941.8719146352
# 002281, method='Nelder-Mead', residual=83941.87191463518
# 002282, method='Nelder-Mead', residual=83941.8719146352
# 002283, method='Nelder-Mead', residual=83941.8719146352
# 002284, method='Nelder-Mead', residual=83941.87191463521
# 002285, method='Nelder-Mead', residual=83941.87191463521
# 002286, method='Nelder-Mead', residual=83941.87191463521
# 002287, method='Nelder-Mead', residual=83941.87191463521
# 002288, method='Nelder-Mead', residual=83941.87191463522
# 002289, method='Nelder-Mead', residual=83941.87191463521
# 002290, method='Nelder-Mead', residual=83941.87191463521
# 002291, method='Nelder-Mead', residual=83941.87191463521
# 002292, method='Nelder-Mead', residual=83941.87191463522
# 002293, method='Nelder-Mead', residual=83941.87191463524
# 002294, method='Nelder-Mead', residual=83941.87191463521
# 002295, method='Nelder-Mead', residual=83941.87191463521
# 002296, method='Nelder-Mead', residual=83941.87191463522
# 002297, method='Nelder-Mead', residual=83941.87191463522
# 002298, method='Nelder-Mead', residual=83941.87191463521
# 002299, method='Nelder-Mead', residual=83941.87191463521
