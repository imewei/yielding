# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras


def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C044_Cys1_Exp2_Creep_XPCS_100Pa_01_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d

def fit_c2_polynomial(num_v=3, num_d=3, paras_fname=None):
    # read raw data
    c2_exp, t_length, phi_list, phi_length = read_data()
    x0 = np.array([4671.967,    -0.105, -2880.094,   454.189,    -0.42 ,   -58.609,
          -0.001,     0.055,    -0.019,     0.555,    -0.086,
               ])

    for method in (
                'Nelder-Mead',
                # 'Powell',
                # 'L-BFGS-B',
                # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
                # 'trust-ncg', 'trust-exact', 'trust-krylov'):
                ):
    # def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
        FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                                args=(phi_list, num_d, num_v, c2_exp, method),
                                 options={"maxiter": 1000000}, tol=0.00001,
                                method=method)

    FitParas = FitOutput['x']
    
    c2_fit = Heterodyne4(FitParas, phi_list)
    shape = c2_fit.shape
    sol_list = []
    for n in range(shape[0]):
        sumy = np.sum(c2_fit[n])
        a = np.array([
            [np.sum(c2_fit[n] ** 2), sumy],
            [sumy, c2_fit[n].size]
        ])
        b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
        sol = np.linalg.solve(a, b)
        sol_list.append(sol)

    
    FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
    np.savetxt('/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/FitParas/C044_FitParas.txt', FitParas, delimiter=",")

def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]
    f_c  = paras[num_d + num_v:num_d + num_v + num_f]
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]

    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    and all(i <= 1 for i in f)== True\
    and all(i >= 0 for i in f)== True\
    :
    
        shape = c2_exp.shape
        residual = 0.0

        c2_fit = Heterodyne4(paras, phi_list)

        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)

        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        # plt.imshow(c2_fit[0])
        # # plt.imshow(c2_exp[0])
        # plt.show()
        
        sol_array = np.array(sol_list).reshape(23,2)
        if all(i <= 0 for i in sol_array[:,0]) == True \
        or all( i >= 0.5 for i in sol_array[:,0]) == True\
        or all( i >= 1.3 for i in sol_array[:,1]) == True\
        or all( i <= 1 for i in sol_array[:,1])== True:
            residual = np.inf
    else:
        residual = np.inf
    
    return residual
def Heterodyne4(x, phi_list):
    global t_length
    global startpoint
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]

    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(qValue**2/2 * -abs(DMat) * dt).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2
    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (t0 + 2*f1s*f2s*f1r*f2r* w * g1_s*g1_r) / ftotal**2

    return g2_all


def Heterodyne5(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    t_length = 999
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE)
    D, v, phio, f, beta, c = separate_params(x, phi_length)
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(-abs((qValue**2/2 * DMat * dt))).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2

    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] / ftotal**2 * (t0 +  2*f1s*f2s*f1r*f2r* w * g1_s*g1_r)

    return g2_all


def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    t_length = 999
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    return D, v, phio, f, beta, c

DTYPE = np.float32
num_d = 3
num_v = 3
num_f = 4
t_length = 999

# %%
DTYPE = np.float32
t_length = 999
gindex = 0
fit_c2_polynomial()
# Out:
# c2_cache_1001_2000.npz
# (23, 999, 999) float32
# 000001, method='Nelder-Mead', residual=43785.45959472656
# 000002, method='Nelder-Mead', residual=44623.668701171875
# 000003, method='Nelder-Mead', residual=53723.88525390625
# 000004, method='Nelder-Mead', residual=61733.800048828125
# 000005, method='Nelder-Mead', residual=48810.71484375
# 000006, method='Nelder-Mead', residual=43799.75
# 000007, method='Nelder-Mead', residual=43935.35314941406
# 000008, method='Nelder-Mead', residual=43785.47375488281
# 000009, method='Nelder-Mead', residual=43853.00207519531
# 000010, method='Nelder-Mead', residual=43784.07177734375
# 000011, method='Nelder-Mead', residual=45415.577392578125
# 000012, method='Nelder-Mead', residual=45353.721435546875
# 000013, method='Nelder-Mead', residual=62357.00939941406
# 000014, method='Nelder-Mead', residual=50659.177490234375
# 000015, method='Nelder-Mead', residual=58414.663330078125
# 000016, method='Nelder-Mead', residual=45613.27868652344
# 000017, method='Nelder-Mead', residual=48490.467041015625
# 000018, method='Nelder-Mead', residual=49357.86828613281
# 000019, method='Nelder-Mead', residual=45082.56433105469
# 000020, method='Nelder-Mead', residual=49755.7626953125
# 000021, method='Nelder-Mead', residual=44907.54968261719
# 000022, method='Nelder-Mead', residual=47105.72277832031
# 000023, method='Nelder-Mead', residual=44168.398681640625
# 000024, method='Nelder-Mead', residual=44466.255859375
# 000025, method='Nelder-Mead', residual=44387.01232910156
# 000026, method='Nelder-Mead', residual=45047.20654296875
# 000027, method='Nelder-Mead', residual=44181.96276855469
# 000028, method='Nelder-Mead', residual=45041.766357421875
# 000029, method='Nelder-Mead', residual=44124.700927734375
# 000030, method='Nelder-Mead', residual=44152.574462890625
# 000031, method='Nelder-Mead', residual=44060.63269042969
# 000032, method='Nelder-Mead', residual=44012.13659667969
# 000033, method='Nelder-Mead', residual=44114.29455566406
# 000034, method='Nelder-Mead', residual=44422.561279296875
# 000035, method='Nelder-Mead', residual=43901.0849609375
# 000036, method='Nelder-Mead', residual=43958.61535644531
# 000037, method='Nelder-Mead', residual=43891.09069824219
# 000038, method='Nelder-Mead', residual=44041.99182128906
# 000039, method='Nelder-Mead', residual=43916.11145019531
# 000040, method='Nelder-Mead', residual=44085.11779785156
# 000041, method='Nelder-Mead', residual=43878.72033691406
# 000042, method='Nelder-Mead', residual=43894.60888671875
# 000043, method='Nelder-Mead', residual=43875.95654296875
# 000044, method='Nelder-Mead', residual=43830.91369628906
# 000045, method='Nelder-Mead', residual=43853.320068359375
# 000046, method='Nelder-Mead', residual=43861.72009277344
# 000047, method='Nelder-Mead', residual=43841.881591796875
# 000048, method='Nelder-Mead', residual=43829.54333496094
# 000049, method='Nelder-Mead', residual=43885.66149902344
# 000050, method='Nelder-Mead', residual=43821.833740234375
# 000051, method='Nelder-Mead', residual=43831.82702636719
# 000052, method='Nelder-Mead', residual=43859.688232421875
# 000053, method='Nelder-Mead', residual=43815.42517089844
# 000054, method='Nelder-Mead', residual=43822.21325683594
# 000055, method='Nelder-Mead', residual=43883.29296875
# 000056, method='Nelder-Mead', residual=43808.56994628906
# 000057, method='Nelder-Mead', residual=43769.510498046875
# 000058, method='Nelder-Mead', residual=43765.58142089844
# 000059, method='Nelder-Mead', residual=43798.07995605469
# 000060, method='Nelder-Mead', residual=43803.15478515625
# 000061, method='Nelder-Mead', residual=43800.83898925781
# 000062, method='Nelder-Mead', residual=43798.39538574219
# 000063, method='Nelder-Mead', residual=43794.63562011719
# 000064, method='Nelder-Mead', residual=43795.337890625
# 000065, method='Nelder-Mead', residual=43790.20764160156
# 000066, method='Nelder-Mead', residual=43789.32702636719
# 000067, method='Nelder-Mead', residual=43781.135986328125
# 000068, method='Nelder-Mead', residual=43768.10925292969
# 000069, method='Nelder-Mead', residual=43782.80139160156
# 000070, method='Nelder-Mead', residual=43791.4267578125
# 000071, method='Nelder-Mead', residual=43783.36181640625
# 000072, method='Nelder-Mead', residual=43794.013427734375
# 000073, method='Nelder-Mead', residual=43779.205810546875
# 000074, method='Nelder-Mead', residual=43781.62890625
# 000075, method='Nelder-Mead', residual=43763.09765625
# 000076, method='Nelder-Mead', residual=43776.8134765625
# 000077, method='Nelder-Mead', residual=43782.556396484375
# 000078, method='Nelder-Mead', residual=43793.69580078125
# 000079, method='Nelder-Mead', residual=43773.921630859375
# 000080, method='Nelder-Mead', residual=43762.70202636719
# 000081, method='Nelder-Mead', residual=43757.34265136719
# 000082, method='Nelder-Mead', residual=43775.06433105469
# 000083, method='Nelder-Mead', residual=43773.16882324219
# 000084, method='Nelder-Mead', residual=43760.46325683594
# 000085, method='Nelder-Mead', residual=43772.36804199219
# 000086, method='Nelder-Mead', residual=43763.656494140625
# 000087, method='Nelder-Mead', residual=43769.66979980469
# 000088, method='Nelder-Mead', residual=43769.21496582031
# 000089, method='Nelder-Mead', residual=43766.298828125
# 000090, method='Nelder-Mead', residual=43767.763427734375
# 000091, method='Nelder-Mead', residual=43767.324951171875
# 000092, method='Nelder-Mead', residual=43766.07043457031
# 000093, method='Nelder-Mead', residual=43758.40905761719
# 000094, method='Nelder-Mead', residual=43765.1689453125
# 000095, method='Nelder-Mead', residual=43773.81799316406
# 000096, method='Nelder-Mead', residual=43762.98571777344
# 000097, method='Nelder-Mead', residual=43757.54052734375
# 000098, method='Nelder-Mead', residual=43763.825927734375
# 000099, method='Nelder-Mead', residual=43765.88684082031
# 000100, method='Nelder-Mead', residual=43763.114501953125
# 000101, method='Nelder-Mead', residual=43765.67712402344
# 000102, method='Nelder-Mead', residual=43762.02978515625
# 000103, method='Nelder-Mead', residual=43757.75964355469
# 000104, method='Nelder-Mead', residual=43756.20361328125
# 000105, method='Nelder-Mead', residual=43755.79650878906
# 000106, method='Nelder-Mead', residual=43759.38269042969
# 000107, method='Nelder-Mead', residual=43754.75305175781
# 000108, method='Nelder-Mead', residual=43758.616455078125
# 000109, method='Nelder-Mead', residual=43757.46520996094
# 000110, method='Nelder-Mead', residual=43753.637939453125
# 000111, method='Nelder-Mead', residual=43753.652099609375
# 000112, method='Nelder-Mead', residual=43758.952392578125
# 000113, method='Nelder-Mead', residual=43756.45947265625
# 000114, method='Nelder-Mead', residual=43756.60998535156
# 000115, method='Nelder-Mead', residual=43756.721435546875
# 000116, method='Nelder-Mead', residual=43756.42395019531
# 000117, method='Nelder-Mead', residual=43754.8486328125
# 000118, method='Nelder-Mead', residual=43757.49572753906
# 000119, method='Nelder-Mead', residual=43755.78991699219
# 000120, method='Nelder-Mead', residual=43754.37731933594
# 000121, method='Nelder-Mead', residual=43753.69958496094
# 000122, method='Nelder-Mead', residual=43755.46423339844
# 000123, method='Nelder-Mead', residual=43754.175048828125
# 000124, method='Nelder-Mead', residual=43755.25
# 000125, method='Nelder-Mead', residual=43753.47900390625
# 000126, method='Nelder-Mead', residual=43753.624267578125
# 000127, method='Nelder-Mead', residual=43753.788330078125
# 000128, method='Nelder-Mead', residual=43753.5390625
# 000129, method='Nelder-Mead', residual=43753.02685546875
# 000130, method='Nelder-Mead', residual=43754.240234375
# 000131, method='Nelder-Mead', residual=43753.92761230469
# 000132, method='Nelder-Mead', residual=43753.10607910156
# 000133, method='Nelder-Mead', residual=43753.53015136719
# 000134, method='Nelder-Mead', residual=43752.87243652344
# 000135, method='Nelder-Mead', residual=43753.0126953125
# 000136, method='Nelder-Mead', residual=43753.03552246094
# 000137, method='Nelder-Mead', residual=43752.821533203125
# 000138, method='Nelder-Mead', residual=43753.27600097656
# 000139, method='Nelder-Mead', residual=43753.86657714844
# 000140, method='Nelder-Mead', residual=43753.16394042969
# 000141, method='Nelder-Mead', residual=43753.0908203125
# 000142, method='Nelder-Mead', residual=43753.23571777344
# 000143, method='Nelder-Mead', residual=43753.47509765625
# 000144, method='Nelder-Mead', residual=43753.454833984375
# 000145, method='Nelder-Mead', residual=43752.6533203125
# 000146, method='Nelder-Mead', residual=43752.69006347656
# 000147, method='Nelder-Mead', residual=43753.41833496094
# 000148, method='Nelder-Mead', residual=43753.191650390625
# 000149, method='Nelder-Mead', residual=43753.46276855469
# 000150, method='Nelder-Mead', residual=43752.9658203125
# 000151, method='Nelder-Mead', residual=43752.63806152344
# 000152, method='Nelder-Mead', residual=43752.95361328125
# 000153, method='Nelder-Mead', residual=43753.08386230469
# 000154, method='Nelder-Mead', residual=43753.07727050781
# 000155, method='Nelder-Mead', residual=43752.86608886719
# 000156, method='Nelder-Mead', residual=43753.045654296875
# 000157, method='Nelder-Mead', residual=43753.03723144531
# 000158, method='Nelder-Mead', residual=43753.154052734375
# 000159, method='Nelder-Mead', residual=43752.79016113281
# 000160, method='Nelder-Mead', residual=43753.226318359375
# 000161, method='Nelder-Mead', residual=43752.780517578125
# 000162, method='Nelder-Mead', residual=43753.046875
# 000163, method='Nelder-Mead', residual=43752.79382324219
# 000164, method='Nelder-Mead', residual=43752.756103515625
# 000165, method='Nelder-Mead', residual=43752.58142089844
# 000166, method='Nelder-Mead', residual=43752.64294433594
# 000167, method='Nelder-Mead', residual=43752.49108886719
# 000168, method='Nelder-Mead', residual=43752.468505859375
# 000169, method='Nelder-Mead', residual=43753.195556640625
# 000170, method='Nelder-Mead', residual=43752.668701171875
# 000171, method='Nelder-Mead', residual=43752.51281738281
# 000172, method='Nelder-Mead', residual=43752.71252441406
# 000173, method='Nelder-Mead', residual=43752.50085449219
# 000174, method='Nelder-Mead', residual=43752.64208984375
# 000175, method='Nelder-Mead', residual=43752.444580078125
# 000176, method='Nelder-Mead', residual=43752.50524902344
# 000177, method='Nelder-Mead', residual=43752.554931640625
# 000178, method='Nelder-Mead', residual=43752.382568359375
# 000179, method='Nelder-Mead', residual=43752.309326171875
# 000180, method='Nelder-Mead', residual=43752.20861816406
# 000181, method='Nelder-Mead', residual=43752.86474609375
# 000182, method='Nelder-Mead', residual=43752.45324707031
# 000183, method='Nelder-Mead', residual=43752.18994140625
# 000184, method='Nelder-Mead', residual=43752.019287109375
# 000185, method='Nelder-Mead', residual=43752.29724121094
# 000186, method='Nelder-Mead', residual=43752.18518066406
# 000187, method='Nelder-Mead', residual=43752.039306640625
# 000188, method='Nelder-Mead', residual=43752.08361816406
# 000189, method='Nelder-Mead', residual=43752.14904785156
# 000190, method='Nelder-Mead', residual=43752.322509765625
# 000191, method='Nelder-Mead', residual=43752.060302734375
# 000192, method='Nelder-Mead', residual=43751.923095703125
# 000193, method='Nelder-Mead', residual=43751.876953125
# 000194, method='Nelder-Mead', residual=43752.21875
# 000195, method='Nelder-Mead', residual=43751.7998046875
# 000196, method='Nelder-Mead', residual=43751.65856933594
# 000197, method='Nelder-Mead', residual=43752.13903808594
# 000198, method='Nelder-Mead', residual=43751.90673828125
# 000199, method='Nelder-Mead', residual=43751.71911621094
# 000200, method='Nelder-Mead', residual=43751.79382324219
# 000201, method='Nelder-Mead', residual=43752.00842285156
# 000202, method='Nelder-Mead', residual=43751.7587890625
# 000203, method='Nelder-Mead', residual=43751.49084472656
# 000204, method='Nelder-Mead', residual=43751.2099609375
# 000205, method='Nelder-Mead', residual=43751.71154785156
# 000206, method='Nelder-Mead', residual=43751.63439941406
# 000207, method='Nelder-Mead', residual=43751.42333984375
# 000208, method='Nelder-Mead', residual=43751.58459472656
# 000209, method='Nelder-Mead', residual=43751.20617675781
# 000210, method='Nelder-Mead', residual=43750.9326171875
# 000211, method='Nelder-Mead', residual=43751.17077636719
# 000212, method='Nelder-Mead', residual=43751.278564453125
# 000213, method='Nelder-Mead', residual=43751.2626953125
# 000214, method='Nelder-Mead', residual=43751.47985839844
# 000215, method='Nelder-Mead', residual=43751.21472167969
# 000216, method='Nelder-Mead', residual=43750.84362792969
# 000217, method='Nelder-Mead', residual=43750.897705078125
# 000218, method='Nelder-Mead', residual=43750.832275390625
# 000219, method='Nelder-Mead', residual=43750.81970214844
# 000220, method='Nelder-Mead', residual=43750.55480957031
# 000221, method='Nelder-Mead', residual=43750.18884277344
# 000222, method='Nelder-Mead', residual=43750.82336425781
# 000223, method='Nelder-Mead', residual=43750.33386230469
# 000224, method='Nelder-Mead', residual=43750.96276855469
# 000225, method='Nelder-Mead', residual=43750.47424316406
# 000226, method='Nelder-Mead', residual=43750.35595703125
# 000227, method='Nelder-Mead', residual=43750.26330566406
# 000228, method='Nelder-Mead', residual=43750.21716308594
# 000229, method='Nelder-Mead', residual=43750.01806640625
# 000230, method='Nelder-Mead', residual=43750.0380859375
# 000231, method='Nelder-Mead', residual=43750.35107421875
# 000232, method='Nelder-Mead', residual=43749.92541503906
# 000233, method='Nelder-Mead', residual=43749.93884277344
# 000234, method='Nelder-Mead', residual=43749.87744140625
# 000235, method='Nelder-Mead', residual=43749.816650390625
# 000236, method='Nelder-Mead', residual=43750.10705566406
# 000237, method='Nelder-Mead', residual=43749.65563964844
# 000238, method='Nelder-Mead', residual=43749.473388671875
# 000239, method='Nelder-Mead', residual=43750.05505371094
# 000240, method='Nelder-Mead', residual=43749.956298828125
# 000241, method='Nelder-Mead', residual=43749.530517578125
# 000242, method='Nelder-Mead', residual=43749.3857421875
# 000243, method='Nelder-Mead', residual=43749.13391113281
# 000244, method='Nelder-Mead', residual=43749.32470703125
# 000245, method='Nelder-Mead', residual=43749.487060546875
# 000246, method='Nelder-Mead', residual=43749.39587402344
# 000247, method='Nelder-Mead', residual=43749.718505859375
# 000248, method='Nelder-Mead', residual=43749.12854003906
# 000249, method='Nelder-Mead', residual=43749.06701660156
# 000250, method='Nelder-Mead', residual=43749.78527832031
# 000251, method='Nelder-Mead', residual=43749.57312011719
# 000252, method='Nelder-Mead', residual=43749.22619628906
# 000253, method='Nelder-Mead', residual=43749.46240234375
# 000254, method='Nelder-Mead', residual=43749.518798828125
# 000255, method='Nelder-Mead', residual=43748.86779785156
# 000256, method='Nelder-Mead', residual=43748.76110839844
# 000257, method='Nelder-Mead', residual=43749.32678222656
# 000258, method='Nelder-Mead', residual=43749.295166015625
# 000259, method='Nelder-Mead', residual=43749.577392578125
# 000260, method='Nelder-Mead', residual=43749.20690917969
# 000261, method='Nelder-Mead', residual=43748.941162109375
# 000262, method='Nelder-Mead', residual=43748.9326171875
# 000263, method='Nelder-Mead', residual=43749.26062011719
# 000264, method='Nelder-Mead', residual=43749.12512207031
# 000265, method='Nelder-Mead', residual=43748.71911621094
# 000266, method='Nelder-Mead', residual=43748.64733886719
# 000267, method='Nelder-Mead', residual=43748.86535644531
# 000268, method='Nelder-Mead', residual=43748.717041015625
# 000269, method='Nelder-Mead', residual=43749.369140625
# 000270, method='Nelder-Mead', residual=43748.90270996094
# 000271, method='Nelder-Mead', residual=43748.56237792969
# 000272, method='Nelder-Mead', residual=43749.352783203125
# 000273, method='Nelder-Mead', residual=43748.853515625
# 000274, method='Nelder-Mead', residual=43748.59948730469
# 000275, method='Nelder-Mead', residual=43748.478759765625
# 000276, method='Nelder-Mead', residual=43748.426025390625
# 000277, method='Nelder-Mead', residual=43748.49560546875
# 000278, method='Nelder-Mead', residual=43748.48681640625
# 000279, method='Nelder-Mead', residual=43748.70373535156
# 000280, method='Nelder-Mead', residual=43748.541748046875
# 000281, method='Nelder-Mead', residual=43748.377197265625
# 000282, method='Nelder-Mead', residual=43748.59033203125
# 000283, method='Nelder-Mead', residual=43748.8486328125
# 000284, method='Nelder-Mead', residual=43748.51745605469
# 000285, method='Nelder-Mead', residual=43748.293701171875
# 000286, method='Nelder-Mead', residual=43748.29345703125
# 000287, method='Nelder-Mead', residual=43748.51867675781
# 000288, method='Nelder-Mead', residual=43748.27551269531
# 000289, method='Nelder-Mead', residual=43748.3623046875
# 000290, method='Nelder-Mead', residual=43748.449951171875
# 000291, method='Nelder-Mead', residual=43748.70397949219
# 000292, method='Nelder-Mead', residual=43748.38610839844
# 000293, method='Nelder-Mead', residual=43748.3623046875
# 000294, method='Nelder-Mead', residual=43748.37951660156
# 000295, method='Nelder-Mead', residual=43748.15368652344
# 000296, method='Nelder-Mead', residual=43748.11962890625
# 000297, method='Nelder-Mead', residual=43748.067138671875
# 000298, method='Nelder-Mead', residual=43748.21472167969
# 000299, method='Nelder-Mead', residual=43748.25598144531
# 000300, method='Nelder-Mead', residual=43748.291015625
# 000301, method='Nelder-Mead', residual=43748.263916015625
# 000302, method='Nelder-Mead', residual=43748.15625
# 000303, method='Nelder-Mead', residual=43748.1748046875
# 000304, method='Nelder-Mead', residual=43748.05065917969
# 000305, method='Nelder-Mead', residual=43748.146484375
# 000306, method='Nelder-Mead', residual=43748.20324707031
# 000307, method='Nelder-Mead', residual=43748.05554199219
# 000308, method='Nelder-Mead', residual=43747.970458984375
# 000309, method='Nelder-Mead', residual=43748.0595703125
# 000310, method='Nelder-Mead', residual=43748.00439453125
# 000311, method='Nelder-Mead', residual=43747.93933105469
# 000312, method='Nelder-Mead', residual=43748.000732421875
# 000313, method='Nelder-Mead', residual=43748.1396484375
# 000314, method='Nelder-Mead', residual=43748.056396484375
# 000315, method='Nelder-Mead', residual=43747.960205078125
# 000316, method='Nelder-Mead', residual=43747.85412597656
# 000317, method='Nelder-Mead', residual=43747.93371582031
# 000318, method='Nelder-Mead', residual=43747.99792480469
# 000319, method='Nelder-Mead', residual=43747.975830078125
# 000320, method='Nelder-Mead', residual=43747.8486328125
# 000321, method='Nelder-Mead', residual=43747.98718261719
# 000322, method='Nelder-Mead', residual=43748.05285644531
# 000323, method='Nelder-Mead', residual=43747.837646484375
# 000324, method='Nelder-Mead', residual=43747.92370605469
# 000325, method='Nelder-Mead', residual=43747.98388671875
# 000326, method='Nelder-Mead', residual=43747.906494140625
# 000327, method='Nelder-Mead', residual=43747.797607421875
# 000328, method='Nelder-Mead', residual=43747.97900390625
# 000329, method='Nelder-Mead', residual=43747.94189453125
# 000330, method='Nelder-Mead', residual=43747.82458496094
# 000331, method='Nelder-Mead', residual=43748.019287109375
# 000332, method='Nelder-Mead', residual=43747.83203125
# 000333, method='Nelder-Mead', residual=43747.784423828125
# 000334, method='Nelder-Mead', residual=43747.783935546875
# 000335, method='Nelder-Mead', residual=43748.00158691406
# 000336, method='Nelder-Mead', residual=43747.80798339844
# 000337, method='Nelder-Mead', residual=43747.86730957031
# 000338, method='Nelder-Mead', residual=43747.684326171875
# 000339, method='Nelder-Mead', residual=43747.75378417969
# 000340, method='Nelder-Mead', residual=43747.68664550781
# 000341, method='Nelder-Mead', residual=43747.89953613281
# 000342, method='Nelder-Mead', residual=43747.74670410156
# 000343, method='Nelder-Mead', residual=43747.76330566406
# 000344, method='Nelder-Mead', residual=43747.866943359375
# 000345, method='Nelder-Mead', residual=43747.732177734375
# 000346, method='Nelder-Mead', residual=43747.79064941406
# 000347, method='Nelder-Mead', residual=43747.63903808594
# 000348, method='Nelder-Mead', residual=43747.635009765625
# 000349, method='Nelder-Mead', residual=43747.67431640625
# 000350, method='Nelder-Mead', residual=43747.84045410156
# 000351, method='Nelder-Mead', residual=43747.69775390625
# 000352, method='Nelder-Mead', residual=43747.68701171875
# 000353, method='Nelder-Mead', residual=43747.64904785156
# 000354, method='Nelder-Mead', residual=43747.65026855469
# 000355, method='Nelder-Mead', residual=43747.80944824219
# 000356, method='Nelder-Mead', residual=43747.663330078125
# 000357, method='Nelder-Mead', residual=43747.51123046875
# 000358, method='Nelder-Mead', residual=43747.422119140625
# 000359, method='Nelder-Mead', residual=43747.53955078125
# 000360, method='Nelder-Mead', residual=43747.46044921875
# 000361, method='Nelder-Mead', residual=43747.51513671875
# 000362, method='Nelder-Mead', residual=43747.74658203125
# 000363, method='Nelder-Mead', residual=43747.583740234375
# 000364, method='Nelder-Mead', residual=43747.450439453125
# 000365, method='Nelder-Mead', residual=43747.396240234375
# 000366, method='Nelder-Mead', residual=43747.33264160156
# 000367, method='Nelder-Mead', residual=43747.67639160156
# 000368, method='Nelder-Mead', residual=43747.54406738281
# 000369, method='Nelder-Mead', residual=43747.41198730469
# 000370, method='Nelder-Mead', residual=43747.331298828125
# 000371, method='Nelder-Mead', residual=43747.286865234375
# 000372, method='Nelder-Mead', residual=43747.25158691406
# 000373, method='Nelder-Mead', residual=43747.17724609375
# 000374, method='Nelder-Mead', residual=43747.28698730469
# 000375, method='Nelder-Mead', residual=43747.1201171875
# 000376, method='Nelder-Mead', residual=43746.95251464844
# 000377, method='Nelder-Mead', residual=43747.113037109375
# 000378, method='Nelder-Mead', residual=43747.02917480469
# 000379, method='Nelder-Mead', residual=43746.94140625
# 000380, method='Nelder-Mead', residual=43746.74609375
# 000381, method='Nelder-Mead', residual=43746.864013671875
# 000382, method='Nelder-Mead', residual=43746.84948730469
# 000383, method='Nelder-Mead', residual=43746.83972167969
# 000384, method='Nelder-Mead', residual=43746.935791015625
# 000385, method='Nelder-Mead', residual=43746.66442871094
# 000386, method='Nelder-Mead', residual=43746.550537109375
# 000387, method='Nelder-Mead', residual=43746.78039550781
# 000388, method='Nelder-Mead', residual=43746.30261230469
# 000389, method='Nelder-Mead', residual=43745.84423828125
# 000390, method='Nelder-Mead', residual=43746.24621582031
# 000391, method='Nelder-Mead', residual=43746.372802734375
# 000392, method='Nelder-Mead', residual=43746.13415527344
# 000393, method='Nelder-Mead', residual=43746.31604003906
# 000394, method='Nelder-Mead', residual=43746.1220703125
# 000395, method='Nelder-Mead', residual=43745.97155761719
# 000396, method='Nelder-Mead', residual=43746.040771484375
# 000397, method='Nelder-Mead', residual=43746.5078125
# 000398, method='Nelder-Mead', residual=43745.71240234375
# 000399, method='Nelder-Mead', residual=43745.43115234375
# 000400, method='Nelder-Mead', residual=43745.68701171875
# 000401, method='Nelder-Mead', residual=43745.513671875
# 000402, method='Nelder-Mead', residual=43745.20520019531
# 000403, method='Nelder-Mead', residual=43744.59228515625
# 000404, method='Nelder-Mead', residual=43745.08312988281
# 000405, method='Nelder-Mead', residual=43745.2099609375
# 000406, method='Nelder-Mead', residual=43744.88537597656
# 000407, method='Nelder-Mead', residual=43744.76232910156
# 000408, method='Nelder-Mead', residual=43744.58215332031
# 000409, method='Nelder-Mead', residual=43744.13439941406
# 000410, method='Nelder-Mead', residual=43744.265869140625
# 000411, method='Nelder-Mead', residual=43743.91271972656
# 000412, method='Nelder-Mead', residual=43743.04553222656
# 000413, method='Nelder-Mead', residual=43743.62548828125
# 000414, method='Nelder-Mead', residual=43743.8154296875
# 000415, method='Nelder-Mead', residual=43743.27978515625
# 000416, method='Nelder-Mead', residual=43743.19030761719
# 000417, method='Nelder-Mead', residual=43743.08166503906
# 000418, method='Nelder-Mead', residual=43742.56823730469
# 000419, method='Nelder-Mead', residual=43741.652587890625
# 000420, method='Nelder-Mead', residual=43742.08984375
# 000421, method='Nelder-Mead', residual=43741.95751953125
# 000422, method='Nelder-Mead', residual=43741.575927734375
# 000423, method='Nelder-Mead', residual=43740.533203125
# 000424, method='Nelder-Mead', residual=43741.448486328125
# 000425, method='Nelder-Mead', residual=43740.87109375
# 000426, method='Nelder-Mead', residual=43740.62268066406
# 000427, method='Nelder-Mead', residual=43740.0546875
# 000428, method='Nelder-Mead', residual=43738.52331542969
# 000429, method='Nelder-Mead', residual=43739.69055175781
# 000430, method='Nelder-Mead', residual=43740.75341796875
# 000431, method='Nelder-Mead', residual=43738.84313964844
# 000432, method='Nelder-Mead', residual=43738.64416503906
# 000433, method='Nelder-Mead', residual=43738.64367675781
# 000434, method='Nelder-Mead', residual=43738.00085449219
# 000435, method='Nelder-Mead', residual=43736.58386230469
# 000436, method='Nelder-Mead', residual=43737.457275390625
# 000437, method='Nelder-Mead', residual=43736.78698730469
# 000438, method='Nelder-Mead', residual=43737.7158203125
# 000439, method='Nelder-Mead', residual=43736.345947265625
# 000440, method='Nelder-Mead', residual=43734.955078125
# 000441, method='Nelder-Mead', residual=43736.23193359375
# 000442, method='Nelder-Mead', residual=43734.30114746094
# 000443, method='Nelder-Mead', residual=43731.509033203125
# 000444, method='Nelder-Mead', residual=43734.43957519531
# 000445, method='Nelder-Mead', residual=43734.05859375
# 000446, method='Nelder-Mead', residual=43733.32849121094
# 000447, method='Nelder-Mead', residual=43732.26818847656
# 000448, method='Nelder-Mead', residual=43731.92626953125
# 000449, method='Nelder-Mead', residual=43731.609130859375
# 000450, method='Nelder-Mead', residual=43730.394287109375
# 000451, method='Nelder-Mead', residual=43727.72644042969
# 000452, method='Nelder-Mead', residual=43729.98474121094
# 000453, method='Nelder-Mead', residual=43728.01525878906
# 000454, method='Nelder-Mead', residual=43727.662353515625
# 000455, method='Nelder-Mead', residual=43724.97009277344
# 000456, method='Nelder-Mead', residual=43729.102294921875
# 000457, method='Nelder-Mead', residual=43725.494873046875
# 000458, method='Nelder-Mead', residual=43725.04846191406
# 000459, method='Nelder-Mead', residual=43724.52453613281
# 000460, method='Nelder-Mead', residual=43721.743896484375
# 000461, method='Nelder-Mead', residual=43723.43249511719
# 000462, method='Nelder-Mead', residual=43722.685791015625
# 000463, method='Nelder-Mead', residual=43722.15979003906
# 000464, method='Nelder-Mead', residual=43721.158203125
# 000465, method='Nelder-Mead', residual=43719.96276855469
# 000466, method='Nelder-Mead', residual=43717.94970703125
# 000467, method='Nelder-Mead', residual=43713.073974609375
# 000468, method='Nelder-Mead', residual=43719.40148925781
# 000469, method='Nelder-Mead', residual=43718.73583984375
# 000470, method='Nelder-Mead', residual=43715.341796875
# 000471, method='Nelder-Mead', residual=43717.97131347656
# 000472, method='Nelder-Mead', residual=43717.535400390625
# 000473, method='Nelder-Mead', residual=43714.915283203125
# 000474, method='Nelder-Mead', residual=43715.67578125
# 000475, method='Nelder-Mead', residual=43715.80725097656
# 000476, method='Nelder-Mead', residual=43716.22204589844
# 000477, method='Nelder-Mead', residual=43716.46472167969
# 000478, method='Nelder-Mead', residual=43712.40625
# 000479, method='Nelder-Mead', residual=43710.90002441406
# 000480, method='Nelder-Mead', residual=43714.15319824219
# 000481, method='Nelder-Mead', residual=43711.601318359375
# 000482, method='Nelder-Mead', residual=43709.922119140625
# 000483, method='Nelder-Mead', residual=43707.158935546875
# 000484, method='Nelder-Mead', residual=43708.64758300781
# 000485, method='Nelder-Mead', residual=43710.27453613281
# 000486, method='Nelder-Mead', residual=43708.48547363281
# 000487, method='Nelder-Mead', residual=43706.679931640625
# 000488, method='Nelder-Mead', residual=43704.06115722656
# 000489, method='Nelder-Mead', residual=43704.110107421875
# 000490, method='Nelder-Mead', residual=43704.9541015625
# 000491, method='Nelder-Mead', residual=43702.17907714844
# 000492, method='Nelder-Mead', residual=43699.129150390625
# 000493, method='Nelder-Mead', residual=43700.49694824219
# 000494, method='Nelder-Mead', residual=43705.28564453125
# 000495, method='Nelder-Mead', residual=43699.40490722656
# 000496, method='Nelder-Mead', residual=43697.925048828125
# 000497, method='Nelder-Mead', residual=43694.78649902344
# 000498, method='Nelder-Mead', residual=43697.12060546875
# 000499, method='Nelder-Mead', residual=43693.968017578125
# 000500, method='Nelder-Mead', residual=43689.62072753906
# 000501, method='Nelder-Mead', residual=43695.82897949219
# 000502, method='Nelder-Mead', residual=43692.13049316406
# 000503, method='Nelder-Mead', residual=43693.83349609375
# 000504, method='Nelder-Mead', residual=43689.215087890625
# 000505, method='Nelder-Mead', residual=43687.19921875
# 000506, method='Nelder-Mead', residual=43687.45166015625
# 000507, method='Nelder-Mead', residual=43684.5390625
# 000508, method='Nelder-Mead', residual=43683.45007324219
# 000509, method='Nelder-Mead', residual=43685.84533691406
# 000510, method='Nelder-Mead', residual=43683.498291015625
# 000511, method='Nelder-Mead', residual=43681.86218261719
# 000512, method='Nelder-Mead', residual=43684.124755859375
# 000513, method='Nelder-Mead', residual=43681.216552734375
# 000514, method='Nelder-Mead', residual=43684.37048339844
# 000515, method='Nelder-Mead', residual=43680.45056152344
# 000516, method='Nelder-Mead', residual=43684.986328125
# 000517, method='Nelder-Mead', residual=43684.62536621094
# 000518, method='Nelder-Mead', residual=43685.43127441406
# 000519, method='Nelder-Mead', residual=43677.14245605469
# 000520, method='Nelder-Mead', residual=43681.28063964844
# 000521, method='Nelder-Mead', residual=43684.13391113281
# 000522, method='Nelder-Mead', residual=43678.86950683594
# 000523, method='Nelder-Mead', residual=43691.03259277344
# 000524, method='Nelder-Mead', residual=43680.86682128906
# 000525, method='Nelder-Mead', residual=43677.4248046875
# 000526, method='Nelder-Mead', residual=43679.62219238281
# 000527, method='Nelder-Mead', residual=43680.60778808594
# 000528, method='Nelder-Mead', residual=43682.89392089844
# 000529, method='Nelder-Mead', residual=43679.99084472656
# 000530, method='Nelder-Mead', residual=43689.7236328125
# 000531, method='Nelder-Mead', residual=43678.44909667969
# 000532, method='Nelder-Mead', residual=43682.921630859375
# 000533, method='Nelder-Mead', residual=43678.97204589844
# 000534, method='Nelder-Mead', residual=43673.917236328125
# 000535, method='Nelder-Mead', residual=43672.08630371094
# 000536, method='Nelder-Mead', residual=43673.29333496094
# 000537, method='Nelder-Mead', residual=43677.03771972656
# 000538, method='Nelder-Mead', residual=43678.70617675781
# 000539, method='Nelder-Mead', residual=43675.89831542969
# 000540, method='Nelder-Mead', residual=43676.64892578125
# 000541, method='Nelder-Mead', residual=43681.23864746094
# 000542, method='Nelder-Mead', residual=43675.71691894531
# 000543, method='Nelder-Mead', residual=43679.828369140625
# 000544, method='Nelder-Mead', residual=43675.56896972656
# 000545, method='Nelder-Mead', residual=43671.35607910156
# 000546, method='Nelder-Mead', residual=43670.831298828125
# 000547, method='Nelder-Mead', residual=43678.32373046875
# 000548, method='Nelder-Mead', residual=43673.226806640625
# 000549, method='Nelder-Mead', residual=43678.690673828125
# 000550, method='Nelder-Mead', residual=43674.94543457031
# 000551, method='Nelder-Mead', residual=43672.29345703125
# 000552, method='Nelder-Mead', residual=43671.15588378906
# 000553, method='Nelder-Mead', residual=43672.97119140625
# 000554, method='Nelder-Mead', residual=43674.12902832031
# 000555, method='Nelder-Mead', residual=43675.12707519531
# 000556, method='Nelder-Mead', residual=43668.85998535156
# 000557, method='Nelder-Mead', residual=43668.22216796875
# 000558, method='Nelder-Mead', residual=43669.82568359375
# 000559, method='Nelder-Mead', residual=43673.61877441406
# 000560, method='Nelder-Mead', residual=43670.762451171875
# 000561, method='Nelder-Mead', residual=43671.4423828125
# 000562, method='Nelder-Mead', residual=43672.23986816406
# 000563, method='Nelder-Mead', residual=43670.04260253906
# 000564, method='Nelder-Mead', residual=43668.76965332031
# 000565, method='Nelder-Mead', residual=43670.36853027344
# 000566, method='Nelder-Mead', residual=43678.197509765625
# 000567, method='Nelder-Mead', residual=43669.30322265625
# 000568, method='Nelder-Mead', residual=43669.89489746094
# 000569, method='Nelder-Mead', residual=43667.068359375
# 000570, method='Nelder-Mead', residual=43669.53259277344
# 000571, method='Nelder-Mead', residual=43673.40612792969
# 000572, method='Nelder-Mead', residual=43668.45324707031
# 000573, method='Nelder-Mead', residual=43668.39855957031
# 000574, method='Nelder-Mead', residual=43672.96008300781
# 000575, method='Nelder-Mead', residual=43668.17395019531
# 000576, method='Nelder-Mead', residual=43668.987548828125
# 000577, method='Nelder-Mead', residual=43670.48864746094
# 000578, method='Nelder-Mead', residual=43668.12060546875
# 000579, method='Nelder-Mead', residual=43668.33020019531
# 000580, method='Nelder-Mead', residual=43670.433349609375
# 000581, method='Nelder-Mead', residual=43667.87121582031
# 000582, method='Nelder-Mead', residual=43666.43859863281
# 000583, method='Nelder-Mead', residual=43667.8134765625
# 000584, method='Nelder-Mead', residual=43668.193115234375
# 000585, method='Nelder-Mead', residual=43668.30993652344
# 000586, method='Nelder-Mead', residual=43668.86755371094
# 000587, method='Nelder-Mead', residual=43667.27734375
# 000588, method='Nelder-Mead', residual=43667.11999511719
# 000589, method='Nelder-Mead', residual=43668.03210449219
# 000590, method='Nelder-Mead', residual=43671.197265625
# 000591, method='Nelder-Mead', residual=43666.952392578125
# 000592, method='Nelder-Mead', residual=43668.53479003906
# 000593, method='Nelder-Mead', residual=43667.009765625
# 000594, method='Nelder-Mead', residual=43666.33752441406
# 000595, method='Nelder-Mead', residual=43667.45166015625
# 000596, method='Nelder-Mead', residual=43668.61364746094
# 000597, method='Nelder-Mead', residual=43666.83801269531
# 000598, method='Nelder-Mead', residual=43667.3076171875
# 000599, method='Nelder-Mead', residual=43666.00537109375
# 000600, method='Nelder-Mead', residual=43667.04248046875
# 000601, method='Nelder-Mead', residual=43668.5078125
# 000602, method='Nelder-Mead', residual=43666.71765136719
# 000603, method='Nelder-Mead', residual=43667.208984375
# 000604, method='Nelder-Mead', residual=43667.79846191406
# 000605, method='Nelder-Mead', residual=43666.44885253906
# 000606, method='Nelder-Mead', residual=43665.43566894531
# 000607, method='Nelder-Mead', residual=43665.14147949219
# 000608, method='Nelder-Mead', residual=43667.43115234375
# 000609, method='Nelder-Mead', residual=43666.285400390625
# 000610, method='Nelder-Mead', residual=43666.3935546875
# 000611, method='Nelder-Mead', residual=43666.27001953125
# 000612, method='Nelder-Mead', residual=43666.3916015625
# 000613, method='Nelder-Mead', residual=43666.05725097656
# 000614, method='Nelder-Mead', residual=43665.7607421875
# 000615, method='Nelder-Mead', residual=43666.00048828125
# 000616, method='Nelder-Mead', residual=43665.68212890625
# 000617, method='Nelder-Mead', residual=43664.95373535156
# 000618, method='Nelder-Mead', residual=43664.954833984375
# 000619, method='Nelder-Mead', residual=43666.00866699219
# 000620, method='Nelder-Mead', residual=43666.18225097656
# 000621, method='Nelder-Mead', residual=43665.34899902344
# 000622, method='Nelder-Mead', residual=43665.12841796875
# 000623, method='Nelder-Mead', residual=43665.97326660156
# 000624, method='Nelder-Mead', residual=43666.299560546875
# 000625, method='Nelder-Mead', residual=43665.35205078125
# 000626, method='Nelder-Mead', residual=43664.38244628906
# 000627, method='Nelder-Mead', residual=43664.022216796875
# 000628, method='Nelder-Mead', residual=43665.079833984375
# 000629, method='Nelder-Mead', residual=43664.13781738281
# 000630, method='Nelder-Mead', residual=43663.65881347656
# 000631, method='Nelder-Mead', residual=43663.26867675781
# 000632, method='Nelder-Mead', residual=43665.982666015625
# 000633, method='Nelder-Mead', residual=43664.75183105469
# 000634, method='Nelder-Mead', residual=43664.01257324219
# 000635, method='Nelder-Mead', residual=43664.388427734375
# 000636, method='Nelder-Mead', residual=43664.13562011719
# 000637, method='Nelder-Mead', residual=43662.860107421875
# 000638, method='Nelder-Mead', residual=43662.144775390625
# 000639, method='Nelder-Mead', residual=43663.530517578125
# 000640, method='Nelder-Mead', residual=43663.06457519531
# 000641, method='Nelder-Mead', residual=43662.98571777344
# 000642, method='Nelder-Mead', residual=43662.28662109375
# 000643, method='Nelder-Mead', residual=43662.277587890625
# 000644, method='Nelder-Mead', residual=43662.21630859375
# 000645, method='Nelder-Mead', residual=43661.6328125
# 000646, method='Nelder-Mead', residual=43661.35009765625
# 000647, method='Nelder-Mead', residual=43661.16455078125
# 000648, method='Nelder-Mead', residual=43660.96057128906
# 000649, method='Nelder-Mead', residual=43660.75573730469
# 000650, method='Nelder-Mead', residual=43660.75964355469
# 000651, method='Nelder-Mead', residual=43661.16271972656
# 000652, method='Nelder-Mead', residual=43663.00524902344
# 000653, method='Nelder-Mead', residual=43659.73181152344
# 000654, method='Nelder-Mead', residual=43658.53076171875
# 000655, method='Nelder-Mead', residual=43659.05798339844
# 000656, method='Nelder-Mead', residual=43661.46520996094
# 000657, method='Nelder-Mead', residual=43659.77990722656
# 000658, method='Nelder-Mead', residual=43659.98425292969
# 000659, method='Nelder-Mead', residual=43659.28857421875
# 000660, method='Nelder-Mead', residual=43659.56384277344
# 000661, method='Nelder-Mead', residual=43656.920166015625
# 000662, method='Nelder-Mead', residual=43654.69323730469
# 000663, method='Nelder-Mead', residual=43661.84118652344
# 000664, method='Nelder-Mead', residual=43659.5458984375
# 000665, method='Nelder-Mead', residual=43657.03967285156
# 000666, method='Nelder-Mead', residual=43657.62170410156
# 000667, method='Nelder-Mead', residual=43656.593017578125
# 000668, method='Nelder-Mead', residual=43655.482421875
# 000669, method='Nelder-Mead', residual=43655.304931640625
# 000670, method='Nelder-Mead', residual=43656.06433105469
# 000671, method='Nelder-Mead', residual=43655.325439453125
# 000672, method='Nelder-Mead', residual=43653.99353027344
# 000673, method='Nelder-Mead', residual=43652.720458984375
# 000674, method='Nelder-Mead', residual=43652.83728027344
# 000675, method='Nelder-Mead', residual=43651.84533691406
# 000676, method='Nelder-Mead', residual=43649.636962890625
# 000677, method='Nelder-Mead', residual=43651.21960449219
# 000678, method='Nelder-Mead', residual=43650.805419921875
# 000679, method='Nelder-Mead', residual=43649.78564453125
# 000680, method='Nelder-Mead', residual=43649.36169433594
# 000681, method='Nelder-Mead', residual=43647.71875
# 000682, method='Nelder-Mead', residual=43648.05029296875
# 000683, method='Nelder-Mead', residual=43647.01843261719
# 000684, method='Nelder-Mead', residual=43644.42431640625
# 000685, method='Nelder-Mead', residual=43647.157470703125
# 000686, method='Nelder-Mead', residual=43644.70593261719
# 000687, method='Nelder-Mead', residual=43642.80517578125
# 000688, method='Nelder-Mead', residual=43639.06787109375
# 000689, method='Nelder-Mead', residual=43643.489013671875
# 000690, method='Nelder-Mead', residual=43639.9775390625
# 000691, method='Nelder-Mead', residual=43640.3515625
# 000692, method='Nelder-Mead', residual=43640.71765136719
# 000693, method='Nelder-Mead', residual=43639.76843261719
# 000694, method='Nelder-Mead', residual=43637.02258300781
# 000695, method='Nelder-Mead', residual=43634.47131347656
# 000696, method='Nelder-Mead', residual=43640.875732421875
# 000697, method='Nelder-Mead', residual=43634.880859375
# 000698, method='Nelder-Mead', residual=43633.27380371094
# 000699, method='Nelder-Mead', residual=43630.38635253906
# 000700, method='Nelder-Mead', residual=43632.350341796875
# 000701, method='Nelder-Mead', residual=43633.27783203125
# 000702, method='Nelder-Mead', residual=43630.12902832031
# 000703, method='Nelder-Mead', residual=43628.01208496094
# 000704, method='Nelder-Mead', residual=43629.014892578125
# 000705, method='Nelder-Mead', residual=43626.68078613281
# 000706, method='Nelder-Mead', residual=43622.94030761719
# 000707, method='Nelder-Mead', residual=43625.05908203125
# 000708, method='Nelder-Mead', residual=43627.69567871094
# 000709, method='Nelder-Mead', residual=43620.325439453125
# 000710, method='Nelder-Mead', residual=43615.265625
# 000711, method='Nelder-Mead', residual=43621.58166503906
# 000712, method='Nelder-Mead', residual=43622.39245605469
# 000713, method='Nelder-Mead', residual=43623.157958984375
# 000714, method='Nelder-Mead', residual=43620.64465332031
# 000715, method='Nelder-Mead', residual=43616.789306640625
# 000716, method='Nelder-Mead', residual=43615.98181152344
# 000717, method='Nelder-Mead', residual=43631.606689453125
# 000718, method='Nelder-Mead', residual=43621.786376953125
# 000719, method='Nelder-Mead', residual=43614.354248046875
# 000720, method='Nelder-Mead', residual=43612.72912597656
# 000721, method='Nelder-Mead', residual=43611.97265625
# 000722, method='Nelder-Mead', residual=43610.50048828125
# 000723, method='Nelder-Mead', residual=43613.9091796875
# 000724, method='Nelder-Mead', residual=43618.79187011719
# 000725, method='Nelder-Mead', residual=43612.66809082031
# 000726, method='Nelder-Mead', residual=43609.47302246094
# 000727, method='Nelder-Mead', residual=43609.64831542969
# 000728, method='Nelder-Mead', residual=43619.7138671875
# 000729, method='Nelder-Mead', residual=43608.74841308594
# 000730, method='Nelder-Mead', residual=43610.05163574219
# 000731, method='Nelder-Mead', residual=43608.41564941406
# 000732, method='Nelder-Mead', residual=43611.72448730469
# 000733, method='Nelder-Mead', residual=43612.612060546875
# 000734, method='Nelder-Mead', residual=43610.2607421875
# 000735, method='Nelder-Mead', residual=43604.15380859375
# 000736, method='Nelder-Mead', residual=43601.935546875
# 000737, method='Nelder-Mead', residual=43604.95617675781
# 000738, method='Nelder-Mead', residual=43608.60192871094
# 000739, method='Nelder-Mead', residual=43600.465576171875
# 000740, method='Nelder-Mead', residual=43596.71008300781
# 000741, method='Nelder-Mead', residual=43605.19873046875
# 000742, method='Nelder-Mead', residual=43600.968017578125
# 000743, method='Nelder-Mead', residual=43613.707275390625
# 000744, method='Nelder-Mead', residual=43605.466796875
# 000745, method='Nelder-Mead', residual=43601.14294433594
# 000746, method='Nelder-Mead', residual=43607.268798828125
# 000747, method='Nelder-Mead', residual=43600.81689453125
# 000748, method='Nelder-Mead', residual=43596.95910644531
# 000749, method='Nelder-Mead', residual=43598.318603515625
# 000750, method='Nelder-Mead', residual=43600.16748046875
# 000751, method='Nelder-Mead', residual=43601.520263671875
# 000752, method='Nelder-Mead', residual=43600.549072265625
# 000753, method='Nelder-Mead', residual=43595.15563964844
# 000754, method='Nelder-Mead', residual=43596.80212402344
# 000755, method='Nelder-Mead', residual=43595.658935546875
# 000756, method='Nelder-Mead', residual=43594.31701660156
# 000757, method='Nelder-Mead', residual=43595.80847167969
# 000758, method='Nelder-Mead', residual=43601.24206542969
# 000759, method='Nelder-Mead', residual=43597.448486328125
# 000760, method='Nelder-Mead', residual=43597.70568847656
# 000761, method='Nelder-Mead', residual=43594.97155761719
# 000762, method='Nelder-Mead', residual=43593.95910644531
# 000763, method='Nelder-Mead', residual=43597.860595703125
# 000764, method='Nelder-Mead', residual=43595.192626953125
# 000765, method='Nelder-Mead', residual=43595.692138671875
# 000766, method='Nelder-Mead', residual=43596.27917480469
# 000767, method='Nelder-Mead', residual=43598.16064453125
# 000768, method='Nelder-Mead', residual=43594.58361816406
# 000769, method='Nelder-Mead', residual=43594.567626953125
# 000770, method='Nelder-Mead', residual=43592.67529296875
# 000771, method='Nelder-Mead', residual=43595.27062988281
# 000772, method='Nelder-Mead', residual=43593.99462890625
# 000773, method='Nelder-Mead', residual=43595.58361816406
# 000774, method='Nelder-Mead', residual=43597.37451171875
# 000775, method='Nelder-Mead', residual=43593.33996582031
# 000776, method='Nelder-Mead', residual=43595.01257324219
# 000777, method='Nelder-Mead', residual=43597.15490722656
# 000778, method='Nelder-Mead', residual=43593.27526855469
# 000779, method='Nelder-Mead', residual=43597.41748046875
# 000780, method='Nelder-Mead', residual=43593.15344238281
# 000781, method='Nelder-Mead', residual=43593.841552734375
# 000782, method='Nelder-Mead', residual=43595.91394042969
# 000783, method='Nelder-Mead', residual=43593.13952636719
# 000784, method='Nelder-Mead', residual=43594.70764160156
# 000785, method='Nelder-Mead', residual=43593.08544921875
# 000786, method='Nelder-Mead', residual=43594.516845703125
# 000787, method='Nelder-Mead', residual=43593.739990234375
# 000788, method='Nelder-Mead', residual=43594.91369628906
# 000789, method='Nelder-Mead', residual=43592.985107421875
# 000790, method='Nelder-Mead', residual=43593.95715332031
# 000791, method='Nelder-Mead', residual=43594.84191894531
# 000792, method='Nelder-Mead', residual=43592.76135253906
# 000793, method='Nelder-Mead', residual=43593.387451171875
# 000794, method='Nelder-Mead', residual=43594.427978515625
# 000795, method='Nelder-Mead', residual=43592.798828125
# 000796, method='Nelder-Mead', residual=43593.60852050781
# 000797, method='Nelder-Mead', residual=43595.50146484375
# 000798, method='Nelder-Mead', residual=43592.578369140625
# 000799, method='Nelder-Mead', residual=43593.73046875
# 000800, method='Nelder-Mead', residual=43592.753662109375
# 000801, method='Nelder-Mead', residual=43593.493896484375
# 000802, method='Nelder-Mead', residual=43592.68688964844
# 000803, method='Nelder-Mead', residual=43593.79162597656
# 000804, method='Nelder-Mead', residual=43592.63488769531
# 000805, method='Nelder-Mead', residual=43592.80798339844
# 000806, method='Nelder-Mead', residual=43593.29382324219
# 000807, method='Nelder-Mead', residual=43592.59912109375
# 000808, method='Nelder-Mead', residual=43592.90539550781
# 000809, method='Nelder-Mead', residual=43592.8388671875
# 000810, method='Nelder-Mead', residual=43592.19348144531
# 000811, method='Nelder-Mead', residual=43592.48474121094
# 000812, method='Nelder-Mead', residual=43592.98291015625
# 000813, method='Nelder-Mead', residual=43592.45227050781
# 000814, method='Nelder-Mead', residual=43592.940673828125
# 000815, method='Nelder-Mead', residual=43592.43798828125
# 000816, method='Nelder-Mead', residual=43593.10595703125
# 000817, method='Nelder-Mead', residual=43592.40478515625
# 000818, method='Nelder-Mead', residual=43592.81005859375
# 000819, method='Nelder-Mead', residual=43592.432373046875
# 000820, method='Nelder-Mead', residual=43593.101318359375
# 000821, method='Nelder-Mead', residual=43592.39587402344
# 000822, method='Nelder-Mead', residual=43592.69152832031
# 000823, method='Nelder-Mead', residual=43592.40246582031
# 000824, method='Nelder-Mead', residual=43592.45556640625
# 000825, method='Nelder-Mead', residual=43592.49157714844
# 000826, method='Nelder-Mead', residual=43592.626220703125
# 000827, method='Nelder-Mead', residual=43592.36779785156
# 000828, method='Nelder-Mead', residual=43592.72607421875
# 000829, method='Nelder-Mead', residual=43592.34436035156
# 000830, method='Nelder-Mead', residual=43592.331787109375
# 000831, method='Nelder-Mead', residual=43592.79638671875
# 000832, method='Nelder-Mead', residual=43592.2919921875
# 000833, method='Nelder-Mead', residual=43592.521240234375
# 000834, method='Nelder-Mead', residual=43592.30419921875
# 000835, method='Nelder-Mead', residual=43592.253173828125
# 000836, method='Nelder-Mead', residual=43592.369140625
# 000837, method='Nelder-Mead', residual=43592.22961425781
# 000838, method='Nelder-Mead', residual=43592.44177246094
# 000839, method='Nelder-Mead', residual=43592.26672363281
# 000840, method='Nelder-Mead', residual=43592.2060546875
# 000841, method='Nelder-Mead', residual=43592.23596191406
# ...
# 001288, method='Nelder-Mead', residual=43568.137451171875
# 001289, method='Nelder-Mead', residual=43568.135009765625
# 001290, method='Nelder-Mead', residual=43568.13671875
# 001291, method='Nelder-Mead', residual=43568.135498046875
# 001292, method='Nelder-Mead', residual=43568.13610839844
# 001293, method='Nelder-Mead', residual=43568.1279296875
# 001294, method='Nelder-Mead', residual=43568.131103515625
# 001295, method='Nelder-Mead', residual=43568.139404296875
# 001296, method='Nelder-Mead', residual=43568.13610839844
# 001297, method='Nelder-Mead', residual=43568.13232421875
# 001298, method='Nelder-Mead', residual=43568.133544921875
# 001299, method='Nelder-Mead', residual=43568.134765625
# 001300, method='Nelder-Mead', residual=43568.12939453125
# 001301, method='Nelder-Mead', residual=43568.13708496094
# 001302, method='Nelder-Mead', residual=43568.13427734375
# 001303, method='Nelder-Mead', residual=43568.132080078125
# 001304, method='Nelder-Mead', residual=43568.134033203125
# 001305, method='Nelder-Mead', residual=43568.135498046875
# 001306, method='Nelder-Mead', residual=43568.137939453125
# 001307, method='Nelder-Mead', residual=43568.134033203125
# 001308, method='Nelder-Mead', residual=43568.12683105469
# 001309, method='Nelder-Mead', residual=43568.1298828125
# 001310, method='Nelder-Mead', residual=43568.13073730469
# 001311, method='Nelder-Mead', residual=43568.12707519531
# 001312, method='Nelder-Mead', residual=43568.13037109375
# 001313, method='Nelder-Mead', residual=43568.129638671875
# 001314, method='Nelder-Mead', residual=43568.12902832031
# 001315, method='Nelder-Mead', residual=43568.132568359375
# 001316, method='Nelder-Mead', residual=43568.13098144531
# 001317, method='Nelder-Mead', residual=43568.13195800781
# 001318, method='Nelder-Mead', residual=43568.13122558594
# 001319, method='Nelder-Mead', residual=43568.12829589844
# 001320, method='Nelder-Mead', residual=43568.13037109375
# 001321, method='Nelder-Mead', residual=43568.128662109375
# 001322, method='Nelder-Mead', residual=43568.129150390625
# 001323, method='Nelder-Mead', residual=43568.12854003906
# 001324, method='Nelder-Mead', residual=43568.1328125
# 001325, method='Nelder-Mead', residual=43568.12927246094
# 001326, method='Nelder-Mead', residual=43568.12841796875
# 001327, method='Nelder-Mead', residual=43568.13317871094
# 001328, method='Nelder-Mead', residual=43568.128173828125
# 001329, method='Nelder-Mead', residual=43568.1259765625
# 001330, method='Nelder-Mead', residual=43568.12902832031
# 001331, method='Nelder-Mead', residual=43568.131591796875
# 001332, method='Nelder-Mead', residual=43568.13037109375
# 001333, method='Nelder-Mead', residual=43568.12890625
# 001334, method='Nelder-Mead', residual=43568.12731933594
# 001335, method='Nelder-Mead', residual=43568.123046875
# 001336, method='Nelder-Mead', residual=43568.12805175781
# 001337, method='Nelder-Mead', residual=43568.12585449219
# 001338, method='Nelder-Mead', residual=43568.12756347656
# 001339, method='Nelder-Mead', residual=43568.12548828125
# 001340, method='Nelder-Mead', residual=43568.127685546875
# 001341, method='Nelder-Mead', residual=43568.129150390625
# 001342, method='Nelder-Mead', residual=43568.125244140625
# 001343, method='Nelder-Mead', residual=43568.12902832031
# 001344, method='Nelder-Mead', residual=43568.1259765625
# 001345, method='Nelder-Mead', residual=43568.12658691406
# 001346, method='Nelder-Mead', residual=43568.12463378906
# 001347, method='Nelder-Mead', residual=43568.124267578125
# 001348, method='Nelder-Mead', residual=43568.124267578125
# 001349, method='Nelder-Mead', residual=43568.13024902344
# 001350, method='Nelder-Mead', residual=43568.125244140625
# 001351, method='Nelder-Mead', residual=43568.125244140625
# 001352, method='Nelder-Mead', residual=43568.12487792969
# 001353, method='Nelder-Mead', residual=43568.128173828125
# 001354, method='Nelder-Mead', residual=43568.12854003906
# 001355, method='Nelder-Mead', residual=43568.12414550781
# 001356, method='Nelder-Mead', residual=43568.12658691406
# 001357, method='Nelder-Mead', residual=43568.125244140625
# 001358, method='Nelder-Mead', residual=43568.12609863281
# 001359, method='Nelder-Mead', residual=43568.127197265625
# 001360, method='Nelder-Mead', residual=43568.12634277344
# 001361, method='Nelder-Mead', residual=43568.124755859375
# 001362, method='Nelder-Mead', residual=43568.12487792969
# 001363, method='Nelder-Mead', residual=43568.12487792969
# 001364, method='Nelder-Mead', residual=43568.126220703125
# 001365, method='Nelder-Mead', residual=43568.12255859375
# 001366, method='Nelder-Mead', residual=43568.12731933594
# 001367, method='Nelder-Mead', residual=43568.1279296875
# 001368, method='Nelder-Mead', residual=43568.125
# 001369, method='Nelder-Mead', residual=43568.125244140625
# 001370, method='Nelder-Mead', residual=43568.125
# 001371, method='Nelder-Mead', residual=43568.12341308594
# 001372, method='Nelder-Mead', residual=43568.12683105469
# 001373, method='Nelder-Mead', residual=43568.12268066406
# 001374, method='Nelder-Mead', residual=43568.12390136719
# 001375, method='Nelder-Mead', residual=43568.125244140625
# 001376, method='Nelder-Mead', residual=43568.12451171875
# 001377, method='Nelder-Mead', residual=43568.1240234375
# 001378, method='Nelder-Mead', residual=43568.12927246094
# 001379, method='Nelder-Mead', residual=43568.12170410156
# 001380, method='Nelder-Mead', residual=43568.12487792969
# 001381, method='Nelder-Mead', residual=43568.125244140625
# 001382, method='Nelder-Mead', residual=43568.12438964844
# 001383, method='Nelder-Mead', residual=43568.12683105469
# 001384, method='Nelder-Mead', residual=43568.12548828125
# 001385, method='Nelder-Mead', residual=43568.12487792969
# 001386, method='Nelder-Mead', residual=43568.12451171875
# 001387, method='Nelder-Mead', residual=43568.12561035156
# 001388, method='Nelder-Mead', residual=43568.125244140625
# 001389, method='Nelder-Mead', residual=43568.125
# 001390, method='Nelder-Mead', residual=43568.12414550781
# 001391, method='Nelder-Mead', residual=43568.123291015625
# 001392, method='Nelder-Mead', residual=43568.12512207031
# 001393, method='Nelder-Mead', residual=43568.12365722656
# 001394, method='Nelder-Mead', residual=43568.123779296875
# 001395, method='Nelder-Mead', residual=43568.12414550781
# 001396, method='Nelder-Mead', residual=43568.126708984375
# 001397, method='Nelder-Mead', residual=43568.12390136719
# 001398, method='Nelder-Mead', residual=43568.126708984375
# 001399, method='Nelder-Mead', residual=43568.12438964844
# 001400, method='Nelder-Mead', residual=43568.12536621094
# 001401, method='Nelder-Mead', residual=43568.12219238281
# 001402, method='Nelder-Mead', residual=43568.123046875
# 001403, method='Nelder-Mead', residual=43568.1220703125
# 001404, method='Nelder-Mead', residual=43568.125
# 001405, method='Nelder-Mead', residual=43568.123291015625
# 001406, method='Nelder-Mead', residual=43568.12170410156
# 001407, method='Nelder-Mead', residual=43568.123291015625
# 001408, method='Nelder-Mead', residual=43568.126220703125
# 001409, method='Nelder-Mead', residual=43568.12292480469
# 001410, method='Nelder-Mead', residual=43568.12353515625
# 001411, method='Nelder-Mead', residual=43568.12634277344
# 001412, method='Nelder-Mead', residual=43568.12438964844
# 001413, method='Nelder-Mead', residual=43568.122802734375
# 001414, method='Nelder-Mead', residual=43568.12451171875
# 001415, method='Nelder-Mead', residual=43568.1240234375
# 001416, method='Nelder-Mead', residual=43568.12353515625
# 001417, method='Nelder-Mead', residual=43568.12341308594
# 001418, method='Nelder-Mead', residual=43568.12268066406
# 001419, method='Nelder-Mead', residual=43568.124267578125
# 001420, method='Nelder-Mead', residual=43568.12365722656
# 001421, method='Nelder-Mead', residual=43568.123046875
# 001422, method='Nelder-Mead', residual=43568.12414550781
# 001423, method='Nelder-Mead', residual=43568.12548828125
# 001424, method='Nelder-Mead', residual=43568.12390136719
# 001425, method='Nelder-Mead', residual=43568.12438964844
# 001426, method='Nelder-Mead', residual=43568.1240234375
# 001427, method='Nelder-Mead', residual=43568.126953125
# 001428, method='Nelder-Mead', residual=43568.12487792969
# 001429, method='Nelder-Mead', residual=43568.123291015625
# 001430, method='Nelder-Mead', residual=43568.125
# 001431, method='Nelder-Mead', residual=43568.122314453125
# 001432, method='Nelder-Mead', residual=43568.12561035156
# 001433, method='Nelder-Mead', residual=43568.12463378906
# 001434, method='Nelder-Mead', residual=43568.125244140625
# 001435, method='Nelder-Mead', residual=43568.12353515625
# 001436, method='Nelder-Mead', residual=43568.12512207031
# 001437, method='Nelder-Mead', residual=43568.12805175781
# 001438, method='Nelder-Mead', residual=43568.125
# 001439, method='Nelder-Mead', residual=43568.1259765625
# 001440, method='Nelder-Mead', residual=43568.12512207031
# 001441, method='Nelder-Mead', residual=43568.12609863281
# 001442, method='Nelder-Mead', residual=43568.12194824219
# 001443, method='Nelder-Mead', residual=43568.12451171875
# 001444, method='Nelder-Mead', residual=43568.12438964844
# 001445, method='Nelder-Mead', residual=43568.1240234375
# 001446, method='Nelder-Mead', residual=43568.123291015625
# 001447, method='Nelder-Mead', residual=43568.12451171875
# 001448, method='Nelder-Mead', residual=43568.124267578125
# 001449, method='Nelder-Mead', residual=43568.124755859375
# 001450, method='Nelder-Mead', residual=43568.12512207031
# 001451, method='Nelder-Mead', residual=43568.12353515625
# 001452, method='Nelder-Mead', residual=43568.125
# 001453, method='Nelder-Mead', residual=43568.1259765625
# 001454, method='Nelder-Mead', residual=43568.12512207031
# 001455, method='Nelder-Mead', residual=43568.12683105469
# 001456, method='Nelder-Mead', residual=43568.12683105469
# 001457, method='Nelder-Mead', residual=43568.12487792969
# 001458, method='Nelder-Mead', residual=43568.123046875
# 001459, method='Nelder-Mead', residual=43568.12438964844
# 001460, method='Nelder-Mead', residual=43568.12353515625
# 001461, method='Nelder-Mead', residual=43568.12548828125
# 001462, method='Nelder-Mead', residual=43568.12438964844
# 001463, method='Nelder-Mead', residual=43568.12487792969
# 001464, method='Nelder-Mead', residual=43568.12451171875
# 001465, method='Nelder-Mead', residual=43568.12390136719
# 001466, method='Nelder-Mead', residual=43568.123291015625
# 001467, method='Nelder-Mead', residual=43568.1240234375
# 001468, method='Nelder-Mead', residual=43568.12463378906
# 001469, method='Nelder-Mead', residual=43568.12243652344
# 001470, method='Nelder-Mead', residual=43568.1240234375
# 001471, method='Nelder-Mead', residual=43568.12255859375
# 001472, method='Nelder-Mead', residual=43568.12487792969
# 001473, method='Nelder-Mead', residual=43568.12438964844
# 001474, method='Nelder-Mead', residual=43568.12487792969
# 001475, method='Nelder-Mead', residual=43568.12438964844
# 001476, method='Nelder-Mead', residual=43568.12414550781
# 001477, method='Nelder-Mead', residual=43568.12438964844
# 001478, method='Nelder-Mead', residual=43568.12536621094
# 001479, method='Nelder-Mead', residual=43568.12353515625
# 001480, method='Nelder-Mead', residual=43568.12512207031
# 001481, method='Nelder-Mead', residual=43568.12683105469
# 001482, method='Nelder-Mead', residual=43568.125244140625
# 001483, method='Nelder-Mead', residual=43568.12353515625
# 001484, method='Nelder-Mead', residual=43568.12536621094
# 001485, method='Nelder-Mead', residual=43568.12536621094
# 001486, method='Nelder-Mead', residual=43568.125244140625
# 001487, method='Nelder-Mead', residual=43568.12390136719
# 001488, method='Nelder-Mead', residual=43568.12683105469
# 001489, method='Nelder-Mead', residual=43568.125244140625
# 001490, method='Nelder-Mead', residual=43568.12438964844
# 001491, method='Nelder-Mead', residual=43568.12438964844
# 001492, method='Nelder-Mead', residual=43568.12390136719
# 001493, method='Nelder-Mead', residual=43568.12292480469
# 001494, method='Nelder-Mead', residual=43568.123046875
# 001495, method='Nelder-Mead', residual=43568.12438964844
# 001496, method='Nelder-Mead', residual=43568.12438964844
# 001497, method='Nelder-Mead', residual=43568.12292480469
# 001498, method='Nelder-Mead', residual=43568.12438964844
# 001499, method='Nelder-Mead', residual=43568.12170410156
# 001500, method='Nelder-Mead', residual=43568.12170410156
# 001501, method='Nelder-Mead', residual=43568.12512207031
# 001502, method='Nelder-Mead', residual=43568.12390136719
# 001503, method='Nelder-Mead', residual=43568.12438964844
# 001504, method='Nelder-Mead', residual=43568.12512207031
# 001505, method='Nelder-Mead', residual=43568.12438964844
# 001506, method='Nelder-Mead', residual=43568.12512207031
# 001507, method='Nelder-Mead', residual=43568.12512207031
# 001508, method='Nelder-Mead', residual=43568.12512207031
# 001509, method='Nelder-Mead', residual=43568.12512207031
# 001510, method='Nelder-Mead', residual=43568.12170410156
# 001511, method='Nelder-Mead', residual=43568.12170410156
# 001512, method='Nelder-Mead', residual=43568.12170410156
# 001513, method='Nelder-Mead', residual=43568.12170410156
# 001514, method='Nelder-Mead', residual=43568.12438964844
# 001515, method='Nelder-Mead', residual=43568.12512207031
# 001516, method='Nelder-Mead', residual=43568.125
# 001517, method='Nelder-Mead', residual=43568.125
# 001518, method='Nelder-Mead', residual=43568.125
# 001519, method='Nelder-Mead', residual=43568.125
# 001520, method='Nelder-Mead', residual=43568.125
# 001521, method='Nelder-Mead', residual=43568.12170410156
# 001522, method='Nelder-Mead', residual=43568.12170410156
# 001523, method='Nelder-Mead', residual=43568.12170410156
# 001524, method='Nelder-Mead', residual=43568.12170410156
# 001525, method='Nelder-Mead', residual=43568.124755859375
# 001526, method='Nelder-Mead', residual=43568.12170410156
# 001527, method='Nelder-Mead', residual=43568.125
# 001528, method='Nelder-Mead', residual=43568.12170410156
# 001529, method='Nelder-Mead', residual=43568.124755859375
# 001530, method='Nelder-Mead', residual=43568.125
# 001531, method='Nelder-Mead', residual=43568.12170410156
# 001532, method='Nelder-Mead', residual=43568.12170410156
# 001533, method='Nelder-Mead', residual=43568.12170410156
# 001534, method='Nelder-Mead', residual=43568.12170410156
# 001535, method='Nelder-Mead', residual=43568.12170410156
# 001536, method='Nelder-Mead', residual=43568.12170410156
# 001537, method='Nelder-Mead', residual=43568.12170410156
# 001538, method='Nelder-Mead', residual=43568.12170410156
# 001539, method='Nelder-Mead', residual=43568.12170410156
# 001540, method='Nelder-Mead', residual=43568.12170410156
# 001541, method='Nelder-Mead', residual=43568.125
# 001542, method='Nelder-Mead', residual=43568.124755859375
# 001543, method='Nelder-Mead', residual=43568.12170410156
# 001544, method='Nelder-Mead', residual=43568.125
# 001545, method='Nelder-Mead', residual=43568.12170410156
# 001546, method='Nelder-Mead', residual=43568.12170410156
# 001547, method='Nelder-Mead', residual=43568.12170410156
# 001548, method='Nelder-Mead', residual=43568.12170410156
# 001549, method='Nelder-Mead', residual=43568.12170410156
# 001550, method='Nelder-Mead', residual=43568.12170410156
# 001551, method='Nelder-Mead', residual=43568.12170410156
# 001552, method='Nelder-Mead', residual=43568.12170410156
# 001553, method='Nelder-Mead', residual=43568.12170410156
# 001554, method='Nelder-Mead', residual=43568.12170410156
# 001555, method='Nelder-Mead', residual=43568.12170410156
# 001556, method='Nelder-Mead', residual=43568.12170410156
# 001557, method='Nelder-Mead', residual=43568.125
# 001558, method='Nelder-Mead', residual=43568.12170410156
# 001559, method='Nelder-Mead', residual=43568.12170410156
# 001560, method='Nelder-Mead', residual=43568.12170410156
# 001561, method='Nelder-Mead', residual=43568.12170410156
# 001562, method='Nelder-Mead', residual=43568.12170410156
# 001563, method='Nelder-Mead', residual=43568.12170410156
# 001564, method='Nelder-Mead', residual=43568.12170410156
# 001565, method='Nelder-Mead', residual=43568.12170410156
# 001566, method='Nelder-Mead', residual=43568.12170410156
# 001567, method='Nelder-Mead', residual=43568.12170410156
# 001568, method='Nelder-Mead', residual=43568.12170410156
# 001569, method='Nelder-Mead', residual=43568.12170410156
