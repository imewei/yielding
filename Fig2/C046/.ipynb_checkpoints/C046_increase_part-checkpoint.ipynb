# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras

def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C046_Cys1_Exp2_Creep_XPCS_120Pa_01_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1002
    CreepEnd = 2001

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d


    
def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]
    f_c  = paras[num_d + num_v:num_d + num_v + num_f]
    tabs = np.linspace(0.1, 0.1*t_length, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = 1 - f_c[0]*np.exp((tabs - f_c[2])*f_c[1])
    
    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    and all(i <= 1 for i in f)== True\
    and all(i >= 0 for i in f)== True\
     and f_c[2] > 0\
    :
    
        shape = c2_exp.shape
        residual = 0.0

        c2_fit = Heterodyne4(paras, phi_list)

        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
       
          
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)
            
        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
            

        sol_array = np.array(sol_list).reshape(23,2)
        if all(i <= 0 for i in sol_array[:,0]) == True \
        or all( i >= 0.5 for i in sol_array[:,0]) == True\
        or all( i >= 1.2 for i in sol_array[:,1]) == True\
        or all( i <= 1 for i in sol_array[:,1])== True:
            residual = np.inf
    else:
        residual = np.inf
    

    return residual

def separate_params(x, phi_length):
    x = x.astype(DTYPE)    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace(0.1, 0.1*t_length, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = 1 - f_c[0]*np.exp((tabs - f_c[2])*f_c[1])
    
    return D, v, phio, f, beta, c

def Heterodyne4(x, phi_list):
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]

    tabs = np.linspace(0.1, 0.1*t_length, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = 1 - f_c[0]*np.exp((tabs - f_c[2])*f_c[1])
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(qValue**2/2 * -abs(DMat) * dt).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2
    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (t0 + 2*f1s*f2s*f1r*f2r* w * g1_s *g1_r)/ftotal**2

    return g2_all

def Heterodyne5(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)

    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace(0.1, 0.1*t_length, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = 1 - f_c[0]*np.exp((tabs - f_c[2])*f_c[1])
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(-abs((qValue**2/2 * DMat * dt))).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2

    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (t0 +  2*f1s*f2s*f1r*f2r * w*g1_s*g1_r) / ftotal**2
    return g2_all

def plot_results(fname):
    c2_exp, t_length, phi_list, phi_length = read_data()
    shape = c2_exp.shape
    paras = read_parameters(fname)
    c2_fit = Heterodyne5(paras, phi_list)
    
    fig = plt.figure(layout='constrained', figsize=(12, 8))
    subfigs = fig.subfigures(6, 4, wspace=0.10)
    subfigs = subfigs.ravel()

    for n in range(phi_length):
        ax = subfigs[n].subplots(1, 2, sharey=True)
        ax[0].imshow(c2_exp[n], vmin=1, vmax=1.35, cmap=plt.cm.jet)
        ax[1].imshow(c2_fit[n], vmin=1, vmax=1.35, cmap=plt.cm.jet)
        # ax[0].imshow(c2_exp[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        # ax[1].imshow(c2_fit[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        ax[0].set_axis_off()
        ax[1].set_axis_off()
    plt.savefig('result_fitting.png', dpi=150)
    plt.show()
    plt.close(fig)

    D, v, phio, f, beta, c = separate_params(paras, phi_length)
    
    fig, ax = plt.subplots(3, 2)
    ax = ax.ravel()
    ax[0].plot(D)
    ax[0].set_title('Diffusion Coefficient')

    ax[1].plot(v)
    ax[1].set_title('velocity')

    ax[2].plot(phio, 'ro', ms=5)
    ax[2].set_title('phio')

    ax[3].plot(f)
    ax[3].set_title('fraction')

    
    ax[4].plot(beta)
    ax[4].set_title('beta')

    ax[5].plot(c)
    ax[5].set_title('c')
    plt.tight_layout()
    


    plt.savefig('result_parameters.png', dpi=300)
    plt.show()
    plt.close(fig)
    print(np.sum(abs(c2_exp.reshape(-1) - c2_fit.reshape(-1))))

# %%
DTYPE = np.float32
gindex = 0
FitParas = None
c2_exp, t_length, phi_list, phi_length = read_data()


num_d=3
num_v=3
num_f=3
# Out:
# c2_cache_1002_2001.npz
# (23, 999, 999) float32

# %%
t_length = 220
DTYPE = np.float32
gindex = 0
FitParas = None
c2_exp, t_length_full, phi_list, phi_length = read_data()
c2_exp_Select = np.zeros((23,t_length,t_length))
for phiIdx, phi in enumerate(phi_list):
    c2_exp_Select[phiIdx] = c2_exp[phiIdx,:t_length,:t_length]
# Out:
# c2_cache_1002_2001.npz
# (23, 999, 999) float32

# %%
x0 = np.array([
    5.227447113282373437e+00,
    2.820479043042209977e+00,
    7.226237038740626986e+02,
    7.853107116746640970e-02,
    4.630096824551399592e+00,
    1.715390830520741929e+03,
    1.651710560205999490e-01,
    -3.509685635032603473e-02,
    2.199777816735317865e-07,
    4.317073582137433141e-03,
              ])

for method in (
            'Nelder-Mead',
            # 'Powell',
            # 'L-BFGS-B',
            # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
            # 'trust-ncg', 'trust-exact', 'trust-krylov'):
            ):
# def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                            args=(phi_list, num_d, num_v, c2_exp_Select, method),
                            options={"maxiter": 1000000}, tol=0.00001,
                            method=method)

FitParas = FitOutput['x']

c2_fit = Heterodyne4(FitParas, phi_list)
shape = c2_fit.shape
sol_list = []
for n in range(shape[0]):
    sumy = np.sum(c2_fit[n])
    a = np.array([
        [np.sum(c2_fit[n] ** 2), sumy],
        [sumy, c2_fit[n].size]
    ])
    b = np.array([np.sum(c2_exp_Select[n] * c2_fit[n]), np.sum(c2_exp_Select[n])])
    sol = np.linalg.solve(a, b)
    sol_list.append(sol)
    
FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
np.savetxt('../FitParas/C046_increase_FitParas.txt', FitParas, delimiter=",")
# Out:
# 000001, method='Nelder-Mead', residual=2180.867832794363
# 000002, method='Nelder-Mead', residual=2182.5057904017776
# 000003, method='Nelder-Mead', residual=2282.9312357280774
# 000004, method='Nelder-Mead', residual=2180.9850625704767
# 000005, method='Nelder-Mead', residual=2181.897226198576
# 000006, method='Nelder-Mead', residual=2189.04206303065
# 000007, method='Nelder-Mead', residual=2184.1190342476943
# 000008, method='Nelder-Mead', residual=2181.057337015849
# 000009, method='Nelder-Mead', residual=2180.8971221256206
# 000010, method='Nelder-Mead', residual=2180.867832794363
# 000011, method='Nelder-Mead', residual=2180.8676503061765
# 000012, method='Nelder-Mead', residual=2264.268034511462
# 000013, method='Nelder-Mead', residual=2203.415341226746
# 000014, method='Nelder-Mead', residual=2206.6641948129095
# 000015, method='Nelder-Mead', residual=2187.5699719223103
# 000016, method='Nelder-Mead', residual=2188.648842504639
# 000017, method='Nelder-Mead', residual=2185.827894627655
# 000018, method='Nelder-Mead', residual=2188.9256127865033
# 000019, method='Nelder-Mead', residual=2182.6332736510935
# 000020, method='Nelder-Mead', residual=2184.874857582395
# 000021, method='Nelder-Mead', residual=2182.960628276722
# 000022, method='Nelder-Mead', residual=2185.939609012364
# 000023, method='Nelder-Mead', residual=2182.5365512908315
# 000024, method='Nelder-Mead', residual=2182.799541138563
# 000025, method='Nelder-Mead', residual=2181.4770669823743
# 000026, method='Nelder-Mead', residual=2183.1075859543143
# 000027, method='Nelder-Mead', residual=2181.388443001941
# 000028, method='Nelder-Mead', residual=2182.6076690950313
# 000029, method='Nelder-Mead', residual=2181.4436372011055
# 000030, method='Nelder-Mead', residual=2183.2525544244118
# 000031, method='Nelder-Mead', residual=2181.225767542679
# 000032, method='Nelder-Mead', residual=2181.618809920773
# 000033, method='Nelder-Mead', residual=2181.374111528799
# 000034, method='Nelder-Mead', residual=2182.0199327835853
# 000035, method='Nelder-Mead', residual=2181.3859566154424
# 000036, method='Nelder-Mead', residual=2181.386407953225
# 000037, method='Nelder-Mead', residual=2181.9791067029914
# 000038, method='Nelder-Mead', residual=2180.8870052846823
# 000039, method='Nelder-Mead', residual=2181.2636432944437
# 000040, method='Nelder-Mead', residual=2181.098265475581
# 000041, method='Nelder-Mead', residual=2181.385928547705
# 000042, method='Nelder-Mead', residual=2180.8137603468713
# 000043, method='Nelder-Mead', residual=2181.1009318838933
# 000044, method='Nelder-Mead', residual=2181.370221028513
# 000045, method='Nelder-Mead', residual=2180.9216028978517
# 000046, method='Nelder-Mead', residual=2181.257968203161
# 000047, method='Nelder-Mead', residual=2180.8939512915767
# 000048, method='Nelder-Mead', residual=2181.3368455946616
# 000049, method='Nelder-Mead', residual=2181.0159695249035
# 000050, method='Nelder-Mead', residual=2181.17312860361
# 000051, method='Nelder-Mead', residual=2180.881730387893
# 000052, method='Nelder-Mead', residual=2180.819637506733
# 000053, method='Nelder-Mead', residual=2180.934010390579
# 000054, method='Nelder-Mead', residual=2180.8745563164307
# 000055, method='Nelder-Mead', residual=2181.087677972202
# 000056, method='Nelder-Mead', residual=2180.8798757946556
# 000057, method='Nelder-Mead', residual=2180.886263204502
# 000058, method='Nelder-Mead', residual=2181.0174926660993
# 000059, method='Nelder-Mead', residual=2180.864674345381
# 000060, method='Nelder-Mead', residual=2180.918827061194
# 000061, method='Nelder-Mead', residual=2180.8794560662045
# 000062, method='Nelder-Mead', residual=2180.9226827113016
# 000063, method='Nelder-Mead', residual=2180.8521313395768
# 000064, method='Nelder-Mead', residual=2180.984627199927
# 000065, method='Nelder-Mead', residual=2180.8844633840167
# 000066, method='Nelder-Mead', residual=2180.795020900955
# 000067, method='Nelder-Mead', residual=2180.8809906887464
# 000068, method='Nelder-Mead', residual=2180.9215400688586
# 000069, method='Nelder-Mead', residual=2180.9136476524786
# 000070, method='Nelder-Mead', residual=2180.9137876660966
# 000071, method='Nelder-Mead', residual=2180.9137876660966
# 000072, method='Nelder-Mead', residual=2180.9016273071607
# 000073, method='Nelder-Mead', residual=2180.91894579934
# 000074, method='Nelder-Mead', residual=2180.9229137801453
# 000075, method='Nelder-Mead', residual=2180.9118927984855
# 000076, method='Nelder-Mead', residual=2180.853048765007
# 000077, method='Nelder-Mead', residual=2180.8390058332125
# 000078, method='Nelder-Mead', residual=2180.829165123446
# 000079, method='Nelder-Mead', residual=2180.8167430733647
# 000080, method='Nelder-Mead', residual=2180.794055745091
# 000081, method='Nelder-Mead', residual=2180.8434789657176
# 000082, method='Nelder-Mead', residual=2180.805812260954
# 000083, method='Nelder-Mead', residual=2180.8399339464436
# 000084, method='Nelder-Mead', residual=2180.8420599414403
# 000085, method='Nelder-Mead', residual=2180.8198288192293
# 000086, method='Nelder-Mead', residual=2180.794267962342
# 000087, method='Nelder-Mead', residual=2180.819926613805
# 000088, method='Nelder-Mead', residual=2180.832901022294
# 000089, method='Nelder-Mead', residual=2180.8568427296045
# 000090, method='Nelder-Mead', residual=2180.819225405706
# 000091, method='Nelder-Mead', residual=2180.8392327389497
# 000092, method='Nelder-Mead', residual=2180.8187077823372
# 000093, method='Nelder-Mead', residual=2180.82487975791
# 000094, method='Nelder-Mead', residual=2180.806148353178
# 000095, method='Nelder-Mead', residual=2180.8452601519625
# 000096, method='Nelder-Mead', residual=2180.799344672371
# 000097, method='Nelder-Mead', residual=2180.834273589052
# 000098, method='Nelder-Mead', residual=2180.821761012971
# 000099, method='Nelder-Mead', residual=2180.8215317645727
# 000100, method='Nelder-Mead', residual=2180.791004912064
# 000101, method='Nelder-Mead', residual=2180.795181335007
# 000102, method='Nelder-Mead', residual=2180.792206495397
# 000103, method='Nelder-Mead', residual=2180.790057292948
# 000104, method='Nelder-Mead', residual=2180.8012227725712
# 000105, method='Nelder-Mead', residual=2180.805488534559
# 000106, method='Nelder-Mead', residual=2180.806500517027
# 000107, method='Nelder-Mead', residual=2180.8072645838874
# 000108, method='Nelder-Mead', residual=2180.820212778095
# 000109, method='Nelder-Mead', residual=2180.82834857349
# 000110, method='Nelder-Mead', residual=2180.796388272203
# 000111, method='Nelder-Mead', residual=2180.822396111414
# 000112, method='Nelder-Mead', residual=2180.7948716484466
# 000113, method='Nelder-Mead', residual=2180.8027382401424
# 000114, method='Nelder-Mead', residual=2180.805300252437
# 000115, method='Nelder-Mead', residual=2180.813269758074
# 000116, method='Nelder-Mead', residual=2180.7927394578696
# 000117, method='Nelder-Mead', residual=2180.8037060839993
# 000118, method='Nelder-Mead', residual=2180.7934020437965
# 000119, method='Nelder-Mead', residual=2180.8015203341265
# 000120, method='Nelder-Mead', residual=2180.79296513012
# 000121, method='Nelder-Mead', residual=2180.7927754033926
# 000122, method='Nelder-Mead', residual=2180.804887258314
# 000123, method='Nelder-Mead', residual=2180.789417207843
# 000124, method='Nelder-Mead', residual=2180.7992294803385
# 000125, method='Nelder-Mead', residual=2180.7898095074447
# 000126, method='Nelder-Mead', residual=2180.7976317140387
# 000127, method='Nelder-Mead', residual=2180.7898628377948
# 000128, method='Nelder-Mead', residual=2180.789393114332
# 000129, method='Nelder-Mead', residual=2180.795920204441
# 000130, method='Nelder-Mead', residual=2180.7929638355768
# 000131, method='Nelder-Mead', residual=2180.8016434683555
# 000132, method='Nelder-Mead', residual=2180.788317135129
# 000133, method='Nelder-Mead', residual=2180.7921326726255
# 000134, method='Nelder-Mead', residual=2180.797072192782
# 000135, method='Nelder-Mead', residual=2180.7890336260275
# 000136, method='Nelder-Mead', residual=2180.7922147474233
# 000137, method='Nelder-Mead', residual=2180.7892001228906
# 000138, method='Nelder-Mead', residual=2180.7866336870256
# 000139, method='Nelder-Mead', residual=2180.7882963813277
# 000140, method='Nelder-Mead', residual=2180.79268067621
# 000141, method='Nelder-Mead', residual=2180.788655106993
# 000142, method='Nelder-Mead', residual=2180.7903967498896
# 000143, method='Nelder-Mead', residual=2180.788311414515
# 000144, method='Nelder-Mead', residual=2180.788209694745
# 000145, method='Nelder-Mead', residual=2180.7859840222172
# 000146, method='Nelder-Mead', residual=2180.7857468053003
# 000147, method='Nelder-Mead', residual=2180.79048898182
# 000148, method='Nelder-Mead', residual=2180.787579720935
# 000149, method='Nelder-Mead', residual=2180.7875779091587
# 000150, method='Nelder-Mead', residual=2180.7908876043275
# 000151, method='Nelder-Mead', residual=2180.787441112354
# 000152, method='Nelder-Mead', residual=2180.789168720809
# 000153, method='Nelder-Mead', residual=2180.787331792802
# 000154, method='Nelder-Mead', residual=2180.7907019542604
# 000155, method='Nelder-Mead', residual=2180.7872402049707
# 000156, method='Nelder-Mead', residual=2180.7850343550886
# 000157, method='Nelder-Mead', residual=2180.7838724848934
# 000158, method='Nelder-Mead', residual=2180.784973650711
# 000159, method='Nelder-Mead', residual=2180.789763159675
# 000160, method='Nelder-Mead', residual=2180.7863284943915
# 000161, method='Nelder-Mead', residual=2180.784153904562
# 000162, method='Nelder-Mead', residual=2180.784122134713
# 000163, method='Nelder-Mead', residual=2180.7858108869223
# 000164, method='Nelder-Mead', residual=2180.783836532464
# 000165, method='Nelder-Mead', residual=2180.783622480726
# 000166, method='Nelder-Mead', residual=2180.7842955943356
# 000167, method='Nelder-Mead', residual=2180.7827176313704
# 000168, method='Nelder-Mead', residual=2180.782463264752
# 000169, method='Nelder-Mead', residual=2180.7812395363185
# 000170, method='Nelder-Mead', residual=2180.7795153242914
# 000171, method='Nelder-Mead', residual=2180.780887472435
# 000172, method='Nelder-Mead', residual=2180.781953938138
# 000173, method='Nelder-Mead', residual=2180.7821779841565
# 000174, method='Nelder-Mead', residual=2180.7791472567606
# 000175, method='Nelder-Mead', residual=2180.777018899701
# 000176, method='Nelder-Mead', residual=2180.780346083664
# 000177, method='Nelder-Mead', residual=2180.779794047713
# 000178, method='Nelder-Mead', residual=2180.7781422348717
# 000179, method='Nelder-Mead', residual=2180.7771866048324
# 000180, method='Nelder-Mead', residual=2180.7772855432995
# 000181, method='Nelder-Mead', residual=2180.775358820722
# 000182, method='Nelder-Mead', residual=2180.7735780349017
# 000183, method='Nelder-Mead', residual=2180.7774710950916
# 000184, method='Nelder-Mead', residual=2180.7740737267036
# 000185, method='Nelder-Mead', residual=2180.7730645566794
# 000186, method='Nelder-Mead', residual=2180.77096111463
# 000187, method='Nelder-Mead', residual=2180.771951352573
# 000188, method='Nelder-Mead', residual=2180.770116431963
# 000189, method='Nelder-Mead', residual=2180.7667351618197
# 000190, method='Nelder-Mead', residual=2180.7750031924047
# 000191, method='Nelder-Mead', residual=2180.76824281547
# 000192, method='Nelder-Mead', residual=2180.7720525464265
# 000193, method='Nelder-Mead', residual=2180.767594687579
# 000194, method='Nelder-Mead', residual=2180.7673647034558
# 000195, method='Nelder-Mead', residual=2180.7661298247995
# 000196, method='Nelder-Mead', residual=2180.7665431708797
# 000197, method='Nelder-Mead', residual=2180.7728300222907
# 000198, method='Nelder-Mead', residual=2180.765794247212
# 000199, method='Nelder-Mead', residual=2180.76591741802
# 000200, method='Nelder-Mead', residual=2180.764848421634
# 000201, method='Nelder-Mead', residual=2180.7649025927385
# 000202, method='Nelder-Mead', residual=2180.7711374103164
# 000203, method='Nelder-Mead', residual=2180.7661154156845
# 000204, method='Nelder-Mead', residual=2180.763593202961
# 000205, method='Nelder-Mead', residual=2180.7638939262824
# 000206, method='Nelder-Mead', residual=2180.7690466317545
# 000207, method='Nelder-Mead', residual=2180.762652049681
# 000208, method='Nelder-Mead', residual=2180.7621907001867
# 000209, method='Nelder-Mead', residual=2180.7663632197746
# 000210, method='Nelder-Mead', residual=2180.762810517641
# 000211, method='Nelder-Mead', residual=2180.7621945842
# 000212, method='Nelder-Mead', residual=2180.759918142029
# 000213, method='Nelder-Mead', residual=2180.758277624711
# 000214, method='Nelder-Mead', residual=2180.763880589985
# 000215, method='Nelder-Mead', residual=2180.766051780236
# 000216, method='Nelder-Mead', residual=2180.75970533793
# 000217, method='Nelder-Mead', residual=2180.7622209561882
# 000218, method='Nelder-Mead', residual=2180.761547693429
# 000219, method='Nelder-Mead', residual=2180.7583289501395
# 000220, method='Nelder-Mead', residual=2180.7611919003216
# 000221, method='Nelder-Mead', residual=2180.7590165757247
# 000222, method='Nelder-Mead', residual=2180.7575416506425
# 000223, method='Nelder-Mead', residual=2180.7560376501256
# 000224, method='Nelder-Mead', residual=2180.755170334723
# 000225, method='Nelder-Mead', residual=2180.751631592901
# 000226, method='Nelder-Mead', residual=2180.754040109995
# 000227, method='Nelder-Mead', residual=2180.753254959952
# 000228, method='Nelder-Mead', residual=2180.7560730853197
# 000229, method='Nelder-Mead', residual=2180.7618166293287
# 000230, method='Nelder-Mead', residual=2180.7571361511627
# 000231, method='Nelder-Mead', residual=2180.7528990569986
# 000232, method='Nelder-Mead', residual=2180.7499192670543
# 000233, method='Nelder-Mead', residual=2180.744928565757
# 000234, method='Nelder-Mead', residual=2180.7527633738773
# 000235, method='Nelder-Mead', residual=2180.7480054022026
# 000236, method='Nelder-Mead', residual=2180.7442125038974
# 000237, method='Nelder-Mead', residual=2180.7312603645396
# 000238, method='Nelder-Mead', residual=2180.7440558909166
# 000239, method='Nelder-Mead', residual=2180.7422919416135
# 000240, method='Nelder-Mead', residual=2180.742965476918
# 000241, method='Nelder-Mead', residual=2180.7326829864655
# 000242, method='Nelder-Mead', residual=2180.731120972702
# 000243, method='Nelder-Mead', residual=2180.7137808156663
# 000244, method='Nelder-Mead', residual=2180.7229088488366
# 000245, method='Nelder-Mead', residual=2180.7238009569983
# 000246, method='Nelder-Mead', residual=2180.716278924829
# 000247, method='Nelder-Mead', residual=2180.7042393308748
# 000248, method='Nelder-Mead', residual=2180.6671512292905
# 000249, method='Nelder-Mead', residual=2180.6988920371214
# 000250, method='Nelder-Mead', residual=2180.691040023212
# 000251, method='Nelder-Mead', residual=2180.6585487111406
# 000252, method='Nelder-Mead', residual=2180.627562808879
# 000253, method='Nelder-Mead', residual=2180.6522680759977
# 000254, method='Nelder-Mead', residual=2180.6392392134453
# 000255, method='Nelder-Mead', residual=2180.624650051447
# 000256, method='Nelder-Mead', residual=2180.6126030595383
# 000257, method='Nelder-Mead', residual=2180.620034921061
# 000258, method='Nelder-Mead', residual=2180.6107136675123
# 000259, method='Nelder-Mead', residual=2180.599372828257
# 000260, method='Nelder-Mead', residual=2180.6191579225883
# 000261, method='Nelder-Mead', residual=2180.6089933773815
# 000262, method='Nelder-Mead', residual=2180.5920873590558
# 000263, method='Nelder-Mead', residual=2180.6398578813296
# 000264, method='Nelder-Mead', residual=2180.5973528710624
# 000265, method='Nelder-Mead', residual=2180.595281389047
# 000266, method='Nelder-Mead', residual=2180.6164901668512
# 000267, method='Nelder-Mead', residual=2180.6730417270446
# 000268, method='Nelder-Mead', residual=2180.611047200693
# 000269, method='Nelder-Mead', residual=2180.5875579914314
# 000270, method='Nelder-Mead', residual=2180.664586646833
# 000271, method='Nelder-Mead', residual=2180.661715482002
# 000272, method='Nelder-Mead', residual=2180.6200950132506
# 000273, method='Nelder-Mead', residual=2180.579340194762
# 000274, method='Nelder-Mead', residual=2180.588926865052
# 000275, method='Nelder-Mead', residual=2180.5894780338785
# 000276, method='Nelder-Mead', residual=2180.5817575676265
# 000277, method='Nelder-Mead', residual=2180.5814491421092
# 000278, method='Nelder-Mead', residual=2180.600061327045
# 000279, method='Nelder-Mead', residual=2180.597397377581
# 000280, method='Nelder-Mead', residual=2180.5976125602288
# 000281, method='Nelder-Mead', residual=2180.587546355778
# 000282, method='Nelder-Mead', residual=2180.6132330940172
# 000283, method='Nelder-Mead', residual=2180.6197062651804
# 000284, method='Nelder-Mead', residual=2180.5932094904856
# 000285, method='Nelder-Mead', residual=2180.6070684475008
# 000286, method='Nelder-Mead', residual=2180.586244570525
# 000287, method='Nelder-Mead', residual=2180.608182236817
# 000288, method='Nelder-Mead', residual=2180.582247136874
# 000289, method='Nelder-Mead', residual=2180.6014371551573
# 000290, method='Nelder-Mead', residual=2180.5854328429664
# 000291, method='Nelder-Mead', residual=2180.593148523222
# 000292, method='Nelder-Mead', residual=2180.582918886971
# 000293, method='Nelder-Mead', residual=2180.5798226907873
# 000294, method='Nelder-Mead', residual=2180.5919928487383
# 000295, method='Nelder-Mead', residual=2180.580764634388
# 000296, method='Nelder-Mead', residual=2180.597553458374
# 000297, method='Nelder-Mead', residual=2180.579750010923
# 000298, method='Nelder-Mead', residual=2180.580933746763
# 000299, method='Nelder-Mead', residual=2180.586653049187
# 000300, method='Nelder-Mead', residual=2180.580805003105
# 000301, method='Nelder-Mead', residual=2180.5861097002467
# 000302, method='Nelder-Mead', residual=2180.5804178119656
# 000303, method='Nelder-Mead', residual=2180.581494618614
# 000304, method='Nelder-Mead', residual=2180.5851774486196
# 000305, method='Nelder-Mead', residual=2180.5790787904775
# 000306, method='Nelder-Mead', residual=2180.576462300441
# 000307, method='Nelder-Mead', residual=2180.576244411269
# 000308, method='Nelder-Mead', residual=2180.5817162193416
# 000309, method='Nelder-Mead', residual=2180.5788049939033
# 000310, method='Nelder-Mead', residual=2180.5779908217937
# 000311, method='Nelder-Mead', residual=2180.5834289714976
# 000312, method='Nelder-Mead', residual=2180.578058859965
# 000313, method='Nelder-Mead', residual=2180.577844260184
# 000314, method='Nelder-Mead', residual=2180.5760274460667
# 000315, method='Nelder-Mead', residual=2180.5777625840346
# 000316, method='Nelder-Mead', residual=2180.5759894849466
# 000317, method='Nelder-Mead', residual=2180.578586094561
# 000318, method='Nelder-Mead', residual=2180.5890248692904
# 000319, method='Nelder-Mead', residual=2180.576632783536
# 000320, method='Nelder-Mead', residual=2180.574524791223
# 000321, method='Nelder-Mead', residual=2180.5745970860476
# 000322, method='Nelder-Mead', residual=2180.5731376106387
# 000323, method='Nelder-Mead', residual=2180.5712771697245
# 000324, method='Nelder-Mead', residual=2180.571234388872
# 000325, method='Nelder-Mead', residual=2180.568297969115
# 000326, method='Nelder-Mead', residual=2180.572989682033
# 000327, method='Nelder-Mead', residual=2180.5692872853388
# 000328, method='Nelder-Mead', residual=2180.569852592934
# 000329, method='Nelder-Mead', residual=2180.569463174156
# 000330, method='Nelder-Mead', residual=2180.5684827801665
# 000331, method='Nelder-Mead', residual=2180.5681376075017
# 000332, method='Nelder-Mead', residual=2180.5695795636652
# 000333, method='Nelder-Mead', residual=2180.5669025816783
# 000334, method='Nelder-Mead', residual=2180.5685393994167
# 000335, method='Nelder-Mead', residual=2180.5641995060014
# 000336, method='Nelder-Mead', residual=2180.562402113388
# 000337, method='Nelder-Mead', residual=2180.5609237772046
# 000338, method='Nelder-Mead', residual=2180.5570124773176
# 000339, method='Nelder-Mead', residual=2180.5626683077553
# 000340, method='Nelder-Mead', residual=2180.5625063871585
# 000341, method='Nelder-Mead', residual=2180.5583526155874
# 000342, method='Nelder-Mead', residual=2180.5578073981724
# 000343, method='Nelder-Mead', residual=2180.5535163635714
# 000344, method='Nelder-Mead', residual=2180.5466536701197
# 000345, method='Nelder-Mead', residual=2180.5534493843006
# 000346, method='Nelder-Mead', residual=2180.547826232244
# 000347, method='Nelder-Mead', residual=2180.549584184328
# 000348, method='Nelder-Mead', residual=2180.5495942417274
# 000349, method='Nelder-Mead', residual=2180.54542081983
# 000350, method='Nelder-Mead', residual=2180.541779731866
# 000351, method='Nelder-Mead', residual=2180.543602077092
# 000352, method='Nelder-Mead', residual=2180.5453486927486
# 000353, method='Nelder-Mead', residual=2180.538354540702
# 000354, method='Nelder-Mead', residual=2180.533526732439
# 000355, method='Nelder-Mead', residual=2180.5328998635096
# 000356, method='Nelder-Mead', residual=2180.5251284892843
# 000357, method='Nelder-Mead', residual=2180.53017916172
# 000358, method='Nelder-Mead', residual=2180.5360700394585
# 000359, method='Nelder-Mead', residual=2180.544122519504
# 000360, method='Nelder-Mead', residual=2180.530470313346
# 000361, method='Nelder-Mead', residual=2180.530269987758
# 000362, method='Nelder-Mead', residual=2180.530709312658
# 000363, method='Nelder-Mead', residual=2180.5256100416523
# 000364, method='Nelder-Mead', residual=2180.525066096304
# 000365, method='Nelder-Mead', residual=2180.531238201642
# 000366, method='Nelder-Mead', residual=2180.520963299386
# 000367, method='Nelder-Mead', residual=2180.522608333722
# 000368, method='Nelder-Mead', residual=2180.5207841663187
# 000369, method='Nelder-Mead', residual=2180.526647543238
# 000370, method='Nelder-Mead', residual=2180.5151124538443
# 000371, method='Nelder-Mead', residual=2180.510078238076
# 000372, method='Nelder-Mead', residual=2180.5138564623167
# 000373, method='Nelder-Mead', residual=2180.5224570088635
# 000374, method='Nelder-Mead', residual=2180.52416440818
# 000375, method='Nelder-Mead', residual=2180.525907519763
# 000376, method='Nelder-Mead', residual=2180.5162623710603
# 000377, method='Nelder-Mead', residual=2180.528244062568
# 000378, method='Nelder-Mead', residual=2180.5188992659946
# 000379, method='Nelder-Mead', residual=2180.515514597801
# 000380, method='Nelder-Mead', residual=2180.5122306702815
# 000381, method='Nelder-Mead', residual=2180.513980425368
# 000382, method='Nelder-Mead', residual=2180.509948462639
# 000383, method='Nelder-Mead', residual=2180.5133309140233
# 000384, method='Nelder-Mead', residual=2180.5164747719227
# 000385, method='Nelder-Mead', residual=2180.5120862917165
# 000386, method='Nelder-Mead', residual=2180.510217337283
# 000387, method='Nelder-Mead', residual=2180.511021894401
# 000388, method='Nelder-Mead', residual=2180.51705844026
# 000389, method='Nelder-Mead', residual=2180.511601754715
# 000390, method='Nelder-Mead', residual=2180.507867663717
# 000391, method='Nelder-Mead', residual=2180.5117672860692
# 000392, method='Nelder-Mead', residual=2180.510952566928
# 000393, method='Nelder-Mead', residual=2180.5112412859403
# 000394, method='Nelder-Mead', residual=2180.507255717567
# 000395, method='Nelder-Mead', residual=2180.5112612023977
# 000396, method='Nelder-Mead', residual=2180.506811716338
# 000397, method='Nelder-Mead', residual=2180.510335889103
# 000398, method='Nelder-Mead', residual=2180.510223709604
# 000399, method='Nelder-Mead', residual=2180.5084966999434
# 000400, method='Nelder-Mead', residual=2180.5061698485874
# 000401, method='Nelder-Mead', residual=2180.5097265767354
# 000402, method='Nelder-Mead', residual=2180.5072498391555
# 000403, method='Nelder-Mead', residual=2180.5117808652835
# 000404, method='Nelder-Mead', residual=2180.507291741691
# 000405, method='Nelder-Mead', residual=2180.5118240989727
# 000406, method='Nelder-Mead', residual=2180.5070434203703
# 000407, method='Nelder-Mead', residual=2180.5078208425257
# 000408, method='Nelder-Mead', residual=2180.5077250876257
# 000409, method='Nelder-Mead', residual=2180.5073756634292
# 000410, method='Nelder-Mead', residual=2180.5064578264787
# 000411, method='Nelder-Mead', residual=2180.5078444700043
# 000412, method='Nelder-Mead', residual=2180.505846989265
# 000413, method='Nelder-Mead', residual=2180.509620459863
# 000414, method='Nelder-Mead', residual=2180.505712765505
# 000415, method='Nelder-Mead', residual=2180.506601419914
# 000416, method='Nelder-Mead', residual=2180.511518843827
# 000417, method='Nelder-Mead', residual=2180.505279443602
# 000418, method='Nelder-Mead', residual=2180.503726277285
# 000419, method='Nelder-Mead', residual=2180.503057591418
# 000420, method='Nelder-Mead', residual=2180.5059768383617
# 000421, method='Nelder-Mead', residual=2180.509371938427
# 000422, method='Nelder-Mead', residual=2180.5050336870977
# 000423, method='Nelder-Mead', residual=2180.5035480829747
# 000424, method='Nelder-Mead', residual=2180.5031478282576
# 000425, method='Nelder-Mead', residual=2180.503710370616
# 000426, method='Nelder-Mead', residual=2180.5038414999312
# 000427, method='Nelder-Mead', residual=2180.5055436896837
# 000428, method='Nelder-Mead', residual=2180.505226678792
# 000429, method='Nelder-Mead', residual=2180.503719660024
# 000430, method='Nelder-Mead', residual=2180.503527069523
# 000431, method='Nelder-Mead', residual=2180.5056047277058
# 000432, method='Nelder-Mead', residual=2180.503485699748
# 000433, method='Nelder-Mead', residual=2180.50086662024
# 000434, method='Nelder-Mead', residual=2180.4996569603586
# 000435, method='Nelder-Mead', residual=2180.503150968488
# 000436, method='Nelder-Mead', residual=2180.499685370123
# 000437, method='Nelder-Mead', residual=2180.5007032868107
# 000438, method='Nelder-Mead', residual=2180.5009613547118
# 000439, method='Nelder-Mead', residual=2180.5046134782033
# 000440, method='Nelder-Mead', residual=2180.501823589584
# 000441, method='Nelder-Mead', residual=2180.49937405368
# 000442, method='Nelder-Mead', residual=2180.4992159981557
# 000443, method='Nelder-Mead', residual=2180.5008823349
# 000444, method='Nelder-Mead', residual=2180.498050666715
# 000445, method='Nelder-Mead', residual=2180.4978142423815
# 000446, method='Nelder-Mead', residual=2180.4996263144517
# 000447, method='Nelder-Mead', residual=2180.4971946296864
# 000448, method='Nelder-Mead', residual=2180.497389024541
# 000449, method='Nelder-Mead', residual=2180.495004994293
# 000450, method='Nelder-Mead', residual=2180.4936368930116
# 000451, method='Nelder-Mead', residual=2180.494888823862
# 000452, method='Nelder-Mead', residual=2180.4948045812284
# 000453, method='Nelder-Mead', residual=2180.496175188919
# 000454, method='Nelder-Mead', residual=2180.4914401881465
# 000455, method='Nelder-Mead', residual=2180.488163244716
# 000456, method='Nelder-Mead', residual=2180.4916706551367
# 000457, method='Nelder-Mead', residual=2180.4887073272857
# 000458, method='Nelder-Mead', residual=2180.491352920013
# 000459, method='Nelder-Mead', residual=2180.4917720249755
# 000460, method='Nelder-Mead', residual=2180.4879400115246
# 000461, method='Nelder-Mead', residual=2180.4879226868425
# 000462, method='Nelder-Mead', residual=2180.487026546567
# 000463, method='Nelder-Mead', residual=2180.488448260152
# 000464, method='Nelder-Mead', residual=2180.48840401928
# 000465, method='Nelder-Mead', residual=2180.4820695539715
# 000466, method='Nelder-Mead', residual=2180.476872067462
# 000467, method='Nelder-Mead', residual=2180.4801403402766
# 000468, method='Nelder-Mead', residual=2180.4839162842295
# 000469, method='Nelder-Mead', residual=2180.4860649178086
# 000470, method='Nelder-Mead', residual=2180.478021321264
# 000471, method='Nelder-Mead', residual=2180.47543950314
# 000472, method='Nelder-Mead', residual=2180.470402152627
# 000473, method='Nelder-Mead', residual=2180.4807892803346
# 000474, method='Nelder-Mead', residual=2180.476904160679
# 000475, method='Nelder-Mead', residual=2180.4710027628034
# 000476, method='Nelder-Mead', residual=2180.473748611502
# 000477, method='Nelder-Mead', residual=2180.4741154892035
# 000478, method='Nelder-Mead', residual=2180.4690500014144
# 000479, method='Nelder-Mead', residual=2180.4705340872724
# 000480, method='Nelder-Mead', residual=2180.4668000364513
# 000481, method='Nelder-Mead', residual=2180.4647798921796
# 000482, method='Nelder-Mead', residual=2180.467279212364
# 000483, method='Nelder-Mead', residual=2180.4632394999057
# 000484, method='Nelder-Mead', residual=2180.4624335941708
# 000485, method='Nelder-Mead', residual=2180.4593329073914
# 000486, method='Nelder-Mead', residual=2180.455452633628
# 000487, method='Nelder-Mead', residual=2180.462952406602
# 000488, method='Nelder-Mead', residual=2180.4565734612856
# 000489, method='Nelder-Mead', residual=2180.4643396228907
# 000490, method='Nelder-Mead', residual=2180.4608195008377
# 000491, method='Nelder-Mead', residual=2180.459964610533
# 000492, method='Nelder-Mead', residual=2180.454110143888
# 000493, method='Nelder-Mead', residual=2180.4566062284985
# 000494, method='Nelder-Mead', residual=2180.4529046216203
# 000495, method='Nelder-Mead', residual=2180.4518347346866
# 000496, method='Nelder-Mead', residual=2180.4598323228893
# 000497, method='Nelder-Mead', residual=2180.4538577035332
# 000498, method='Nelder-Mead', residual=2180.4630808266734
# 000499, method='Nelder-Mead', residual=2180.456378468671
# 000500, method='Nelder-Mead', residual=2180.4620057043553
# 000501, method='Nelder-Mead', residual=2180.463975330362
# 000502, method='Nelder-Mead', residual=2180.455153789879
# 000503, method='Nelder-Mead', residual=2180.46311416339
# 000504, method='Nelder-Mead', residual=2180.4560322976263
# 000505, method='Nelder-Mead', residual=2180.4517680543922
# 000506, method='Nelder-Mead', residual=2180.4544878902743
# 000507, method='Nelder-Mead', residual=2180.4545568623207
# 000508, method='Nelder-Mead', residual=2180.450395551769
# 000509, method='Nelder-Mead', residual=2180.454508121581
# 000510, method='Nelder-Mead', residual=2180.452064330077
# 000511, method='Nelder-Mead', residual=2180.4488579728923
# 000512, method='Nelder-Mead', residual=2180.4488665214612
# 000513, method='Nelder-Mead', residual=2180.448581607881
# 000514, method='Nelder-Mead', residual=2180.4498731134786
# 000515, method='Nelder-Mead', residual=2180.45274918305
# 000516, method='Nelder-Mead', residual=2180.4509939260165
# 000517, method='Nelder-Mead', residual=2180.4526235926405
# 000518, method='Nelder-Mead', residual=2180.4496783590225
# 000519, method='Nelder-Mead', residual=2180.4454669555753
# 000520, method='Nelder-Mead', residual=2180.4424583643295
# 000521, method='Nelder-Mead', residual=2180.4502454773374
# 000522, method='Nelder-Mead', residual=2180.449699961251
# 000523, method='Nelder-Mead', residual=2180.4466196249246
# 000524, method='Nelder-Mead', residual=2180.4468358290364
# 000525, method='Nelder-Mead', residual=2180.4432206327724
# 000526, method='Nelder-Mead', residual=2180.448014911894
# 000527, method='Nelder-Mead', residual=2180.4443537942525
# 000528, method='Nelder-Mead', residual=2180.446401810999
# 000529, method='Nelder-Mead', residual=2180.4464802900093
# 000530, method='Nelder-Mead', residual=2180.4496289858066
# 000531, method='Nelder-Mead', residual=2180.4455132427474
# 000532, method='Nelder-Mead', residual=2180.4439928318016
# 000533, method='Nelder-Mead', residual=2180.440311513467
# 000534, method='Nelder-Mead', residual=2180.4377064656433
# 000535, method='Nelder-Mead', residual=2180.443175746772
# 000536, method='Nelder-Mead', residual=2180.436562420899
# 000537, method='Nelder-Mead', residual=2180.4250378499246
# 000538, method='Nelder-Mead', residual=2180.4371171168877
# 000539, method='Nelder-Mead', residual=2180.4432340751346
# 000540, method='Nelder-Mead', residual=2180.4317638502202
# 000541, method='Nelder-Mead', residual=2180.426226202609
# 000542, method='Nelder-Mead', residual=2180.4315455719043
# 000543, method='Nelder-Mead', residual=2180.424263250608
# 000544, method='Nelder-Mead', residual=2180.4276200568656
# 000545, method='Nelder-Mead', residual=2180.4322931399593
# 000546, method='Nelder-Mead', residual=2180.4183678370646
# 000547, method='Nelder-Mead', residual=2180.4520232507243
# 000548, method='Nelder-Mead', residual=2180.423540730679
# 000549, method='Nelder-Mead', residual=2180.4184824183376
# 000550, method='Nelder-Mead', residual=2180.420316844092
# 000551, method='Nelder-Mead', residual=2180.4268807261546
# 000552, method='Nelder-Mead', residual=2180.42713324533
# 000553, method='Nelder-Mead', residual=2180.438618945475
# 000554, method='Nelder-Mead', residual=2180.4228376330566
# 000555, method='Nelder-Mead', residual=2180.4325334468635
# 000556, method='Nelder-Mead', residual=2180.4236048984912
# 000557, method='Nelder-Mead', residual=2180.4288421320416
# 000558, method='Nelder-Mead', residual=2180.419840794202
# 000559, method='Nelder-Mead', residual=2180.434145233067
# 000560, method='Nelder-Mead', residual=2180.418469433024
# 000561, method='Nelder-Mead', residual=2180.4209137944313
# 000562, method='Nelder-Mead', residual=2180.4211982366005
# 000563, method='Nelder-Mead', residual=2180.426340369369
# 000564, method='Nelder-Mead', residual=2180.4195048122447
# 000565, method='Nelder-Mead', residual=2180.4259115786917
# 000566, method='Nelder-Mead', residual=2180.4193347224877
# 000567, method='Nelder-Mead', residual=2180.4206708429356
# 000568, method='Nelder-Mead', residual=2180.4347403676607
# 000569, method='Nelder-Mead', residual=2180.418270407201
# 000570, method='Nelder-Mead', residual=2180.4197392442525
# 000571, method='Nelder-Mead', residual=2180.4217227831036
# 000572, method='Nelder-Mead', residual=2180.418104096866
# 000573, method='Nelder-Mead', residual=2180.4245086069086
# 000574, method='Nelder-Mead', residual=2180.4176299744945
# 000575, method='Nelder-Mead', residual=2180.421103742749
# 000576, method='Nelder-Mead', residual=2180.4180029161084
# 000577, method='Nelder-Mead', residual=2180.417677894166
# 000578, method='Nelder-Mead', residual=2180.4188222166235
# 000579, method='Nelder-Mead', residual=2180.419566646881
# 000580, method='Nelder-Mead', residual=2180.4177321462803
# 000581, method='Nelder-Mead', residual=2180.419962383032
# 000582, method='Nelder-Mead', residual=2180.4176801189556
# 000583, method='Nelder-Mead', residual=2180.4188118042766
# 000584, method='Nelder-Mead', residual=2180.4177248510778
# 000585, method='Nelder-Mead', residual=2180.419203255082
# 000586, method='Nelder-Mead', residual=2180.4174240172
# 000587, method='Nelder-Mead', residual=2180.418006309404
# 000588, method='Nelder-Mead', residual=2180.418941237508
# 000589, method='Nelder-Mead', residual=2180.417311345822
# 000590, method='Nelder-Mead', residual=2180.417924147885
# 000591, method='Nelder-Mead', residual=2180.41827313444
# 000592, method='Nelder-Mead', residual=2180.417255311414
# 000593, method='Nelder-Mead', residual=2180.419009243249
# 000594, method='Nelder-Mead', residual=2180.4173547115784
# 000595, method='Nelder-Mead', residual=2180.417657791537
# 000596, method='Nelder-Mead', residual=2180.4186028036524
# 000597, method='Nelder-Mead', residual=2180.4170455926683
# 000598, method='Nelder-Mead', residual=2180.4169842185497
# 000599, method='Nelder-Mead', residual=2180.41756682089
# 000600, method='Nelder-Mead', residual=2180.4172566533693
# 000601, method='Nelder-Mead', residual=2180.4173704259247
# 000602, method='Nelder-Mead', residual=2180.41936423653
# 000603, method='Nelder-Mead', residual=2180.417047003489
# 000604, method='Nelder-Mead', residual=2180.4182005808316
# 000605, method='Nelder-Mead', residual=2180.4170628671286
# 000606, method='Nelder-Mead', residual=2180.417446828065
# 000607, method='Nelder-Mead', residual=2180.4170301001072
# 000608, method='Nelder-Mead', residual=2180.4170613942815
# 000609, method='Nelder-Mead', residual=2180.417622998682
# 000610, method='Nelder-Mead', residual=2180.4169235043955
# 000611, method='Nelder-Mead', residual=2180.4170889875336
# 000612, method='Nelder-Mead', residual=2180.4169772269684
# 000613, method='Nelder-Mead', residual=2180.4171048026546
# 000614, method='Nelder-Mead', residual=2180.4171769175005
# 000615, method='Nelder-Mead', residual=2180.4169114706333
# 000616, method='Nelder-Mead', residual=2180.417273481546
# 000617, method='Nelder-Mead', residual=2180.4169581619244
# 000618, method='Nelder-Mead', residual=2180.4170663336604
# 000619, method='Nelder-Mead', residual=2180.416954521492
# 000620, method='Nelder-Mead', residual=2180.41685430135
# 000621, method='Nelder-Mead', residual=2180.4173016124337
# 000622, method='Nelder-Mead', residual=2180.4171728800584
# 000623, method='Nelder-Mead', residual=2180.4168625198354
# 000624, method='Nelder-Mead', residual=2180.4170628115467
# 000625, method='Nelder-Mead', residual=2180.416837129956
# 000626, method='Nelder-Mead', residual=2180.4170576837932
# 000627, method='Nelder-Mead', residual=2180.416991719709
# 000628, method='Nelder-Mead', residual=2180.4171577038237
# 000629, method='Nelder-Mead', residual=2180.416866859378
# 000630, method='Nelder-Mead', residual=2180.4169722704564
# 000631, method='Nelder-Mead', residual=2180.417014950448
# 000632, method='Nelder-Mead', residual=2180.4169006567618
# 000633, method='Nelder-Mead', residual=2180.4171975331965
# 000634, method='Nelder-Mead', residual=2180.4168975537814
# 000635, method='Nelder-Mead', residual=2180.4169283788096
# 000636, method='Nelder-Mead', residual=2180.416966210167
# 000637, method='Nelder-Mead', residual=2180.4167912930347
# 000638, method='Nelder-Mead', residual=2180.417087646256
# 000639, method='Nelder-Mead', residual=2180.416839448164
# 000640, method='Nelder-Mead', residual=2180.4168653888496
# 000641, method='Nelder-Mead', residual=2180.4169548521036
# 000642, method='Nelder-Mead', residual=2180.4168765840986
# 000643, method='Nelder-Mead', residual=2180.4169352215226
# 000644, method='Nelder-Mead', residual=2180.4168582999514
# 000645, method='Nelder-Mead', residual=2180.4168528451105
# 000646, method='Nelder-Mead', residual=2180.416925708581
# 000647, method='Nelder-Mead', residual=2180.4167727593817
# 000648, method='Nelder-Mead', residual=2180.416845924744
# 000649, method='Nelder-Mead', residual=2180.4169823916513
# 000650, method='Nelder-Mead', residual=2180.416778475718
# 000651, method='Nelder-Mead', residual=2180.416772269634
# 000652, method='Nelder-Mead', residual=2180.417112177786
# 000653, method='Nelder-Mead', residual=2180.416845950587
# 000654, method='Nelder-Mead', residual=2180.4167779123845
# 000655, method='Nelder-Mead', residual=2180.4171822642393
# 000656, method='Nelder-Mead', residual=2180.4167992028497
# 000657, method='Nelder-Mead', residual=2180.4167872921726
# 000658, method='Nelder-Mead', residual=2180.416863448993
# 000659, method='Nelder-Mead', residual=2180.4167515548615
# 000660, method='Nelder-Mead', residual=2180.416966255808
# 000661, method='Nelder-Mead', residual=2180.416754423404
# 000662, method='Nelder-Mead', residual=2180.416853649735
# 000663, method='Nelder-Mead', residual=2180.416840211397
# 000664, method='Nelder-Mead', residual=2180.416849766038
# 000665, method='Nelder-Mead', residual=2180.4168413162424
# 000666, method='Nelder-Mead', residual=2180.4168402827586
# 000667, method='Nelder-Mead', residual=2180.4169287529576
# 000668, method='Nelder-Mead', residual=2180.416866876134
# 000669, method='Nelder-Mead', residual=2180.4169265022074
# 000670, method='Nelder-Mead', residual=2180.4168542968077
# 000671, method='Nelder-Mead', residual=2180.4167807775325
# 000672, method='Nelder-Mead', residual=2180.416803857126
# 000673, method='Nelder-Mead', residual=2180.4167712858252
# 000674, method='Nelder-Mead', residual=2180.416946830828
# 000675, method='Nelder-Mead', residual=2180.4168403775875
# 000676, method='Nelder-Mead', residual=2180.416812422918
# 000677, method='Nelder-Mead', residual=2180.416798818396
# 000678, method='Nelder-Mead', residual=2180.4167865917207
# 000679, method='Nelder-Mead', residual=2180.416854411551
# 000680, method='Nelder-Mead', residual=2180.4168468268335
# 000681, method='Nelder-Mead', residual=2180.4168096641747
# 000682, method='Nelder-Mead', residual=2180.416843557053
# 000683, method='Nelder-Mead', residual=2180.41686916907
# 000684, method='Nelder-Mead', residual=2180.416712960781
# 000685, method='Nelder-Mead', residual=2180.4168017107368
# 000686, method='Nelder-Mead', residual=2180.4167433292328
# 000687, method='Nelder-Mead', residual=2180.416834856959
# 000688, method='Nelder-Mead', residual=2180.4168263550123
# 000689, method='Nelder-Mead', residual=2180.4168461950208
# 000690, method='Nelder-Mead', residual=2180.416851432022
# 000691, method='Nelder-Mead', residual=2180.4168105792223
# 000692, method='Nelder-Mead', residual=2180.416828450471
# 000693, method='Nelder-Mead', residual=2180.4168847614533
# 000694, method='Nelder-Mead', residual=2180.416805777248
# 000695, method='Nelder-Mead', residual=2180.41677901345
# 000696, method='Nelder-Mead', residual=2180.416780612003
# 000697, method='Nelder-Mead', residual=2180.416699619234
# 000698, method='Nelder-Mead', residual=2180.41676137472
# 000699, method='Nelder-Mead', residual=2180.416794973081
# 000700, method='Nelder-Mead', residual=2180.4167423171116
# 000701, method='Nelder-Mead', residual=2180.416875912442
# 000702, method='Nelder-Mead', residual=2180.416887630479
# 000703, method='Nelder-Mead', residual=2180.416796104433
# 000704, method='Nelder-Mead', residual=2180.4167981882124
# 000705, method='Nelder-Mead', residual=2180.4167999471806
# 000706, method='Nelder-Mead', residual=2180.4167693834434
# 000707, method='Nelder-Mead', residual=2180.416794075503
# 000708, method='Nelder-Mead', residual=2180.4167402706516
# 000709, method='Nelder-Mead', residual=2180.41675106517
# 000710, method='Nelder-Mead', residual=2180.4167647012177
# 000711, method='Nelder-Mead', residual=2180.4168336696234
# 000712, method='Nelder-Mead', residual=2180.4168466292517
# 000713, method='Nelder-Mead', residual=2180.41680506051
# 000714, method='Nelder-Mead', residual=2180.4167330913797
# 000715, method='Nelder-Mead', residual=2180.416793648517
# 000716, method='Nelder-Mead', residual=2180.416913500304
# 000717, method='Nelder-Mead', residual=2180.416949328764
# 000718, method='Nelder-Mead', residual=2180.4167975366677
# 000719, method='Nelder-Mead', residual=2180.416920375368
# 000720, method='Nelder-Mead', residual=2180.4167416244204
# 000721, method='Nelder-Mead', residual=2180.4169191049345
# 000722, method='Nelder-Mead', residual=2180.416897897503
# 000723, method='Nelder-Mead', residual=2180.4168580811943
# 000724, method='Nelder-Mead', residual=2180.416773620972
# 000725, method='Nelder-Mead', residual=2180.416892276703
# 000726, method='Nelder-Mead', residual=2180.416752803351
# 000727, method='Nelder-Mead', residual=2180.4169341170577
# 000728, method='Nelder-Mead', residual=2180.4168306880606
# 000729, method='Nelder-Mead', residual=2180.4168647873157
# 000730, method='Nelder-Mead', residual=2180.4168193549062
# 000731, method='Nelder-Mead', residual=2180.416839909304
# 000732, method='Nelder-Mead', residual=2180.4167827391907
# 000733, method='Nelder-Mead', residual=2180.4167527800864
# 000734, method='Nelder-Mead', residual=2180.416705920533
# 000735, method='Nelder-Mead', residual=2180.4167840959253
# 000736, method='Nelder-Mead', residual=2180.4168217513834
# 000737, method='Nelder-Mead', residual=2180.416886586352
# 000738, method='Nelder-Mead', residual=2180.416846489842
# 000739, method='Nelder-Mead', residual=2180.416869324412
# 000740, method='Nelder-Mead', residual=2180.416923064928
# 000741, method='Nelder-Mead', residual=2180.416724035036
# 000742, method='Nelder-Mead', residual=2180.4169054980894
# 000743, method='Nelder-Mead', residual=2180.416873194743
# 000744, method='Nelder-Mead', residual=2180.416741688231
# 000745, method='Nelder-Mead', residual=2180.4168340360116
# 000746, method='Nelder-Mead', residual=2180.4167977024813
# 000747, method='Nelder-Mead', residual=2180.41678617576
# 000748, method='Nelder-Mead', residual=2180.416805020263
# 000749, method='Nelder-Mead', residual=2180.416928375955
# 000750, method='Nelder-Mead', residual=2180.4168918051173
# 000751, method='Nelder-Mead', residual=2180.4166826405813
# 000752, method='Nelder-Mead', residual=2180.416928375955
# 000753, method='Nelder-Mead', residual=2180.416919817328
# 000754, method='Nelder-Mead', residual=2180.4168919264453
# 000755, method='Nelder-Mead', residual=2180.4167492459696
# 000756, method='Nelder-Mead', residual=2180.416762727228
# 000757, method='Nelder-Mead', residual=2180.416856953513
# 000758, method='Nelder-Mead', residual=2180.41671982209
# 000759, method='Nelder-Mead', residual=2180.416673534957
# 000760, method='Nelder-Mead', residual=2180.4166961831756
# 000761, method='Nelder-Mead', residual=2180.4167262935375
# 000762, method='Nelder-Mead', residual=2180.416989955811
# 000763, method='Nelder-Mead', residual=2180.4168958040273
# 000764, method='Nelder-Mead', residual=2180.4168893363294
# 000765, method='Nelder-Mead', residual=2180.4166976808915
# 000766, method='Nelder-Mead', residual=2180.4168927564224
# 000767, method='Nelder-Mead', residual=2180.416858106764
# 000768, method='Nelder-Mead', residual=2180.4167662310383
# 000769, method='Nelder-Mead', residual=2180.416823749053
# 000770, method='Nelder-Mead', residual=2180.4168685232466
# 000771, method='Nelder-Mead', residual=2180.4169489768874
# 000772, method='Nelder-Mead', residual=2180.4167066854848
# 000773, method='Nelder-Mead', residual=2180.416816458481
# 000774, method='Nelder-Mead', residual=2180.416688132641
# 000775, method='Nelder-Mead', residual=2180.4168118426974
# 000776, method='Nelder-Mead', residual=2180.4167259523256
# 000777, method='Nelder-Mead', residual=2180.416807467183
# 000778, method='Nelder-Mead', residual=2180.416726226921
# 000779, method='Nelder-Mead', residual=2180.4167110793996
# 000780, method='Nelder-Mead', residual=2180.4167184154167
# 000781, method='Nelder-Mead', residual=2180.41692085414
# 000782, method='Nelder-Mead', residual=2180.416883351917
# 000783, method='Nelder-Mead', residual=2180.416716799728
# 000784, method='Nelder-Mead', residual=2180.4167072276377
# 000785, method='Nelder-Mead', residual=2180.416722978075
# 000786, method='Nelder-Mead', residual=2180.4167281634495
# 000787, method='Nelder-Mead', residual=2180.4167416233295
# 000788, method='Nelder-Mead', residual=2180.4167315802256
# 000789, method='Nelder-Mead', residual=2180.4167946699777
# 000790, method='Nelder-Mead', residual=2180.416703326362
# 000791, method='Nelder-Mead', residual=2180.416710816917
# 000792, method='Nelder-Mead', residual=2180.41668885312
# 000793, method='Nelder-Mead', residual=2180.416720694729
# 000794, method='Nelder-Mead', residual=2180.416737051829
# 000795, method='Nelder-Mead', residual=2180.4167202999097
# 000796, method='Nelder-Mead', residual=2180.416749815021
# 000797, method='Nelder-Mead', residual=2180.416769115578
# 000798, method='Nelder-Mead', residual=2180.416786506596
# 000799, method='Nelder-Mead', residual=2180.4167851470315
# 000800, method='Nelder-Mead', residual=2180.4167890946687
# 000801, method='Nelder-Mead', residual=2180.416808370415
# 000802, method='Nelder-Mead', residual=2180.4167625905375
# 000803, method='Nelder-Mead', residual=2180.4167063010004
# 000804, method='Nelder-Mead', residual=2180.4166797554512
# 000805, method='Nelder-Mead', residual=2180.4168120822937
# 000806, method='Nelder-Mead', residual=2180.416740623633
# 000807, method='Nelder-Mead', residual=2180.416731112241
# 000808, method='Nelder-Mead', residual=2180.416713847268
# 000809, method='Nelder-Mead', residual=2180.416808457633
# 000810, method='Nelder-Mead', residual=2180.416731214685
# 000811, method='Nelder-Mead', residual=2180.4167315533914
# 000812, method='Nelder-Mead', residual=2180.4167078745927
# 000813, method='Nelder-Mead', residual=2180.4167127586884
# 000814, method='Nelder-Mead', residual=2180.4166626484953
# 000815, method='Nelder-Mead', residual=2180.4166740434057
# 000816, method='Nelder-Mead', residual=2180.416663319421
# 000817, method='Nelder-Mead', residual=2180.4167132269786
# 000818, method='Nelder-Mead', residual=2180.41673593552
# 000819, method='Nelder-Mead', residual=2180.416728884132
# 000820, method='Nelder-Mead', residual=2180.4167691513385
# 000821, method='Nelder-Mead', residual=2180.4167497714457
# 000822, method='Nelder-Mead', residual=2180.416670176606
# 000823, method='Nelder-Mead', residual=2180.4166692431722
# 000824, method='Nelder-Mead', residual=2180.416658554723
# 000825, method='Nelder-Mead', residual=2180.4166719570494
# 000826, method='Nelder-Mead', residual=2180.4167515348804
# 000827, method='Nelder-Mead', residual=2180.4166701651448
# 000828, method='Nelder-Mead', residual=2180.4166704316713
# 000829, method='Nelder-Mead', residual=2180.4167645560533
# 000830, method='Nelder-Mead', residual=2180.41672330217
# 000831, method='Nelder-Mead', residual=2180.4167588008913
# 000832, method='Nelder-Mead', residual=2180.4167182854426
# 000833, method='Nelder-Mead', residual=2180.416779589123
# 000834, method='Nelder-Mead', residual=2180.4167712825174
# 000835, method='Nelder-Mead', residual=2180.4166779642687
# 000836, method='Nelder-Mead', residual=2180.4166770638553
# 000837, method='Nelder-Mead', residual=2180.4166519316727
# 000838, method='Nelder-Mead', residual=2180.4166817076766
# 000839, method='Nelder-Mead', residual=2180.4166777303562
# 000840, method='Nelder-Mead', residual=2180.4166809879775
# 000841, method='Nelder-Mead', residual=2180.4167088583167
# 000842, method='Nelder-Mead', residual=2180.4166777303562
# 000843, method='Nelder-Mead', residual=2180.4166672015126
# 000844, method='Nelder-Mead', residual=2180.416762748578
# 000845, method='Nelder-Mead', residual=2180.416708352186
# 000846, method='Nelder-Mead', residual=2180.4166882459053
# 000847, method='Nelder-Mead', residual=2180.416762748578
# 000848, method='Nelder-Mead', residual=2180.4167033621015
# 000849, method='Nelder-Mead', residual=2180.4166831905754
# 000850, method='Nelder-Mead', residual=2180.4166762497807
# 000851, method='Nelder-Mead', residual=2180.416707233604
# 000852, method='Nelder-Mead', residual=2180.4166779642687
# 000853, method='Nelder-Mead', residual=2180.416679672503
# 000854, method='Nelder-Mead', residual=2180.4166723285616
# 000855, method='Nelder-Mead', residual=2180.4166817076766
# 000856, method='Nelder-Mead', residual=2180.416679695523
# 000857, method='Nelder-Mead', residual=2180.4166526572376
# 000858, method='Nelder-Mead', residual=2180.4167078487876
# 000859, method='Nelder-Mead', residual=2180.4166547566856
# 000860, method='Nelder-Mead', residual=2180.4166589673077
# 000861, method='Nelder-Mead', residual=2180.4166547566856
# 000862, method='Nelder-Mead', residual=2180.4166589673077
# 000863, method='Nelder-Mead', residual=2180.4166589673077
# 000864, method='Nelder-Mead', residual=2180.4166589673077
# 000865, method='Nelder-Mead', residual=2180.4166873166273
# 000866, method='Nelder-Mead', residual=2180.4166548296885
# 000867, method='Nelder-Mead', residual=2180.4166555742263
# 000868, method='Nelder-Mead', residual=2180.4166537490055
# 000869, method='Nelder-Mead', residual=2180.4166537490055
# 000870, method='Nelder-Mead', residual=2180.4166526572376
# 000871, method='Nelder-Mead', residual=2180.4166526572376
# 000872, method='Nelder-Mead', residual=2180.4166526572376
# 000873, method='Nelder-Mead', residual=2180.4166550733025
# 000874, method='Nelder-Mead', residual=2180.4166537490055
# 000875, method='Nelder-Mead', residual=2180.4166726811595
# 000876, method='Nelder-Mead', residual=2180.4166537490055
# 000877, method='Nelder-Mead', residual=2180.4166483916188
# 000878, method='Nelder-Mead', residual=2180.41665968662
# 000879, method='Nelder-Mead', residual=2180.4166589025785
# 000880, method='Nelder-Mead', residual=2180.4166537490055
# 000881, method='Nelder-Mead', residual=2180.416650393079
# 000882, method='Nelder-Mead', residual=2180.4166589025785
# 000883, method='Nelder-Mead', residual=2180.4166537490055
# 000884, method='Nelder-Mead', residual=2180.416650393079
# 000885, method='Nelder-Mead', residual=2180.4166519316727
# 000886, method='Nelder-Mead', residual=2180.4166526572376
# 000887, method='Nelder-Mead', residual=2180.416650393079
# 000888, method='Nelder-Mead', residual=2180.4166519316727
# 000889, method='Nelder-Mead', residual=2180.4166519316727
# 000890, method='Nelder-Mead', residual=2180.4166537490055
# 000891, method='Nelder-Mead', residual=2180.4166526572376
# 000892, method='Nelder-Mead', residual=2180.4166492567797
# 000893, method='Nelder-Mead', residual=2180.4166537490055
# 000894, method='Nelder-Mead', residual=2180.4166483916188
# 000895, method='Nelder-Mead', residual=2180.4166589025785
# 000896, method='Nelder-Mead', residual=2180.4166519316727
# 000897, method='Nelder-Mead', residual=2180.4166483916188
# 000898, method='Nelder-Mead', residual=2180.4166483916188
# 000899, method='Nelder-Mead', residual=2180.4166589025785
# 000900, method='Nelder-Mead', residual=2180.4166519316727
# 000901, method='Nelder-Mead', residual=2180.4166483916188
# 000902, method='Nelder-Mead', residual=2180.4166483916188
# 000903, method='Nelder-Mead', residual=2180.4166483916188
# 000904, method='Nelder-Mead', residual=2180.4166519316727
# 000905, method='Nelder-Mead', residual=2180.4166483916188
# 000906, method='Nelder-Mead', residual=2180.416650393079
# 000907, method='Nelder-Mead', residual=2180.416650393079
# 000908, method='Nelder-Mead', residual=2180.416650393079
# 000909, method='Nelder-Mead', residual=2180.416650393079
# 000910, method='Nelder-Mead', residual=2180.416650393079
# 000911, method='Nelder-Mead', residual=2180.4166589025785
# 000912, method='Nelder-Mead', residual=2180.416650393079
# 000913, method='Nelder-Mead', residual=2180.4166483916188
# 000914, method='Nelder-Mead', residual=2180.4166483916188
# 000915, method='Nelder-Mead', residual=2180.4166589025785
# 000916, method='Nelder-Mead', residual=2180.416650393079
# 000917, method='Nelder-Mead', residual=2180.4166483916188
# 000918, method='Nelder-Mead', residual=2180.4166483916188
# 000919, method='Nelder-Mead', residual=2180.4166483916188
# 000920, method='Nelder-Mead', residual=2180.4166483916188
# 000921, method='Nelder-Mead', residual=2180.4166483916188
# 000922, method='Nelder-Mead', residual=2180.4166483916188
# 000923, method='Nelder-Mead', residual=2180.416650393079
# 000924, method='Nelder-Mead', residual=2180.4166483916188
# 000925, method='Nelder-Mead', residual=2180.4166483916188
# 000926, method='Nelder-Mead', residual=2180.416650393079
