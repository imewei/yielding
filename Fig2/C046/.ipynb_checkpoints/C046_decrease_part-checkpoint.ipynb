# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras

def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C046_Cys1_Exp2_Creep_XPCS_120Pa_01_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart
    
    cache_fname = DataFolderName.replace('.hdf', '.npz')
    cache_fname = f'c2_cache_{CreepStart}_{cache_fname}'
    
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d


def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    global t_length
    global startpoint

    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]
    f_c  = paras[num_d + num_v:num_d + num_v + num_f]
    tabs = np.linspace((startpoint+1)*0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]

    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    and all(i <= 1 for i in f)== True\
    and all(i >= 0 for i in f)== True\
    and (D_c[2] >= 0) == True\
    :
    
        shape = c2_exp.shape
        residual = 0.0

        c2_fit = Heterodyne4(paras, phi_list)

        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)

            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)
            
        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        
        sol_array = np.array(sol_list).reshape(23,2)
        if all(i <= 0 for i in sol_array[:,0]) == True \
        or all( i >= 0.5 for i in sol_array[:,0]) == True\
        or all( i >= 1.3 for i in sol_array[:,1]) == True\
        or all( i <= 1 for i in sol_array[:,1])== True:
            residual = np.inf
            
    else:
        residual = np.inf
    return residual

def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace((startpoint+1)*0.1, 99.9, t_length, dtype=DTYPE)
    
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]
    
    return D, v, phio, f, beta, c

def Heterodyne4(x, phi_list):
    global t_length
    global startpoint
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace((startpoint+1)*0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)

    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(qValue**2/2 * -abs(DMat) * dt).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2
    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (t0 + 2*f1s*f2s*f1r*f2r* w * g1_s* g1_r) / ftotal**2

    return g2_all

def Heterodyne5(x, phi_list):
    global t_length
    global startpoint
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    f_c  = x[num_d + num_v:num_d + num_v + num_f]
    phio = x[num_d + num_v + num_f]
    
    beta = x[num_d + num_v + num_f + 1: num_d + num_v + num_f + phi_length + 1]
    c    = x[num_v + num_f + num_d + phi_length + 1:num_v + num_f + num_d + 2*phi_length + 1]
    
    tabs = np.linspace((startpoint+1)*0.1, 99.9, t_length, dtype=DTYPE)
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    f = f_c[0] * np.exp(f_c[1]*(tabs - f_c[2])) + f_c[3]
    f1s,f2s = np.meshgrid(f,f)
    f1r = 1 - f1s
    f2r = 1 - f2s
    ftotal = np.sqrt((f1s**2 + f1r**2) * (f2s**2 + f2r**2))
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    dt = 0.1
    qValue = 0.0054

    g1_s = np.exp(-abs((qValue**2/2 * DMat * dt))).astype(DTYPE)
    g1_r = g1_s
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    t0 = (f1r*f2r*g1_r) ** 2 + (f1s*f2s*g1_s) ** 2

    for n in range(phi_length):
        w = np.cos(qValue * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (t0 +  2*f1s*f2s*f1r*f2r*w* g1_s* g1_r) / ftotal**2
    return g2_all

def plot_results(fname):
    c2_exp, t_length, phi_list, phi_length = read_data()
    shape = c2_exp.shape
    paras = read_parameters(fname)
    c2_fit = Heterodyne5(paras, phi_list)
    
    fig = plt.figure(layout='constrained', figsize=(12, 8))
    subfigs = fig.subfigures(6, 4, wspace=0.10)
    subfigs = subfigs.ravel()

    for n in range(phi_length):
        ax = subfigs[n].subplots(1, 2, sharey=True)
        ax[0].imshow(c2_exp[n], vmin=1, vmax=1.30, cmap=plt.cm.jet)
        ax[1].imshow(c2_fit[n], vmin=1, vmax=1.30, cmap=plt.cm.jet)
        # ax[0].imshow(c2_exp[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        # ax[1].imshow(c2_fit[n], vmin=None, vmax=None, cmap=plt.cm.jet)
        ax[0].set_axis_off()
        ax[1].set_axis_off()
    plt.savefig('result_fitting.png', dpi=150)
    plt.show()
    plt.close(fig)

    D, v, phio, f, beta, c = separate_params(paras, phi_length)
    
    fig, ax = plt.subplots(3, 2)
    ax = ax.ravel()
    ax[0].plot(D)
    ax[0].set_title('Diffusion Coefficient')

    ax[1].plot(v)
    ax[1].set_title('velocity')

    ax[2].plot(phio, 'ro', ms=5)
    ax[2].set_title('phio')

    ax[3].plot(f)
    ax[3].set_title('fraction')

    
    ax[4].plot(beta)
    ax[4].set_title('beta')

    ax[5].plot(c)
    ax[5].set_title('c')
    plt.tight_layout()

    plt.savefig('result_parameters.png', dpi=300)
    plt.show()
    plt.close(fig)
    print(np.sum(abs(c2_exp.reshape(-1) - c2_fit.reshape(-1))))

# %%
DTYPE = np.float32
gindex = 0
FitParas = None

global t_length
DTYPE = np.float32
startpoint = 250
t_length = 999 - startpoint
tabs = np.linspace((startpoint+1)*0.1, 99.9, t_length, dtype=DTYPE)
gindex = 0
FitParas = None
c2_exp, t_length_full, phi_list, phi_length = read_data()
c2_exp_Select = np.zeros((23,t_length,t_length))
for phiIdx, phi in enumerate(phi_list):
    c2_exp_Select[phiIdx] = c2_exp[phiIdx,startpoint:,startpoint:]

num_d=3
num_v=3
num_f=4
# Out:
# c2_cache_1001_C046_Cys1_Exp2_Creep_XPCS_120Pa_01_att02_Lq2_001_0001-8000_Twotime.npz
# (23, 999, 999) float32

# %%
gindex = 0
x0 = np.array([1.788e+13, -5.729e+00, 0,
               2.835e+18, -8.805e+00, -1.229e-02,
               -1.450e-01, 7.677e-03, -1.313e+01,  1.055e+00,
               -3.338e+00,])
# x0 = read_parameters('C046_FitParas_decrease_Final_09072023.csv')[:10]
for method in (
            'Nelder-Mead',
            # 'Powell',
            # 'L-BFGS-B',
            # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
            # 'trust-ncg', 'trust-exact', 'trust-krylov'):
            ):
# def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
#     FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
#                             args=(phi_list, num_d, num_v, c2_exp_Select, method),
#                             options={"maxiter": 10000}, tol=0.000001,
#                             method=method)
    FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                            args=(phi_list, num_d, num_v, c2_exp_Select, method),
                            options={"maxfev": 4000}, tol=0.000001,
                            method=method)
print('optimization is done')  
FitParas = FitOutput['x']

c2_fit = Heterodyne4(FitParas, phi_list)
shape = c2_fit.shape
sol_list = []
for n in range(shape[0]):
    sumy = np.sum(c2_fit[n])
    a = np.array([
        [np.sum(c2_fit[n] ** 2), sumy],
        [sumy, c2_fit[n].size]
    ])
    b = np.array([np.sum(c2_exp_Select[n] * c2_fit[n]), np.sum(c2_exp_Select[n])])
    sol = np.linalg.solve(a, b)
    sol_list.append(sol)
    
FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
np.savetxt('/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/FitParas/C046_decrease_FitParas.txt', FitParas, delimiter=",")
# Out:
# 000001, method='Nelder-Mead', residual=25873.12061750932
# 000002, method='Nelder-Mead', residual=25701.754120037585
# 000003, method='Nelder-Mead', residual=36106.6057685639
# 000004, method='Nelder-Mead', residual=25873.12061750932
# 000005, method='Nelder-Mead', residual=25954.758017369502
# 000006, method='Nelder-Mead', residual=28807.938512127592
# 000007, method='Nelder-Mead', residual=25873.12061750932
# 000008, method='Nelder-Mead', residual=25851.70310679357
# 000009, method='Nelder-Mead', residual=25860.678213975963
# 000010, method='Nelder-Mead', residual=25867.645142007772
# 000011, method='Nelder-Mead', residual=26403.670017338536
# 000012, method='Nelder-Mead', residual=25876.197599403633
# 000013, method='Nelder-Mead', residual=32143.66661630983
# 000014, method='Nelder-Mead', residual=26854.57801722657
# 000015, method='Nelder-Mead', residual=29426.79464032215
# 000016, method='Nelder-Mead', residual=28191.841396464904
# 000017, method='Nelder-Mead', residual=28714.469117688936
# 000018, method='Nelder-Mead', residual=27101.88603279983
# 000019, method='Nelder-Mead', residual=27858.128216377692
# 000020, method='Nelder-Mead', residual=26307.89117085372
# 000021, method='Nelder-Mead', residual=31132.304059556503
# 000022, method='Nelder-Mead', residual=25630.052990012373
# 000023, method='Nelder-Mead', residual=26101.221998266716
# 000024, method='Nelder-Mead', residual=27439.46805486743
# 000025, method='Nelder-Mead', residual=25899.230066876553
# 000026, method='Nelder-Mead', residual=26411.81619102264
# 000027, method='Nelder-Mead', residual=25727.42066611959
# 000028, method='Nelder-Mead', residual=25721.282618885427
# 000029, method='Nelder-Mead', residual=25945.188533501143
# 000030, method='Nelder-Mead', residual=25764.37935428925
# 000031, method='Nelder-Mead', residual=25589.8338734373
# 000032, method='Nelder-Mead', residual=25573.258109317045
# 000033, method='Nelder-Mead', residual=25575.68060444849
# 000034, method='Nelder-Mead', residual=25583.006709011177
# 000035, method='Nelder-Mead', residual=25713.797003402877
# 000036, method='Nelder-Mead', residual=25616.74825193032
# 000037, method='Nelder-Mead', residual=25643.362006489235
# 000038, method='Nelder-Mead', residual=25713.089127350704
# 000039, method='Nelder-Mead', residual=25525.77178178393
# 000040, method='Nelder-Mead', residual=25676.965092683662
# 000041, method='Nelder-Mead', residual=25686.93786447403
# 000042, method='Nelder-Mead', residual=25488.332733749117
# 000043, method='Nelder-Mead', residual=25571.616305236323
# 000044, method='Nelder-Mead', residual=25897.310894532406
# 000045, method='Nelder-Mead', residual=25550.200809362577
# 000046, method='Nelder-Mead', residual=25501.194386658186
# 000047, method='Nelder-Mead', residual=26008.62034316942
# 000048, method='Nelder-Mead', residual=25528.145185056157
# 000049, method='Nelder-Mead', residual=25637.382265083445
# 000050, method='Nelder-Mead', residual=25500.229938193635
# 000051, method='Nelder-Mead', residual=25625.30649784313
# 000052, method='Nelder-Mead', residual=25756.125794664986
# 000053, method='Nelder-Mead', residual=25525.483176929323
# 000054, method='Nelder-Mead', residual=25678.16029554708
# 000055, method='Nelder-Mead', residual=25533.899995707954
# 000056, method='Nelder-Mead', residual=25454.95423514894
# 000057, method='Nelder-Mead', residual=25502.440295241908
# 000058, method='Nelder-Mead', residual=25428.90676662174
# 000059, method='Nelder-Mead', residual=25419.010777877877
# 000060, method='Nelder-Mead', residual=25412.05974979554
# 000061, method='Nelder-Mead', residual=25424.345021964004
# 000062, method='Nelder-Mead', residual=25421.789694230243
# 000063, method='Nelder-Mead', residual=25405.382773354857
# 000064, method='Nelder-Mead', residual=25462.357170961135
# 000065, method='Nelder-Mead', residual=25386.262378795367
# 000066, method='Nelder-Mead', residual=25448.611943688196
# 000067, method='Nelder-Mead', residual=25415.43409355334
# 000068, method='Nelder-Mead', residual=25480.18803838106
# 000069, method='Nelder-Mead', residual=25436.238752696612
# 000070, method='Nelder-Mead', residual=25435.68036211557
# 000071, method='Nelder-Mead', residual=25513.833046521333
# 000072, method='Nelder-Mead', residual=25413.868528905914
# 000073, method='Nelder-Mead', residual=25409.736538772668
# 000074, method='Nelder-Mead', residual=25424.323100926198
# 000075, method='Nelder-Mead', residual=25411.470781364525
# 000076, method='Nelder-Mead', residual=25571.877946079356
# 000077, method='Nelder-Mead', residual=25377.1492094107
# 000078, method='Nelder-Mead', residual=25425.84377740814
# 000079, method='Nelder-Mead', residual=25389.84024413224
# 000080, method='Nelder-Mead', residual=25443.744223036316
# 000081, method='Nelder-Mead', residual=25393.86209192417
# 000082, method='Nelder-Mead', residual=25369.464458277595
# 000083, method='Nelder-Mead', residual=25394.885042910413
# 000084, method='Nelder-Mead', residual=25405.402845682827
# 000085, method='Nelder-Mead', residual=25393.966387379776
# 000086, method='Nelder-Mead', residual=25406.2428084053
# 000087, method='Nelder-Mead', residual=25362.801036079487
# 000088, method='Nelder-Mead', residual=25381.100008058314
# 000089, method='Nelder-Mead', residual=25430.438916204093
# 000090, method='Nelder-Mead', residual=25377.385466188203
# 000091, method='Nelder-Mead', residual=25355.82236316979
# 000092, method='Nelder-Mead', residual=25377.081656656705
# 000093, method='Nelder-Mead', residual=25410.468831624406
# 000094, method='Nelder-Mead', residual=25373.89413760506
# 000095, method='Nelder-Mead', residual=25390.368235834325
# 000096, method='Nelder-Mead', residual=25372.40673804171
# 000097, method='Nelder-Mead', residual=25369.965157523024
# 000098, method='Nelder-Mead', residual=25365.317177882716
# 000099, method='Nelder-Mead', residual=25379.927484591648
# 000100, method='Nelder-Mead', residual=25357.494649552373
# 000101, method='Nelder-Mead', residual=25383.82046752985
# 000102, method='Nelder-Mead', residual=25362.334726594683
# 000103, method='Nelder-Mead', residual=25367.227170858343
# 000104, method='Nelder-Mead', residual=25361.080079670923
# 000105, method='Nelder-Mead', residual=25370.527350950815
# 000106, method='Nelder-Mead', residual=25372.295166021227
# 000107, method='Nelder-Mead', residual=25380.50912655139
# 000108, method='Nelder-Mead', residual=25355.176791424274
# 000109, method='Nelder-Mead', residual=25377.2602861513
# 000110, method='Nelder-Mead', residual=25352.180521741087
# 000111, method='Nelder-Mead', residual=25376.177405669132
# 000112, method='Nelder-Mead', residual=25354.912470752133
# 000113, method='Nelder-Mead', residual=25363.52368687743
# 000114, method='Nelder-Mead', residual=25394.872050209742
# 000115, method='Nelder-Mead', residual=25351.625325799418
# 000116, method='Nelder-Mead', residual=25392.43814668097
# 000117, method='Nelder-Mead', residual=25352.36795651129
# 000118, method='Nelder-Mead', residual=25361.86279736997
# 000119, method='Nelder-Mead', residual=25375.60577142947
# 000120, method='Nelder-Mead', residual=25349.966419349174
# 000121, method='Nelder-Mead', residual=25349.240482489546
# 000122, method='Nelder-Mead', residual=25360.230826198855
# 000123, method='Nelder-Mead', residual=25365.959916995438
# 000124, method='Nelder-Mead', residual=25352.003317896146
# 000125, method='Nelder-Mead', residual=25372.02499015682
# 000126, method='Nelder-Mead', residual=25352.023100623115
# 000127, method='Nelder-Mead', residual=25358.427257984513
# 000128, method='Nelder-Mead', residual=25352.070995920738
# 000129, method='Nelder-Mead', residual=25360.82929248779
# 000130, method='Nelder-Mead', residual=25350.02190115502
# 000131, method='Nelder-Mead', residual=25345.04464354864
# 000132, method='Nelder-Mead', residual=25339.569334781834
# 000133, method='Nelder-Mead', residual=25352.187585689535
# 000134, method='Nelder-Mead', residual=25348.03186871442
# 000135, method='Nelder-Mead', residual=25355.75177250474
# 000136, method='Nelder-Mead', residual=25347.466104841977
# 000137, method='Nelder-Mead', residual=25354.883873412928
# 000138, method='Nelder-Mead', residual=25348.415895037302
# 000139, method='Nelder-Mead', residual=25345.27800666843
# 000140, method='Nelder-Mead', residual=25341.610488679547
# 000141, method='Nelder-Mead', residual=25345.014195178832
# 000142, method='Nelder-Mead', residual=25343.358151814766
# 000143, method='Nelder-Mead', residual=25351.492676025213
# 000144, method='Nelder-Mead', residual=25348.19904636814
# 000145, method='Nelder-Mead', residual=25339.49629091611
# 000146, method='Nelder-Mead', residual=25341.367359386328
# 000147, method='Nelder-Mead', residual=25341.782835454876
# 000148, method='Nelder-Mead', residual=25343.308846998676
# 000149, method='Nelder-Mead', residual=25343.18399311992
# 000150, method='Nelder-Mead', residual=25341.20312587028
# 000151, method='Nelder-Mead', residual=25338.268066688455
# 000152, method='Nelder-Mead', residual=25332.990636621667
# 000153, method='Nelder-Mead', residual=25332.73222719741
# 000154, method='Nelder-Mead', residual=25324.400358881914
# 000155, method='Nelder-Mead', residual=25339.533051482565
# 000156, method='Nelder-Mead', residual=25331.400533608485
# 000157, method='Nelder-Mead', residual=25332.93221387253
# 000158, method='Nelder-Mead', residual=25330.303262470457
# 000159, method='Nelder-Mead', residual=25331.58040141739
# 000160, method='Nelder-Mead', residual=25328.29774466845
# 000161, method='Nelder-Mead', residual=25325.84401498146
# 000162, method='Nelder-Mead', residual=25321.1381718905
# 000163, method='Nelder-Mead', residual=25316.614350271902
# 000164, method='Nelder-Mead', residual=25321.60038468607
# 000165, method='Nelder-Mead', residual=25331.773957842113
# 000166, method='Nelder-Mead', residual=25327.786120098077
# 000167, method='Nelder-Mead', residual=25315.61103003255
# 000168, method='Nelder-Mead', residual=25307.234834892824
# 000169, method='Nelder-Mead', residual=25312.48727698004
# 000170, method='Nelder-Mead', residual=25325.372631307673
# 000171, method='Nelder-Mead', residual=25313.72492008457
# 000172, method='Nelder-Mead', residual=25307.319794652118
# 000173, method='Nelder-Mead', residual=25307.597514871795
# 000174, method='Nelder-Mead', residual=25308.645433088925
# 000175, method='Nelder-Mead', residual=25325.587558008858
# 000176, method='Nelder-Mead', residual=25305.686565230466
# 000177, method='Nelder-Mead', residual=25297.753432092184
# 000178, method='Nelder-Mead', residual=25314.837432880457
# 000179, method='Nelder-Mead', residual=25300.89701061584
# 000180, method='Nelder-Mead', residual=25291.6510131071
# 000181, method='Nelder-Mead', residual=25268.309542542785
# 000182, method='Nelder-Mead', residual=25289.75435575737
# 000183, method='Nelder-Mead', residual=25287.140147279748
# 000184, method='Nelder-Mead', residual=25295.346602215744
# 000185, method='Nelder-Mead', residual=25281.291869269415
# 000186, method='Nelder-Mead', residual=25268.227802491434
# 000187, method='Nelder-Mead', residual=25242.98363034226
# 000188, method='Nelder-Mead', residual=25277.215996641844
# 000189, method='Nelder-Mead', residual=25264.128464656653
# 000190, method='Nelder-Mead', residual=25247.58806557624
# 000191, method='Nelder-Mead', residual=25233.66025404014
# 000192, method='Nelder-Mead', residual=25232.249096920998
# 000193, method='Nelder-Mead', residual=25243.748537761716
# 000194, method='Nelder-Mead', residual=25227.79228532722
# 000195, method='Nelder-Mead', residual=25234.445938209465
# 000196, method='Nelder-Mead', residual=25226.802600852396
# 000197, method='Nelder-Mead', residual=25258.43719192546
# 000198, method='Nelder-Mead', residual=25231.656330600825
# 000199, method='Nelder-Mead', residual=25240.867529076364
# 000200, method='Nelder-Mead', residual=25252.056020499684
# 000201, method='Nelder-Mead', residual=25265.22507243006
# 000202, method='Nelder-Mead', residual=25283.95782558797
# 000203, method='Nelder-Mead', residual=25241.80206415239
# 000204, method='Nelder-Mead', residual=25271.502927998816
# 000205, method='Nelder-Mead', residual=25229.464692549314
# 000206, method='Nelder-Mead', residual=25260.910425760743
# 000207, method='Nelder-Mead', residual=25231.71836739734
# 000208, method='Nelder-Mead', residual=25250.01102350185
# 000209, method='Nelder-Mead', residual=25231.261486422205
# 000210, method='Nelder-Mead', residual=25247.91114218685
# 000211, method='Nelder-Mead', residual=25233.515056721622
# 000212, method='Nelder-Mead', residual=25227.161736691916
# 000213, method='Nelder-Mead', residual=25246.454086464317
# 000214, method='Nelder-Mead', residual=25228.212744269822
# 000215, method='Nelder-Mead', residual=25249.478536702958
# 000216, method='Nelder-Mead', residual=25228.081379636697
# 000217, method='Nelder-Mead', residual=25235.558973769243
# 000218, method='Nelder-Mead', residual=25228.581438188583
# 000219, method='Nelder-Mead', residual=25231.243230114324
# 000220, method='Nelder-Mead', residual=25238.37389040749
# 000221, method='Nelder-Mead', residual=25225.157823556936
# 000222, method='Nelder-Mead', residual=25236.508107435024
# 000223, method='Nelder-Mead', residual=25224.637688102277
# 000224, method='Nelder-Mead', residual=25235.680506253422
# 000225, method='Nelder-Mead', residual=25225.271351394073
# 000226, method='Nelder-Mead', residual=25230.9304085097
# 000227, method='Nelder-Mead', residual=25228.54047646822
# 000228, method='Nelder-Mead', residual=25237.395628541537
# 000229, method='Nelder-Mead', residual=25223.475153384275
# 000230, method='Nelder-Mead', residual=25235.286921241845
# 000231, method='Nelder-Mead', residual=25226.51389502133
# 000232, method='Nelder-Mead', residual=25226.907104564347
# 000233, method='Nelder-Mead', residual=25231.209955566395
# 000234, method='Nelder-Mead', residual=25223.092138740554
# 000235, method='Nelder-Mead', residual=25229.45557108577
# 000236, method='Nelder-Mead', residual=25223.330387149123
# 000237, method='Nelder-Mead', residual=25230.90531593005
# 000238, method='Nelder-Mead', residual=25223.294927832667
# 000239, method='Nelder-Mead', residual=25228.487549437985
# 000240, method='Nelder-Mead', residual=25224.742632673057
# 000241, method='Nelder-Mead', residual=25228.511583815
# 000242, method='Nelder-Mead', residual=25225.807096999266
# 000243, method='Nelder-Mead', residual=25224.198331169515
# 000244, method='Nelder-Mead', residual=25227.550535551352
# 000245, method='Nelder-Mead', residual=25221.63578011706
# 000246, method='Nelder-Mead', residual=25223.735527810975
# 000247, method='Nelder-Mead', residual=25225.572443340858
# 000248, method='Nelder-Mead', residual=25223.26246258091
# 000249, method='Nelder-Mead', residual=25225.40827338203
# 000250, method='Nelder-Mead', residual=25223.26735461242
# 000251, method='Nelder-Mead', residual=25229.587351079797
# 000252, method='Nelder-Mead', residual=25223.93217231304
# 000253, method='Nelder-Mead', residual=25224.38354799721
# 000254, method='Nelder-Mead', residual=25225.963381654987
# 000255, method='Nelder-Mead', residual=25223.217653286847
# 000256, method='Nelder-Mead', residual=25224.661861922785
# 000257, method='Nelder-Mead', residual=25223.517389592394
# 000258, method='Nelder-Mead', residual=25224.542971579103
# 000259, method='Nelder-Mead', residual=25222.203411601113
# 000260, method='Nelder-Mead', residual=25224.45175843555
# 000261, method='Nelder-Mead', residual=25222.03381044006
# 000262, method='Nelder-Mead', residual=25224.544710576876
# 000263, method='Nelder-Mead', residual=25223.355750634048
# 000264, method='Nelder-Mead', residual=25222.1173584231
# 000265, method='Nelder-Mead', residual=25228.160406184674
# 000266, method='Nelder-Mead', residual=25221.566830850923
# 000267, method='Nelder-Mead', residual=25223.71371347266
# 000268, method='Nelder-Mead', residual=25221.168081474018
# 000269, method='Nelder-Mead', residual=25221.559615584018
# 000270, method='Nelder-Mead', residual=25221.79884671634
# 000271, method='Nelder-Mead', residual=25221.93787832711
# 000272, method='Nelder-Mead', residual=25225.31893290646
# 000273, method='Nelder-Mead', residual=25222.763419428997
# 000274, method='Nelder-Mead', residual=25223.472722444643
# 000275, method='Nelder-Mead', residual=25222.457700073515
# 000276, method='Nelder-Mead', residual=25224.434606184182
# 000277, method='Nelder-Mead', residual=25222.059840314767
# 000278, method='Nelder-Mead', residual=25224.235056793015
# 000279, method='Nelder-Mead', residual=25220.86197512253
# 000280, method='Nelder-Mead', residual=25221.938929637992
# 000281, method='Nelder-Mead', residual=25221.50774415707
# 000282, method='Nelder-Mead', residual=25223.180617263923
# 000283, method='Nelder-Mead', residual=25220.81689269355
# 000284, method='Nelder-Mead', residual=25222.7576350404
# 000285, method='Nelder-Mead', residual=25220.809904699327
# 000286, method='Nelder-Mead', residual=25224.03987407047
# 000287, method='Nelder-Mead', residual=25221.872837062296
# 000288, method='Nelder-Mead', residual=25223.477277019036
# 000289, method='Nelder-Mead', residual=25220.90737139267
# 000290, method='Nelder-Mead', residual=25221.621528988177
# 000291, method='Nelder-Mead', residual=25222.619658343338
# 000292, method='Nelder-Mead', residual=25221.280679061296
# 000293, method='Nelder-Mead', residual=25222.475470406338
# 000294, method='Nelder-Mead', residual=25221.265958455533
# 000295, method='Nelder-Mead', residual=25221.583553824596
# 000296, method='Nelder-Mead', residual=25220.659096130028
# 000297, method='Nelder-Mead', residual=25221.457398451766
# 000298, method='Nelder-Mead', residual=25222.719802744727
# 000299, method='Nelder-Mead', residual=25221.33590741496
# 000300, method='Nelder-Mead', residual=25220.708668172774
# 000301, method='Nelder-Mead', residual=25221.152068059313
# 000302, method='Nelder-Mead', residual=25222.270432511024
# 000303, method='Nelder-Mead', residual=25221.362621203567
# 000304, method='Nelder-Mead', residual=25221.25003303176
# 000305, method='Nelder-Mead', residual=25221.0012829185
# 000306, method='Nelder-Mead', residual=25221.76060567933
# 000307, method='Nelder-Mead', residual=25221.73750937835
# 000308, method='Nelder-Mead', residual=25220.992201805828
# 000309, method='Nelder-Mead', residual=25221.058703240273
# 000310, method='Nelder-Mead', residual=25220.755006409403
# 000311, method='Nelder-Mead', residual=25221.711822939622
# 000312, method='Nelder-Mead', residual=25220.787855076716
# 000313, method='Nelder-Mead', residual=25220.995440263276
# 000314, method='Nelder-Mead', residual=25221.1639107668
# 000315, method='Nelder-Mead', residual=25220.624842787813
# 000316, method='Nelder-Mead', residual=25220.766649080953
# 000317, method='Nelder-Mead', residual=25221.033069119963
# 000318, method='Nelder-Mead', residual=25220.980977421368
# 000319, method='Nelder-Mead', residual=25221.854366831485
# 000320, method='Nelder-Mead', residual=25221.09971001158
# 000321, method='Nelder-Mead', residual=25220.746924800984
# 000322, method='Nelder-Mead', residual=25220.788203280103
# 000323, method='Nelder-Mead', residual=25221.77780886954
# 000324, method='Nelder-Mead', residual=25221.030315415708
# 000325, method='Nelder-Mead', residual=25220.6066427827
# 000326, method='Nelder-Mead', residual=25221.211189855494
# 000327, method='Nelder-Mead', residual=25220.727311260503
# 000328, method='Nelder-Mead', residual=25220.593279641143
# 000329, method='Nelder-Mead', residual=25220.541849809826
# 000330, method='Nelder-Mead', residual=25221.06299505243
# 000331, method='Nelder-Mead', residual=25221.181051181768
# 000332, method='Nelder-Mead', residual=25220.542852391027
# 000333, method='Nelder-Mead', residual=25220.552227434273
# 000334, method='Nelder-Mead', residual=25220.620308738482
# 000335, method='Nelder-Mead', residual=25220.682537483684
# 000336, method='Nelder-Mead', residual=25220.646008851512
# 000337, method='Nelder-Mead', residual=25220.63847852511
# 000338, method='Nelder-Mead', residual=25220.614371377178
# 000339, method='Nelder-Mead', residual=25220.693201867572
# 000340, method='Nelder-Mead', residual=25220.748424316724
# 000341, method='Nelder-Mead', residual=25221.245921811715
# 000342, method='Nelder-Mead', residual=25221.03412335045
# 000343, method='Nelder-Mead', residual=25220.674492302587
# 000344, method='Nelder-Mead', residual=25220.87861612876
# 000345, method='Nelder-Mead', residual=25220.774521617903
# 000346, method='Nelder-Mead', residual=25220.523858500783
# 000347, method='Nelder-Mead', residual=25221.03412335045
# 000348, method='Nelder-Mead', residual=25220.500893118584
# 000349, method='Nelder-Mead', residual=25220.93769327612
# 000350, method='Nelder-Mead', residual=25220.461454582182
# 000351, method='Nelder-Mead', residual=25220.46647808183
# 000352, method='Nelder-Mead', residual=25221.063930733497
# 000353, method='Nelder-Mead', residual=25220.67892658357
# 000354, method='Nelder-Mead', residual=25220.422806601666
# 000355, method='Nelder-Mead', residual=25221.063930733497
# 000356, method='Nelder-Mead', residual=25221.131949185165
# 000357, method='Nelder-Mead', residual=25220.644316203357
# 000358, method='Nelder-Mead', residual=25221.058738750402
# 000359, method='Nelder-Mead', residual=25220.616897648553
# 000360, method='Nelder-Mead', residual=25221.105800147456
# 000361, method='Nelder-Mead', residual=25220.600390120635
# 000362, method='Nelder-Mead', residual=25220.368756713266
# 000363, method='Nelder-Mead', residual=25220.382336926617
# 000364, method='Nelder-Mead', residual=25221.082808078234
# 000365, method='Nelder-Mead', residual=25220.56223738622
# 000366, method='Nelder-Mead', residual=25220.928112475696
# 000367, method='Nelder-Mead', residual=25220.532468794267
# 000368, method='Nelder-Mead', residual=25220.43547385032
# 000369, method='Nelder-Mead', residual=25221.040316339535
# 000370, method='Nelder-Mead', residual=25220.583629269306
# 000371, method='Nelder-Mead', residual=25220.944271365373
# 000372, method='Nelder-Mead', residual=25220.495155474866
# 000373, method='Nelder-Mead', residual=25221.09174947256
# 000374, method='Nelder-Mead', residual=25220.503799776456
# 000375, method='Nelder-Mead', residual=25220.598742293398
# 000376, method='Nelder-Mead', residual=25220.45426878312
# 000377, method='Nelder-Mead', residual=25220.624919265967
# 000378, method='Nelder-Mead', residual=25220.601686273818
# 000379, method='Nelder-Mead', residual=25220.455938071656
# 000380, method='Nelder-Mead', residual=25220.44874686402
# 000381, method='Nelder-Mead', residual=25220.364946164536
# 000382, method='Nelder-Mead', residual=25220.4934294881
# 000383, method='Nelder-Mead', residual=25220.492171801645
# 000384, method='Nelder-Mead', residual=25220.43370745868
# 000385, method='Nelder-Mead', residual=25220.37884894357
# 000386, method='Nelder-Mead', residual=25220.416228470967
# 000387, method='Nelder-Mead', residual=25220.496592323652
# 000388, method='Nelder-Mead', residual=25220.529622296184
# 000389, method='Nelder-Mead', residual=25220.479095071154
# 000390, method='Nelder-Mead', residual=25220.527474370454
# 000391, method='Nelder-Mead', residual=25220.46872067153
# 000392, method='Nelder-Mead', residual=25220.353580680647
# 000393, method='Nelder-Mead', residual=25220.90112680416
# 000394, method='Nelder-Mead', residual=25220.381999873676
# 000395, method='Nelder-Mead', residual=25220.413914090084
# 000396, method='Nelder-Mead', residual=25220.472600384583
# 000397, method='Nelder-Mead', residual=25220.45871038798
# 000398, method='Nelder-Mead', residual=25220.554448509665
# 000399, method='Nelder-Mead', residual=25220.434805564768
# 000400, method='Nelder-Mead', residual=25220.416847952605
# 000401, method='Nelder-Mead', residual=25220.38587239928
# 000402, method='Nelder-Mead', residual=25220.374554968676
# 000403, method='Nelder-Mead', residual=25220.380108064317
# 000404, method='Nelder-Mead', residual=25220.432483559416
# 000405, method='Nelder-Mead', residual=25220.394267651325
# 000406, method='Nelder-Mead', residual=25220.364587610056
# 000407, method='Nelder-Mead', residual=25220.325864778424
# 000408, method='Nelder-Mead', residual=25220.28585256045
# 000409, method='Nelder-Mead', residual=25220.380686627148
# 000410, method='Nelder-Mead', residual=25220.421632395024
# 000411, method='Nelder-Mead', residual=25220.412160636806
# 000412, method='Nelder-Mead', residual=25220.30475224233
# 000413, method='Nelder-Mead', residual=25220.32945368935
# 000414, method='Nelder-Mead', residual=25220.329932938417
# 000415, method='Nelder-Mead', residual=25220.40588659115
# 000416, method='Nelder-Mead', residual=25220.389186951936
# 000417, method='Nelder-Mead', residual=25220.32844775012
# 000418, method='Nelder-Mead', residual=25220.340783067135
# 000419, method='Nelder-Mead', residual=25220.341751774067
# 000420, method='Nelder-Mead', residual=25220.392288465337
# 000421, method='Nelder-Mead', residual=25220.334616846045
# 000422, method='Nelder-Mead', residual=25220.34185034136
# 000423, method='Nelder-Mead', residual=25220.408789690453
# 000424, method='Nelder-Mead', residual=25220.375248329212
# 000425, method='Nelder-Mead', residual=25220.369970491127
# 000426, method='Nelder-Mead', residual=25220.397021699566
# 000427, method='Nelder-Mead', residual=25220.339217726134
# 000428, method='Nelder-Mead', residual=25220.388877622096
# 000429, method='Nelder-Mead', residual=25220.32188591083
# 000430, method='Nelder-Mead', residual=25220.358512174742
# 000431, method='Nelder-Mead', residual=25220.340202990006
# 000432, method='Nelder-Mead', residual=25220.369418564358
# 000433, method='Nelder-Mead', residual=25220.32259577631
# 000434, method='Nelder-Mead', residual=25220.30263243115
# 000435, method='Nelder-Mead', residual=25220.36342051588
# 000436, method='Nelder-Mead', residual=25220.307883518406
# 000437, method='Nelder-Mead', residual=25220.303375483298
# 000438, method='Nelder-Mead', residual=25220.35949179902
# 000439, method='Nelder-Mead', residual=25220.324197196896
# 000440, method='Nelder-Mead', residual=25220.375907626385
# 000441, method='Nelder-Mead', residual=25220.323994961833
# 000442, method='Nelder-Mead', residual=25220.311998425568
# 000443, method='Nelder-Mead', residual=25220.324619311385
# 000444, method='Nelder-Mead', residual=25220.86458644951
# 000445, method='Nelder-Mead', residual=25220.319812184734
# 000446, method='Nelder-Mead', residual=25220.327673963675
# 000447, method='Nelder-Mead', residual=25220.328856025517
# 000448, method='Nelder-Mead', residual=25220.314272343407
# 000449, method='Nelder-Mead', residual=25220.287273311013
# 000450, method='Nelder-Mead', residual=25220.31861247337
# 000451, method='Nelder-Mead', residual=25220.302588859417
# 000452, method='Nelder-Mead', residual=25220.30212035918
# 000453, method='Nelder-Mead', residual=25220.3269800789
# 000454, method='Nelder-Mead', residual=25220.31318963966
# 000455, method='Nelder-Mead', residual=25220.31176629835
# 000456, method='Nelder-Mead', residual=25220.309162036385
# 000457, method='Nelder-Mead', residual=25220.306779577786
# 000458, method='Nelder-Mead', residual=25220.325208196864
# 000459, method='Nelder-Mead', residual=25220.302551157707
# 000460, method='Nelder-Mead', residual=25220.30838590647
# 000461, method='Nelder-Mead', residual=25220.32560340153
# 000462, method='Nelder-Mead', residual=25220.32071497224
# 000463, method='Nelder-Mead', residual=25220.28665760179
# 000464, method='Nelder-Mead', residual=25220.292637879684
# 000465, method='Nelder-Mead', residual=25220.29362503185
# 000466, method='Nelder-Mead', residual=25220.28859610141
# 000467, method='Nelder-Mead', residual=25220.315913499973
# 000468, method='Nelder-Mead', residual=25220.29399052494
# 000469, method='Nelder-Mead', residual=25220.3204571568
# 000470, method='Nelder-Mead', residual=25220.32215169972
# 000471, method='Nelder-Mead', residual=25220.30535371644
# 000472, method='Nelder-Mead', residual=25220.30721882584
# 000473, method='Nelder-Mead', residual=25220.296574391366
# 000474, method='Nelder-Mead', residual=25220.285638854224
# 000475, method='Nelder-Mead', residual=25220.304166995356
# 000476, method='Nelder-Mead', residual=25220.29267622008
# 000477, method='Nelder-Mead', residual=25220.304114875806
# 000478, method='Nelder-Mead', residual=25220.304592848282
# 000479, method='Nelder-Mead', residual=25220.296364701673
# 000480, method='Nelder-Mead', residual=25220.302916741046
# 000481, method='Nelder-Mead', residual=25220.31422354171
# 000482, method='Nelder-Mead', residual=25220.289483979286
# 000483, method='Nelder-Mead', residual=25220.304683945233
# 000484, method='Nelder-Mead', residual=25220.306363925596
# 000485, method='Nelder-Mead', residual=25220.289379496364
# 000486, method='Nelder-Mead', residual=25220.289927270118
# 000487, method='Nelder-Mead', residual=25220.29106922042
# 000488, method='Nelder-Mead', residual=25220.29016114316
# 000489, method='Nelder-Mead', residual=25220.2979853165
# 000490, method='Nelder-Mead', residual=25220.290402561986
# 000491, method='Nelder-Mead', residual=25220.29734205851
# 000492, method='Nelder-Mead', residual=25220.291917719784
# 000493, method='Nelder-Mead', residual=25220.28451107497
# 000494, method='Nelder-Mead', residual=25220.28433496298
# 000495, method='Nelder-Mead', residual=25220.29625676869
# 000496, method='Nelder-Mead', residual=25220.291180715
# 000497, method='Nelder-Mead', residual=25220.293296132822
# 000498, method='Nelder-Mead', residual=25220.307601354583
# 000499, method='Nelder-Mead', residual=25220.298211453748
# 000500, method='Nelder-Mead', residual=25220.28431325501
# 000501, method='Nelder-Mead', residual=25220.2848508878
# 000502, method='Nelder-Mead', residual=25220.285192985713
# 000503, method='Nelder-Mead', residual=25220.285486310244
# 000504, method='Nelder-Mead', residual=25220.284804197014
# 000505, method='Nelder-Mead', residual=25220.285945502525
# 000506, method='Nelder-Mead', residual=25220.286176694633
# 000507, method='Nelder-Mead', residual=25220.285575475584
# 000508, method='Nelder-Mead', residual=25220.28624078937
# 000509, method='Nelder-Mead', residual=25220.285742360706
# 000510, method='Nelder-Mead', residual=25220.29698486273
# 000511, method='Nelder-Mead', residual=25220.2978575027
# 000512, method='Nelder-Mead', residual=25220.284634655374
# 000513, method='Nelder-Mead', residual=25220.28427606926
# 000514, method='Nelder-Mead', residual=25220.282740762927
# 000515, method='Nelder-Mead', residual=25220.28466690755
# 000516, method='Nelder-Mead', residual=25220.28424887858
# 000517, method='Nelder-Mead', residual=25220.296965379548
# 000518, method='Nelder-Mead', residual=25220.285407897863
# 000519, method='Nelder-Mead', residual=25220.283875407764
# 000520, method='Nelder-Mead', residual=25220.283641223556
# 000521, method='Nelder-Mead', residual=25220.2843643989
# 000522, method='Nelder-Mead', residual=25220.28347024126
# 000523, method='Nelder-Mead', residual=25220.298176629258
# 000524, method='Nelder-Mead', residual=25220.28575770574
# 000525, method='Nelder-Mead', residual=25220.28352808679
# 000526, method='Nelder-Mead', residual=25220.283717360988
# 000527, method='Nelder-Mead', residual=25220.283818759137
# 000528, method='Nelder-Mead', residual=25220.28415942015
# 000529, method='Nelder-Mead', residual=25220.28397157535
# 000530, method='Nelder-Mead', residual=25220.282838551317
# 000531, method='Nelder-Mead', residual=25220.28280428232
# 000532, method='Nelder-Mead', residual=25220.283145368507
# 000533, method='Nelder-Mead', residual=25220.282877032623
# 000534, method='Nelder-Mead', residual=25220.28405697009
# 000535, method='Nelder-Mead', residual=25220.28411725716
# 000536, method='Nelder-Mead', residual=25220.284144451838
# 000537, method='Nelder-Mead', residual=25220.283731361516
# 000538, method='Nelder-Mead', residual=25220.283683968533
# 000539, method='Nelder-Mead', residual=25220.29711822652
# 000540, method='Nelder-Mead', residual=25220.283938018874
# 000541, method='Nelder-Mead', residual=25220.28393246062
# 000542, method='Nelder-Mead', residual=25220.283953407943
# 000543, method='Nelder-Mead', residual=25220.283953917937
# 000544, method='Nelder-Mead', residual=25220.282639973055
# 000545, method='Nelder-Mead', residual=25220.28400094819
# 000546, method='Nelder-Mead', residual=25220.283878677248
# 000547, method='Nelder-Mead', residual=25220.28413400707
# 000548, method='Nelder-Mead', residual=25220.284034567514
# 000549, method='Nelder-Mead', residual=25220.28258746991
# 000550, method='Nelder-Mead', residual=25220.283003793687
# 000551, method='Nelder-Mead', residual=25220.2848420292
# 000552, method='Nelder-Mead', residual=25220.283588332928
# 000553, method='Nelder-Mead', residual=25220.28390718926
# 000554, method='Nelder-Mead', residual=25220.284037391782
# 000555, method='Nelder-Mead', residual=25220.283953068436
# 000556, method='Nelder-Mead', residual=25220.28264021202
# 000557, method='Nelder-Mead', residual=25220.282554464724
# 000558, method='Nelder-Mead', residual=25220.282396250997
# 000559, method='Nelder-Mead', residual=25220.282856334285
# 000560, method='Nelder-Mead', residual=25220.282521466146
# 000561, method='Nelder-Mead', residual=25220.282758250083
# 000562, method='Nelder-Mead', residual=25220.282712430635
# 000563, method='Nelder-Mead', residual=25220.28254773866
# 000564, method='Nelder-Mead', residual=25220.2825437204
# 000565, method='Nelder-Mead', residual=25220.28249019978
# 000566, method='Nelder-Mead', residual=25220.2823660164
# 000567, method='Nelder-Mead', residual=25220.28220137719
# 000568, method='Nelder-Mead', residual=25220.282423981374
# 000569, method='Nelder-Mead', residual=25220.282358666722
# 000570, method='Nelder-Mead', residual=25220.28225833557
# 000571, method='Nelder-Mead', residual=25220.282440073763
# 000572, method='Nelder-Mead', residual=25220.28133818733
# 000573, method='Nelder-Mead', residual=25220.282037271725
# 000574, method='Nelder-Mead', residual=25220.28113898125
# 000575, method='Nelder-Mead', residual=25220.281700420102
# 000576, method='Nelder-Mead', residual=25220.282552307526
# 000577, method='Nelder-Mead', residual=25220.282334484324
# 000578, method='Nelder-Mead', residual=25220.28223655681
# 000579, method='Nelder-Mead', residual=25220.296508878553
# 000580, method='Nelder-Mead', residual=25220.282437372283
# 000581, method='Nelder-Mead', residual=25220.28224746941
# 000582, method='Nelder-Mead', residual=25220.282260709464
# 000583, method='Nelder-Mead', residual=25220.282160954983
# 000584, method='Nelder-Mead', residual=25220.28117628229
# 000585, method='Nelder-Mead', residual=25220.281867049507
# 000586, method='Nelder-Mead', residual=25220.28129669406
# 000587, method='Nelder-Mead', residual=25220.281985025755
# 000588, method='Nelder-Mead', residual=25220.294941502027
# 000589, method='Nelder-Mead', residual=25220.28223734028
# 000590, method='Nelder-Mead', residual=25220.281919037665
# 000591, method='Nelder-Mead', residual=25220.282070262943
# 000592, method='Nelder-Mead', residual=25220.281922444054
# 000593, method='Nelder-Mead', residual=25220.28201736505
# 000594, method='Nelder-Mead', residual=25220.282029449765
# 000595, method='Nelder-Mead', residual=25220.281852524862
# 000596, method='Nelder-Mead', residual=25220.282015398257
# 000597, method='Nelder-Mead', residual=25220.282465459088
# 000598, method='Nelder-Mead', residual=25220.281946677198
# 000599, method='Nelder-Mead', residual=25220.28102712214
# 000600, method='Nelder-Mead', residual=25220.296060563374
# 000601, method='Nelder-Mead', residual=25220.28101314791
# 000602, method='Nelder-Mead', residual=25220.281240047232
# 000603, method='Nelder-Mead', residual=25220.281456604436
# 000604, method='Nelder-Mead', residual=25220.282525418585
# 000605, method='Nelder-Mead', residual=25220.282047409957
# 000606, method='Nelder-Mead', residual=25220.28116818806
# 000607, method='Nelder-Mead', residual=25220.281220428606
# 000608, method='Nelder-Mead', residual=25220.281254894253
# 000609, method='Nelder-Mead', residual=25220.28119957829
# 000610, method='Nelder-Mead', residual=25220.281147807797
# 000611, method='Nelder-Mead', residual=25220.28127026172
# 000612, method='Nelder-Mead', residual=25220.28193711581
# 000613, method='Nelder-Mead', residual=25220.28199787296
# 000614, method='Nelder-Mead', residual=25220.282030950326
# 000615, method='Nelder-Mead', residual=25220.28206972826
# 000616, method='Nelder-Mead', residual=25220.281967583636
# 000617, method='Nelder-Mead', residual=25220.281197634158
# 000618, method='Nelder-Mead', residual=25220.281228222364
# 000619, method='Nelder-Mead', residual=25220.28121509803
# 000620, method='Nelder-Mead', residual=25220.28128948436
# 000621, method='Nelder-Mead', residual=25220.282286710397
# 000622, method='Nelder-Mead', residual=25220.28216855383
# 000623, method='Nelder-Mead', residual=25220.281167116995
# 000624, method='Nelder-Mead', residual=25220.281117571572
# 000625, method='Nelder-Mead', residual=25220.28121109495
# 000626, method='Nelder-Mead', residual=25220.28121886777
# 000627, method='Nelder-Mead', residual=25220.281243859954
# 000628, method='Nelder-Mead', residual=25220.28121109495
# 000629, method='Nelder-Mead', residual=25220.281264206686
# 000630, method='Nelder-Mead', residual=25220.28131197597
# 000631, method='Nelder-Mead', residual=25220.28122057279
# 000632, method='Nelder-Mead', residual=25220.28126060982
# 000633, method='Nelder-Mead', residual=25220.281963642523
# 000634, method='Nelder-Mead', residual=25220.28135377843
# 000635, method='Nelder-Mead', residual=25220.281354601506
# 000636, method='Nelder-Mead', residual=25220.28127662757
# 000637, method='Nelder-Mead', residual=25220.28127662757
# 000638, method='Nelder-Mead', residual=25220.281167823603
# 000639, method='Nelder-Mead', residual=25220.281167823603
# 000640, method='Nelder-Mead', residual=25220.281264474066
# 000641, method='Nelder-Mead', residual=25220.28121109495
# 000642, method='Nelder-Mead', residual=25220.281167823603
# 000643, method='Nelder-Mead', residual=25220.281278175527
# 000644, method='Nelder-Mead', residual=25220.281153200176
# 000645, method='Nelder-Mead', residual=25220.281212148
# 000646, method='Nelder-Mead', residual=25220.282021947296
# 000647, method='Nelder-Mead', residual=25220.281409352516
# 000648, method='Nelder-Mead', residual=25220.281273955483
# 000649, method='Nelder-Mead', residual=25220.280957643823
# 000650, method='Nelder-Mead', residual=25220.28194545487
# 000651, method='Nelder-Mead', residual=25220.281167823603
# 000652, method='Nelder-Mead', residual=25220.281167823603
# 000653, method='Nelder-Mead', residual=25220.28198420352
# 000654, method='Nelder-Mead', residual=25220.281254311587
# 000655, method='Nelder-Mead', residual=25220.281019767182
# 000656, method='Nelder-Mead', residual=25220.281044514915
# 000657, method='Nelder-Mead', residual=25220.281052040227
# 000658, method='Nelder-Mead', residual=25220.281167823603
# 000659, method='Nelder-Mead', residual=25220.281167823603
# 000660, method='Nelder-Mead', residual=25220.281167823603
# 000661, method='Nelder-Mead', residual=25220.281167823603
# 000662, method='Nelder-Mead', residual=25220.280982583587
# 000663, method='Nelder-Mead', residual=25220.280957349874
# 000664, method='Nelder-Mead', residual=25220.280957643823
# 000665, method='Nelder-Mead', residual=25220.281007455833
# 000666, method='Nelder-Mead', residual=25220.281167823603
# 000667, method='Nelder-Mead', residual=25220.280982583587
# 000668, method='Nelder-Mead', residual=25220.281167823603
# 000669, method='Nelder-Mead', residual=25220.281167823603
# 000670, method='Nelder-Mead', residual=25220.28114263257
# 000671, method='Nelder-Mead', residual=25220.281167823603
# 000672, method='Nelder-Mead', residual=25220.280982583587
# 000673, method='Nelder-Mead', residual=25220.280982583587
# 000674, method='Nelder-Mead', residual=25220.280957643823
# 000675, method='Nelder-Mead', residual=25220.280994355504
# 000676, method='Nelder-Mead', residual=25220.280957643823
# 000677, method='Nelder-Mead', residual=25220.280994355504
# 000678, method='Nelder-Mead', residual=25220.280987351154
# 000679, method='Nelder-Mead', residual=25220.281167823603
# 000680, method='Nelder-Mead', residual=25220.280957643823
# 000681, method='Nelder-Mead', residual=25220.281167823603
# 000682, method='Nelder-Mead', residual=25220.280957643823
# 000683, method='Nelder-Mead', residual=25220.281003117325
# 000684, method='Nelder-Mead', residual=25220.280987351154
# 000685, method='Nelder-Mead', residual=25220.280957349874
# 000686, method='Nelder-Mead', residual=25220.280957643823
# 000687, method='Nelder-Mead', residual=25220.280957349874
# 000688, method='Nelder-Mead', residual=25220.280957643823
# 000689, method='Nelder-Mead', residual=25220.280957643823
# 000690, method='Nelder-Mead', residual=25220.280957643823
# 000691, method='Nelder-Mead', residual=25220.280982583587
# 000692, method='Nelder-Mead', residual=25220.280982583587
# 000693, method='Nelder-Mead', residual=25220.280982583587
# 000694, method='Nelder-Mead', residual=25220.280982583587
# 000695, method='Nelder-Mead', residual=25220.280987351154
# 000696, method='Nelder-Mead', residual=25220.281003117325
# 000697, method='Nelder-Mead', residual=25220.280982583587
# 000698, method='Nelder-Mead', residual=25220.280957349874
# 000699, method='Nelder-Mead', residual=25220.281007455833
# 000700, method='Nelder-Mead', residual=25220.280982583587
# 000701, method='Nelder-Mead', residual=25220.280957349874
# 000702, method='Nelder-Mead', residual=25220.280957349874
# 000703, method='Nelder-Mead', residual=25220.280957349874
# 000704, method='Nelder-Mead', residual=25220.280957349874
# 000705, method='Nelder-Mead', residual=25220.280957349874
# 000706, method='Nelder-Mead', residual=25220.280957349874
# 000707, method='Nelder-Mead', residual=25220.280957349874
# 000708, method='Nelder-Mead', residual=25220.280982583587
# 000709, method='Nelder-Mead', residual=25220.280982583587
# 000710, method='Nelder-Mead', residual=25220.280982583587
# 000711, method='Nelder-Mead', residual=25220.280982583587
# 000712, method='Nelder-Mead', residual=25220.281003117325
# 000713, method='Nelder-Mead', residual=25220.280982583587
# 000714, method='Nelder-Mead', residual=25220.280957349874
# 000715, method='Nelder-Mead', residual=25220.280957349874
# 000716, method='Nelder-Mead', residual=25220.280957349874
# 000717, method='Nelder-Mead', residual=25220.280957349874
# 000718, method='Nelder-Mead', residual=25220.280957349874
# 000719, method='Nelder-Mead', residual=25220.280957349874
# 000720, method='Nelder-Mead', residual=25220.280957349874
# 000721, method='Nelder-Mead', residual=25220.280957349874
# 000722, method='Nelder-Mead', residual=25220.280982583587
# 000723, method='Nelder-Mead', residual=25220.280957349874
# 000724, method='Nelder-Mead', residual=25220.280982583587
# 000725, method='Nelder-Mead', residual=25220.281003117325
# 000726, method='Nelder-Mead', residual=25220.280957349874
# 000727, method='Nelder-Mead', residual=25220.280957349874
# 000728, method='Nelder-Mead', residual=25220.280957349874
# 000729, method='Nelder-Mead', residual=25220.280957349874
# 000730, method='Nelder-Mead', residual=25220.280957349874
# 000731, method='Nelder-Mead', residual=25220.280957349874
# 000732, method='Nelder-Mead', residual=25220.280957349874
# 000733, method='Nelder-Mead', residual=25220.280957349874
# 000734, method='Nelder-Mead', residual=25220.280957349874
# 000735, method='Nelder-Mead', residual=25220.280957349874
# 000736, method='Nelder-Mead', residual=25220.280957349874
# 000737, method='Nelder-Mead', residual=25220.280957349874
# 000738, method='Nelder-Mead', residual=25220.280957349874
# 000739, method='Nelder-Mead', residual=25220.280957349874
# 000740, method='Nelder-Mead', residual=25220.280957349874
# 000741, method='Nelder-Mead', residual=25220.280957349874
# 000742, method='Nelder-Mead', residual=25220.280957349874
# 000743, method='Nelder-Mead', residual=25220.280957349874
# 000744, method='Nelder-Mead', residual=25220.280957349874
# 000745, method='Nelder-Mead', residual=25220.280957349874
# 000746, method='Nelder-Mead', residual=25220.280957349874
# 000747, method='Nelder-Mead', residual=25220.280957349874
# 000748, method='Nelder-Mead', residual=25220.280957349874
# 000749, method='Nelder-Mead', residual=25220.280957349874
# 000750, method='Nelder-Mead', residual=25220.280957349874
# 000751, method='Nelder-Mead', residual=25220.280957349874
# 000752, method='Nelder-Mead', residual=25220.280957349874
# 000753, method='Nelder-Mead', residual=25220.280957349874
# 000754, method='Nelder-Mead', residual=25220.280957349874
# 000755, method='Nelder-Mead', residual=25220.280957349874
# 000756, method='Nelder-Mead', residual=25220.280957349874
# 000757, method='Nelder-Mead', residual=25220.280957349874
# 000758, method='Nelder-Mead', residual=25220.280957349874
# 000759, method='Nelder-Mead', residual=25220.280957349874
# 000760, method='Nelder-Mead', residual=25220.280957349874
# 000761, method='Nelder-Mead', residual=25220.280957349874
# 000762, method='Nelder-Mead', residual=25220.280957349874
# 000763, method='Nelder-Mead', residual=25220.280957349874
# 000764, method='Nelder-Mead', residual=25220.280957349874
# 000765, method='Nelder-Mead', residual=25220.280957349874
# 000766, method='Nelder-Mead', residual=25220.280957349874
# 000767, method='Nelder-Mead', residual=25220.280957349874
# 000768, method='Nelder-Mead', residual=25220.280957349874
# 000769, method='Nelder-Mead', residual=25220.280957349874
# 000770, method='Nelder-Mead', residual=25220.280957349874
# 000771, method='Nelder-Mead', residual=25220.280957349874
# 000772, method='Nelder-Mead', residual=25220.280957349874
# 000773, method='Nelder-Mead', residual=25220.280957349874
# 000774, method='Nelder-Mead', residual=25220.280957349874
# 000775, method='Nelder-Mead', residual=25220.280957349874
# 000776, method='Nelder-Mead', residual=25220.280957349874
# 000777, method='Nelder-Mead', residual=25220.280957349874
# 000778, method='Nelder-Mead', residual=25220.280957349874
# 000779, method='Nelder-Mead', residual=25220.280957349874
# 000780, method='Nelder-Mead', residual=25220.280957349874
# 000781, method='Nelder-Mead', residual=25220.280957349874
# 000782, method='Nelder-Mead', residual=25220.280957349874
# 000783, method='Nelder-Mead', residual=25220.280957349874
# 000784, method='Nelder-Mead', residual=25220.280957349874
# 000785, method='Nelder-Mead', residual=25220.280957349874
# 000786, method='Nelder-Mead', residual=25220.280957349874
# 000787, method='Nelder-Mead', residual=25220.280957349874
# 000788, method='Nelder-Mead', residual=25220.280957349874
# 000789, method='Nelder-Mead', residual=25220.280957349874
# 000790, method='Nelder-Mead', residual=25220.280957349874
# 000791, method='Nelder-Mead', residual=25220.280957349874
# 000792, method='Nelder-Mead', residual=25220.280957349874
# 000793, method='Nelder-Mead', residual=25220.280957349874
# 000794, method='Nelder-Mead', residual=25220.280957349874
# 000795, method='Nelder-Mead', residual=25220.280957349874
# 000796, method='Nelder-Mead', residual=25220.280957349874
# 000797, method='Nelder-Mead', residual=25220.280957349874
# 000798, method='Nelder-Mead', residual=25220.280957349874
# 000799, method='Nelder-Mead', residual=25220.280957349874
# 000800, method='Nelder-Mead', residual=25220.280957349874
# 000801, method='Nelder-Mead', residual=25220.280957349874
# 000802, method='Nelder-Mead', residual=25220.280957349874
# 000803, method='Nelder-Mead', residual=25220.280957349874
# 000804, method='Nelder-Mead', residual=25220.280957349874
# 000805, method='Nelder-Mead', residual=25220.280957349874
# 000806, method='Nelder-Mead', residual=25220.280957349874
# 000807, method='Nelder-Mead', residual=25220.280957349874
# 000808, method='Nelder-Mead', residual=25220.280957349874
# 000809, method='Nelder-Mead', residual=25220.280957349874
# 000810, method='Nelder-Mead', residual=25220.280957349874
# 000811, method='Nelder-Mead', residual=25220.280957349874
# 000812, method='Nelder-Mead', residual=25220.280957349874
# 000813, method='Nelder-Mead', residual=25220.280957349874
# 000814, method='Nelder-Mead', residual=25220.280957349874
# 000815, method='Nelder-Mead', residual=25220.280957349874
# 000816, method='Nelder-Mead', residual=25220.280957349874
# 000817, method='Nelder-Mead', residual=25220.280957349874
# 000818, method='Nelder-Mead', residual=25220.280957349874
# 000819, method='Nelder-Mead', residual=25220.280957349874
# 000820, method='Nelder-Mead', residual=25220.280957349874
# 000821, method='Nelder-Mead', residual=25220.280957349874
# 000822, method='Nelder-Mead', residual=25220.280957349874
# 000823, method='Nelder-Mead', residual=25220.280957349874
# 000824, method='Nelder-Mead', residual=25220.280957349874
# 000825, method='Nelder-Mead', residual=25220.280957349874
# 000826, method='Nelder-Mead', residual=25220.280957349874
# 000827, method='Nelder-Mead', residual=25220.280957349874
# 000828, method='Nelder-Mead', residual=25220.280957349874
# 000829, method='Nelder-Mead', residual=25220.280957349874
# 000830, method='Nelder-Mead', residual=25220.280957349874
# 000831, method='Nelder-Mead', residual=25220.280957349874
# 000832, method='Nelder-Mead', residual=25220.280957349874
# 000833, method='Nelder-Mead', residual=25220.280957349874
# 000834, method='Nelder-Mead', residual=25220.280957349874
# 000835, method='Nelder-Mead', residual=25220.280957349874
# 000836, method='Nelder-Mead', residual=25220.280957349874
# 000837, method='Nelder-Mead', residual=25220.280957349874
# 000838, method='Nelder-Mead', residual=25220.280957349874
# 000839, method='Nelder-Mead', residual=25220.280957349874
# 000840, method='Nelder-Mead', residual=25220.280957349874
# 000841, method='Nelder-Mead', residual=25220.280957349874
# 000842, method='Nelder-Mead', residual=25220.280957349874
# 000843, method='Nelder-Mead', residual=25220.280957349874
# 000844, method='Nelder-Mead', residual=25220.280957349874
# 000845, method='Nelder-Mead', residual=25220.280957349874
# 000846, method='Nelder-Mead', residual=25220.280957349874
# 000847, method='Nelder-Mead', residual=25220.280957349874
# 000848, method='Nelder-Mead', residual=25220.280957349874
# 000849, method='Nelder-Mead', residual=25220.280957349874
# 000850, method='Nelder-Mead', residual=25220.280957349874
# 000851, method='Nelder-Mead', residual=25220.280957349874
# 000852, method='Nelder-Mead', residual=25220.280957349874
# 000853, method='Nelder-Mead', residual=25220.280957349874
# 000854, method='Nelder-Mead', residual=25220.280957349874
# 000855, method='Nelder-Mead', residual=25220.280957349874
# 000856, method='Nelder-Mead', residual=25220.280957349874
# 000857, method='Nelder-Mead', residual=25220.280957349874
# 000858, method='Nelder-Mead', residual=25220.280957349874
# 000859, method='Nelder-Mead', residual=25220.280957349874
# 000860, method='Nelder-Mead', residual=25220.280957349874
# 000861, method='Nelder-Mead', residual=25220.280957349874
# 000862, method='Nelder-Mead', residual=25220.280957349874
# 000863, method='Nelder-Mead', residual=25220.280957349874
# 000864, method='Nelder-Mead', residual=25220.280957349874
# 000865, method='Nelder-Mead', residual=25220.280957349874
# 000866, method='Nelder-Mead', residual=25220.280957349874
# 000867, method='Nelder-Mead', residual=25220.280957349874
# 000868, method='Nelder-Mead', residual=25220.280957349874
# 000869, method='Nelder-Mead', residual=25220.280957349874
# 000870, method='Nelder-Mead', residual=25220.280957349874
# 000871, method='Nelder-Mead', residual=25220.280957349874
# 000872, method='Nelder-Mead', residual=25220.280957349874
# 000873, method='Nelder-Mead', residual=25220.280957349874
# 000874, method='Nelder-Mead', residual=25220.280957349874
# 000875, method='Nelder-Mead', residual=25220.280957349874
# 000876, method='Nelder-Mead', residual=25220.280957349874
# 000877, method='Nelder-Mead', residual=25220.280957349874
# 000878, method='Nelder-Mead', residual=25220.280957349874
# 000879, method='Nelder-Mead', residual=25220.280957349874
# 000880, method='Nelder-Mead', residual=25220.280957349874
# 000881, method='Nelder-Mead', residual=25220.280957349874
# 000882, method='Nelder-Mead', residual=25220.280957349874
# 000883, method='Nelder-Mead', residual=25220.280957349874
# 000884, method='Nelder-Mead', residual=25220.280957349874
# 000885, method='Nelder-Mead', residual=25220.280957349874
# 000886, method='Nelder-Mead', residual=25220.280957349874
# 000887, method='Nelder-Mead', residual=25220.280957349874
# 000888, method='Nelder-Mead', residual=25220.280957349874
# 000889, method='Nelder-Mead', residual=25220.280957349874
# 000890, method='Nelder-Mead', residual=25220.280957349874
# 000891, method='Nelder-Mead', residual=25220.280957349874
# 000892, method='Nelder-Mead', residual=25220.280957349874
# 000893, method='Nelder-Mead', residual=25220.280957349874
# 000894, method='Nelder-Mead', residual=25220.280957349874
# 000895, method='Nelder-Mead', residual=25220.280957349874
# 000896, method='Nelder-Mead', residual=25220.280957349874
# 000897, method='Nelder-Mead', residual=25220.280957349874
# 000898, method='Nelder-Mead', residual=25220.280957349874
# 000899, method='Nelder-Mead', residual=25220.280957349874
# 000900, method='Nelder-Mead', residual=25220.280957349874
# 000901, method='Nelder-Mead', residual=25220.280957349874
# 000902, method='Nelder-Mead', residual=25220.280957349874
# 000903, method='Nelder-Mead', residual=25220.280957349874
# 000904, method='Nelder-Mead', residual=25220.280957349874
# 000905, method='Nelder-Mead', residual=25220.280957349874
# 000906, method='Nelder-Mead', residual=25220.280957349874
# 000907, method='Nelder-Mead', residual=25220.280957349874
# 000908, method='Nelder-Mead', residual=25220.280957349874
# 000909, method='Nelder-Mead', residual=25220.280957349874
# 000910, method='Nelder-Mead', residual=25220.280957349874
# 000911, method='Nelder-Mead', residual=25220.280957349874
# 000912, method='Nelder-Mead', residual=25220.280957349874
# 000913, method='Nelder-Mead', residual=25220.280957349874
# 000914, method='Nelder-Mead', residual=25220.280957349874
# 000915, method='Nelder-Mead', residual=25220.280957349874
# 000916, method='Nelder-Mead', residual=25220.280957349874
# 000917, method='Nelder-Mead', residual=25220.280957349874
# 000918, method='Nelder-Mead', residual=25220.280957349874
# 000919, method='Nelder-Mead', residual=25220.280957349874
# 000920, method='Nelder-Mead', residual=25220.280957349874
# 000921, method='Nelder-Mead', residual=25220.280957349874
# 000922, method='Nelder-Mead', residual=25220.280957349874
# 000923, method='Nelder-Mead', residual=25220.280957349874
# 000924, method='Nelder-Mead', residual=25220.280957349874
# 000925, method='Nelder-Mead', residual=25220.280957349874
# 000926, method='Nelder-Mead', residual=25220.280957349874
# 000927, method='Nelder-Mead', residual=25220.280957349874
# 000928, method='Nelder-Mead', residual=25220.280957349874
# 000929, method='Nelder-Mead', residual=25220.280957349874
# 000930, method='Nelder-Mead', residual=25220.280957349874
# 000931, method='Nelder-Mead', residual=25220.280957349874
# 000932, method='Nelder-Mead', residual=25220.280957349874
# 000933, method='Nelder-Mead', residual=25220.280957349874
# 000934, method='Nelder-Mead', residual=25220.280957349874
# 000935, method='Nelder-Mead', residual=25220.280957349874
# 000936, method='Nelder-Mead', residual=25220.280957349874
# 000937, method='Nelder-Mead', residual=25220.280957349874
# 000938, method='Nelder-Mead', residual=25220.280957349874
# 000939, method='Nelder-Mead', residual=25220.280957349874
# 000940, method='Nelder-Mead', residual=25220.280957349874
# 000941, method='Nelder-Mead', residual=25220.280957349874
# 000942, method='Nelder-Mead', residual=25220.280957349874
# 000943, method='Nelder-Mead', residual=25220.280957349874
# 000944, method='Nelder-Mead', residual=25220.280957349874
# 000945, method='Nelder-Mead', residual=25220.280957349874
# 000946, method='Nelder-Mead', residual=25220.280957349874
# 000947, method='Nelder-Mead', residual=25220.280957349874
# 000948, method='Nelder-Mead', residual=25220.280957349874
# 000949, method='Nelder-Mead', residual=25220.280957349874
# 000950, method='Nelder-Mead', residual=25220.280957349874
# 000951, method='Nelder-Mead', residual=25220.280957349874
# 000952, method='Nelder-Mead', residual=25220.280957349874
# 000953, method='Nelder-Mead', residual=25220.280957349874
# 000954, method='Nelder-Mead', residual=25220.280957349874
# 000955, method='Nelder-Mead', residual=25220.280957349874
# 000956, method='Nelder-Mead', residual=25220.280957349874
# 000957, method='Nelder-Mead', residual=25220.280957349874
# 000958, method='Nelder-Mead', residual=25220.280957349874
# 000959, method='Nelder-Mead', residual=25220.280957349874
# 000960, method='Nelder-Mead', residual=25220.280957349874
# 000961, method='Nelder-Mead', residual=25220.280957349874
# 000962, method='Nelder-Mead', residual=25220.280957349874
# 000963, method='Nelder-Mead', residual=25220.280957349874
# 000964, method='Nelder-Mead', residual=25220.280957349874
# 000965, method='Nelder-Mead', residual=25220.280957349874
# 000966, method='Nelder-Mead', residual=25220.280957349874
# 000967, method='Nelder-Mead', residual=25220.280957349874
# 000968, method='Nelder-Mead', residual=25220.280957349874
# 000969, method='Nelder-Mead', residual=25220.280957349874
# 000970, method='Nelder-Mead', residual=25220.280957349874
# 000971, method='Nelder-Mead', residual=25220.280957349874
# 000972, method='Nelder-Mead', residual=25220.280957349874
# 000973, method='Nelder-Mead', residual=25220.280957349874
# 000974, method='Nelder-Mead', residual=25220.280957349874
# 000975, method='Nelder-Mead', residual=25220.280957349874
# 000976, method='Nelder-Mead', residual=25220.280957349874
# 000977, method='Nelder-Mead', residual=25220.280957349874
# 000978, method='Nelder-Mead', residual=25220.280957349874
# 000979, method='Nelder-Mead', residual=25220.280957349874
# 000980, method='Nelder-Mead', residual=25220.280957349874
# 000981, method='Nelder-Mead', residual=25220.280957349874
# 000982, method='Nelder-Mead', residual=25220.280957349874
# 000983, method='Nelder-Mead', residual=25220.280957349874
# 000984, method='Nelder-Mead', residual=25220.280957349874
# 000985, method='Nelder-Mead', residual=25220.280957349874
# 000986, method='Nelder-Mead', residual=25220.280957349874
# 000987, method='Nelder-Mead', residual=25220.280957349874
# 000988, method='Nelder-Mead', residual=25220.280957349874
# 000989, method='Nelder-Mead', residual=25220.280957349874
# 000990, method='Nelder-Mead', residual=25220.280957349874
# 000991, method='Nelder-Mead', residual=25220.280957349874
# 000992, method='Nelder-Mead', residual=25220.280957349874
# 000993, method='Nelder-Mead', residual=25220.280957349874
# 000994, method='Nelder-Mead', residual=25220.280957349874
# 000995, method='Nelder-Mead', residual=25220.280957349874
# 000996, method='Nelder-Mead', residual=25220.280957349874
# 000997, method='Nelder-Mead', residual=25220.280957349874
# 000998, method='Nelder-Mead', residual=25220.280957349874
# 000999, method='Nelder-Mead', residual=25220.280957349874
# 001000, method='Nelder-Mead', residual=25220.280957349874
# 001001, method='Nelder-Mead', residual=25220.280957349874
# 001002, method='Nelder-Mead', residual=25220.280957349874
# 001003, method='Nelder-Mead', residual=25220.280957349874
# 001004, method='Nelder-Mead', residual=25220.280957349874
# 001005, method='Nelder-Mead', residual=25220.280957349874
# 001006, method='Nelder-Mead', residual=25220.280957349874
# 001007, method='Nelder-Mead', residual=25220.280957349874
# 001008, method='Nelder-Mead', residual=25220.280957349874
# 001009, method='Nelder-Mead', residual=25220.280957349874
# 001010, method='Nelder-Mead', residual=25220.280957349874
# 001011, method='Nelder-Mead', residual=25220.280957349874
# 001012, method='Nelder-Mead', residual=25220.280957349874
# 001013, method='Nelder-Mead', residual=25220.280957349874
# 001014, method='Nelder-Mead', residual=25220.280957349874
# 001015, method='Nelder-Mead', residual=25220.280957349874
# 001016, method='Nelder-Mead', residual=25220.280957349874
# 001017, method='Nelder-Mead', residual=25220.280957349874
# 001018, method='Nelder-Mead', residual=25220.280957349874
# 001019, method='Nelder-Mead', residual=25220.280957349874
# 001020, method='Nelder-Mead', residual=25220.280957349874
# 001021, method='Nelder-Mead', residual=25220.280957349874
# 001022, method='Nelder-Mead', residual=25220.280957349874
# 001023, method='Nelder-Mead', residual=25220.280957349874
# 001024, method='Nelder-Mead', residual=25220.280957349874
# 001025, method='Nelder-Mead', residual=25220.280957349874
# 001026, method='Nelder-Mead', residual=25220.280957349874
# 001027, method='Nelder-Mead', residual=25220.280957349874
# 001028, method='Nelder-Mead', residual=25220.280957349874
# 001029, method='Nelder-Mead', residual=25220.280957349874
# 001030, method='Nelder-Mead', residual=25220.280957349874
# 001031, method='Nelder-Mead', residual=25220.280957349874
# 001032, method='Nelder-Mead', residual=25220.280957349874
# 001033, method='Nelder-Mead', residual=25220.280957349874
# 001034, method='Nelder-Mead', residual=25220.280957349874
# 001035, method='Nelder-Mead', residual=25220.280957349874
# 001036, method='Nelder-Mead', residual=25220.280957349874
# 001037, method='Nelder-Mead', residual=25220.280957349874
# 001038, method='Nelder-Mead', residual=25220.280957349874
# 001039, method='Nelder-Mead', residual=25220.280957349874
# 001040, method='Nelder-Mead', residual=25220.280957349874
# 001041, method='Nelder-Mead', residual=25220.280957349874
# 001042, method='Nelder-Mead', residual=25220.280957349874
# 001043, method='Nelder-Mead', residual=25220.280957349874
# 001044, method='Nelder-Mead', residual=25220.280957349874
# 001045, method='Nelder-Mead', residual=25220.280957349874
# 001046, method='Nelder-Mead', residual=25220.280957349874
# 001047, method='Nelder-Mead', residual=25220.280957349874
# 001048, method='Nelder-Mead', residual=25220.280957349874
# 001049, method='Nelder-Mead', residual=25220.280957349874
# 001050, method='Nelder-Mead', residual=25220.280957349874
# 001051, method='Nelder-Mead', residual=25220.280957349874
# 001052, method='Nelder-Mead', residual=25220.280957349874
# 001053, method='Nelder-Mead', residual=25220.280957349874
# 001054, method='Nelder-Mead', residual=25220.280957349874
# 001055, method='Nelder-Mead', residual=25220.280957349874
# 001056, method='Nelder-Mead', residual=25220.280957349874
# 001057, method='Nelder-Mead', residual=25220.280957349874
# 001058, method='Nelder-Mead', residual=25220.280957349874
# 001059, method='Nelder-Mead', residual=25220.280957349874
# 001060, method='Nelder-Mead', residual=25220.280957349874
# 001061, method='Nelder-Mead', residual=25220.280957349874
# 001062, method='Nelder-Mead', residual=25220.280957349874
# 001063, method='Nelder-Mead', residual=25220.280957349874
# 001064, method='Nelder-Mead', residual=25220.280957349874
# 001065, method='Nelder-Mead', residual=25220.280957349874
# 001066, method='Nelder-Mead', residual=25220.280957349874
# optimization is done
