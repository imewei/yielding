# %%
import matplotlib.pyplot as plt
import sys
import scipy as sp
import numpy as np
import time
import os
from xpcs_viewer import XpcsFile as xf
import scipy.optimize as op
import h5py

# %%
def IntegralMat2(Array):
    length = len(Array)
    cs = np.cumsum(Array)
    mat1 = np.tile(cs, length).reshape(length, length)
    deltaMat = np.abs(mat1 - mat1.T)
    return deltaMat

def read_parameters(fname):
    if fname.endswith('.txt'):
        paras = np.loadtxt(fname)
    elif fname.endswith('.csv'):
        paras = np.loadtxt(fname, delimiter=',')
    else:
        paras = None
    return paras


def read_data():
    # save_folder = '/home/8ididata/2022-3/hongrui202210/NonequilibratedAnalysis'
    DataFolderPath = '/gdata/s8id-dmdtn/2022-3/hongrui202210/Submitted_Folder_NC/Fig2/data_Twotime'
    DataFolderName = 'C021_Cys0_Exp2_Creep_XPCS_25Pa_01_att02_Lq2_001_0001-8000_Twotime.hdf'
    # Object = xf(os.path.join(DataFolderPath, DataFolderName), cwd='')

    phi_list = np.loadtxt('../phi_list.txt')
    phi_length = len(phi_list)
    CreepStart = 1001
    CreepEnd = 2000

    t_length = CreepEnd - CreepStart

    cache_fname = f'c2_cache_{CreepStart}_{CreepEnd}.npz'
    print(cache_fname)
    if os.path.isfile(cache_fname):
        c2_exp = np.load(cache_fname)['c2_exp'].astype(DTYPE)
    else:
        c2_exp = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
        for phiIdx, phi in enumerate(phi_list):
            cMat = Object.get_twotime_c2(
                    'exchange', phiIdx+1)[CreepStart:CreepEnd, CreepStart:CreepEnd]
            c2_exp[phiIdx] = cMat
        np.savez(cache_fname, c2_exp=c2_exp)
    
    # fix the diagonal line
    c2_exp = fix_diagonal_c2(c2_exp)
    print(c2_exp.shape, c2_exp.dtype)
    return c2_exp.astype(DTYPE), t_length, phi_list.astype(DTYPE), phi_length

def fix_diagonal_c2(c2_3d):
    c2_all = []
    for n in range(c2_3d.shape[0]):
        c2 = c2_3d[n]
        size = c2.shape[0]
        side_band = c2[(np.arange(size - 1), np.arange(1, size))]
        diag_val = np.zeros(size)
        diag_val[:-1] += side_band
        diag_val[1:] += side_band
        norm = np.ones(size)
        norm[1:-1] = 2
        c2[np.diag_indices(c2.shape[0])] = diag_val / norm
    
    return c2_3d

def fit_c2_polynomial(num_v=3, num_d=3, paras_fname=None):
    # read raw data
    c2_exp, t_length, phi_list, phi_length = read_data()
    x0 = np.array([
    2.667865850405673336e+04,
    -5.525712724506776086e-01,
    1.302208313276888817e-03,
    6.909744435613457414e-03,
    -7.443212487873459571e-01,
    6.399584426337057448e-17,
    -2.014956863461539793e+00,
              ])
    for method in (
                'Nelder-Mead',
                # 'Powell',
                # 'L-BFGS-B',
                # 'TNC', 'COBYLA', 'SLSQP', 'trust-constr', 'dogleg',
                # 'trust-ncg', 'trust-exact', 'trust-krylov'):
                ):
    # def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
        FitOutput = op.minimize(fun=chiFunc_polynomial, x0=x0, 
                                args=(phi_list, num_d, num_v, c2_exp, method),
                                 options={"maxiter": 1000000}, tol=0.00001,
                                method=method)

    FitParas = FitOutput['x']
    
    c2_fit = Homodyne1(FitParas, phi_list)
    shape = c2_fit.shape
    sol_list = []
    for n in range(shape[0]):
        sumy = np.sum(c2_fit[n])
        a = np.array([
            [np.sum(c2_fit[n] ** 2), sumy],
            [sumy, c2_fit[n].size]
        ])
        b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
        sol = np.linalg.solve(a, b)
        sol_list.append(sol)

    
    FitParas = np.hstack([FitParas, np.array(sol_list).T.reshape(-1)])
    np.savetxt('../FitParas/C021_FitParas.txt', FitParas, delimiter=",")

def chiFunc_polynomial(paras, phi_list, num_d, num_v, c2_exp, method):
    shape = c2_exp.shape
    residual = 0.0
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = paras[0:num_d]
    v_c  = paras[num_d: num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]


    if all(i >= 0 for i in v) == True\
    and all(i >= 0 for i in D)== True\
    and v_c[2] > 0\
    and D_c[2] > 0\
    :
        c2_fit = Homodyne1(paras, phi_list)
        sol_list = []
        for n in range(shape[0]):
            sumy = np.sum(c2_fit[n])
            a = np.array([
                [np.sum(c2_fit[n] ** 2), sumy],
                [sumy, c2_fit[n].size]
            ])
            b = np.array([np.sum(c2_exp[n] * c2_fit[n]), np.sum(c2_exp[n])])
            sol = np.linalg.solve(a, b)
            residual += np.sum(np.square(c2_fit[n] * sol[0] + sol[1] - c2_exp[n]))
            sol_list.append(sol)

        global gindex
        gindex += 1
        print(f'{gindex:06d}, {method=}, {residual=}')

        if gindex % 500 == 0:
            save_name = f'curr_paras_poly_{gindex:06d}.txt'
            sol_list = np.array(sol_list).T.reshape(-1)
            paras = np.hstack([paras, sol_list])
            np.savetxt(save_name, paras)
            np.savetxt('latest_paras_poly.txt', paras)
        # plt.imshow(c2_fit[0])
        # # plt.imshow(c2_exp[0])
        # plt.show()
    else:
        residual = np.inf
    
    
    return residual



def Homodyne1(x, phi_list):
    phi_length = len(phi_list) 

    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    g1_s = np.exp(-qValue**2 / 2 * abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)
    
    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = (w * g1_s) ** 2

    return g2_all

def Homodyne2(x, phi_list):
    phi_length = len(phi_list) 
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    D, v, phio, beta, c = separate_params(x, phi_length)
    DMat = IntegralMat2(D)
    vMat = IntegralMat2(v)
    
    
    g1_s = np.exp(qValue**2 / 2 * -abs(DMat) * dt).astype(DTYPE)
    g2_all = np.zeros((phi_length, t_length, t_length), dtype=DTYPE)

    for n in range(phi_length):
        w = np.sinc(1/2 /np.pi * qValue* gap * vMat * dt * np.cos(np.deg2rad(phio - phi_list[n])))
        g2_all[n] = c[n] + beta[n] * (w * g1_s)** 2
    return g2_all


def separate_params(x, phi_length):
    x = x.astype(DTYPE)
    t_length = 999
    num_d = 3
    num_v = 3
    
    D_c  = x[0:num_d]
    v_c  = x[num_d: num_d + num_v]
    phio = x[num_d + num_v]

    beta = x[num_d + num_v + 1: num_d + num_v + phi_length + 1]
    c = x[num_d + num_v + phi_length + 1: num_d + num_v + 2 * phi_length + 1]
    
    tabs = np.linspace(0.1, 99.9, t_length, dtype=DTYPE) 
    v = v_c[0]*(tabs)**v_c[1] + v_c[2]
    D = D_c[0]*(tabs)**D_c[1] + D_c[2]

    return D, v, phio, beta, c

# %%
dt = 0.1
qValue = 0.0054
gap = 2e6

DTYPE = np.float64
gindex = 0
fit_c2_polynomial()
# Out:
# c2_cache_1001_2000.npz
# (23, 999, 999) float64
# 000001, method='Nelder-Mead', residual=88255.31415063485
# 000002, method='Nelder-Mead', residual=88257.96101553271
# 000003, method='Nelder-Mead', residual=88269.03142877859
# 000004, method='Nelder-Mead', residual=88255.31415125658
# 000005, method='Nelder-Mead', residual=88283.06355203294
# 000006, method='Nelder-Mead', residual=88516.07921368905
# 000007, method='Nelder-Mead', residual=88255.31415063486
# 000008, method='Nelder-Mead', residual=88255.88889260177
# 000009, method='Nelder-Mead', residual=88568.08393274376
# 000010, method='Nelder-Mead', residual=88316.38633736572
# 000011, method='Nelder-Mead', residual=88340.07991598397
# 000012, method='Nelder-Mead', residual=88268.09488062898
# 000013, method='Nelder-Mead', residual=88301.15267231897
# 000014, method='Nelder-Mead', residual=88260.77991508553
# 000015, method='Nelder-Mead', residual=88274.71347103243
# 000016, method='Nelder-Mead', residual=88258.32626147785
# 000017, method='Nelder-Mead', residual=88273.50577592143
# 000018, method='Nelder-Mead', residual=88257.85144921788
# 000019, method='Nelder-Mead', residual=88263.915054382
# 000020, method='Nelder-Mead', residual=88256.32047118219
# 000021, method='Nelder-Mead', residual=88261.07559381348
# 000022, method='Nelder-Mead', residual=88255.76043153409
# 000023, method='Nelder-Mead', residual=88258.28668963941
# 000024, method='Nelder-Mead', residual=88255.87348649451
# 000025, method='Nelder-Mead', residual=88259.03279212059
# 000026, method='Nelder-Mead', residual=88255.75130657607
# 000027, method='Nelder-Mead', residual=88257.08953050859
# 000028, method='Nelder-Mead', residual=88255.42467880582
# 000029, method='Nelder-Mead', residual=88256.39865657678
# 000030, method='Nelder-Mead', residual=88255.34091148441
# 000031, method='Nelder-Mead', residual=88256.08627319767
# 000032, method='Nelder-Mead', residual=88255.37009652598
# 000033, method='Nelder-Mead', residual=88256.18501633781
# 000034, method='Nelder-Mead', residual=88255.32484115919
# 000035, method='Nelder-Mead', residual=88256.01293499806
# 000036, method='Nelder-Mead', residual=88255.33718924936
# 000037, method='Nelder-Mead', residual=88255.6923227407
# 000038, method='Nelder-Mead', residual=88255.26004757285
# 000039, method='Nelder-Mead', residual=88255.37302404917
# 000040, method='Nelder-Mead', residual=88255.27233603949
# 000041, method='Nelder-Mead', residual=88255.65217398241
# 000042, method='Nelder-Mead', residual=88255.23805580636
# 000043, method='Nelder-Mead', residual=88255.41205745122
# 000044, method='Nelder-Mead', residual=88255.2624045904
# 000045, method='Nelder-Mead', residual=88255.50998184708
# 000046, method='Nelder-Mead', residual=88255.25122670154
# 000047, method='Nelder-Mead', residual=88255.20632420089
# 000048, method='Nelder-Mead', residual=88255.19804211176
# 000049, method='Nelder-Mead', residual=88255.19736798045
# 000050, method='Nelder-Mead', residual=88255.23194546276
# 000051, method='Nelder-Mead', residual=88255.20955902337
# 000052, method='Nelder-Mead', residual=88255.17258252713
# 000053, method='Nelder-Mead', residual=88255.19453507535
# 000054, method='Nelder-Mead', residual=88255.2235148087
# 000055, method='Nelder-Mead', residual=88255.26243249784
# 000056, method='Nelder-Mead', residual=88255.20460033856
# 000057, method='Nelder-Mead', residual=88255.35137697472
# 000058, method='Nelder-Mead', residual=88255.19366110244
# 000059, method='Nelder-Mead', residual=88255.16682432833
# 000060, method='Nelder-Mead', residual=88255.18673185239
# 000061, method='Nelder-Mead', residual=88255.2162687453
# 000062, method='Nelder-Mead', residual=88255.1871395372
# 000063, method='Nelder-Mead', residual=88255.19522696389
# 000064, method='Nelder-Mead', residual=88255.18823258637
# 000065, method='Nelder-Mead', residual=88255.18297124762
# 000066, method='Nelder-Mead', residual=88255.1971905918
# 000067, method='Nelder-Mead', residual=88255.17856954862
# 000068, method='Nelder-Mead', residual=88255.18445185531
# 000069, method='Nelder-Mead', residual=88255.18212609133
# 000070, method='Nelder-Mead', residual=88255.16463013976
# 000071, method='Nelder-Mead', residual=88255.17786170937
# 000072, method='Nelder-Mead', residual=88255.18187126965
# 000073, method='Nelder-Mead', residual=88255.18198389153
# 000074, method='Nelder-Mead', residual=88255.1743927328
# 000075, method='Nelder-Mead', residual=88255.18743766782
# 000076, method='Nelder-Mead', residual=88255.1684155843
# 000077, method='Nelder-Mead', residual=88255.18457683046
# 000078, method='Nelder-Mead', residual=88255.16854894128
# 000079, method='Nelder-Mead', residual=88255.17260835155
# 000080, method='Nelder-Mead', residual=88255.17933187615
# 000081, method='Nelder-Mead', residual=88255.16689549171
# 000082, method='Nelder-Mead', residual=88255.18316200089
# 000083, method='Nelder-Mead', residual=88255.16512252603
# 000084, method='Nelder-Mead', residual=88255.17947557419
# 000085, method='Nelder-Mead', residual=88255.16490925166
# 000086, method='Nelder-Mead', residual=88255.16724398325
# 000087, method='Nelder-Mead', residual=88255.16564702062
# 000088, method='Nelder-Mead', residual=88255.16934044873
# 000089, method='Nelder-Mead', residual=88255.16370224411
# 000090, method='Nelder-Mead', residual=88255.17342900061
# 000091, method='Nelder-Mead', residual=88255.16295315
# 000092, method='Nelder-Mead', residual=88255.1706785224
# 000093, method='Nelder-Mead', residual=88255.16313342712
# 000094, method='Nelder-Mead', residual=88255.16675421373
# 000095, method='Nelder-Mead', residual=88255.16343306204
# 000096, method='Nelder-Mead', residual=88255.16979502676
# 000097, method='Nelder-Mead', residual=88255.16280761728
# 000098, method='Nelder-Mead', residual=88255.1645681379
# 000099, method='Nelder-Mead', residual=88255.16454762872
# 000100, method='Nelder-Mead', residual=88255.16376510289
# 000101, method='Nelder-Mead', residual=88255.16891705286
# 000102, method='Nelder-Mead', residual=88255.16241015734
# 000103, method='Nelder-Mead', residual=88255.16400994384
# 000104, method='Nelder-Mead', residual=88255.16260681847
# 000105, method='Nelder-Mead', residual=88255.16410657387
# 000106, method='Nelder-Mead', residual=88255.16256029566
# 000107, method='Nelder-Mead', residual=88255.16233228147
# 000108, method='Nelder-Mead', residual=88255.16436390381
# 000109, method='Nelder-Mead', residual=88255.16215983835
# 000110, method='Nelder-Mead', residual=88255.16404243474
# 000111, method='Nelder-Mead', residual=88255.16209641883
# 000112, method='Nelder-Mead', residual=88255.16398751417
# 000113, method='Nelder-Mead', residual=88255.16469890479
# 000114, method='Nelder-Mead', residual=88255.16189428489
# 000115, method='Nelder-Mead', residual=88255.16175121661
# 000116, method='Nelder-Mead', residual=88255.1629320966
# 000117, method='Nelder-Mead', residual=88255.16180795942
# 000118, method='Nelder-Mead', residual=88255.16294505582
# 000119, method='Nelder-Mead', residual=88255.16176047767
# 000120, method='Nelder-Mead', residual=88255.16282612686
# 000121, method='Nelder-Mead', residual=88255.16171958698
# 000122, method='Nelder-Mead', residual=88255.16255939881
# 000123, method='Nelder-Mead', residual=88255.16171826146
# 000124, method='Nelder-Mead', residual=88255.16175694764
# 000125, method='Nelder-Mead', residual=88255.16338931848
# 000126, method='Nelder-Mead', residual=88255.16153324678
# 000127, method='Nelder-Mead', residual=88255.16166818475
# 000128, method='Nelder-Mead', residual=88255.16230350929
# 000129, method='Nelder-Mead', residual=88255.16152901789
# 000130, method='Nelder-Mead', residual=88255.16200189725
# 000131, method='Nelder-Mead', residual=88255.16154561844
# 000132, method='Nelder-Mead', residual=88255.16180995424
# 000133, method='Nelder-Mead', residual=88255.1615628968
# 000134, method='Nelder-Mead', residual=88255.16148233299
# 000135, method='Nelder-Mead', residual=88255.16173490218
# 000136, method='Nelder-Mead', residual=88255.16133945799
# 000137, method='Nelder-Mead', residual=88255.16139340111
# 000138, method='Nelder-Mead', residual=88255.16134946507
# 000139, method='Nelder-Mead', residual=88255.16195092634
# 000140, method='Nelder-Mead', residual=88255.1614246014
# 000141, method='Nelder-Mead', residual=88255.16154835885
# 000142, method='Nelder-Mead', residual=88255.16142013966
# 000143, method='Nelder-Mead', residual=88255.16134426091
# 000144, method='Nelder-Mead', residual=88255.16137439074
# 000145, method='Nelder-Mead', residual=88255.16125033553
# 000146, method='Nelder-Mead', residual=88255.16133090011
# 000147, method='Nelder-Mead', residual=88255.16131331364
# 000148, method='Nelder-Mead', residual=88255.16141226955
# 000149, method='Nelder-Mead', residual=88255.16122557402
# 000150, method='Nelder-Mead', residual=88255.16130372154
# 000151, method='Nelder-Mead', residual=88255.1613981699
# 000152, method='Nelder-Mead', residual=88255.16128507875
# 000153, method='Nelder-Mead', residual=88255.16127619927
# 000154, method='Nelder-Mead', residual=88255.16125229126
# 000155, method='Nelder-Mead', residual=88255.16119052548
# 000156, method='Nelder-Mead', residual=88255.16127049948
# 000157, method='Nelder-Mead', residual=88255.1611405821
# 000158, method='Nelder-Mead', residual=88255.16118177662
# 000159, method='Nelder-Mead', residual=88255.16113764785
# 000160, method='Nelder-Mead', residual=88255.16121724974
# 000161, method='Nelder-Mead', residual=88255.16113940926
# 000162, method='Nelder-Mead', residual=88255.16112909728
# 000163, method='Nelder-Mead', residual=88255.16127061311
# 000164, method='Nelder-Mead', residual=88255.16122724305
# 000165, method='Nelder-Mead', residual=88255.16115701519
# 000166, method='Nelder-Mead', residual=88255.16123128257
# 000167, method='Nelder-Mead', residual=88255.16113614831
# 000168, method='Nelder-Mead', residual=88255.16109447746
# 000169, method='Nelder-Mead', residual=88255.16121607312
# 000170, method='Nelder-Mead', residual=88255.16100604285
# 000171, method='Nelder-Mead', residual=88255.16097287257
# 000172, method='Nelder-Mead', residual=88255.16125207595
# 000173, method='Nelder-Mead', residual=88255.16107270253
# 000174, method='Nelder-Mead', residual=88255.16104882766
# 000175, method='Nelder-Mead', residual=88255.16111561941
# 000176, method='Nelder-Mead', residual=88255.16105554023
# 000177, method='Nelder-Mead', residual=88255.1609691943
# 000178, method='Nelder-Mead', residual=88255.16097654987
# 000179, method='Nelder-Mead', residual=88255.16097786168
# 000180, method='Nelder-Mead', residual=88255.16104558739
# 000181, method='Nelder-Mead', residual=88255.16090316445
# 000182, method='Nelder-Mead', residual=88255.16088649823
# 000183, method='Nelder-Mead', residual=88255.1609791253
# 000184, method='Nelder-Mead', residual=88255.1611465679
# 000185, method='Nelder-Mead', residual=88255.16095877267
# 000186, method='Nelder-Mead', residual=88255.1609487074
# 000187, method='Nelder-Mead', residual=88255.16084114817
# 000188, method='Nelder-Mead', residual=88255.16082797034
# 000189, method='Nelder-Mead', residual=88255.16098084829
# 000190, method='Nelder-Mead', residual=88255.16091108817
# 000191, method='Nelder-Mead', residual=88255.16084275824
# 000192, method='Nelder-Mead', residual=88255.16082013928
# 000193, method='Nelder-Mead', residual=88255.16084718419
# 000194, method='Nelder-Mead', residual=88255.16085757468
# 000195, method='Nelder-Mead', residual=88255.16077654349
# 000196, method='Nelder-Mead', residual=88255.16080714125
# 000197, method='Nelder-Mead', residual=88255.16069756473
# 000198, method='Nelder-Mead', residual=88255.1606408107
# 000199, method='Nelder-Mead', residual=88255.16076076654
# 000200, method='Nelder-Mead', residual=88255.16079822398
# 000201, method='Nelder-Mead', residual=88255.16082388435
# 000202, method='Nelder-Mead', residual=88255.16070821385
# 000203, method='Nelder-Mead', residual=88255.16067391334
# 000204, method='Nelder-Mead', residual=88255.16074649527
# 000205, method='Nelder-Mead', residual=88255.1605721733
# 000206, method='Nelder-Mead', residual=88255.16051273899
# 000207, method='Nelder-Mead', residual=88255.16060321691
# 000208, method='Nelder-Mead', residual=88255.16063711859
# 000209, method='Nelder-Mead', residual=88255.16043971128
# 000210, method='Nelder-Mead', residual=88255.16033144074
# 000211, method='Nelder-Mead', residual=88255.16055435478
# 000212, method='Nelder-Mead', residual=88255.16042460853
# 000213, method='Nelder-Mead', residual=88255.160321716
# 000214, method='Nelder-Mead', residual=88255.16025433327
# 000215, method='Nelder-Mead', residual=88255.16037813944
# 000216, method='Nelder-Mead', residual=88255.1601799733
# 000217, method='Nelder-Mead', residual=88255.16010367687
# 000218, method='Nelder-Mead', residual=88255.16027231525
# 000219, method='Nelder-Mead', residual=88255.16016854209
# 000220, method='Nelder-Mead', residual=88255.1600234205
# 000221, method='Nelder-Mead', residual=88255.16003594142
# 000222, method='Nelder-Mead', residual=88255.16003906692
# 000223, method='Nelder-Mead', residual=88255.1600358035
# 000224, method='Nelder-Mead', residual=88255.16000718287
# 000225, method='Nelder-Mead', residual=88255.1602333129
# 000226, method='Nelder-Mead', residual=88255.16010258356
# 000227, method='Nelder-Mead', residual=88255.16004695298
# 000228, method='Nelder-Mead', residual=88255.1600162995
# 000229, method='Nelder-Mead', residual=88255.16006881179
# 000230, method='Nelder-Mead', residual=88255.16015767801
# 000231, method='Nelder-Mead', residual=88255.15998251943
# 000232, method='Nelder-Mead', residual=88255.16007633322
# 000233, method='Nelder-Mead', residual=88255.15997795039
# 000234, method='Nelder-Mead', residual=88255.16029105872
# 000235, method='Nelder-Mead', residual=88255.15995230366
# 000236, method='Nelder-Mead', residual=88255.1600827563
# 000237, method='Nelder-Mead', residual=88255.15997100231
# 000238, method='Nelder-Mead', residual=88255.16002676697
# 000239, method='Nelder-Mead', residual=88255.15997023956
# 000240, method='Nelder-Mead', residual=88255.16001566005
# 000241, method='Nelder-Mead', residual=88255.1600422591
# 000242, method='Nelder-Mead', residual=88255.15996510338
# 000243, method='Nelder-Mead', residual=88255.16002855256
# 000244, method='Nelder-Mead', residual=88255.15996597418
# 000245, method='Nelder-Mead', residual=88255.15997744314
# 000246, method='Nelder-Mead', residual=88255.15997949369
# 000247, method='Nelder-Mead', residual=88255.15995471079
# 000248, method='Nelder-Mead', residual=88255.1599478865
# 000249, method='Nelder-Mead', residual=88255.15998697329
# 000250, method='Nelder-Mead', residual=88255.15999340673
# 000251, method='Nelder-Mead', residual=88255.15995006177
# 000252, method='Nelder-Mead', residual=88255.16001623904
# 000253, method='Nelder-Mead', residual=88255.15994608589
# 000254, method='Nelder-Mead', residual=88255.15997174576
# 000255, method='Nelder-Mead', residual=88255.1599502048
# 000256, method='Nelder-Mead', residual=88255.1599440553
# 000257, method='Nelder-Mead', residual=88255.1599713275
# 000258, method='Nelder-Mead', residual=88255.15995267998
# 000259, method='Nelder-Mead', residual=88255.15997286647
# 000260, method='Nelder-Mead', residual=88255.15994163358
# 000261, method='Nelder-Mead', residual=88255.15996127068
# 000262, method='Nelder-Mead', residual=88255.15994217977
# 000263, method='Nelder-Mead', residual=88255.15994903268
# 000264, method='Nelder-Mead', residual=88255.15995044271
# 000265, method='Nelder-Mead', residual=88255.15994202794
# 000266, method='Nelder-Mead', residual=88255.15994804248
# 000267, method='Nelder-Mead', residual=88255.15995090881
# 000268, method='Nelder-Mead', residual=88255.15994132591
# 000269, method='Nelder-Mead', residual=88255.15994964408
# 000270, method='Nelder-Mead', residual=88255.15994106261
# 000271, method='Nelder-Mead', residual=88255.15995894306
# 000272, method='Nelder-Mead', residual=88255.15994018936
# 000273, method='Nelder-Mead', residual=88255.15994213318
# 000274, method='Nelder-Mead', residual=88255.15994766114
# 000275, method='Nelder-Mead', residual=88255.15993965842
# 000276, method='Nelder-Mead', residual=88255.15994387247
# 000277, method='Nelder-Mead', residual=88255.15993939419
# 000278, method='Nelder-Mead', residual=88255.15994693262
# 000279, method='Nelder-Mead', residual=88255.15993912639
# 000280, method='Nelder-Mead', residual=88255.15993962395
# 000281, method='Nelder-Mead', residual=88255.15994509746
# 000282, method='Nelder-Mead', residual=88255.15993895319
# 000283, method='Nelder-Mead', residual=88255.1599434074
# 000284, method='Nelder-Mead', residual=88255.15993903566
# 000285, method='Nelder-Mead', residual=88255.15994098909
# 000286, method='Nelder-Mead', residual=88255.15993913231
# 000287, method='Nelder-Mead', residual=88255.15993927469
# 000288, method='Nelder-Mead', residual=88255.15993862912
# 000289, method='Nelder-Mead', residual=88255.15994052043
# 000290, method='Nelder-Mead', residual=88255.15994060927
# 000291, method='Nelder-Mead', residual=88255.15993852557
# 000292, method='Nelder-Mead', residual=88255.15993920865
# 000293, method='Nelder-Mead', residual=88255.15993959192
# 000294, method='Nelder-Mead', residual=88255.15993848782
# 000295, method='Nelder-Mead', residual=88255.15993958338
# 000296, method='Nelder-Mead', residual=88255.15993846457
# 000297, method='Nelder-Mead', residual=88255.15993935896
# 000298, method='Nelder-Mead', residual=88255.15993845768
# 000299, method='Nelder-Mead', residual=88255.15994005773
# 000300, method='Nelder-Mead', residual=88255.15993839428
# 000301, method='Nelder-Mead', residual=88255.15993856628
# 000302, method='Nelder-Mead', residual=88255.15993892743
# 000303, method='Nelder-Mead', residual=88255.15993838591
# 000304, method='Nelder-Mead', residual=88255.15993924989
# 000305, method='Nelder-Mead', residual=88255.15993825934
# 000306, method='Nelder-Mead', residual=88255.1599388041
# 000307, method='Nelder-Mead', residual=88255.15993828485
# 000308, method='Nelder-Mead', residual=88255.15993851871
# 000309, method='Nelder-Mead', residual=88255.15993829373
# 000310, method='Nelder-Mead', residual=88255.15993886568
# 000311, method='Nelder-Mead', residual=88255.15993825288
# 000312, method='Nelder-Mead', residual=88255.1599387152
# 000313, method='Nelder-Mead', residual=88255.15993826302
# 000314, method='Nelder-Mead', residual=88255.15993818152
# 000315, method='Nelder-Mead', residual=88255.15993836563
# 000316, method='Nelder-Mead', residual=88255.15993832907
# 000317, method='Nelder-Mead', residual=88255.15993846796
# 000318, method='Nelder-Mead', residual=88255.15993822867
# 000319, method='Nelder-Mead', residual=88255.15993838453
# 000320, method='Nelder-Mead', residual=88255.1599382172
# 000321, method='Nelder-Mead', residual=88255.15993823574
# 000322, method='Nelder-Mead', residual=88255.15993826502
# 000323, method='Nelder-Mead', residual=88255.15993819729
# 000324, method='Nelder-Mead', residual=88255.1599382436
# 000325, method='Nelder-Mead', residual=88255.1599383341
# 000326, method='Nelder-Mead', residual=88255.15993818914
# 000327, method='Nelder-Mead', residual=88255.15993831147
# 000328, method='Nelder-Mead', residual=88255.15993818965
# 000329, method='Nelder-Mead', residual=88255.15993824737
# 000330, method='Nelder-Mead', residual=88255.1599381925
# 000331, method='Nelder-Mead', residual=88255.15993819613
# 000332, method='Nelder-Mead', residual=88255.15993824655
# 000333, method='Nelder-Mead', residual=88255.15993818345
# 000334, method='Nelder-Mead', residual=88255.15993817913
# 000335, method='Nelder-Mead', residual=88255.15993824988
# 000336, method='Nelder-Mead', residual=88255.15993819258
# 000337, method='Nelder-Mead', residual=88255.15993822413
# 000338, method='Nelder-Mead', residual=88255.15993817063
# 000339, method='Nelder-Mead', residual=88255.15993819691
# 000340, method='Nelder-Mead', residual=88255.15993817209
# 000341, method='Nelder-Mead', residual=88255.15993818773
# 000342, method='Nelder-Mead', residual=88255.15993820438
# 000343, method='Nelder-Mead', residual=88255.1599381699
# 000344, method='Nelder-Mead', residual=88255.15993817848
# 000345, method='Nelder-Mead', residual=88255.15993818112
# 000346, method='Nelder-Mead', residual=88255.15993818856
# 000347, method='Nelder-Mead', residual=88255.15993816764
# 000348, method='Nelder-Mead', residual=88255.15993818846
# 000349, method='Nelder-Mead', residual=88255.15993816694
# 000350, method='Nelder-Mead', residual=88255.15993818988
# 000351, method='Nelder-Mead', residual=88255.15993816665
# 000352, method='Nelder-Mead', residual=88255.1599381843
# 000353, method='Nelder-Mead', residual=88255.15993816649
# 000354, method='Nelder-Mead', residual=88255.15993819258
# 000355, method='Nelder-Mead', residual=88255.15993816553
# 000356, method='Nelder-Mead', residual=88255.1599381702
# 000357, method='Nelder-Mead', residual=88255.1599381792
# 000358, method='Nelder-Mead', residual=88255.15993816411
# 000359, method='Nelder-Mead', residual=88255.1599381715
# 000360, method='Nelder-Mead', residual=88255.15993816471
# 000361, method='Nelder-Mead', residual=88255.15993816935
# 000362, method='Nelder-Mead', residual=88255.15993816449
# 000363, method='Nelder-Mead', residual=88255.1599381703
# 000364, method='Nelder-Mead', residual=88255.15993816385
# 000365, method='Nelder-Mead', residual=88255.15993816566
# 000366, method='Nelder-Mead', residual=88255.1599381688
# 000367, method='Nelder-Mead', residual=88255.15993816353
# 000368, method='Nelder-Mead', residual=88255.15993816602
# 000369, method='Nelder-Mead', residual=88255.15993816347
# 000370, method='Nelder-Mead', residual=88255.15993816695
# 000371, method='Nelder-Mead', residual=88255.15993816331
# 000372, method='Nelder-Mead', residual=88255.15993816532
# 000373, method='Nelder-Mead', residual=88255.15993816333
# 000374, method='Nelder-Mead', residual=88255.15993816518
# 000375, method='Nelder-Mead', residual=88255.15993816312
# 000376, method='Nelder-Mead', residual=88255.15993816775
# 000377, method='Nelder-Mead', residual=88255.15993816283
# 000378, method='Nelder-Mead', residual=88255.15993816653
# 000379, method='Nelder-Mead', residual=88255.15993816285
# 000380, method='Nelder-Mead', residual=88255.15993816212
# 000381, method='Nelder-Mead', residual=88255.15993816228
# 000382, method='Nelder-Mead', residual=88255.15993816352
# 000383, method='Nelder-Mead', residual=88255.15993816277
# 000384, method='Nelder-Mead', residual=88255.15993816302
# 000385, method='Nelder-Mead', residual=88255.15993816308
# 000386, method='Nelder-Mead', residual=88255.15993816298
# 000387, method='Nelder-Mead', residual=88255.15993816219
# 000388, method='Nelder-Mead', residual=88255.15993816315
# 000389, method='Nelder-Mead', residual=88255.15993816247
# 000390, method='Nelder-Mead', residual=88255.1599381631
# 000391, method='Nelder-Mead', residual=88255.15993816248
# 000392, method='Nelder-Mead', residual=88255.15993816276
# 000393, method='Nelder-Mead', residual=88255.15993816225
# 000394, method='Nelder-Mead', residual=88255.15993816282
# 000395, method='Nelder-Mead', residual=88255.15993816232
# 000396, method='Nelder-Mead', residual=88255.15993816232
# 000397, method='Nelder-Mead', residual=88255.15993816283
# 000398, method='Nelder-Mead', residual=88255.15993816228
# 000399, method='Nelder-Mead', residual=88255.15993816187
# 000400, method='Nelder-Mead', residual=88255.1599381619
# 000401, method='Nelder-Mead', residual=88255.15993816165
# 000402, method='Nelder-Mead', residual=88255.15993816148
# 000403, method='Nelder-Mead', residual=88255.15993816203
# 000404, method='Nelder-Mead', residual=88255.15993816183
# 000405, method='Nelder-Mead', residual=88255.15993816158
# 000406, method='Nelder-Mead', residual=88255.15993816144
# 000407, method='Nelder-Mead', residual=88255.15993816158
# 000408, method='Nelder-Mead', residual=88255.15993816157
# 000409, method='Nelder-Mead', residual=88255.15993816106
# 000410, method='Nelder-Mead', residual=88255.15993816091
# 000411, method='Nelder-Mead', residual=88255.1599381615
# 000412, method='Nelder-Mead', residual=88255.15993816113
# 000413, method='Nelder-Mead', residual=88255.15993816045
# 000414, method='Nelder-Mead', residual=88255.1599381599
# 000415, method='Nelder-Mead', residual=88255.15993816062
# 000416, method='Nelder-Mead', residual=88255.15993816154
# 000417, method='Nelder-Mead', residual=88255.15993816094
# 000418, method='Nelder-Mead', residual=88255.1599381608
# 000419, method='Nelder-Mead', residual=88255.1599381599
# 000420, method='Nelder-Mead', residual=88255.15993816024
# 000421, method='Nelder-Mead', residual=88255.15993815991
# 000422, method='Nelder-Mead', residual=88255.15993815952
# 000423, method='Nelder-Mead', residual=88255.15993815925
# 000424, method='Nelder-Mead', residual=88255.15993815956
# 000425, method='Nelder-Mead', residual=88255.15993815883
# 000426, method='Nelder-Mead', residual=88255.15993815837
# 000427, method='Nelder-Mead', residual=88255.15993815789
# 000428, method='Nelder-Mead', residual=88255.15993815662
# 000429, method='Nelder-Mead', residual=88255.15993815844
# 000430, method='Nelder-Mead', residual=88255.15993815765
# 000431, method='Nelder-Mead', residual=88255.15993815706
# 000432, method='Nelder-Mead', residual=88255.15993815612
# 000433, method='Nelder-Mead', residual=88255.1599381549
# 000434, method='Nelder-Mead', residual=88255.15993815518
# 000435, method='Nelder-Mead', residual=88255.1599381539
# 000436, method='Nelder-Mead', residual=88255.15993815154
# 000437, method='Nelder-Mead', residual=88255.1599381536
# 000438, method='Nelder-Mead', residual=88255.15993815285
# 000439, method='Nelder-Mead', residual=88255.15993815105
# 000440, method='Nelder-Mead', residual=88255.15993814854
# 000441, method='Nelder-Mead', residual=88255.15993814898
# 000442, method='Nelder-Mead', residual=88255.15993814754
# 000443, method='Nelder-Mead', residual=88255.15993814416
# 000444, method='Nelder-Mead', residual=88255.15993814553
# 000445, method='Nelder-Mead', residual=88255.1599381433
# 000446, method='Nelder-Mead', residual=88255.15993813887
# 000447, method='Nelder-Mead', residual=88255.15993814016
# 000448, method='Nelder-Mead', residual=88255.15993813911
# 000449, method='Nelder-Mead', residual=88255.15993813648
# 000450, method='Nelder-Mead', residual=88255.15993813248
# 000451, method='Nelder-Mead', residual=88255.15993813312
# 000452, method='Nelder-Mead', residual=88255.15993812769
# 000453, method='Nelder-Mead', residual=88255.15993811846
# 000454, method='Nelder-Mead', residual=88255.15993812436
# 000455, method='Nelder-Mead', residual=88255.15993811935
# 000456, method='Nelder-Mead', residual=88255.15993812215
# 000457, method='Nelder-Mead', residual=88255.15993811359
# 000458, method='Nelder-Mead', residual=88255.15993810326
# 000459, method='Nelder-Mead', residual=88255.15993811259
# 000460, method='Nelder-Mead', residual=88255.15993810352
# 000461, method='Nelder-Mead', residual=88255.1599380988
# 000462, method='Nelder-Mead', residual=88255.15993808901
# 000463, method='Nelder-Mead', residual=88255.15993809277
# 000464, method='Nelder-Mead', residual=88255.15993808566
# 000465, method='Nelder-Mead', residual=88255.15993807002
# 000466, method='Nelder-Mead', residual=88255.1599380832
# 000467, method='Nelder-Mead', residual=88255.15993807315
# 000468, method='Nelder-Mead', residual=88255.15993806312
# 000469, method='Nelder-Mead', residual=88255.15993804655
# 000470, method='Nelder-Mead', residual=88255.15993805628
# 000471, method='Nelder-Mead', residual=88255.15993804492
# 000472, method='Nelder-Mead', residual=88255.15993802944
# 000473, method='Nelder-Mead', residual=88255.1599380343
# 000474, method='Nelder-Mead', residual=88255.15993802529
# 000475, method='Nelder-Mead', residual=88255.1599380116
# 000476, method='Nelder-Mead', residual=88255.15993800103
# 000477, method='Nelder-Mead', residual=88255.15993797127
# 000478, method='Nelder-Mead', residual=88255.15993799138
# 000479, method='Nelder-Mead', residual=88255.15993800564
# 000480, method='Nelder-Mead', residual=88255.15993796951
# 000481, method='Nelder-Mead', residual=88255.15993795136
# 000482, method='Nelder-Mead', residual=88255.1599379723
# 000483, method='Nelder-Mead', residual=88255.159937951
# 000484, method='Nelder-Mead', residual=88255.15993794875
# 000485, method='Nelder-Mead', residual=88255.15993793627
# 000486, method='Nelder-Mead', residual=88255.15993794688
# 000487, method='Nelder-Mead', residual=88255.15993799373
# 000488, method='Nelder-Mead', residual=88255.15993790407
# 000489, method='Nelder-Mead', residual=88255.15993786913
# 000490, method='Nelder-Mead', residual=88255.1599379591
# 000491, method='Nelder-Mead', residual=88255.15993792885
# 000492, method='Nelder-Mead', residual=88255.15993786855
# 000493, method='Nelder-Mead', residual=88255.15993782233
# 000494, method='Nelder-Mead', residual=88255.15993793766
# 000495, method='Nelder-Mead', residual=88255.15993800339
# 000496, method='Nelder-Mead', residual=88255.15993791154
# 000497, method='Nelder-Mead', residual=88255.15993789436
# 000498, method='Nelder-Mead', residual=88255.15993784978
# 000499, method='Nelder-Mead', residual=88255.15993787453
# 000500, method='Nelder-Mead', residual=88255.15993780452
# 000501, method='Nelder-Mead', residual=88255.15993775093
# 000502, method='Nelder-Mead', residual=88255.15993777532
# 000503, method='Nelder-Mead', residual=88255.15993777056
# 000504, method='Nelder-Mead', residual=88255.15993775547
# 000505, method='Nelder-Mead', residual=88255.15993775554
# 000506, method='Nelder-Mead', residual=88255.1599376888
# 000507, method='Nelder-Mead', residual=88255.15993762673
# 000508, method='Nelder-Mead', residual=88255.15993762664
# 000509, method='Nelder-Mead', residual=88255.1599375288
# 000510, method='Nelder-Mead', residual=88255.15993760347
# 000511, method='Nelder-Mead', residual=88255.15993759116
# 000512, method='Nelder-Mead', residual=88255.15993752175
# 000513, method='Nelder-Mead', residual=88255.15993741584
# 000514, method='Nelder-Mead', residual=88255.15993747574
# 000515, method='Nelder-Mead', residual=88255.15993746053
# 000516, method='Nelder-Mead', residual=88255.15993732077
# 000517, method='Nelder-Mead', residual=88255.1599371827
# 000518, method='Nelder-Mead', residual=88255.1599372613
# 000519, method='Nelder-Mead', residual=88255.15993717925
# 000520, method='Nelder-Mead', residual=88255.15993698406
# 000521, method='Nelder-Mead', residual=88255.15993711051
# 000522, method='Nelder-Mead', residual=88255.15993706198
# 000523, method='Nelder-Mead', residual=88255.15993694638
# 000524, method='Nelder-Mead', residual=88255.15993677166
# 000525, method='Nelder-Mead', residual=88255.15993684591
# 000526, method='Nelder-Mead', residual=88255.15993673212
# 000527, method='Nelder-Mead', residual=88255.15993662427
# 000528, method='Nelder-Mead', residual=88255.15993666954
# 000529, method='Nelder-Mead', residual=88255.1599364502
# 000530, method='Nelder-Mead', residual=88255.15993614736
# 000531, method='Nelder-Mead', residual=88255.15993634923
# 000532, method='Nelder-Mead', residual=88255.15993622823
# 000533, method='Nelder-Mead', residual=88255.15993644051
# 000534, method='Nelder-Mead', residual=88255.15993632737
# 000535, method='Nelder-Mead', residual=88255.15993633648
# 000536, method='Nelder-Mead', residual=88255.15993607388
# 000537, method='Nelder-Mead', residual=88255.15993605161
# 000538, method='Nelder-Mead', residual=88255.15993578549
# 000539, method='Nelder-Mead', residual=88255.15993550677
# 000540, method='Nelder-Mead', residual=88255.15993560424
# 000541, method='Nelder-Mead', residual=88255.15993581443
# 000542, method='Nelder-Mead', residual=88255.15993540609
# 000543, method='Nelder-Mead', residual=88255.15993507743
# 000544, method='Nelder-Mead', residual=88255.15993510783
# 000545, method='Nelder-Mead', residual=88255.1599350363
# 000546, method='Nelder-Mead', residual=88255.15993488787
# 000547, method='Nelder-Mead', residual=88255.15993543026
# 000548, method='Nelder-Mead', residual=88255.1599343159
# 000549, method='Nelder-Mead', residual=88255.15993356526
# 000550, method='Nelder-Mead', residual=88255.15993388562
# 000551, method='Nelder-Mead', residual=88255.15993392239
# 000552, method='Nelder-Mead', residual=88255.15993335076
# 000553, method='Nelder-Mead', residual=88255.15993253088
# 000554, method='Nelder-Mead', residual=88255.1599333188
# 000555, method='Nelder-Mead', residual=88255.15993266182
# 000556, method='Nelder-Mead', residual=88255.15993247829
# 000557, method='Nelder-Mead', residual=88255.15993249333
# 000558, method='Nelder-Mead', residual=88255.15993147179
# 000559, method='Nelder-Mead', residual=88255.15993040151
# 000560, method='Nelder-Mead', residual=88255.15993154893
# 000561, method='Nelder-Mead', residual=88255.15993048638
# 000562, method='Nelder-Mead', residual=88255.15993017913
# 000563, method='Nelder-Mead', residual=88255.15992925384
# 000564, method='Nelder-Mead', residual=88255.1599294847
# 000565, method='Nelder-Mead', residual=88255.15992901014
# 000566, method='Nelder-Mead', residual=88255.1599282035
# 000567, method='Nelder-Mead', residual=88255.15992785872
# 000568, method='Nelder-Mead', residual=88255.15992889709
# 000569, method='Nelder-Mead', residual=88255.15993003153
# 000570, method='Nelder-Mead', residual=88255.1599277114
# 000571, method='Nelder-Mead', residual=88255.1599292137
# 000572, method='Nelder-Mead', residual=88255.1599290657
# 000573, method='Nelder-Mead', residual=88255.1599298057
# 000574, method='Nelder-Mead', residual=88255.15992857859
# 000575, method='Nelder-Mead', residual=88255.15992806625
# 000576, method='Nelder-Mead', residual=88255.15992858066
# 000577, method='Nelder-Mead', residual=88255.15992725609
# 000578, method='Nelder-Mead', residual=88255.15992783407
# 000579, method='Nelder-Mead', residual=88255.15992809272
# 000580, method='Nelder-Mead', residual=88255.1599277556
# 000581, method='Nelder-Mead', residual=88255.15992719107
# 000582, method='Nelder-Mead', residual=88255.15992717473
# 000583, method='Nelder-Mead', residual=88255.15992675825
# 000584, method='Nelder-Mead', residual=88255.15992756831
# 000585, method='Nelder-Mead', residual=88255.1599268787
# 000586, method='Nelder-Mead', residual=88255.15992881058
# 000587, method='Nelder-Mead', residual=88255.15992717815
# 000588, method='Nelder-Mead', residual=88255.15992731947
# 000589, method='Nelder-Mead', residual=88255.15992696738
# 000590, method='Nelder-Mead', residual=88255.15992722468
# 000591, method='Nelder-Mead', residual=88255.15992654503
# 000592, method='Nelder-Mead', residual=88255.1599262997
# 000593, method='Nelder-Mead', residual=88255.15992661845
# 000594, method='Nelder-Mead', residual=88255.15992615142
# 000595, method='Nelder-Mead', residual=88255.15992659071
# 000596, method='Nelder-Mead', residual=88255.1599262463
# 000597, method='Nelder-Mead', residual=88255.15992660925
# 000598, method='Nelder-Mead', residual=88255.15992664921
# 000599, method='Nelder-Mead', residual=88255.15992614764
# 000600, method='Nelder-Mead', residual=88255.15992634514
# 000601, method='Nelder-Mead', residual=88255.15992641833
# 000602, method='Nelder-Mead', residual=88255.15992637604
# 000603, method='Nelder-Mead', residual=88255.15992636618
# 000604, method='Nelder-Mead', residual=88255.15992634527
# 000605, method='Nelder-Mead', residual=88255.15992644877
# 000606, method='Nelder-Mead', residual=88255.15992620341
# 000607, method='Nelder-Mead', residual=88255.15992588717
# 000608, method='Nelder-Mead', residual=88255.15992577825
# 000609, method='Nelder-Mead', residual=88255.15992610673
# 000610, method='Nelder-Mead', residual=88255.15992594139
# 000611, method='Nelder-Mead', residual=88255.15992610372
# 000612, method='Nelder-Mead', residual=88255.15992582559
# 000613, method='Nelder-Mead', residual=88255.15992564628
# 000614, method='Nelder-Mead', residual=88255.15992554299
# 000615, method='Nelder-Mead', residual=88255.15992588768
# 000616, method='Nelder-Mead', residual=88255.15992549098
# 000617, method='Nelder-Mead', residual=88255.15992535587
# 000618, method='Nelder-Mead', residual=88255.15992562496
# 000619, method='Nelder-Mead', residual=88255.159925593
# 000620, method='Nelder-Mead', residual=88255.15992569344
# 000621, method='Nelder-Mead', residual=88255.15992550526
# 000622, method='Nelder-Mead', residual=88255.15992516892
# 000623, method='Nelder-Mead', residual=88255.15992496742
# 000624, method='Nelder-Mead', residual=88255.15992539031
# 000625, method='Nelder-Mead', residual=88255.1599250711
# 000626, method='Nelder-Mead', residual=88255.15992543889
# 000627, method='Nelder-Mead', residual=88255.15992531684
# 000628, method='Nelder-Mead', residual=88255.15992519226
# 000629, method='Nelder-Mead', residual=88255.15992485966
# 000630, method='Nelder-Mead', residual=88255.15992476587
# 000631, method='Nelder-Mead', residual=88255.15992512697
# 000632, method='Nelder-Mead', residual=88255.15992517845
# 000633, method='Nelder-Mead', residual=88255.15992512919
# 000634, method='Nelder-Mead', residual=88255.1599251133
# 000635, method='Nelder-Mead', residual=88255.15992512622
# 000636, method='Nelder-Mead', residual=88255.15992474927
# 000637, method='Nelder-Mead', residual=88255.159924685
# 000638, method='Nelder-Mead', residual=88255.15992498513
# 000639, method='Nelder-Mead', residual=88255.15992515879
# 000640, method='Nelder-Mead', residual=88255.15992490962
# 000641, method='Nelder-Mead', residual=88255.15992494156
# 000642, method='Nelder-Mead', residual=88255.1599249387
# 000643, method='Nelder-Mead', residual=88255.15992467498
# 000644, method='Nelder-Mead', residual=88255.15992473492
# 000645, method='Nelder-Mead', residual=88255.15992494859
# 000646, method='Nelder-Mead', residual=88255.15992487813
# 000647, method='Nelder-Mead', residual=88255.15992476324
# 000648, method='Nelder-Mead', residual=88255.15992456535
# 000649, method='Nelder-Mead', residual=88255.15992442668
# 000650, method='Nelder-Mead', residual=88255.15992466961
# 000651, method='Nelder-Mead', residual=88255.15992468307
# 000652, method='Nelder-Mead', residual=88255.15992449876
# 000653, method='Nelder-Mead', residual=88255.15992480666
# 000654, method='Nelder-Mead', residual=88255.15992458776
# 000655, method='Nelder-Mead', residual=88255.15992458773
# 000656, method='Nelder-Mead', residual=88255.1599244284
# 000657, method='Nelder-Mead', residual=88255.15992456247
# 000658, method='Nelder-Mead', residual=88255.15992464178
# 000659, method='Nelder-Mead', residual=88255.15992451475
# 000660, method='Nelder-Mead', residual=88255.15992439991
# 000661, method='Nelder-Mead', residual=88255.15992439342
# 000662, method='Nelder-Mead', residual=88255.15992443055
# 000663, method='Nelder-Mead', residual=88255.15992447652
# 000664, method='Nelder-Mead', residual=88255.15992423546
# 000665, method='Nelder-Mead', residual=88255.15992409363
# 000666, method='Nelder-Mead', residual=88255.15992438959
# 000667, method='Nelder-Mead', residual=88255.15992439745
# 000668, method='Nelder-Mead', residual=88255.15992437754
# 000669, method='Nelder-Mead', residual=88255.15992432294
# 000670, method='Nelder-Mead', residual=88255.15992427447
# 000671, method='Nelder-Mead', residual=88255.15992429844
# 000672, method='Nelder-Mead', residual=88255.15992423371
# 000673, method='Nelder-Mead', residual=88255.15992430982
# 000674, method='Nelder-Mead', residual=88255.15992409381
# 000675, method='Nelder-Mead', residual=88255.15992410413
# 000676, method='Nelder-Mead', residual=88255.15992413375
# 000677, method='Nelder-Mead', residual=88255.15992412981
# 000678, method='Nelder-Mead', residual=88255.15992399174
# 000679, method='Nelder-Mead', residual=88255.15992416067
# 000680, method='Nelder-Mead', residual=88255.15992395548
# 000681, method='Nelder-Mead', residual=88255.15992393593
# 000682, method='Nelder-Mead', residual=88255.15992386856
# 000683, method='Nelder-Mead', residual=88255.15992375421
# 000684, method='Nelder-Mead', residual=88255.15992405085
# 000685, method='Nelder-Mead', residual=88255.15992389551
# 000686, method='Nelder-Mead', residual=88255.15992407632
# 000687, method='Nelder-Mead', residual=88255.15992384513
# 000688, method='Nelder-Mead', residual=88255.15992371735
# 000689, method='Nelder-Mead', residual=88255.15992363592
# 000690, method='Nelder-Mead', residual=88255.15992374229
# 000691, method='Nelder-Mead', residual=88255.159923767
# 000692, method='Nelder-Mead', residual=88255.159923717
# 000693, method='Nelder-Mead', residual=88255.15992380635
# 000694, method='Nelder-Mead', residual=88255.15992353791
# 000695, method='Nelder-Mead', residual=88255.15992348314
# 000696, method='Nelder-Mead', residual=88255.15992347512
# 000697, method='Nelder-Mead', residual=88255.15992344245
# 000698, method='Nelder-Mead', residual=88255.15992333632
# 000699, method='Nelder-Mead', residual=88255.15992320632
# 000700, method='Nelder-Mead', residual=88255.1599233955
# 000701, method='Nelder-Mead', residual=88255.15992338325
# 000702, method='Nelder-Mead', residual=88255.15992339888
# 000703, method='Nelder-Mead', residual=88255.15992351517
# 000704, method='Nelder-Mead', residual=88255.15992334734
# 000705, method='Nelder-Mead', residual=88255.15992348705
# 000706, method='Nelder-Mead', residual=88255.1599233264
# 000707, method='Nelder-Mead', residual=88255.15992319783
# 000708, method='Nelder-Mead', residual=88255.15992330151
# 000709, method='Nelder-Mead', residual=88255.15992332315
# 000710, method='Nelder-Mead', residual=88255.15992337535
# 000711, method='Nelder-Mead', residual=88255.15992338002
# 000712, method='Nelder-Mead', residual=88255.15992318893
# 000713, method='Nelder-Mead', residual=88255.15992332407
# 000714, method='Nelder-Mead', residual=88255.15992330661
# 000715, method='Nelder-Mead', residual=88255.15992324307
# 000716, method='Nelder-Mead', residual=88255.15992324593
# 000717, method='Nelder-Mead', residual=88255.1599231262
# 000718, method='Nelder-Mead', residual=88255.15992326825
# 000719, method='Nelder-Mead', residual=88255.15992335672
# 000720, method='Nelder-Mead', residual=88255.1599231765
# 000721, method='Nelder-Mead', residual=88255.15992322864
# 000722, method='Nelder-Mead', residual=88255.15992342494
# 000723, method='Nelder-Mead', residual=88255.15992313751
# 000724, method='Nelder-Mead', residual=88255.15992317916
# 000725, method='Nelder-Mead', residual=88255.15992337289
# 000726, method='Nelder-Mead', residual=88255.15992313265
# 000727, method='Nelder-Mead', residual=88255.15992314994
# 000728, method='Nelder-Mead', residual=88255.15992304223
# 000729, method='Nelder-Mead', residual=88255.15992317493
# 000730, method='Nelder-Mead', residual=88255.1599232918
# 000731, method='Nelder-Mead', residual=88255.15992310384
# 000732, method='Nelder-Mead', residual=88255.15992305336
# 000733, method='Nelder-Mead', residual=88255.15992317778
# 000734, method='Nelder-Mead', residual=88255.15992310172
# 000735, method='Nelder-Mead', residual=88255.15992309645
# 000736, method='Nelder-Mead', residual=88255.15992312423
# 000737, method='Nelder-Mead', residual=88255.15992312157
# 000738, method='Nelder-Mead', residual=88255.15992309195
# 000739, method='Nelder-Mead', residual=88255.15992311397
# 000740, method='Nelder-Mead', residual=88255.1599231431
# 000741, method='Nelder-Mead', residual=88255.15992307535
# 000742, method='Nelder-Mead', residual=88255.15992311768
# 000743, method='Nelder-Mead', residual=88255.15992307493
# 000744, method='Nelder-Mead', residual=88255.1599230614
# 000745, method='Nelder-Mead', residual=88255.15992302302
# 000746, method='Nelder-Mead', residual=88255.15992310028
# 000747, method='Nelder-Mead', residual=88255.15992305882
# 000748, method='Nelder-Mead', residual=88255.15992300979
# 000749, method='Nelder-Mead', residual=88255.15992302453
# 000750, method='Nelder-Mead', residual=88255.15992298725
# 000751, method='Nelder-Mead', residual=88255.15992302957
# 000752, method='Nelder-Mead', residual=88255.15992299562
# 000753, method='Nelder-Mead', residual=88255.15992302372
# 000754, method='Nelder-Mead', residual=88255.1599229922
# 000755, method='Nelder-Mead', residual=88255.15992300474
# 000756, method='Nelder-Mead', residual=88255.15992299693
# 000757, method='Nelder-Mead', residual=88255.15992300508
# 000758, method='Nelder-Mead', residual=88255.15992297618
# 000759, method='Nelder-Mead', residual=88255.15992298907
# 000760, method='Nelder-Mead', residual=88255.15992300549
# 000761, method='Nelder-Mead', residual=88255.15992298891
# 000762, method='Nelder-Mead', residual=88255.15992296152
# 000763, method='Nelder-Mead', residual=88255.15992300349
# 000764, method='Nelder-Mead', residual=88255.15992298433
# 000765, method='Nelder-Mead', residual=88255.15992299092
# 000766, method='Nelder-Mead', residual=88255.15992298463
# 000767, method='Nelder-Mead', residual=88255.15992300032
# 000768, method='Nelder-Mead', residual=88255.15992297944
# 000769, method='Nelder-Mead', residual=88255.15992299329
# 000770, method='Nelder-Mead', residual=88255.15992297961
# 000771, method='Nelder-Mead', residual=88255.15992296675
# 000772, method='Nelder-Mead', residual=88255.15992298182
# 000773, method='Nelder-Mead', residual=88255.15992296091
# 000774, method='Nelder-Mead', residual=88255.15992297459
# 000775, method='Nelder-Mead', residual=88255.15992297934
# 000776, method='Nelder-Mead', residual=88255.15992297261
# 000777, method='Nelder-Mead', residual=88255.15992296844
# 000778, method='Nelder-Mead', residual=88255.159922971
# 000779, method='Nelder-Mead', residual=88255.1599229697
# 000780, method='Nelder-Mead', residual=88255.15992296585
# 000781, method='Nelder-Mead', residual=88255.15992296723
# 000782, method='Nelder-Mead', residual=88255.15992297228
# 000783, method='Nelder-Mead', residual=88255.15992296468
# 000784, method='Nelder-Mead', residual=88255.15992296564
# 000785, method='Nelder-Mead', residual=88255.15992298194
# 000786, method='Nelder-Mead', residual=88255.1599229626
# 000787, method='Nelder-Mead', residual=88255.15992296454
# 000788, method='Nelder-Mead', residual=88255.15992296487
# 000789, method='Nelder-Mead', residual=88255.15992296797
# 000790, method='Nelder-Mead', residual=88255.15992296273
# 000791, method='Nelder-Mead', residual=88255.15992295848
# 000792, method='Nelder-Mead', residual=88255.15992296358
# 000793, method='Nelder-Mead', residual=88255.15992296225
# 000794, method='Nelder-Mead', residual=88255.15992296237
# 000795, method='Nelder-Mead', residual=88255.15992296369
# 000796, method='Nelder-Mead', residual=88255.15992296123
# 000797, method='Nelder-Mead', residual=88255.15992296014
# 000798, method='Nelder-Mead', residual=88255.15992296355
# 000799, method='Nelder-Mead', residual=88255.15992296068
# 000800, method='Nelder-Mead', residual=88255.15992295762
# 000801, method='Nelder-Mead', residual=88255.15992296065
# 000802, method='Nelder-Mead', residual=88255.15992296202
# 000803, method='Nelder-Mead', residual=88255.15992295984
# 000804, method='Nelder-Mead', residual=88255.15992295882
# 000805, method='Nelder-Mead', residual=88255.1599229594
# 000806, method='Nelder-Mead', residual=88255.1599229583
# 000807, method='Nelder-Mead', residual=88255.15992295672
# 000808, method='Nelder-Mead', residual=88255.15992295946
# 000809, method='Nelder-Mead', residual=88255.15992295869
# 000810, method='Nelder-Mead', residual=88255.15992295976
# 000811, method='Nelder-Mead', residual=88255.15992295831
# 000812, method='Nelder-Mead', residual=88255.15992295835
# 000813, method='Nelder-Mead', residual=88255.15992295751
# 000814, method='Nelder-Mead', residual=88255.15992295815
# 000815, method='Nelder-Mead', residual=88255.15992295757
# 000816, method='Nelder-Mead', residual=88255.15992295786
# 000817, method='Nelder-Mead', residual=88255.15992295748
# 000818, method='Nelder-Mead', residual=88255.1599229573
# 000819, method='Nelder-Mead', residual=88255.1599229576
# 000820, method='Nelder-Mead', residual=88255.15992295746
# 000821, method='Nelder-Mead', residual=88255.15992295758
# 000822, method='Nelder-Mead', residual=88255.15992295682
# 000823, method='Nelder-Mead', residual=88255.15992295722
# 000824, method='Nelder-Mead', residual=88255.15992295674
# 000825, method='Nelder-Mead', residual=88255.15992295755
# 000826, method='Nelder-Mead', residual=88255.15992295707
# 000827, method='Nelder-Mead', residual=88255.15992295678
# 000828, method='Nelder-Mead', residual=88255.15992295709
# 000829, method='Nelder-Mead', residual=88255.15992295697
# 000830, method='Nelder-Mead', residual=88255.1599229571
# 000831, method='Nelder-Mead', residual=88255.15992295685
# 000832, method='Nelder-Mead', residual=88255.15992295694
# 000833, method='Nelder-Mead', residual=88255.1599229565
# 000834, method='Nelder-Mead', residual=88255.15992295652
# 000835, method='Nelder-Mead', residual=88255.15992295652
# 000836, method='Nelder-Mead', residual=88255.1599229563
# 000837, method='Nelder-Mead', residual=88255.15992295666
# 000838, method='Nelder-Mead', residual=88255.15992295656
# 000839, method='Nelder-Mead', residual=88255.15992295662
# 000840, method='Nelder-Mead', residual=88255.15992295703
# 000841, method='Nelder-Mead', residual=88255.1599229565
# 000842, method='Nelder-Mead', residual=88255.1599229565
# 000843, method='Nelder-Mead', residual=88255.15992295624
# 000844, method='Nelder-Mead', residual=88255.15992295613
# 000845, method='Nelder-Mead', residual=88255.15992295607
# 000846, method='Nelder-Mead', residual=88255.15992295629
# 000847, method='Nelder-Mead', residual=88255.1599229562
# 000848, method='Nelder-Mead', residual=88255.15992295631
# 000849, method='Nelder-Mead', residual=88255.15992295602
# 000850, method='Nelder-Mead', residual=88255.15992295604
# 000851, method='Nelder-Mead', residual=88255.15992295629
# 000852, method='Nelder-Mead', residual=88255.15992295624
# 000853, method='Nelder-Mead', residual=88255.15992295613
# 000854, method='Nelder-Mead', residual=88255.15992295615
# 000855, method='Nelder-Mead', residual=88255.15992295621
# 000856, method='Nelder-Mead', residual=88255.15992295602
# 000857, method='Nelder-Mead', residual=88255.15992295617
# 000858, method='Nelder-Mead', residual=88255.1599229561
# 000859, method='Nelder-Mead', residual=88255.1599229562
# 000860, method='Nelder-Mead', residual=88255.15992295608
# 000861, method='Nelder-Mead', residual=88255.15992295592
# 000862, method='Nelder-Mead', residual=88255.15992295604
# 000863, method='Nelder-Mead', residual=88255.15992295605
# 000864, method='Nelder-Mead', residual=88255.15992295588
# 000865, method='Nelder-Mead', residual=88255.15992295592
# 000866, method='Nelder-Mead', residual=88255.15992295589
# 000867, method='Nelder-Mead', residual=88255.15992295601
# 000868, method='Nelder-Mead', residual=88255.15992295582
# 000869, method='Nelder-Mead', residual=88255.15992295588
# 000870, method='Nelder-Mead', residual=88255.15992295594
# 000871, method='Nelder-Mead', residual=88255.15992295595
# 000872, method='Nelder-Mead', residual=88255.1599229559
# 000873, method='Nelder-Mead', residual=88255.15992295579
# 000874, method='Nelder-Mead', residual=88255.15992295578
# 000875, method='Nelder-Mead', residual=88255.15992295586
# 000876, method='Nelder-Mead', residual=88255.15992295588
# 000877, method='Nelder-Mead', residual=88255.1599229558
# 000878, method='Nelder-Mead', residual=88255.15992295585
# 000879, method='Nelder-Mead', residual=88255.15992295583
# 000880, method='Nelder-Mead', residual=88255.15992295586
# 000881, method='Nelder-Mead', residual=88255.15992295583
# 000882, method='Nelder-Mead', residual=88255.15992295582
# 000883, method='Nelder-Mead', residual=88255.15992295573
# 000884, method='Nelder-Mead', residual=88255.15992295576
# 000885, method='Nelder-Mead', residual=88255.15992295582
# 000886, method='Nelder-Mead', residual=88255.15992295579
# 000887, method='Nelder-Mead', residual=88255.1599229558
# 000888, method='Nelder-Mead', residual=88255.15992295582
# 000889, method='Nelder-Mead', residual=88255.15992295575
# 000890, method='Nelder-Mead', residual=88255.1599229558
# 000891, method='Nelder-Mead', residual=88255.15992295576
# 000892, method='Nelder-Mead', residual=88255.15992295579
# 000893, method='Nelder-Mead', residual=88255.1599229558
# 000894, method='Nelder-Mead', residual=88255.15992295579
# 000895, method='Nelder-Mead', residual=88255.15992295578
# 000896, method='Nelder-Mead', residual=88255.15992295578
# 000897, method='Nelder-Mead', residual=88255.15992295578
# 000898, method='Nelder-Mead', residual=88255.15992295578
# 000899, method='Nelder-Mead', residual=88255.15992295576
# 000900, method='Nelder-Mead', residual=88255.15992295579
# 000901, method='Nelder-Mead', residual=88255.15992295575
# 000902, method='Nelder-Mead', residual=88255.1599229558
# 000903, method='Nelder-Mead', residual=88255.15992295578
# 000904, method='Nelder-Mead', residual=88255.15992295575
# 000905, method='Nelder-Mead', residual=88255.15992295578
# 000906, method='Nelder-Mead', residual=88255.15992295576
# 000907, method='Nelder-Mead', residual=88255.15992295573
# 000908, method='Nelder-Mead', residual=88255.15992295576
# 000909, method='Nelder-Mead', residual=88255.15992295576
# 000910, method='Nelder-Mead', residual=88255.15992295576
# 000911, method='Nelder-Mead', residual=88255.15992295576
# 000912, method='Nelder-Mead', residual=88255.15992295578
# 000913, method='Nelder-Mead', residual=88255.15992295575
# 000914, method='Nelder-Mead', residual=88255.15992295578
# 000915, method='Nelder-Mead', residual=88255.15992295576
# 000916, method='Nelder-Mead', residual=88255.15992295576
# 000917, method='Nelder-Mead', residual=88255.15992295576
# 000918, method='Nelder-Mead', residual=88255.15992295576
# 000919, method='Nelder-Mead', residual=88255.15992295578
# 000920, method='Nelder-Mead', residual=88255.15992295575
# 000921, method='Nelder-Mead', residual=88255.15992295578
# 000922, method='Nelder-Mead', residual=88255.15992295576
# 000923, method='Nelder-Mead', residual=88255.15992295576
# 000924, method='Nelder-Mead', residual=88255.15992295575
# 000925, method='Nelder-Mead', residual=88255.15992295578
# 000926, method='Nelder-Mead', residual=88255.15992295575
# 000927, method='Nelder-Mead', residual=88255.15992295578
# 000928, method='Nelder-Mead', residual=88255.15992295578
# 000929, method='Nelder-Mead', residual=88255.15992295576
# 000930, method='Nelder-Mead', residual=88255.15992295576
# 000931, method='Nelder-Mead', residual=88255.15992295578
# 000932, method='Nelder-Mead', residual=88255.15992295578
# 000933, method='Nelder-Mead', residual=88255.15992295576
# 000934, method='Nelder-Mead', residual=88255.15992295575
# 000935, method='Nelder-Mead', residual=88255.15992295576
# 000936, method='Nelder-Mead', residual=88255.15992295578
# 000937, method='Nelder-Mead', residual=88255.15992295576
# 000938, method='Nelder-Mead', residual=88255.15992295576
# 000939, method='Nelder-Mead', residual=88255.15992295576
# 000940, method='Nelder-Mead', residual=88255.15992295578
# 000941, method='Nelder-Mead', residual=88255.15992295579
# 000942, method='Nelder-Mead', residual=88255.15992295576
# 000943, method='Nelder-Mead', residual=88255.15992295578
# 000944, method='Nelder-Mead', residual=88255.15992295578
# 000945, method='Nelder-Mead', residual=88255.15992295579
# 000946, method='Nelder-Mead', residual=88255.15992295576
# 000947, method='Nelder-Mead', residual=88255.15992295578
# 000948, method='Nelder-Mead', residual=88255.15992295576
# 000949, method='Nelder-Mead', residual=88255.15992295575
# 000950, method='Nelder-Mead', residual=88255.1599229558
# 000951, method='Nelder-Mead', residual=88255.15992295578
# 000952, method='Nelder-Mead', residual=88255.15992295573
# 000953, method='Nelder-Mead', residual=88255.15992295578
# 000954, method='Nelder-Mead', residual=88255.15992295575
# 000955, method='Nelder-Mead', residual=88255.15992295578
# 000956, method='Nelder-Mead', residual=88255.15992295576
# 000957, method='Nelder-Mead', residual=88255.15992295575
# 000958, method='Nelder-Mead', residual=88255.15992295578
# 000959, method='Nelder-Mead', residual=88255.15992295575
# 000960, method='Nelder-Mead', residual=88255.15992295576
# 000961, method='Nelder-Mead', residual=88255.15992295573
# 000962, method='Nelder-Mead', residual=88255.15992295578
# 000963, method='Nelder-Mead', residual=88255.15992295576
# 000964, method='Nelder-Mead', residual=88255.15992295575
# 000965, method='Nelder-Mead', residual=88255.15992295578
# 000966, method='Nelder-Mead', residual=88255.15992295576
# 000967, method='Nelder-Mead', residual=88255.15992295578
# 000968, method='Nelder-Mead', residual=88255.15992295576
# 000969, method='Nelder-Mead', residual=88255.15992295576
# 000970, method='Nelder-Mead', residual=88255.15992295578
# 000971, method='Nelder-Mead', residual=88255.15992295576
# 000972, method='Nelder-Mead', residual=88255.15992295578
# 000973, method='Nelder-Mead', residual=88255.15992295578
# 000974, method='Nelder-Mead', residual=88255.15992295576
# 000975, method='Nelder-Mead', residual=88255.15992295576
# 000976, method='Nelder-Mead', residual=88255.15992295578
# 000977, method='Nelder-Mead', residual=88255.15992295578
# 000978, method='Nelder-Mead', residual=88255.15992295573
# 000979, method='Nelder-Mead', residual=88255.15992295576
# 000980, method='Nelder-Mead', residual=88255.15992295576
# 000981, method='Nelder-Mead', residual=88255.15992295578
# 000982, method='Nelder-Mead', residual=88255.15992295575
# 000983, method='Nelder-Mead', residual=88255.15992295576
# 000984, method='Nelder-Mead', residual=88255.15992295578
# 000985, method='Nelder-Mead', residual=88255.15992295575
# 000986, method='Nelder-Mead', residual=88255.15992295576
# 000987, method='Nelder-Mead', residual=88255.15992295578
# 000988, method='Nelder-Mead', residual=88255.15992295576
# 000989, method='Nelder-Mead', residual=88255.15992295578
# 000990, method='Nelder-Mead', residual=88255.15992295576
# 000991, method='Nelder-Mead', residual=88255.15992295578
# 000992, method='Nelder-Mead', residual=88255.15992295573
# 000993, method='Nelder-Mead', residual=88255.15992295576
# 000994, method='Nelder-Mead', residual=88255.15992295575
# 000995, method='Nelder-Mead', residual=88255.15992295578
# 000996, method='Nelder-Mead', residual=88255.15992295576
# 000997, method='Nelder-Mead', residual=88255.15992295576
# 000998, method='Nelder-Mead', residual=88255.15992295576
# 000999, method='Nelder-Mead', residual=88255.15992295578
# 001000, method='Nelder-Mead', residual=88255.15992295578
# 001001, method='Nelder-Mead', residual=88255.15992295579
# 001002, method='Nelder-Mead', residual=88255.15992295579
# 001003, method='Nelder-Mead', residual=88255.15992295578
# 001004, method='Nelder-Mead', residual=88255.15992295575
# 001005, method='Nelder-Mead', residual=88255.15992295578
# 001006, method='Nelder-Mead', residual=88255.15992295576
# 001007, method='Nelder-Mead', residual=88255.15992295576
# 001008, method='Nelder-Mead', residual=88255.15992295578
# 001009, method='Nelder-Mead', residual=88255.15992295578
# 001010, method='Nelder-Mead', residual=88255.15992295575
# 001011, method='Nelder-Mead', residual=88255.15992295576
# 001012, method='Nelder-Mead', residual=88255.15992295576
# 001013, method='Nelder-Mead', residual=88255.15992295578
# 001014, method='Nelder-Mead', residual=88255.15992295576
# 001015, method='Nelder-Mead', residual=88255.15992295573
# 001016, method='Nelder-Mead', residual=88255.15992295575
